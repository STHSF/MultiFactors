# %% [markdown]
# # alpha1-alpha10因子risk—netural回测结果

# %%
# %matplotlib inline
import sys
sys.path.append('../../')
import pandas as pd
from PyFin.api import *
from alphamind.api import *
from src.conf.models import *
import numpy as np
from alphamind.execution.naiveexecutor import NaiveExecutor
from matplotlib import pyplot as plt

data_source = 'postgresql+psycopg2://alpha:alpha@180.166.26.82:8889/alpha'
engine = SqlEngine(data_source)

universe = Universe('zz500')
freq = '2b'
benchmark_code = 905
start_date = '2010-01-01'
end_date = '2019-05-01'
ref_dates = makeSchedule(start_date, end_date, freq, 'china.sse')
horizon = map_freq(freq)
industry_name = 'sw'
industry_level = 1

factors_store = {
    'f0': CSQuantiles(LAST('alpha_1'), groups='sw1'), 'f1': CSQuantiles(LAST('alpha_2'), groups='sw1'), 'f2': CSQuantiles(LAST('alpha_3'), groups='sw1'),
    'f3': CSQuantiles(LAST('alpha_4'), groups='sw1'), 'f4': CSQuantiles(LAST('alpha_5'), groups='sw1'), 'f5': CSQuantiles(LAST('alpha_6'), groups='sw1'),
    'f6': CSQuantiles(LAST('alpha_7'), groups='sw1'), 'f7': CSQuantiles(LAST('alpha_8'), groups='sw1'), 'f8': CSQuantiles(LAST('alpha_9'), groups='sw1'),
    'f9': CSQuantiles(LAST('alpha_10'), groups='sw1'), 'f10': CSQuantiles(LAST('alpha_11'), groups='sw1'), 'f11': CSQuantiles(LAST('alpha_12'), groups='sw1'),
    'f12': CSQuantiles(LAST('alpha_13'), groups='sw1'), 'f13': CSQuantiles(LAST('alpha_14'), groups='sw1'), 'f14': CSQuantiles(LAST('alpha_15'), groups='sw1'),
    'f15': CSQuantiles(LAST('alpha_16'), groups='sw1'), 'f16': CSQuantiles(LAST('alpha_17'), groups='sw1'), 'f17': CSQuantiles(LAST('alpha_18'), groups='sw1'),
    'f18': CSQuantiles(LAST('alpha_19'), groups='sw1'), 'f19': CSQuantiles(LAST('alpha_20'), groups='sw1'), 'f20': CSQuantiles(LAST('alpha_21'), groups='sw1'),
    'f21': CSQuantiles(LAST('alpha_22'), groups='sw1'), 'f22': CSQuantiles(LAST('alpha_23'), groups='sw1'), 'f23': CSQuantiles(LAST('alpha_24'), groups='sw1'),
    'f24': CSQuantiles(LAST('alpha_25'), groups='sw1'), 'f25': CSQuantiles(LAST('alpha_26'), groups='sw1'), 'f26': CSQuantiles(LAST('alpha_27'), groups='sw1'),
    'f27': CSQuantiles(LAST('alpha_28'), groups='sw1'), 'f28': CSQuantiles(LAST('alpha_29'), groups='sw1'), 'f29': CSQuantiles(LAST('alpha_30'), groups='sw1'),
    'f30': CSQuantiles(LAST('alpha_31'), groups='sw1'), 'f31': CSQuantiles(LAST('alpha_32'), groups='sw1'), 'f32': CSQuantiles(LAST('alpha_33'), groups='sw1'),
    'f33': CSQuantiles(LAST('alpha_34'), groups='sw1'), 'f34': CSQuantiles(LAST('alpha_35'), groups='sw1'), 'f35': CSQuantiles(LAST('alpha_36'), groups='sw1'),
    'f36': CSQuantiles(LAST('alpha_37'), groups='sw1'), 'f37': CSQuantiles(LAST('alpha_38'), groups='sw1'), 'f38': CSQuantiles(LAST('alpha_39'), groups='sw1'),
    'f39': CSQuantiles(LAST('alpha_40'), groups='sw1'), 'f40': CSQuantiles(LAST('alpha_41'), groups='sw1'), 'f41': CSQuantiles(LAST('alpha_42'), groups='sw1'),}

factor_data_org = engine.fetch_factor_range(universe, factors_store, dates=ref_dates, used_factor_tables=[Alpha191])


industry = engine.fetch_industry_range(universe, dates=ref_dates)
factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code']).fillna(0.)
risk_total = engine.fetch_risk_model_range(universe, dates=ref_dates)[1]

return_data = engine.fetch_dx_return_range(universe, dates=ref_dates, horizon=horizon, offset=0,benchmark = benchmark_code)

benchmark_total = engine.fetch_benchmark_range(dates=ref_dates, benchmark=benchmark_code)
industry_total = engine.fetch_industry_matrix_range(universe, dates=ref_dates, category=industry_name, level=industry_level)

weight_gap = 0.01
industry_names = industry_list(industry_name, industry_level)
constraint_risk = ['EARNYILD', 'LIQUIDTY', 'GROWTH', 'SIZE', 'BETA', 'MOMENTUM'] + industry_names
total_risk_names = constraint_risk + ['benchmark', 'total']

b_type = []
l_val = []
u_val = []

previous_pos = pd.DataFrame()
rets = []
turn_overs = []
leverags = []
trade_dates = []

for name in total_risk_names:
        if name == 'benchmark':
            b_type.append(BoundaryType.RELATIVE)
            l_val.append(0.0)
            u_val.append(1.0)
        elif name == 'total':
            b_type.append(BoundaryType.ABSOLUTE)
            l_val.append(.0)
            u_val.append(.0)
        else:
            b_type.append(BoundaryType.ABSOLUTE)
            l_val.append(-0.005)
            u_val.append(0.005)

bounds = create_box_bounds(total_risk_names, b_type, l_val, u_val)

train_data = pd.merge(factor_data, return_data, on=['trade_date', 'code']).dropna()

features = ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9']
label = ['dx']

# %%time
from datetime import datetime, timedelta
from m1_xgb import *
from src.conf.configuration import regress_conf
import xgboost as xgb

# take ref_dates[i] as an example
for i, date_inde in enumerate(ref_dates):
    alpha_logger.info('{0} is start'.format(date_inde))
    # Machine learning model
    trade_date_pre = date_inde - timedelta(days=1)
    # train_x = factor_data[factor_data.trade_date <= trade_date_pre]
    # train_y_excess = return_data[return_data.trade_date <= trade_date_pre]
    # train = pd.merge(train_x, train_y_excess, on=['trade_date', 'code'])
    # if len(train_x) <= 0 or len(train_y_excess)<=0:
    #     continue
    # print('len_train_x: %s, len_train_y: %s' %(len(train_x), len(train_y_excess)))
    
    # Train data
    train = train_data[train_data.trade_date <= trade_date_pre].dropna()
    if len(train) <= 0:
        continue
    x_train = train[features]
    y_train = train[label]
    alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
    alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))
    
    # Train
    # xgb_setting
    regress_conf.xgb_config_r()
    regress_conf.cv_folds = 5
    regress_conf.early_stop_round = 4
    regress_conf.max_round = 10
    # Training
    tic = time.time()
    alpha_logger.info('X_train.shape={}, X_test.shape = {}'.format(np.shape(x_train), np.shape(y_train)))
    xgb_model = XGBooster(regress_conf)
    best_score, best_round, cv_rounds, best_model = xgb_model.fit(x_train, y_train)
    alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
    alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
    
    # Test data
    # test_x = factor_data[factor_data.trade_date == date_inde]
    # test_y_excess = return_data[return_data.trade_date == date_inde]   
    # total_data_test_excess = pd.merge(test_x, test_y_excess, on=['trade_date', 'code']).dropna()
    total_data_test_excess = train_data[train_data.trade_date == date_inde]
    total_data_test_excess_pre = total_data_test_excess
    if len(total_data_test_excess) <= 0:
        continue

    industry_matrix = industry_total[industry_total.trade_date == date_inde]
    benchmark_w = benchmark_total[benchmark_total.trade_date == date_inde]
    risk_matrix = risk_total[risk_total.trade_date == date_inde]

    total_data = pd.merge(industry_matrix, benchmark_w, on=['code'], how='left').fillna(0.)
    total_data = pd.merge(total_data, risk_matrix, on=['code'])
    alpha_logger.info('{0} len_total_data: {1}'.format(date_inde, len(total_data)))

    total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
    alpha_logger.info('{0} len_total_data_test_excess: {1}'.format(date_inde, len(total_data_test_excess)))
    
    if len(total_data_test_excess_pre) != len(total_data_test_excess):
        print('total_data_test_exces_pre: %s' % len(total_data_test_excess_pre))
        print('total_data_test_excess: %s' % len(total_data_test_excess))
        
    codes = total_data_test_excess.code.values.tolist()
    alpha_logger.info('{0} full re-balance: {1}'.format(date_inde, len(codes)))
    dx_returns = return_data[return_data.trade_date == date_inde][['code', 'dx']]

    benchmark_w = total_data_test_excess.weight.values
    alpha_logger.info('shape_of_benchmark_w: {}'.format(np.shape(benchmark_w)))
    is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))
    total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                     is_in_benchmark,
                                     np.ones_like(is_in_benchmark)],
                                     axis=1)
    total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
    alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))
    constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
    alpha_logger.info('shape_of_constraints: {}'.format(np.shape(constraints.risk_targets())))

    lbound = np.maximum(0., benchmark_w - weight_gap)
    ubound = weight_gap + benchmark_w
    
    # predict
    x_pred = total_data_test_excess[features]
    dpred = xgb.DMatrix(x_pred.values)
    predict_xgboost = best_model.predict(dpred)
    a = np.shape(predict_xgboost)
    predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
    alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))
    
    # backtest
    target_pos, _ = er_portfolio_analysis(predict_xgboost,
                                          total_data_test_excess['industry'].values,
                                          None,
                                          constraints,
                                          False,
                                          benchmark_w,
                                          method = 'risk_neutral',
                                          lbound=lbound,
                                          ubound=ubound)
#     target_pos, _ = er_portfolio_analysis(predict_xgboost,
#                                           total_data_test_excess['industry'].values,
#                                           None,
#                                           None,
#                                           False,
#                                           None,
#                                           method = 'ls')
    alpha_logger.info('target_pos: {}'.format(np.shape(target_pos)))
    target_pos['code'] = codes
    result = pd.merge(target_pos, dx_returns, on=['code'])
    ret = result.weight.values @ (np.exp(result.dx.values) - 1.)
    trade_dates.append(date_inde)
    rets.append(np.log(1. + ret))
    alpha_logger.info('{0} is finished'.format(date_inde))
# Out:
# /home/jerry/workshop/virtualenv/alpha-mind/lib/python3.6/site-packages/psycopg2-2.7.7-py3.6-linux-x86_64.egg/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# %%time
factors = list(factors_store.keys())
factors
# Out:
# CPU times: user 1min 1s, sys: 15.3 s, total: 1min 16s
# Wall time: 3min 55s

# %%
# %%time

len(factor_data)
# Out:
# CPU times: user 12.2 s, sys: 2.14 s, total: 14.4 s
# Wall time: 51.4 s

# %%
# %%time
len(return_data)
# Out:
# CPU times: user 3.27 s, sys: 441 ms, total: 3.71 s
# Wall time: 21 s

# %%
# %%time
# Out:
# CPU times: user 3.74 s, sys: 542 ms, total: 4.28 s
# Wall time: 17.9 s

# %%
# # Constraintes settings

# %%
# train_data.head()
# Out:
#   trade_date        f0        f1       f10       f11       f12       f13       f14       f15      f16       f17       f18       f19        f2       f20       f21       f22       f23       f24       f25       f26       f27       f28       f29        f3       f30       f31       f32       f33       f34       f35       f36       f37  f38       f39        f4       f40       f41        f5        f6        f7        f8        f9  code  chgPct secShortName  industry_code industry        dx
# 0 2010-01-04  0.120690  0.230603  0.017241  0.465517  0.619612  0.085129  0.079741  0.386853  0.00000  0.084052  0.735991  0.727371  0.508082  0.469828  0.000000  0.065733  0.440733  0.000000  0.558190  0.626078  0.330819  0.852371  0.768319  0.403556  0.407328  0.366379  0.401940  0.332974  0.000000  0.675647  0.000000  0.627694  0.0  0.432112  0.081358  0.276940  0.237069  0.390086  0.061422  0.784483  0.112069  0.278017     5 -0.0050         世纪星源        1030320      房地产  0.006132
# 1 2010-01-04  0.823276  0.831897  0.448276  0.000000  0.627155  0.164871  0.148707  0.561422  0.00000  0.165948  0.921336  0.279095  0.689116  0.766164  0.000000  0.455819  0.000000  0.000000  0.000000  0.034483  0.000000  0.326509  0.629310  0.403556  0.000000  0.216056  0.000000  0.000000  0.000000  0.475216  0.000000  0.627694  0.0  0.084052  0.434806  0.000000  0.000000  0.390086  0.000000  0.687500  0.038793  0.000000     6 -0.0185         深振业A        1030320      房地产 -0.035202
# 2 2010-01-04  0.353448  0.213362  0.100216  0.630388  0.566810  0.311422  0.241379  0.767241  0.40625  0.436422  0.544181  0.600216  0.436422  0.396552  0.252155  0.202586  0.429957  0.302802  0.662716  0.750000  0.193966  0.673491  0.689655  0.403556  0.417026  0.315733  0.461207  0.323276  0.678879  0.199353  0.508621  0.627694  0.0  0.223060  0.369612  0.500000  0.743534  0.390086  0.028017  0.692888  0.084052  0.089440    16 -0.0143         深康佳A        1030313     家用电器 -0.070012
# 3 2010-01-04  0.561422  0.162716  0.653017  0.353448  0.421336  0.745690  0.693966  0.741379  0.05819  0.628233  0.322198  0.609914  0.220905  0.537716  0.561422  0.834052  0.568966  0.225216  0.294181  0.446121  0.617457  0.425647  0.064655  0.903017  0.353448  0.507543  0.407328  0.386853  0.075431  0.507543  0.423491  0.314655  0.0  0.923491  0.355065  0.196121  0.169181  0.390086  0.800647  0.399784  0.826509  0.665948    22  0.0059         深赤湾A        1030319     交通运输  0.016499
# 4 2010-01-04  0.288793  0.051724  0.695043  0.000000  0.910560  0.004310  0.398707  0.160560  0.00000  0.021552  0.395474  0.188578  0.933190  0.865302  0.000000  0.126078  0.000000  0.000000  0.000000  0.500000  0.000000  0.157328  0.654095  0.403556  0.000000  0.741918  0.000000  0.000000  0.000000  0.404095  0.000000  0.627694  0.0  0.426724  0.218750  0.000000  0.000000  0.850754  0.000000  0.915948  0.967672  0.000000    28 -0.0043         一致药业        1030317     医药生物  0.033443

# %%
# features = ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13',
#             'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26',
#             'f27', 'f28', 'f29', 'f30', 'f31', 'f32', 'f33', 'f34', 'f35', 'f36', 'f37', 'f38', 'f39',
#             'f40', 'f41']

# %%
# %%time
from datetime import datetime, timedelta
from m1_xgb import *
from src.conf.configuration import regress_conf
import xgboost as xgb

# take ref_dates[i] as an example
for i, date_inde in enumerate(ref_dates):
    alpha_logger.info('{0} is start'.format(date_inde))
    # Machine learning model
    trade_date_pre = date_inde - timedelta(days=1)
    # train_x = factor_data[factor_data.trade_date <= trade_date_pre]
    # train_y_excess = return_data[return_data.trade_date <= trade_date_pre]
    # train = pd.merge(train_x, train_y_excess, on=['trade_date', 'code'])
    # if len(train_x) <= 0 or len(train_y_excess)<=0:
    #     continue
    # print('len_train_x: %s, len_train_y: %s' %(len(train_x), len(train_y_excess)))
    
    # Train data
    train = train_data[train_data.trade_date <= trade_date_pre].dropna()
    if len(train) <= 0:
        continue
    x_train = train[features]
    y_train = train[label]
    alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
    alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))
    
    # Train
    # xgb_setting
    regress_conf.xgb_config_r()
    regress_conf.cv_folds = 5
    regress_conf.early_stop_round = 4
    regress_conf.max_round = 10
    # Training
    tic = time.time()
    alpha_logger.info('X_train.shape={}, X_test.shape = {}'.format(np.shape(x_train), np.shape(y_train)))
    xgb_model = XGBooster(regress_conf)
    best_score, best_round, cv_rounds, best_model = xgb_model.fit(x_train, y_train)
    alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
    alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
    
    # Test data
    # test_x = factor_data[factor_data.trade_date == date_inde]
    # test_y_excess = return_data[return_data.trade_date == date_inde]   
    # total_data_test_excess = pd.merge(test_x, test_y_excess, on=['trade_date', 'code']).dropna()
    total_data_test_excess = train_data[train_data.trade_date == date_inde]
    total_data_test_excess_pre = total_data_test_excess
    if len(total_data_test_excess) <= 0:
        continue

    industry_matrix = industry_total[industry_total.trade_date == date_inde]
    benchmark_w = benchmark_total[benchmark_total.trade_date == date_inde]
    risk_matrix = risk_total[risk_total.trade_date == date_inde]

    total_data = pd.merge(industry_matrix, benchmark_w, on=['code'], how='left').fillna(0.)
    total_data = pd.merge(total_data, risk_matrix, on=['code'])
    alpha_logger.info('{0} len_total_data: {1}'.format(date_inde, len(total_data)))

    total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
    alpha_logger.info('{0} len_total_data_test_excess: {1}'.format(date_inde, len(total_data_test_excess)))
    
    if len(total_data_test_excess_pre) != len(total_data_test_excess):
        print('total_data_test_exces_pre: %s' % len(total_data_test_excess_pre))
        print('total_data_test_excess: %s' % len(total_data_test_excess))
        
    codes = total_data_test_excess.code.values.tolist()
    alpha_logger.info('{0} full re-balance: {1}'.format(date_inde, len(codes)))
    dx_returns = return_data[return_data.trade_date == date_inde][['code', 'dx']]

    benchmark_w = total_data_test_excess.weight.values
    alpha_logger.info('shape_of_benchmark_w: {}'.format(np.shape(benchmark_w)))
    is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))
    total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                     is_in_benchmark,
                                     np.ones_like(is_in_benchmark)],
                                     axis=1)
    total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
    alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))
    constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
    alpha_logger.info('shape_of_constraints: {}'.format(np.shape(constraints.risk_targets())))

    lbound = np.maximum(0., benchmark_w - weight_gap)
    ubound = weight_gap + benchmark_w
    
    # predict
    x_pred = total_data_test_excess[features]
    dpred = xgb.DMatrix(x_pred.values)
    predict_xgboost = best_model.predict(dpred)
    a = np.shape(predict_xgboost)
    predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
    alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))
    
    # backtest
    target_pos, _ = er_portfolio_analysis(predict_xgboost,
                                          total_data_test_excess['industry'].values,
                                          None,
                                          constraints,
                                          False,
                                          benchmark_w,
                                          method = 'risk_neutral',
                                          lbound=lbound,
                                          ubound=ubound)
#     target_pos, _ = er_portfolio_analysis(predict_xgboost,
#                                           total_data_test_excess['industry'].values,
#                                           None,
#                                           None,
#                                           False,
#                                           None,
#                                           method = 'ls')
    alpha_logger.info('target_pos: {}'.format(np.shape(target_pos)))
    target_pos['code'] = codes
    result = pd.merge(target_pos, dx_returns, on=['code'])
    ret = result.weight.values @ (np.exp(result.dx.values) - 1.)
    trade_dates.append(date_inde)
    rets.append(np.log(1. + ret))
    alpha_logger.info('{0} is finished'.format(date_inde))
# Out:
# 2019-06-24 13:20:22,177 - ALPHA_MIND - INFO - 2010-01-04 00:00:00 is start
# 2019-06-24 13:20:22,190 - ALPHA_MIND - INFO - 2010-01-06 00:00:00 is start
# 2019-06-24 13:20:22,196 - ALPHA_MIND - INFO - len_x_train: 500, len_y_train: 500
# 2019-06-24 13:20:22,196 - ALPHA_MIND - INFO - X_train.shape=(500, 10), X_test.shape = (500, 1)
# 2019-06-24 13:20:22,197 - ALPHA_MIND - INFO - X_train.shape=(500, 10), X_test.shape = (500, 1)
# cross_validation。。。。
# [0]	train-rmse:0.495401	test-rmse:0.4954
# [1]	train-rmse:0.490475	test-rmse:0.490474
# [2]	train-rmse:0.485599	test-rmse:0.485598
# [3]	train-rmse:0.480771	test-rmse:0.48077
# [4]	train-rmse:0.475991	test-rmse:0.47599
# [5]	train-rmse:0.47126	test-rmse:0.471259
# [6]	train-rmse:0.466576	test-rmse:0.466574
# [7]	train-rmse:0.461938	test-rmse:0.461937
# [8]	train-rmse:0.457347	test-rmse:0.457346
# [9]	train-rmse:0.452802	test-rmse:0.452801
# 2019-06-24 13:20:22,377 - ALPHA_MIND - INFO - Training time cost 0.1799468994140625s
# 2019-06-24 13:20:22,377 - ALPHA_MIND - INFO - best_score = 0.45280060000000005, best_round = 9
# 2019-06-24 13:20:22,393 - ALPHA_MIND - INFO - 2010-01-06 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,399 - ALPHA_MIND - INFO - 2010-01-06 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,400 - ALPHA_MIND - INFO - 2010-01-06 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,403 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,405 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,406 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,412 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,418 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,421 - ALPHA_MIND - INFO - 2010-01-06 00:00:00 is finished
# 2019-06-24 13:20:22,422 - ALPHA_MIND - INFO - 2010-01-08 00:00:00 is start
# 2019-06-24 13:20:22,427 - ALPHA_MIND - INFO - len_x_train: 1000, len_y_train: 1000
# 2019-06-24 13:20:22,428 - ALPHA_MIND - INFO - X_train.shape=(1000, 10), X_test.shape = (1000, 1)
# 2019-06-24 13:20:22,428 - ALPHA_MIND - INFO - X_train.shape=(1000, 10), X_test.shape = (1000, 1)
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495401        0.000259        0.495400       0.001048
# 1         0.490475        0.000256        0.490474       0.001050
# 2         0.485599        0.000253        0.485598       0.001052
# 3         0.480771        0.000250        0.480770       0.001054
# 4         0.475991        0.000248        0.475990       0.001056
# 5         0.471260        0.000245        0.471259       0.001058
# 6         0.466576        0.000242        0.466574       0.001060
# 7         0.461938        0.000240        0.461937       0.001062
# 8         0.457347        0.000237        0.457346       0.001064
# 9         0.452802        0.000234        0.452801       0.001066
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.17943549156188965(s)
# cross_validation。。。。
# [0]	train-rmse:0.495799	test-rmse:0.495798
# [1]	train-rmse:0.490864	test-rmse:0.490863
# [2]	train-rmse:0.485979	test-rmse:0.485978
# [3]	train-rmse:0.481143	test-rmse:0.481141
# [4]	train-rmse:0.476354	test-rmse:0.476353
# [5]	train-rmse:0.471615	test-rmse:0.471613
# [6]	train-rmse:0.466922	test-rmse:0.466921
# [7]	train-rmse:0.462276	test-rmse:0.462275
# [8]	train-rmse:0.457678	test-rmse:0.457676
# [9]	train-rmse:0.453125	test-rmse:0.453124
# 2019-06-24 13:20:22,454 - ALPHA_MIND - INFO - Training time cost 0.026178359985351562s
# 2019-06-24 13:20:22,454 - ALPHA_MIND - INFO - best_score = 0.4531238, best_round = 9
# 2019-06-24 13:20:22,468 - ALPHA_MIND - INFO - 2010-01-08 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,474 - ALPHA_MIND - INFO - 2010-01-08 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,475 - ALPHA_MIND - INFO - 2010-01-08 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,478 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,479 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,481 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,483 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,488 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,492 - ALPHA_MIND - INFO - 2010-01-08 00:00:00 is finished
# 2019-06-24 13:20:22,492 - ALPHA_MIND - INFO - 2010-01-12 00:00:00 is start
# 2019-06-24 13:20:22,498 - ALPHA_MIND - INFO - len_x_train: 1500, len_y_train: 1500
# 2019-06-24 13:20:22,498 - ALPHA_MIND - INFO - X_train.shape=(1500, 10), X_test.shape = (1500, 1)
# 2019-06-24 13:20:22,498 - ALPHA_MIND - INFO - X_train.shape=(1500, 10), X_test.shape = (1500, 1)
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495799        0.000282        0.495798       0.001142
# 1         0.490864        0.000278        0.490863       0.001145
# 2         0.485979        0.000276        0.485978       0.001147
# 3         0.481143        0.000273        0.481141       0.001149
# 4         0.476354        0.000270        0.476353       0.001152
# 5         0.471615        0.000267        0.471613       0.001154
# 6         0.466922        0.000264        0.466921       0.001156
# 7         0.462276        0.000261        0.462275       0.001158
# 8         0.457678        0.000258        0.457676       0.001160
# 9         0.453125        0.000255        0.453124       0.001163
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.025789260864257812(s)
# cross_validation。。。。
# [0]	train-rmse:0.495838	test-rmse:0.495835
# [1]	train-rmse:0.490901	test-rmse:0.490898
# [2]	train-rmse:0.486014	test-rmse:0.486011
# [3]	train-rmse:0.481176	test-rmse:0.481173
# [4]	train-rmse:0.476387	test-rmse:0.476384
# [5]	train-rmse:0.471645	test-rmse:0.471642
# [6]	train-rmse:0.466951	test-rmse:0.466948
# [7]	train-rmse:0.462305	test-rmse:0.462301
# [8]	train-rmse:0.457704	test-rmse:0.457701
# [9]	train-rmse:0.45315	test-rmse:0.453147
# 2019-06-24 13:20:22,525 - ALPHA_MIND - INFO - Training time cost 0.027263879776000977s
# 2019-06-24 13:20:22,526 - ALPHA_MIND - INFO - best_score = 0.4531470000000001, best_round = 9
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495838        0.000450        0.495835       0.001828
# 1         0.490901        0.000445        0.490898       0.001832
# 2         0.486014        0.000441        0.486011       0.001836
# 3         0.481176        0.000436        0.481173       0.001840
# 4         0.476387        0.000431        0.476384       0.001844
# 5         0.471645        0.000427        0.471642       0.001847
# 6         0.466951        0.000422        0.466948       0.001851
# 7         0.462305        0.000418        0.462301       0.001855
# 8         0.457704        0.000413        0.457701       0.001858
# 9         0.453150        0.000409        0.453147       0.001862
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.026877641677856445(s)
# 2019-06-24 13:20:22,539 - ALPHA_MIND - INFO - 2010-01-12 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,544 - ALPHA_MIND - INFO - 2010-01-12 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,546 - ALPHA_MIND - INFO - 2010-01-12 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,548 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,550 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,551 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,558 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,563 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,567 - ALPHA_MIND - INFO - 2010-01-12 00:00:00 is finished
# 2019-06-24 13:20:22,567 - ALPHA_MIND - INFO - 2010-01-14 00:00:00 is start
# 2019-06-24 13:20:22,574 - ALPHA_MIND - INFO - len_x_train: 2000, len_y_train: 2000
# 2019-06-24 13:20:22,575 - ALPHA_MIND - INFO - X_train.shape=(2000, 10), X_test.shape = (2000, 1)
# 2019-06-24 13:20:22,575 - ALPHA_MIND - INFO - X_train.shape=(2000, 10), X_test.shape = (2000, 1)
# cross_validation。。。。
# [0]	train-rmse:0.49607	test-rmse:0.496068
# [1]	train-rmse:0.491131	test-rmse:0.491129
# [2]	train-rmse:0.486241	test-rmse:0.486239
# [3]	train-rmse:0.4814	test-rmse:0.481398
# [4]	train-rmse:0.476608	test-rmse:0.476606
# [5]	train-rmse:0.471864	test-rmse:0.471862
# [6]	train-rmse:0.467168	test-rmse:0.467166
# [7]	train-rmse:0.462518	test-rmse:0.462516
# [8]	train-rmse:0.457915	test-rmse:0.457914
# [9]	train-rmse:0.453359	test-rmse:0.453357
# 2019-06-24 13:20:22,609 - ALPHA_MIND - INFO - Training time cost 0.033731937408447266s
# 2019-06-24 13:20:22,609 - ALPHA_MIND - INFO - best_score = 0.4533568, best_round = 9
# 2019-06-24 13:20:22,623 - ALPHA_MIND - INFO - 2010-01-14 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,628 - ALPHA_MIND - INFO - 2010-01-14 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,630 - ALPHA_MIND - INFO - 2010-01-14 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,633 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496070        0.000361        0.496068       0.001464
# 1         0.491131        0.000357        0.491129       0.001468
# 2         0.486241        0.000353        0.486239       0.001471
# 3         0.481400        0.000350        0.481398       0.001474
# 4         0.476608        0.000346        0.476606       0.001477
# 5         0.471864        0.000342        0.471862       0.001480
# 6         0.467168        0.000338        0.467166       0.001483
# 7         0.462518        0.000335        0.462516       0.001486
# 8         0.457915        0.000332        0.457914       0.001489
# 9         0.453359        0.000328        0.453357       0.001492
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.033209800720214844(s)
# 2019-06-24 13:20:22,635 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,637 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,639 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,644 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,648 - ALPHA_MIND - INFO - 2010-01-14 00:00:00 is finished
# 2019-06-24 13:20:22,648 - ALPHA_MIND - INFO - 2010-01-18 00:00:00 is start
# 2019-06-24 13:20:22,656 - ALPHA_MIND - INFO - len_x_train: 2500, len_y_train: 2500
# 2019-06-24 13:20:22,656 - ALPHA_MIND - INFO - X_train.shape=(2500, 10), X_test.shape = (2500, 1)
# 2019-06-24 13:20:22,657 - ALPHA_MIND - INFO - X_train.shape=(2500, 10), X_test.shape = (2500, 1)
# cross_validation。。。。
# [0]	train-rmse:0.495954	test-rmse:0.495953
# [1]	train-rmse:0.491014	test-rmse:0.491014
# [2]	train-rmse:0.486124	test-rmse:0.486124
# [3]	train-rmse:0.481283	test-rmse:0.481283
# [4]	train-rmse:0.476491	test-rmse:0.47649
# [5]	train-rmse:0.471747	test-rmse:0.471746
# [6]	train-rmse:0.46705	test-rmse:0.467049
# [7]	train-rmse:0.4624	test-rmse:0.4624
# [8]	train-rmse:0.457797	test-rmse:0.457797
# [9]	train-rmse:0.453241	test-rmse:0.45324
# 2019-06-24 13:20:22,689 - ALPHA_MIND - INFO - Training time cost 0.03239035606384277s
# 2019-06-24 13:20:22,689 - ALPHA_MIND - INFO - best_score = 0.45324020000000004, best_round = 9
# 2019-06-24 13:20:22,704 - ALPHA_MIND - INFO - 2010-01-18 00:00:00 len_total_data: 500
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495954        0.000182        0.495953       0.000738
# 1         0.491014        0.000181        0.491014       0.000740
# 2         0.486124        0.000179        0.486124       0.000742
# 3         0.481283        0.000177        0.481283       0.000744
# 4         0.476491        0.000176        0.476490       0.000746
# 5         0.471747        0.000174        0.471746       0.000748
# 6         0.467050        0.000173        0.467049       0.000750
# 7         0.462400        0.000171        0.462400       0.000752
# 8         0.457797        0.000170        0.457797       0.000754
# 9         0.453241        0.000168        0.453240       0.000756
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.031999826431274414(s)
# 2019-06-24 13:20:22,709 - ALPHA_MIND - INFO - 2010-01-18 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,710 - ALPHA_MIND - INFO - 2010-01-18 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,713 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,714 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,716 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,718 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,723 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,726 - ALPHA_MIND - INFO - 2010-01-18 00:00:00 is finished
# 2019-06-24 13:20:22,727 - ALPHA_MIND - INFO - 2010-01-20 00:00:00 is start
# 2019-06-24 13:20:22,734 - ALPHA_MIND - INFO - len_x_train: 3000, len_y_train: 3000
# 2019-06-24 13:20:22,734 - ALPHA_MIND - INFO - X_train.shape=(3000, 10), X_test.shape = (3000, 1)
# 2019-06-24 13:20:22,734 - ALPHA_MIND - INFO - X_train.shape=(3000, 10), X_test.shape = (3000, 1)
# cross_validation。。。。
# [0]	train-rmse:0.495913	test-rmse:0.495912
# [1]	train-rmse:0.490975	test-rmse:0.490974
# [2]	train-rmse:0.486087	test-rmse:0.486086
# [3]	train-rmse:0.481248	test-rmse:0.481247
# [4]	train-rmse:0.476458	test-rmse:0.476457
# [5]	train-rmse:0.471716	test-rmse:0.471715
# [6]	train-rmse:0.467021	test-rmse:0.46702
# [7]	train-rmse:0.462374	test-rmse:0.462373
# [8]	train-rmse:0.457773	test-rmse:0.457772
# [9]	train-rmse:0.453218	test-rmse:0.453217
# 2019-06-24 13:20:22,770 - ALPHA_MIND - INFO - Training time cost 0.035781145095825195s
# 2019-06-24 13:20:22,770 - ALPHA_MIND - INFO - best_score = 0.4532172, best_round = 9
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495913        0.000231        0.495912       0.000936
# 1         0.490975        0.000229        0.490974       0.000938
# 2         0.486087        0.000227        0.486086       0.000941
# 3         0.481248        0.000225        0.481247       0.000943
# 4         0.476458        0.000223        0.476457       0.000946
# 5         0.471716        0.000221        0.471715       0.000948
# 6         0.467021        0.000218        0.467020       0.000951
# 7         0.462374        0.000216        0.462373       0.000953
# 8         0.457773        0.000215        0.457772       0.000955
# 9         0.453218        0.000212        0.453217       0.000958
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.03540229797363281(s)
# 2019-06-24 13:20:22,786 - ALPHA_MIND - INFO - 2010-01-20 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,791 - ALPHA_MIND - INFO - 2010-01-20 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,793 - ALPHA_MIND - INFO - 2010-01-20 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,795 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,797 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,798 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,801 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,806 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,810 - ALPHA_MIND - INFO - 2010-01-20 00:00:00 is finished
# 2019-06-24 13:20:22,810 - ALPHA_MIND - INFO - 2010-01-22 00:00:00 is start
# 2019-06-24 13:20:22,817 - ALPHA_MIND - INFO - len_x_train: 3500, len_y_train: 3500
# 2019-06-24 13:20:22,818 - ALPHA_MIND - INFO - X_train.shape=(3500, 10), X_test.shape = (3500, 1)
# 2019-06-24 13:20:22,818 - ALPHA_MIND - INFO - X_train.shape=(3500, 10), X_test.shape = (3500, 1)
# cross_validation。。。。
# [0]	train-rmse:0.495591	test-rmse:0.495591
# [1]	train-rmse:0.490658	test-rmse:0.490658
# [2]	train-rmse:0.485775	test-rmse:0.485774
# [3]	train-rmse:0.48094	test-rmse:0.480939
# [4]	train-rmse:0.476154	test-rmse:0.476153
# [5]	train-rmse:0.471416	test-rmse:0.471415
# [6]	train-rmse:0.466725	test-rmse:0.466725
# [7]	train-rmse:0.462082	test-rmse:0.462082
# [8]	train-rmse:0.457485	test-rmse:0.457485
# [9]	train-rmse:0.452935	test-rmse:0.452934
# 2019-06-24 13:20:22,854 - ALPHA_MIND - INFO - Training time cost 0.03589367866516113s
# 2019-06-24 13:20:22,854 - ALPHA_MIND - INFO - best_score = 0.4529344, best_round = 9
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495591        0.000159        0.495591       0.000646
# 1         0.490658        0.000158        0.490658       0.000648
# 2         0.485775        0.000156        0.485774       0.000649
# 3         0.480940        0.000154        0.480939       0.000651
# 4         0.476154        0.000153        0.476153       0.000652
# 5         0.471416        0.000151        0.471415       0.000653
# 6         0.466725        0.000150        0.466725       0.000655
# 7         0.462082        0.000148        0.462082       0.000656
# 8         0.457485        0.000147        0.457485       0.000658
# 9         0.452935        0.000145        0.452934       0.000659
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.03547048568725586(s)
# 2019-06-24 13:20:22,868 - ALPHA_MIND - INFO - 2010-01-22 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,873 - ALPHA_MIND - INFO - 2010-01-22 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,875 - ALPHA_MIND - INFO - 2010-01-22 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,877 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,879 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,880 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,884 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,889 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,893 - ALPHA_MIND - INFO - 2010-01-22 00:00:00 is finished
# 2019-06-24 13:20:22,894 - ALPHA_MIND - INFO - 2010-01-26 00:00:00 is start
# 2019-06-24 13:20:22,901 - ALPHA_MIND - INFO - len_x_train: 4000, len_y_train: 4000
# 2019-06-24 13:20:22,902 - ALPHA_MIND - INFO - X_train.shape=(4000, 10), X_test.shape = (4000, 1)
# 2019-06-24 13:20:22,902 - ALPHA_MIND - INFO - X_train.shape=(4000, 10), X_test.shape = (4000, 1)
# cross_validation。。。。
# [0]	train-rmse:0.495939	test-rmse:0.495938
# [1]	train-rmse:0.491003	test-rmse:0.491001
# [2]	train-rmse:0.486115	test-rmse:0.486114
# [3]	train-rmse:0.481277	test-rmse:0.481276
# [4]	train-rmse:0.476488	test-rmse:0.476487
# [5]	train-rmse:0.471747	test-rmse:0.471745
# [6]	train-rmse:0.467053	test-rmse:0.467052
# [7]	train-rmse:0.462406	test-rmse:0.462405
# [8]	train-rmse:0.457806	test-rmse:0.457805
# [9]	train-rmse:0.453253	test-rmse:0.453252
# 2019-06-24 13:20:22,942 - ALPHA_MIND - INFO - Training time cost 0.03993344306945801s
# 2019-06-24 13:20:22,942 - ALPHA_MIND - INFO - best_score = 0.45325160000000003, best_round = 9
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.495939        0.000266        0.495938       0.001077
# 1         0.491003        0.000263        0.491001       0.001080
# 2         0.486115        0.000261        0.486114       0.001083
# 3         0.481277        0.000258        0.481276       0.001085
# 4         0.476488        0.000255        0.476487       0.001088
# 5         0.471747        0.000254        0.471745       0.001090
# 6         0.467053        0.000251        0.467052       0.001092
# 7         0.462406        0.000248        0.462405       0.001095
# 8         0.457806        0.000246        0.457805       0.001097
# 9         0.453253        0.000243        0.453252       0.001100
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.039522409439086914(s)
# 2019-06-24 13:20:22,957 - ALPHA_MIND - INFO - 2010-01-26 00:00:00 len_total_data: 500
# 2019-06-24 13:20:22,962 - ALPHA_MIND - INFO - 2010-01-26 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:22,964 - ALPHA_MIND - INFO - 2010-01-26 00:00:00 full re-balance: 500
# 2019-06-24 13:20:22,966 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:22,968 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:22,969 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:22,976 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:22,981 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:22,985 - ALPHA_MIND - INFO - 2010-01-26 00:00:00 is finished
# 2019-06-24 13:20:22,985 - ALPHA_MIND - INFO - 2010-01-28 00:00:00 is start
# 2019-06-24 13:20:22,994 - ALPHA_MIND - INFO - len_x_train: 4500, len_y_train: 4500
# 2019-06-24 13:20:22,994 - ALPHA_MIND - INFO - X_train.shape=(4500, 10), X_test.shape = (4500, 1)
# 2019-06-24 13:20:22,994 - ALPHA_MIND - INFO - X_train.shape=(4500, 10), X_test.shape = (4500, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496238	test-rmse:0.496236
# [1]	train-rmse:0.491298	test-rmse:0.491296
# [2]	train-rmse:0.486408	test-rmse:0.486406
# [3]	train-rmse:0.481566	test-rmse:0.481565
# [4]	train-rmse:0.476774	test-rmse:0.476772
# [5]	train-rmse:0.47203	test-rmse:0.472027
# [6]	train-rmse:0.467333	test-rmse:0.467331
# [7]	train-rmse:0.462683	test-rmse:0.46268
# [8]	train-rmse:0.45808	test-rmse:0.458078
# [9]	train-rmse:0.453523	test-rmse:0.453521
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496238        0.000358        0.496236       0.001452
# 1         0.491298        0.000355        0.491296       0.001455
# 2         0.486408        0.000351        0.486406       0.001458
# 3         0.481566        0.000347        0.481565       0.001462
# 4         0.476774        0.000343        0.476772       0.001465
# 5         0.472030        0.000340        0.472027       0.001468
# 6         0.467333        0.000336        0.467331       0.001470
# 7         0.462683        0.000332        0.462680       0.001474
# 8         0.458080        0.000329        0.458078       0.001477
# 9         0.453523        0.000325        0.453521       0.001479
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 13:20:23,036 - ALPHA_MIND - INFO - Training time cost 0.04131031036376953s
# 2019-06-24 13:20:23,036 - ALPHA_MIND - INFO - best_score = 0.453521, best_round = 9
# spend time :0.040848493576049805(s)
# 2019-06-24 13:20:23,049 - ALPHA_MIND - INFO - 2010-01-28 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,055 - ALPHA_MIND - INFO - 2010-01-28 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,057 - ALPHA_MIND - INFO - 2010-01-28 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,059 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,061 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,062 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,064 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:23,069 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:23,073 - ALPHA_MIND - INFO - 2010-01-28 00:00:00 is finished
# 2019-06-24 13:20:23,073 - ALPHA_MIND - INFO - 2010-02-01 00:00:00 is start
# 2019-06-24 13:20:23,082 - ALPHA_MIND - INFO - len_x_train: 5000, len_y_train: 5000
# 2019-06-24 13:20:23,082 - ALPHA_MIND - INFO - X_train.shape=(5000, 10), X_test.shape = (5000, 1)
# 2019-06-24 13:20:23,082 - ALPHA_MIND - INFO - X_train.shape=(5000, 10), X_test.shape = (5000, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496547	test-rmse:0.496547
# [1]	train-rmse:0.491605	test-rmse:0.491605
# [2]	train-rmse:0.486713	test-rmse:0.486713
# [3]	train-rmse:0.481871	test-rmse:0.48187
# [4]	train-rmse:0.477077	test-rmse:0.477076
# [5]	train-rmse:0.472331	test-rmse:0.47233
# [6]	train-rmse:0.467632	test-rmse:0.467632
# [7]	train-rmse:0.462981	test-rmse:0.462981
# [8]	train-rmse:0.458376	test-rmse:0.458376
# [9]	train-rmse:0.453818	test-rmse:0.453818
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496547        0.000138        0.496547       0.000560
# 1         0.491605        0.000136        0.491605       0.000561
# 2         0.486713        0.000135        0.486713       0.000562
# 3         0.481871        0.000133        0.481870       0.000563
# 4         0.477077        0.000132        0.477076       0.000564
# 5         0.472331        0.000130        0.472330       0.000565
# 6         0.467632        0.000129        0.467632       0.000566
# 7         0.462981        0.000127        0.462981       0.000567
# 8         0.458376        0.000126        0.458376       0.000568
# 9         0.453818        0.000124        0.453818       0.000569
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 13:20:23,127 - ALPHA_MIND - INFO - Training time cost 0.04440426826477051s
# 2019-06-24 13:20:23,127 - ALPHA_MIND - INFO - best_score = 0.45381800000000005, best_round = 9
# spend time :0.04401588439941406(s)
# 2019-06-24 13:20:23,142 - ALPHA_MIND - INFO - 2010-02-01 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,147 - ALPHA_MIND - INFO - 2010-02-01 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,148 - ALPHA_MIND - INFO - 2010-02-01 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,151 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,152 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,154 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,156 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:23,161 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:23,165 - ALPHA_MIND - INFO - 2010-02-01 00:00:00 is finished
# 2019-06-24 13:20:23,166 - ALPHA_MIND - INFO - 2010-02-03 00:00:00 is start
# 2019-06-24 13:20:23,175 - ALPHA_MIND - INFO - len_x_train: 5500, len_y_train: 5500
# 2019-06-24 13:20:23,176 - ALPHA_MIND - INFO - X_train.shape=(5500, 10), X_test.shape = (5500, 1)
# 2019-06-24 13:20:23,176 - ALPHA_MIND - INFO - X_train.shape=(5500, 10), X_test.shape = (5500, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496449	test-rmse:0.496449
# [1]	train-rmse:0.491508	test-rmse:0.491508
# [2]	train-rmse:0.486618	test-rmse:0.486618
# [3]	train-rmse:0.481776	test-rmse:0.481776
# [4]	train-rmse:0.476984	test-rmse:0.476984
# [5]	train-rmse:0.472239	test-rmse:0.472239
# [6]	train-rmse:0.467542	test-rmse:0.467542
# [7]	train-rmse:0.462892	test-rmse:0.462892
# [8]	train-rmse:0.458288	test-rmse:0.458288
# [9]	train-rmse:0.453732	test-rmse:0.453731
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496449        0.000077        0.496449       0.000312
# 1         0.491508        0.000076        0.491508       0.000313
# 2         0.486618        0.000075        0.486618       0.000313
# 3         0.481776        0.000075        0.481776       0.000314
# 4         0.476984        0.000074        0.476984       0.000315
# 5         0.472239        0.000073        0.472239       0.000315
# 6         0.467542        0.000072        0.467542       0.000316
# 7         0.462892        0.000072        0.462892       0.000317
# 8         0.458288        0.000071        0.458288       0.000317
# 9         0.453732        0.000070        0.453731       0.000318
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.049448490142822266(s)
# 2019-06-24 13:20:23,226 - ALPHA_MIND - INFO - Training time cost 0.05018734931945801s
# 2019-06-24 13:20:23,227 - ALPHA_MIND - INFO - best_score = 0.4537314, best_round = 9
# 2019-06-24 13:20:23,240 - ALPHA_MIND - INFO - 2010-02-03 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,246 - ALPHA_MIND - INFO - 2010-02-03 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,247 - ALPHA_MIND - INFO - 2010-02-03 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,250 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,251 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,253 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,256 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:23,261 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:23,265 - ALPHA_MIND - INFO - 2010-02-03 00:00:00 is finished
# 2019-06-24 13:20:23,266 - ALPHA_MIND - INFO - 2010-02-05 00:00:00 is start
# 2019-06-24 13:20:23,275 - ALPHA_MIND - INFO - len_x_train: 6000, len_y_train: 6000
# 2019-06-24 13:20:23,276 - ALPHA_MIND - INFO - X_train.shape=(6000, 10), X_test.shape = (6000, 1)
# 2019-06-24 13:20:23,276 - ALPHA_MIND - INFO - X_train.shape=(6000, 10), X_test.shape = (6000, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496479	test-rmse:0.496479
# [1]	train-rmse:0.491538	test-rmse:0.491538
# [2]	train-rmse:0.486647	test-rmse:0.486647
# [3]	train-rmse:0.481805	test-rmse:0.481805
# [4]	train-rmse:0.477012	test-rmse:0.477011
# [5]	train-rmse:0.472266	test-rmse:0.472266
# [6]	train-rmse:0.467569	test-rmse:0.467568
# [7]	train-rmse:0.462918	test-rmse:0.462918
# [8]	train-rmse:0.458315	test-rmse:0.458315
# [9]	train-rmse:0.453758	test-rmse:0.453757
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496479        0.000113        0.496479       0.000459
# 1         0.491538        0.000112        0.491538       0.000460
# 2         0.486647        0.000111        0.486647       0.000460
# 3         0.481805        0.000110        0.481805       0.000462
# 4         0.477012        0.000108        0.477011       0.000463
# 5         0.472266        0.000107        0.472266       0.000464
# 6         0.467569        0.000106        0.467568       0.000464
# 7         0.462918        0.000105        0.462918       0.000465
# 8         0.458315        0.000104        0.458315       0.000466
# 9         0.453758        0.000103        0.453757       0.000467
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 13:20:23,326 - ALPHA_MIND - INFO - Training time cost 0.05001640319824219s
# 2019-06-24 13:20:23,326 - ALPHA_MIND - INFO - best_score = 0.45375740000000003, best_round = 9
# spend time :0.04951977729797363(s)
# 2019-06-24 13:20:23,340 - ALPHA_MIND - INFO - 2010-02-05 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,345 - ALPHA_MIND - INFO - 2010-02-05 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,347 - ALPHA_MIND - INFO - 2010-02-05 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,350 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,352 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,353 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,362 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:23,367 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:23,371 - ALPHA_MIND - INFO - 2010-02-05 00:00:00 is finished
# 2019-06-24 13:20:23,372 - ALPHA_MIND - INFO - 2010-02-09 00:00:00 is start
# 2019-06-24 13:20:23,381 - ALPHA_MIND - INFO - len_x_train: 6500, len_y_train: 6500
# 2019-06-24 13:20:23,381 - ALPHA_MIND - INFO - X_train.shape=(6500, 10), X_test.shape = (6500, 1)
# 2019-06-24 13:20:23,382 - ALPHA_MIND - INFO - X_train.shape=(6500, 10), X_test.shape = (6500, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496309	test-rmse:0.496309
# [1]	train-rmse:0.49137	test-rmse:0.491369
# [2]	train-rmse:0.48648	test-rmse:0.48648
# [3]	train-rmse:0.481639	test-rmse:0.481639
# [4]	train-rmse:0.476847	test-rmse:0.476847
# [5]	train-rmse:0.472103	test-rmse:0.472103
# [6]	train-rmse:0.467407	test-rmse:0.467407
# [7]	train-rmse:0.462758	test-rmse:0.462758
# [8]	train-rmse:0.458156	test-rmse:0.458155
# [9]	train-rmse:0.453599	test-rmse:0.4536
# 2019-06-24 13:20:23,432 - ALPHA_MIND - INFO - Training time cost 0.05033469200134277s
# 2019-06-24 13:20:23,432 - ALPHA_MIND - INFO - best_score = 0.4535996, best_round = 9
# 2019-06-24 13:20:23,446 - ALPHA_MIND - INFO - 2010-02-09 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,451 - ALPHA_MIND - INFO - 2010-02-09 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,453 - ALPHA_MIND - INFO - 2010-02-09 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,455 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,457 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,458 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,464 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:23,469 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:23,473 - ALPHA_MIND - INFO - 2010-02-09 00:00:00 is finished
# 2019-06-24 13:20:23,474 - ALPHA_MIND - INFO - 2010-02-11 00:00:00 is start
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496309        0.000126        0.496309       0.000513
# 1         0.491370        0.000125        0.491369       0.000514
# 2         0.486480        0.000124        0.486480       0.000515
# 3         0.481639        0.000122        0.481639       0.000516
# 4         0.476847        0.000121        0.476847       0.000517
# 5         0.472103        0.000120        0.472103       0.000518
# 6         0.467407        0.000119        0.467407       0.000519
# 7         0.462758        0.000117        0.462758       0.000520
# 8         0.458156        0.000116        0.458155       0.000521
# 9         0.453599        0.000115        0.453600       0.000522
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.04987311363220215(s)
# 2019-06-24 13:20:23,483 - ALPHA_MIND - INFO - len_x_train: 7000, len_y_train: 7000
# 2019-06-24 13:20:23,484 - ALPHA_MIND - INFO - X_train.shape=(7000, 10), X_test.shape = (7000, 1)
# 2019-06-24 13:20:23,484 - ALPHA_MIND - INFO - X_train.shape=(7000, 10), X_test.shape = (7000, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496346	test-rmse:0.496345
# [1]	train-rmse:0.491405	test-rmse:0.491405
# [2]	train-rmse:0.486514	test-rmse:0.486514
# [3]	train-rmse:0.481672	test-rmse:0.481672
# [4]	train-rmse:0.476879	test-rmse:0.476879
# [5]	train-rmse:0.472134	test-rmse:0.472133
# [6]	train-rmse:0.467436	test-rmse:0.467436
# [7]	train-rmse:0.462786	test-rmse:0.462786
# [8]	train-rmse:0.458183	test-rmse:0.458182
# [9]	train-rmse:0.453625	test-rmse:0.453625
# 2019-06-24 13:20:23,537 - ALPHA_MIND - INFO - Training time cost 0.052764892578125s
# 2019-06-24 13:20:23,537 - ALPHA_MIND - INFO - best_score = 0.4536252, best_round = 9
# 2019-06-24 13:20:23,551 - ALPHA_MIND - INFO - 2010-02-11 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,556 - ALPHA_MIND - INFO - 2010-02-11 00:00:00 len_total_data_test_excess: 499
# 2019-06-24 13:20:23,558 - ALPHA_MIND - INFO - 2010-02-11 00:00:00 full re-balance: 499
# 2019-06-24 13:20:23,561 - ALPHA_MIND - INFO - shape_of_benchmark_w: (499,)
# 2019-06-24 13:20:23,562 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (499, 36)
# 2019-06-24 13:20:23,563 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,566 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (499, 1)
# 2019-06-24 13:20:23,571 - ALPHA_MIND - INFO - target_pos: (499, 3)
# 2019-06-24 13:20:23,575 - ALPHA_MIND - INFO - 2010-02-11 00:00:00 is finished
# 2019-06-24 13:20:23,575 - ALPHA_MIND - INFO - 2010-02-22 00:00:00 is start
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496346        0.000129        0.496345       0.000522
# 1         0.491405        0.000127        0.491405       0.000523
# 2         0.486514        0.000125        0.486514       0.000524
# 3         0.481672        0.000123        0.481672       0.000524
# 4         0.476879        0.000122        0.476879       0.000524
# 5         0.472134        0.000120        0.472133       0.000525
# 6         0.467436        0.000118        0.467436       0.000525
# 7         0.462786        0.000116        0.462786       0.000525
# 8         0.458183        0.000115        0.458182       0.000525
# 9         0.453625        0.000113        0.453625       0.000526
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.05232548713684082(s)
# 2019-06-24 13:20:23,585 - ALPHA_MIND - INFO - len_x_train: 7499, len_y_train: 7499
# 2019-06-24 13:20:23,586 - ALPHA_MIND - INFO - X_train.shape=(7499, 10), X_test.shape = (7499, 1)
# 2019-06-24 13:20:23,586 - ALPHA_MIND - INFO - X_train.shape=(7499, 10), X_test.shape = (7499, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496251	test-rmse:0.496251
# [1]	train-rmse:0.491311	test-rmse:0.49131
# [2]	train-rmse:0.48642	test-rmse:0.486419
# [3]	train-rmse:0.481578	test-rmse:0.481577
# [4]	train-rmse:0.476785	test-rmse:0.476784
# [5]	train-rmse:0.47204	test-rmse:0.472039
# [6]	train-rmse:0.467343	test-rmse:0.467342
# [7]	train-rmse:0.462692	test-rmse:0.462692
# [8]	train-rmse:0.458089	test-rmse:0.458088
# [9]	train-rmse:0.453532	test-rmse:0.453531
# 2019-06-24 13:20:23,639 - ALPHA_MIND - INFO - Training time cost 0.0531611442565918s
# 2019-06-24 13:20:23,640 - ALPHA_MIND - INFO - best_score = 0.453531, best_round = 9
# 2019-06-24 13:20:23,653 - ALPHA_MIND - INFO - 2010-02-22 00:00:00 len_total_data: 499
# 2019-06-24 13:20:23,658 - ALPHA_MIND - INFO - 2010-02-22 00:00:00 len_total_data_test_excess: 499
# 2019-06-24 13:20:23,660 - ALPHA_MIND - INFO - 2010-02-22 00:00:00 full re-balance: 499
# 2019-06-24 13:20:23,662 - ALPHA_MIND - INFO - shape_of_benchmark_w: (499,)
# 2019-06-24 13:20:23,664 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (499, 36)
# 2019-06-24 13:20:23,665 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,667 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (499, 1)
# 2019-06-24 13:20:23,673 - ALPHA_MIND - INFO - target_pos: (499, 3)
# 2019-06-24 13:20:23,678 - ALPHA_MIND - INFO - 2010-02-22 00:00:00 is finished
# 2019-06-24 13:20:23,678 - ALPHA_MIND - INFO - 2010-02-24 00:00:00 is start
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496251        0.000207        0.496251       0.000840
# 1         0.491311        0.000204        0.491310       0.000841
# 2         0.486420        0.000202        0.486419       0.000843
# 3         0.481578        0.000200        0.481577       0.000844
# 4         0.476785        0.000197        0.476784       0.000846
# 5         0.472040        0.000195        0.472039       0.000847
# 6         0.467343        0.000192        0.467342       0.000848
# 7         0.462692        0.000190        0.462692       0.000849
# 8         0.458089        0.000188        0.458088       0.000850
# 9         0.453532        0.000185        0.453531       0.000851
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.05274629592895508(s)
# 2019-06-24 13:20:23,689 - ALPHA_MIND - INFO - len_x_train: 7998, len_y_train: 7998
# 2019-06-24 13:20:23,689 - ALPHA_MIND - INFO - X_train.shape=(7998, 10), X_test.shape = (7998, 1)
# 2019-06-24 13:20:23,689 - ALPHA_MIND - INFO - X_train.shape=(7998, 10), X_test.shape = (7998, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496217	test-rmse:0.496217
# [1]	train-rmse:0.491276	test-rmse:0.491276
# [2]	train-rmse:0.486385	test-rmse:0.486384
# [3]	train-rmse:0.481543	test-rmse:0.481543
# [4]	train-rmse:0.47675	test-rmse:0.476749
# [5]	train-rmse:0.472004	test-rmse:0.472004
# [6]	train-rmse:0.467307	test-rmse:0.467306
# [7]	train-rmse:0.462656	test-rmse:0.462656
# [8]	train-rmse:0.458052	test-rmse:0.458052
# [9]	train-rmse:0.453495	test-rmse:0.453494
# 2019-06-24 13:20:23,746 - ALPHA_MIND - INFO - Training time cost 0.05610346794128418s
# 2019-06-24 13:20:23,746 - ALPHA_MIND - INFO - best_score = 0.4534942, best_round = 9
# 2019-06-24 13:20:23,760 - ALPHA_MIND - INFO - 2010-02-24 00:00:00 len_total_data: 499
# 2019-06-24 13:20:23,766 - ALPHA_MIND - INFO - 2010-02-24 00:00:00 len_total_data_test_excess: 499
# 2019-06-24 13:20:23,767 - ALPHA_MIND - INFO - 2010-02-24 00:00:00 full re-balance: 499
# 2019-06-24 13:20:23,770 - ALPHA_MIND - INFO - shape_of_benchmark_w: (499,)
# 2019-06-24 13:20:23,772 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (499, 36)
# 2019-06-24 13:20:23,773 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,775 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (499, 1)
# 2019-06-24 13:20:23,781 - ALPHA_MIND - INFO - target_pos: (499, 3)
# 2019-06-24 13:20:23,785 - ALPHA_MIND - INFO - 2010-02-24 00:00:00 is finished
# 2019-06-24 13:20:23,786 - ALPHA_MIND - INFO - 2010-02-26 00:00:00 is start
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496217        0.000201        0.496217       0.000813
# 1         0.491276        0.000198        0.491276       0.000814
# 2         0.486385        0.000196        0.486384       0.000816
# 3         0.481543        0.000194        0.481543       0.000817
# 4         0.476750        0.000191        0.476749       0.000819
# 5         0.472004        0.000189        0.472004       0.000820
# 6         0.467307        0.000187        0.467306       0.000821
# 7         0.462656        0.000185        0.462656       0.000822
# 8         0.458052        0.000182        0.458052       0.000824
# 9         0.453495        0.000180        0.453494       0.000825
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.05563044548034668(s)
# 2019-06-24 13:20:23,797 - ALPHA_MIND - INFO - len_x_train: 8497, len_y_train: 8497
# 2019-06-24 13:20:23,798 - ALPHA_MIND - INFO - X_train.shape=(8497, 10), X_test.shape = (8497, 1)
# 2019-06-24 13:20:23,798 - ALPHA_MIND - INFO - X_train.shape=(8497, 10), X_test.shape = (8497, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496142	test-rmse:0.496142
# [1]	train-rmse:0.491201	test-rmse:0.491201
# [2]	train-rmse:0.48631	test-rmse:0.48631
# [3]	train-rmse:0.481468	test-rmse:0.481468
# [4]	train-rmse:0.476675	test-rmse:0.476675
# [5]	train-rmse:0.47193	test-rmse:0.471929
# [6]	train-rmse:0.467232	test-rmse:0.467232
# [7]	train-rmse:0.462582	test-rmse:0.462581
# [8]	train-rmse:0.457978	test-rmse:0.457978
# [9]	train-rmse:0.453421	test-rmse:0.45342
# 2019-06-24 13:20:23,859 - ALPHA_MIND - INFO - Training time cost 0.06127214431762695s
# 2019-06-24 13:20:23,860 - ALPHA_MIND - INFO - best_score = 0.45342020000000005, best_round = 9
# 2019-06-24 13:20:23,873 - ALPHA_MIND - INFO - 2010-02-26 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,879 - ALPHA_MIND - INFO - 2010-02-26 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,880 - ALPHA_MIND - INFO - 2010-02-26 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,883 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,885 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,886 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:23,888 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496142        0.000141        0.496142       0.000571
# 1         0.491201        0.000139        0.491201       0.000572
# 2         0.486310        0.000138        0.486310       0.000573
# 3         0.481468        0.000136        0.481468       0.000574
# 4         0.476675        0.000135        0.476675       0.000576
# 5         0.471930        0.000133        0.471929       0.000577
# 6         0.467232        0.000132        0.467232       0.000578
# 7         0.462582        0.000131        0.462581       0.000579
# 8         0.457978        0.000129        0.457978       0.000580
# 9         0.453421        0.000128        0.453420       0.000581
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.06073260307312012(s)
# 2019-06-24 13:20:23,894 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:23,898 - ALPHA_MIND - INFO - 2010-02-26 00:00:00 is finished
# 2019-06-24 13:20:23,898 - ALPHA_MIND - INFO - 2010-03-02 00:00:00 is start
# 2019-06-24 13:20:23,909 - ALPHA_MIND - INFO - len_x_train: 8997, len_y_train: 8997
# 2019-06-24 13:20:23,909 - ALPHA_MIND - INFO - X_train.shape=(8997, 10), X_test.shape = (8997, 1)
# 2019-06-24 13:20:23,910 - ALPHA_MIND - INFO - X_train.shape=(8997, 10), X_test.shape = (8997, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496066	test-rmse:0.496066
# [1]	train-rmse:0.491126	test-rmse:0.491125
# [2]	train-rmse:0.486235	test-rmse:0.486235
# [3]	train-rmse:0.481393	test-rmse:0.481393
# [4]	train-rmse:0.476601	test-rmse:0.4766
# [5]	train-rmse:0.471856	test-rmse:0.471855
# [6]	train-rmse:0.467159	test-rmse:0.467158
# [7]	train-rmse:0.462508	test-rmse:0.462508
# [8]	train-rmse:0.457905	test-rmse:0.457905
# [9]	train-rmse:0.453348	test-rmse:0.453348
# 2019-06-24 13:20:23,969 - ALPHA_MIND - INFO - Training time cost 0.05960249900817871s
# 2019-06-24 13:20:23,970 - ALPHA_MIND - INFO - best_score = 0.4533478000000001, best_round = 9
# 2019-06-24 13:20:23,983 - ALPHA_MIND - INFO - 2010-03-02 00:00:00 len_total_data: 500
# 2019-06-24 13:20:23,988 - ALPHA_MIND - INFO - 2010-03-02 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:23,990 - ALPHA_MIND - INFO - 2010-03-02 00:00:00 full re-balance: 500
# 2019-06-24 13:20:23,992 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:23,994 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:23,995 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496066        0.000168        0.496066       0.000681
# 1         0.491126        0.000166        0.491125       0.000682
# 2         0.486235        0.000164        0.486235       0.000683
# 3         0.481393        0.000162        0.481393       0.000685
# 4         0.476601        0.000160        0.476600       0.000686
# 5         0.471856        0.000159        0.471855       0.000687
# 6         0.467159        0.000156        0.467158       0.000688
# 7         0.462508        0.000155        0.462508       0.000689
# 8         0.457905        0.000153        0.457905       0.000691
# 9         0.453348        0.000151        0.453348       0.000692
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.05919146537780762(s)
# 2019-06-24 13:20:24,004 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 13:20:24,009 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 13:20:24,013 - ALPHA_MIND - INFO - 2010-03-02 00:00:00 is finished
# 2019-06-24 13:20:24,013 - ALPHA_MIND - INFO - 2010-03-04 00:00:00 is start
# 2019-06-24 13:20:24,025 - ALPHA_MIND - INFO - len_x_train: 9497, len_y_train: 9497
# 2019-06-24 13:20:24,025 - ALPHA_MIND - INFO - X_train.shape=(9497, 10), X_test.shape = (9497, 1)
# 2019-06-24 13:20:24,026 - ALPHA_MIND - INFO - X_train.shape=(9497, 10), X_test.shape = (9497, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496041	test-rmse:0.496041
# [1]	train-rmse:0.491101	test-rmse:0.491101
# [2]	train-rmse:0.48621	test-rmse:0.48621
# [3]	train-rmse:0.481369	test-rmse:0.481369
# [4]	train-rmse:0.476576	test-rmse:0.476576
# [5]	train-rmse:0.471831	test-rmse:0.471831
# [6]	train-rmse:0.467134	test-rmse:0.467134
# [7]	train-rmse:0.462484	test-rmse:0.462484
# [8]	train-rmse:0.457881	test-rmse:0.45788
# [9]	train-rmse:0.453324	test-rmse:0.453323
# 2019-06-24 13:20:24,090 - ALPHA_MIND - INFO - Training time cost 0.06392145156860352s
# 2019-06-24 13:20:24,090 - ALPHA_MIND - INFO - best_score = 0.45332340000000004, best_round = 9
# 2019-06-24 13:20:24,103 - ALPHA_MIND - INFO - 2010-03-04 00:00:00 len_total_data: 500
# 2019-06-24 13:20:24,109 - ALPHA_MIND - INFO - 2010-03-04 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 13:20:24,110 - ALPHA_MIND - INFO - 2010-03-04 00:00:00 full re-balance: 500
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496041        0.000106        0.496041       0.000431
# 1         0.491101        0.000105        0.491101       0.000432
# 2         0.486210        0.000104        0.486210       0.000433
# 3         0.481369        0.000103        0.481369       0.000434
# 4         0.476576        0.000102        0.476576       0.000435
# 5         0.471831        0.000101        0.471831       0.000436
# 6         0.467134        0.000100        0.467134       0.000436
# 7         0.462484        0.000098        0.462484       0.000437
# 8         0.457881        0.000097        0.457880       0.000438
# 9         0.453324        0.000096        0.453323       0.000439
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# spend time :0.06342887878417969(s)
# 2019-06-24 13:20:24,113 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 13:20:24,115 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 13:20:24,116 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 13:20:24,119 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# ...
# 2019-06-24 14:14:32,319 - ALPHA_MIND - INFO - 2019-04-11 00:00:00 full re-balance: 500
# 2019-06-24 14:14:32,322 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:14:32,323 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:14:32,325 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:14:32,327 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:14:32,333 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:14:32,338 - ALPHA_MIND - INFO - 2019-04-11 00:00:00 is finished
# 2019-06-24 14:14:32,338 - ALPHA_MIND - INFO - 2019-04-15 00:00:00 is start
# spend time :4.4355316162109375(s)
# 2019-06-24 14:14:32,768 - ALPHA_MIND - INFO - len_x_train: 563440, len_y_train: 563440
# 2019-06-24 14:14:32,768 - ALPHA_MIND - INFO - X_train.shape=(563440, 10), X_test.shape = (563440, 1)
# 2019-06-24 14:14:32,769 - ALPHA_MIND - INFO - X_train.shape=(563440, 10), X_test.shape = (563440, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496198	test-rmse:0.496198
# [1]	train-rmse:0.491255	test-rmse:0.491256
# [2]	train-rmse:0.486363	test-rmse:0.486362
# [3]	train-rmse:0.481518	test-rmse:0.481518
# [4]	train-rmse:0.476723	test-rmse:0.476723
# [5]	train-rmse:0.471976	test-rmse:0.471976
# [6]	train-rmse:0.467277	test-rmse:0.467277
# [7]	train-rmse:0.462625	test-rmse:0.462625
# [8]	train-rmse:0.458019	test-rmse:0.458019
# [9]	train-rmse:0.45346	test-rmse:0.45346
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496198        0.000025        0.496198       0.000102
# 1         0.491255        0.000025        0.491256       0.000102
# 2         0.486363        0.000025        0.486362       0.000102
# 3         0.481518        0.000025        0.481518       0.000103
# 4         0.476723        0.000024        0.476723       0.000103
# 5         0.471976        0.000024        0.471976       0.000103
# 6         0.467277        0.000024        0.467277       0.000103
# 7         0.462625        0.000024        0.462625       0.000104
# 8         0.458019        0.000023        0.458019       0.000104
# 9         0.453460        0.000023        0.453460       0.000104
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 14:14:37,178 - ALPHA_MIND - INFO - Training time cost 4.4093475341796875s
# 2019-06-24 14:14:37,179 - ALPHA_MIND - INFO - best_score = 0.45346020000000004, best_round = 9
# 2019-06-24 14:14:37,193 - ALPHA_MIND - INFO - 2019-04-15 00:00:00 len_total_data: 500
# 2019-06-24 14:14:37,198 - ALPHA_MIND - INFO - 2019-04-15 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 14:14:37,200 - ALPHA_MIND - INFO - 2019-04-15 00:00:00 full re-balance: 500
# 2019-06-24 14:14:37,203 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:14:37,205 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:14:37,206 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:14:37,212 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:14:37,219 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:14:37,223 - ALPHA_MIND - INFO - 2019-04-15 00:00:00 is finished
# 2019-06-24 14:14:37,223 - ALPHA_MIND - INFO - 2019-04-17 00:00:00 is start
# spend time :4.408588886260986(s)
# 2019-06-24 14:14:37,644 - ALPHA_MIND - INFO - len_x_train: 563940, len_y_train: 563940
# 2019-06-24 14:14:37,645 - ALPHA_MIND - INFO - X_train.shape=(563940, 10), X_test.shape = (563940, 1)
# 2019-06-24 14:14:37,645 - ALPHA_MIND - INFO - X_train.shape=(563940, 10), X_test.shape = (563940, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496198	test-rmse:0.496198
# [1]	train-rmse:0.491255	test-rmse:0.491255
# [2]	train-rmse:0.486362	test-rmse:0.486362
# [3]	train-rmse:0.481518	test-rmse:0.481518
# [4]	train-rmse:0.476723	test-rmse:0.476723
# [5]	train-rmse:0.471976	test-rmse:0.471976
# [6]	train-rmse:0.467277	test-rmse:0.467277
# [7]	train-rmse:0.462624	test-rmse:0.462624
# [8]	train-rmse:0.458019	test-rmse:0.458019
# [9]	train-rmse:0.45346	test-rmse:0.45346
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496198        0.000012        0.496198       0.000050
# 1         0.491255        0.000012        0.491255       0.000050
# 2         0.486362        0.000012        0.486362       0.000050
# 3         0.481518        0.000012        0.481518       0.000050
# 4         0.476723        0.000012        0.476723       0.000051
# 5         0.471976        0.000012        0.471976       0.000051
# 6         0.467277        0.000012        0.467277       0.000050
# 7         0.462624        0.000012        0.462624       0.000051
# 8         0.458019        0.000011        0.458019       0.000051
# 9         0.453460        0.000011        0.453460       0.000051
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 14:14:42,300 - ALPHA_MIND - INFO - Training time cost 4.654317617416382s
# 2019-06-24 14:14:42,300 - ALPHA_MIND - INFO - best_score = 0.45346000000000003, best_round = 9
# 2019-06-24 14:14:42,314 - ALPHA_MIND - INFO - 2019-04-17 00:00:00 len_total_data: 500
# 2019-06-24 14:14:42,319 - ALPHA_MIND - INFO - 2019-04-17 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 14:14:42,321 - ALPHA_MIND - INFO - 2019-04-17 00:00:00 full re-balance: 500
# 2019-06-24 14:14:42,323 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:14:42,325 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:14:42,326 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:14:42,335 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:14:42,341 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:14:42,346 - ALPHA_MIND - INFO - 2019-04-17 00:00:00 is finished
# 2019-06-24 14:14:42,346 - ALPHA_MIND - INFO - 2019-04-19 00:00:00 is start
# spend time :4.653667449951172(s)
# 2019-06-24 14:14:42,775 - ALPHA_MIND - INFO - len_x_train: 564440, len_y_train: 564440
# 2019-06-24 14:14:42,776 - ALPHA_MIND - INFO - X_train.shape=(564440, 10), X_test.shape = (564440, 1)
# 2019-06-24 14:14:42,776 - ALPHA_MIND - INFO - X_train.shape=(564440, 10), X_test.shape = (564440, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496198	test-rmse:0.496198
# [1]	train-rmse:0.491256	test-rmse:0.491255
# [2]	train-rmse:0.486363	test-rmse:0.486363
# [3]	train-rmse:0.481519	test-rmse:0.481519
# [4]	train-rmse:0.476723	test-rmse:0.476723
# [5]	train-rmse:0.471976	test-rmse:0.471976
# [6]	train-rmse:0.467277	test-rmse:0.467277
# [7]	train-rmse:0.462625	test-rmse:0.462625
# [8]	train-rmse:0.458019	test-rmse:0.458019
# [9]	train-rmse:0.45346	test-rmse:0.45346
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496198        0.000008        0.496198       0.000034
# 1         0.491256        0.000008        0.491255       0.000034
# 2         0.486363        0.000008        0.486363       0.000034
# 3         0.481519        0.000008        0.481519       0.000035
# 4         0.476723        0.000008        0.476723       0.000034
# 5         0.471976        0.000008        0.471976       0.000035
# 6         0.467277        0.000008        0.467277       0.000035
# 7         0.462625        0.000008        0.462625       0.000035
# 8         0.458019        0.000008        0.458019       0.000035
# 9         0.453460        0.000008        0.453460       0.000035
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 14:14:47,298 - ALPHA_MIND - INFO - Training time cost 4.521950006484985s
# 2019-06-24 14:14:47,299 - ALPHA_MIND - INFO - best_score = 0.45346020000000004, best_round = 9
# 2019-06-24 14:14:47,313 - ALPHA_MIND - INFO - 2019-04-19 00:00:00 len_total_data: 500
# 2019-06-24 14:14:47,319 - ALPHA_MIND - INFO - 2019-04-19 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 14:14:47,320 - ALPHA_MIND - INFO - 2019-04-19 00:00:00 full re-balance: 500
# 2019-06-24 14:14:47,324 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:14:47,325 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:14:47,327 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:14:47,332 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:14:47,339 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:14:47,343 - ALPHA_MIND - INFO - 2019-04-19 00:00:00 is finished
# 2019-06-24 14:14:47,344 - ALPHA_MIND - INFO - 2019-04-23 00:00:00 is start
# spend time :4.52110481262207(s)
# 2019-06-24 14:14:47,776 - ALPHA_MIND - INFO - len_x_train: 564940, len_y_train: 564940
# 2019-06-24 14:14:47,776 - ALPHA_MIND - INFO - X_train.shape=(564940, 10), X_test.shape = (564940, 1)
# 2019-06-24 14:14:47,777 - ALPHA_MIND - INFO - X_train.shape=(564940, 10), X_test.shape = (564940, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496199	test-rmse:0.496199
# [1]	train-rmse:0.491256	test-rmse:0.491256
# [2]	train-rmse:0.486364	test-rmse:0.486363
# [3]	train-rmse:0.48152	test-rmse:0.48152
# [4]	train-rmse:0.476724	test-rmse:0.476724
# [5]	train-rmse:0.471977	test-rmse:0.471977
# [6]	train-rmse:0.467278	test-rmse:0.467278
# [7]	train-rmse:0.462626	test-rmse:0.462626
# [8]	train-rmse:0.45802	test-rmse:0.45802
# [9]	train-rmse:0.453461	test-rmse:0.453461
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496199        0.000023        0.496199       0.000091
# 1         0.491256        0.000022        0.491256       0.000091
# 2         0.486364        0.000022        0.486363       0.000092
# 3         0.481520        0.000022        0.481520       0.000092
# 4         0.476724        0.000021        0.476724       0.000092
# 5         0.471977        0.000021        0.471977       0.000092
# 6         0.467278        0.000021        0.467278       0.000093
# 7         0.462626        0.000021        0.462626       0.000093
# 8         0.458020        0.000021        0.458020       0.000093
# 9         0.453461        0.000021        0.453461       0.000093
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 14:14:52,594 - ALPHA_MIND - INFO - Training time cost 4.817691087722778s
# 2019-06-24 14:14:52,595 - ALPHA_MIND - INFO - best_score = 0.45346080000000005, best_round = 9
# 2019-06-24 14:14:52,608 - ALPHA_MIND - INFO - 2019-04-23 00:00:00 len_total_data: 500
# 2019-06-24 14:14:52,614 - ALPHA_MIND - INFO - 2019-04-23 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 14:14:52,616 - ALPHA_MIND - INFO - 2019-04-23 00:00:00 full re-balance: 500
# 2019-06-24 14:14:52,619 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:14:52,620 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:14:52,622 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:14:52,628 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:14:52,635 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:14:52,639 - ALPHA_MIND - INFO - 2019-04-23 00:00:00 is finished
# 2019-06-24 14:14:52,640 - ALPHA_MIND - INFO - 2019-04-25 00:00:00 is start
# spend time :4.816965818405151(s)
# 2019-06-24 14:14:53,064 - ALPHA_MIND - INFO - len_x_train: 565440, len_y_train: 565440
# 2019-06-24 14:14:53,064 - ALPHA_MIND - INFO - X_train.shape=(565440, 10), X_test.shape = (565440, 1)
# 2019-06-24 14:14:53,065 - ALPHA_MIND - INFO - X_train.shape=(565440, 10), X_test.shape = (565440, 1)
# cross_validation。。。。
# [0]	train-rmse:0.4962	test-rmse:0.4962
# [1]	train-rmse:0.491258	test-rmse:0.491258
# [2]	train-rmse:0.486364	test-rmse:0.486365
# [3]	train-rmse:0.48152	test-rmse:0.481521
# [4]	train-rmse:0.476725	test-rmse:0.476725
# [5]	train-rmse:0.471978	test-rmse:0.471978
# [6]	train-rmse:0.467279	test-rmse:0.467279
# [7]	train-rmse:0.462627	test-rmse:0.462627
# [8]	train-rmse:0.458021	test-rmse:0.458021
# [9]	train-rmse:0.453462	test-rmse:0.453462
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496200        0.000016        0.496200       0.000067
# 1         0.491258        0.000017        0.491258       0.000067
# 2         0.486364        0.000016        0.486365       0.000067
# 3         0.481520        0.000016        0.481521       0.000068
# 4         0.476725        0.000016        0.476725       0.000068
# 5         0.471978        0.000016        0.471978       0.000068
# 6         0.467279        0.000016        0.467279       0.000068
# 7         0.462627        0.000016        0.462627       0.000069
# 8         0.458021        0.000015        0.458021       0.000069
# 9         0.453462        0.000015        0.453462       0.000069
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 14:14:58,432 - ALPHA_MIND - INFO - Training time cost 5.366724491119385s
# 2019-06-24 14:14:58,432 - ALPHA_MIND - INFO - best_score = 0.4534622, best_round = 9
# 2019-06-24 14:14:58,445 - ALPHA_MIND - INFO - 2019-04-25 00:00:00 len_total_data: 500
# 2019-06-24 14:14:58,451 - ALPHA_MIND - INFO - 2019-04-25 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 14:14:58,452 - ALPHA_MIND - INFO - 2019-04-25 00:00:00 full re-balance: 500
# 2019-06-24 14:14:58,455 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:14:58,457 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:14:58,458 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:14:58,485 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:14:58,492 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:14:58,495 - ALPHA_MIND - INFO - 2019-04-25 00:00:00 is finished
# 2019-06-24 14:14:58,496 - ALPHA_MIND - INFO - 2019-04-29 00:00:00 is start
# spend time :5.366119384765625(s)
# 2019-06-24 14:14:58,934 - ALPHA_MIND - INFO - len_x_train: 565940, len_y_train: 565940
# 2019-06-24 14:14:58,934 - ALPHA_MIND - INFO - X_train.shape=(565940, 10), X_test.shape = (565940, 1)
# 2019-06-24 14:14:58,935 - ALPHA_MIND - INFO - X_train.shape=(565940, 10), X_test.shape = (565940, 1)
# cross_validation。。。。
# [0]	train-rmse:0.496204	test-rmse:0.496204
# [1]	train-rmse:0.491262	test-rmse:0.491261
# [2]	train-rmse:0.486368	test-rmse:0.486368
# [3]	train-rmse:0.481524	test-rmse:0.481524
# [4]	train-rmse:0.476729	test-rmse:0.476729
# [5]	train-rmse:0.471982	test-rmse:0.471982
# [6]	train-rmse:0.467283	test-rmse:0.467283
# [7]	train-rmse:0.462631	test-rmse:0.462631
# [8]	train-rmse:0.458025	test-rmse:0.458025
# [9]	train-rmse:0.453466	test-rmse:0.453466
# cv_result    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.496204        0.000017        0.496204       0.000068
# 1         0.491262        0.000017        0.491261       0.000068
# 2         0.486368        0.000016        0.486368       0.000068
# 3         0.481524        0.000016        0.481524       0.000068
# 4         0.476729        0.000016        0.476729       0.000068
# 5         0.471982        0.000016        0.471982       0.000068
# 6         0.467283        0.000016        0.467283       0.000069
# 7         0.462631        0.000016        0.462631       0.000069
# 8         0.458025        0.000015        0.458025       0.000069
# 9         0.453466        0.000016        0.453466       0.000069
# type_cv_result <class 'pandas.core.frame.DataFrame'>
# 2019-06-24 14:15:03,718 - ALPHA_MIND - INFO - Training time cost 4.783425807952881s
# 2019-06-24 14:15:03,719 - ALPHA_MIND - INFO - best_score = 0.45346580000000003, best_round = 9
# 2019-06-24 14:15:03,733 - ALPHA_MIND - INFO - 2019-04-29 00:00:00 len_total_data: 500
# 2019-06-24 14:15:03,738 - ALPHA_MIND - INFO - 2019-04-29 00:00:00 len_total_data_test_excess: 500
# 2019-06-24 14:15:03,739 - ALPHA_MIND - INFO - 2019-04-29 00:00:00 full re-balance: 500
# 2019-06-24 14:15:03,742 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-06-24 14:15:03,744 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-06-24 14:15:03,745 - ALPHA_MIND - INFO - shape_of_constraints: (2, 36)
# 2019-06-24 14:15:03,747 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-06-24 14:15:03,754 - ALPHA_MIND - INFO - target_pos: (500, 3)
# 2019-06-24 14:15:03,758 - ALPHA_MIND - INFO - 2019-04-29 00:00:00 is finished
# spend time :4.782803058624268(s)
# CPU times: user 5h 27min 55s, sys: 15.7 s, total: 5h 28min 10s
# Wall time: 54min 41s

# %%
print(len(rets), len(trade_dates))
# Out:
# 1132 1132

# %%
ret_df = pd.DataFrame({'xgb_regress': rets}, index=trade_dates)
ret_df.loc[advanceDateByCalendar('china.sse', ref_dates[-1], freq).strftime('%Y-%m-%d')] = 0.
ret_df = ret_df.shift(1)
ret_df.iloc[0] = 0.

ret_df[['xgb_regress']].cumsum().plot(figsize=(12, 6), 
                                      title='Fixed freq rebalanced: {0}'.format(freq))
