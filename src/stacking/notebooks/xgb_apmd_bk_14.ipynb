# %% [markdown]
# # 基础因子risk—netural回测结果

# %% [markdown]
# 添加费后曲线

# %%
# %matplotlib inline
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../../')
import pandas as pd
from PyFin.api import *
from alphamind.api import *
from src.conf.models import *
import numpy as np
from alphamind.execution.naiveexecutor import NaiveExecutor
from matplotlib import pyplot as plt

data_source = 'postgresql+psycopg2://alpha:alpha@180.166.26.82:8889/alpha'
engine = SqlEngine(data_source)

# %%
universe = Universe('zz500')
freq = '3b'
benchmark_code = 905
start_date = '2018-01-01'
end_date = '2019-08-01'
ref_dates = makeSchedule(start_date, end_date, freq, 'china.sse')
horizon = map_freq(freq)
industry_name = 'sw'
industry_level = 1

# %%
basic_factor_store = {
    'AccountsPayablesTDays': CSQuantiles(LAST('AccountsPayablesTDays'), groups='sw1'), 
    'AccountsPayablesTRate': CSQuantiles(LAST('AccountsPayablesTRate'), groups='sw1'), 
    'AdminiExpenseRate': CSQuantiles(LAST('AdminiExpenseRate'), groups='sw1'), 
    'ARTDays': CSQuantiles(LAST('ARTDays'), groups='sw1'), 
    'ARTRate': CSQuantiles(LAST('ARTRate'), groups='sw1'), 
    'ASSI': CSQuantiles(LAST('ASSI'), groups='sw1'), 
    'BLEV': CSQuantiles(LAST('BLEV'), groups='sw1'), 
    'BondsPayableToAsset': CSQuantiles(LAST('BondsPayableToAsset'), groups='sw1'), 
    'CashRateOfSales': CSQuantiles(LAST('CashRateOfSales'), groups='sw1'), 
    'CashToCurrentLiability': CSQuantiles(LAST('CashToCurrentLiability'), groups='sw1'), 
    'CMRA': CSQuantiles(LAST('CMRA'), groups='sw1'), 
    'CTOP': CSQuantiles(LAST('CTOP'), groups='sw1'), 
    'CTP5': CSQuantiles(LAST('CTP5'), groups='sw1'), 
    'CurrentAssetsRatio': CSQuantiles(LAST('CurrentAssetsRatio'), groups='sw1'), 
    'CurrentAssetsTRate': CSQuantiles(LAST('CurrentAssetsTRate'), groups='sw1'), 
    'CurrentRatio': CSQuantiles(LAST('CurrentRatio'), groups='sw1'), 
    'DAVOL10': CSQuantiles(LAST('DAVOL10'), groups='sw1'), 
    'DAVOL20': CSQuantiles(LAST('DAVOL20'), groups='sw1'), 
    'DAVOL5': CSQuantiles(LAST('DAVOL5'), groups='sw1'), 
    'DDNBT': CSQuantiles(LAST('DDNBT'), groups='sw1'), 
    'DDNCR': CSQuantiles(LAST('DDNCR'), groups='sw1'), 
    'DDNSR': CSQuantiles(LAST('DDNSR'), groups='sw1'), 
    'DebtEquityRatio': CSQuantiles(LAST('DebtEquityRatio'), groups='sw1'), 
    'DebtsAssetRatio': CSQuantiles(LAST('DebtsAssetRatio'), groups='sw1'), 
    'DHILO': CSQuantiles(LAST('DHILO'), groups='sw1'), 
    'DilutedEPS': CSQuantiles(LAST('DilutedEPS'), groups='sw1'), 
    'DVRAT': CSQuantiles(LAST('DVRAT'), groups='sw1'), 
    'EBITToTOR': CSQuantiles(LAST('EBITToTOR'), groups='sw1'), 
    'EGRO': CSQuantiles(LAST('EGRO'), groups='sw1'), 
    'EMA10': CSQuantiles(LAST('EMA10'), groups='sw1'), 
    'EMA120': CSQuantiles(LAST('EMA120'), groups='sw1'), 
    'EMA20': CSQuantiles(LAST('EMA20'), groups='sw1'), 
    'EMA5': CSQuantiles(LAST('EMA5'), groups='sw1'), 
    'EMA60': CSQuantiles(LAST('EMA60'), groups='sw1'), 
    'EPS': CSQuantiles(LAST('EPS'), groups='sw1'), 
    'EquityFixedAssetRatio': CSQuantiles(LAST('EquityFixedAssetRatio'), groups='sw1'), 
    'EquityToAsset': CSQuantiles(LAST('EquityToAsset'), groups='sw1'), 
    'EquityTRate': CSQuantiles(LAST('EquityTRate'), groups='sw1'), 
    'ETOP': CSQuantiles(LAST('ETOP'), groups='sw1'), 
    'ETP5': CSQuantiles(LAST('ETP5'), groups='sw1'), 
    'FinancialExpenseRate': CSQuantiles(LAST('FinancialExpenseRate'), groups='sw1'), 
    'FinancingCashGrowRate': CSQuantiles(LAST('FinancingCashGrowRate'), groups='sw1'), 
    'FixAssetRatio': CSQuantiles(LAST('FixAssetRatio'), groups='sw1'), 
    'FixedAssetsTRate': CSQuantiles(LAST('FixedAssetsTRate'), groups='sw1'), 
    'GrossIncomeRatio': CSQuantiles(LAST('GrossIncomeRatio'), groups='sw1'), 
    'HBETA': CSQuantiles(LAST('HBETA'), groups='sw1'), 
    'HSIGMA': CSQuantiles(LAST('HBETA'), groups='sw1'), 
    'IntangibleAssetRatio': CSQuantiles(LAST('IntangibleAssetRatio'), groups='sw1'), 
    'InventoryTDays': CSQuantiles(LAST('InventoryTDays'), groups='sw1'), 
    'InventoryTRate': CSQuantiles(LAST('InventoryTRate'), groups='sw1'), 
    'InvestCashGrowRate': CSQuantiles(LAST('InvestCashGrowRate'), groups='sw1'), 
    'LCAP': CSQuantiles(LAST('LCAP'), groups='sw1'), 
    'LFLO': CSQuantiles(LAST('LFLO'), groups='sw1'), 
    'LongDebtToAsset': CSQuantiles(LAST('LongDebtToAsset'), groups='sw1'), 
    'LongDebtToWorkingCapital': CSQuantiles(LAST('LongDebtToWorkingCapital'), groups='sw1'), 
    'LongTermDebtToAsset': CSQuantiles(LAST('LongTermDebtToAsset'), groups='sw1'), 
    'MA10': CSQuantiles(LAST('MA10'), groups='sw1'), 
    'MA120': CSQuantiles(LAST('MA120'), groups='sw1'), 
    'MA20': CSQuantiles(LAST('MA20'), groups='sw1'), 
    'MA5': CSQuantiles(LAST('MA5'), groups='sw1'), 
    'MA60': CSQuantiles(LAST('MA60'), groups='sw1'), 
    'MAWVAD': CSQuantiles(LAST('MAWVAD'), groups='sw1'), 
    'MFI': CSQuantiles(LAST('MFI'), groups='sw1'), 
    'MLEV': CSQuantiles(LAST('MLEV'), groups='sw1'), 
    'NetAssetGrowRate': CSQuantiles(LAST('NetAssetGrowRate'), groups='sw1'), 
    'NetProfitGrowRate': CSQuantiles(LAST('NetProfitGrowRate'), groups='sw1'), 
    'NetProfitRatio': CSQuantiles(LAST('NetProfitRatio'), groups='sw1'), 
    'NOCFToOperatingNI': CSQuantiles(LAST('NetProfitRatio'), groups='sw1'), 
    'NonCurrentAssetsRatio': CSQuantiles(LAST('NonCurrentAssetsRatio'), groups='sw1'), 
    'NPParentCompanyGrowRate': CSQuantiles(LAST('NPParentCompanyGrowRate'), groups='sw1'), 
    'NPToTOR': CSQuantiles(LAST('NPToTOR'), groups='sw1'), 
    'OperatingExpenseRate': CSQuantiles(LAST('OperatingExpenseRate'), groups='sw1'), 
    'OperatingProfitGrowRate': CSQuantiles(LAST('OperatingProfitGrowRate'), groups='sw1'), 
    'OperatingProfitRatio': CSQuantiles(LAST('OperatingProfitRatio'), groups='sw1'), 
    'OperatingProfitToTOR': CSQuantiles(LAST('OperatingProfitToTOR'), groups='sw1'), 
    'OperatingRevenueGrowRate': CSQuantiles(LAST('OperatingRevenueGrowRate'), groups='sw1'), 
    'OperCashGrowRate': CSQuantiles(LAST('OperCashGrowRate'), groups='sw1'), 
    'OperCashInToCurrentLiability': CSQuantiles(LAST('OperCashInToCurrentLiability'), groups='sw1'), 
    'PB': CSQuantiles(LAST('PB'), groups='sw1'), 
    'PCF': CSQuantiles(LAST('PCF'), groups='sw1'), 
    'PE': CSQuantiles(LAST('PE'), groups='sw1'), 
    'PS': CSQuantiles(LAST('PS'), groups='sw1'), 
    'PSY': CSQuantiles(LAST('PSY'), groups='sw1'), 
    'QuickRatio': CSQuantiles(LAST('QuickRatio'), groups='sw1'), 
    'REVS10': CSQuantiles(LAST('REVS10'), groups='sw1'), 
    'REVS20': CSQuantiles(LAST('REVS20'), groups='sw1'), 
    'REVS5': CSQuantiles(LAST('REVS5'), groups='sw1'), 
    'ROA': CSQuantiles(LAST('REVS5'), groups='sw1'), 
    'ROA5': CSQuantiles(LAST('ROA5'), groups='sw1'), 
    'ROE': CSQuantiles(LAST('ROE'), groups='sw1'), 
    'ROE5': CSQuantiles(LAST('ROE5'), groups='sw1'), 
    'RSI': CSQuantiles(LAST('RSI'), groups='sw1'), 
    'RSTR12': CSQuantiles(LAST('RSTR12'), groups='sw1'), 
    'RSTR24': CSQuantiles(LAST('RSTR24'), groups='sw1'), 
    'SalesCostRatio': CSQuantiles(LAST('SalesCostRatio'), groups='sw1'), 
    'SaleServiceCashToOR': CSQuantiles(LAST('SaleServiceCashToOR'), groups='sw1'), 
    'SUE': CSQuantiles(LAST('SUE'), groups='sw1'), 
    'TaxRatio': CSQuantiles(LAST('TaxRatio'), groups='sw1'), 
    'TOBT': CSQuantiles(LAST('TOBT'), groups='sw1'), 
    'TotalAssetGrowRate': CSQuantiles(LAST('TotalAssetGrowRate'), groups='sw1'), 
    'TotalAssetsTRate': CSQuantiles(LAST('TotalAssetsTRate'), groups='sw1'), 
    'TotalProfitCostRatio': CSQuantiles(LAST('TotalProfitCostRatio'), groups='sw1'), 
    'TotalProfitGrowRate': CSQuantiles(LAST('TotalProfitGrowRate'), groups='sw1'), 
    'VOL10': CSQuantiles(LAST('VOL10'), groups='sw1'), 
    'VOL120': CSQuantiles(LAST('VOL120'), groups='sw1'), 
    'VOL20': CSQuantiles(LAST('VOL20'), groups='sw1'), 
    'VOL240': CSQuantiles(LAST('VOL240'), groups='sw1'), 
    'VOL5': CSQuantiles(LAST('VOL5'), groups='sw1'), 
    'VOL60': CSQuantiles(LAST('VOL60'), groups='sw1'), 
    'WVAD': CSQuantiles(LAST('WVAD'), groups='sw1'), 
    'REC': CSQuantiles(LAST('REC'), groups='sw1'), 
    'DAREC': CSQuantiles(LAST('DAREC'), groups='sw1'), 
    'GREC': CSQuantiles(LAST('GREC'), groups='sw1'), 
    'FY12P': CSQuantiles(LAST('FY12P'), groups='sw1'), 
    'DAREV': CSQuantiles(LAST('DAREV'), groups='sw1'), 
    'GREV': CSQuantiles(LAST('GREV'), groups='sw1'), 
    'SFY12P': CSQuantiles(LAST('SFY12P'), groups='sw1'), 
    'DASREV': CSQuantiles(LAST('DASREV'), groups='sw1'), 
    'GSREV': CSQuantiles(LAST('GSREV'), groups='sw1'), 
    'FEARNG': CSQuantiles(LAST('FEARNG'), groups='sw1'), 
    'FSALESG': CSQuantiles(LAST('FSALESG'), groups='sw1'), 
    'TA2EV': CSQuantiles(LAST('TA2EV'), groups='sw1'), 
    'CFO2EV': CSQuantiles(LAST('CFO2EV'), groups='sw1'), 
    'ACCA': CSQuantiles(LAST('ACCA'), groups='sw1'), 
    'DEGM': CSQuantiles(LAST('DEGM'), groups='sw1'), 
    'SUOI': CSQuantiles(LAST('SUOI'), groups='sw1'), 
    'EARNMOM': CSQuantiles(LAST('EARNMOM'), groups='sw1'), 
    'FiftyTwoWeekHigh': CSQuantiles(LAST('FiftyTwoWeekHigh'), groups='sw1'), 
    'Volatility': CSQuantiles(LAST('Volatility'), groups='sw1'), 
    'Skewness': CSQuantiles(LAST('Skewness'), groups='sw1'), 
    'ILLIQUIDITY': CSQuantiles(LAST('ILLIQUIDITY'), groups='sw1'), 
    'BackwardADJ': CSQuantiles(LAST('BackwardADJ'), groups='sw1'), 
    'MACD': CSQuantiles(LAST('MACD'), groups='sw1'), 
    'ADTM': CSQuantiles(LAST('ADTM'), groups='sw1'), 
    'ATR14': CSQuantiles(LAST('ATR14'), groups='sw1'), 
    'ATR6': CSQuantiles(LAST('ATR6'), groups='sw1'), 
    'BIAS10': CSQuantiles(LAST('BIAS10'), groups='sw1'), 
    'BIAS20': CSQuantiles(LAST('BIAS20'), groups='sw1'), 
    'BIAS5': CSQuantiles(LAST('BIAS5'), groups='sw1'), 
    'BIAS60': CSQuantiles(LAST('BIAS60'), groups='sw1'), 
    'BollDown': CSQuantiles(LAST('BollDown'), groups='sw1'), 
    'BollUp': CSQuantiles(LAST('BollUp'), groups='sw1'), 
    'CCI10': CSQuantiles(LAST('CCI10'), groups='sw1'), 
    'CCI20': CSQuantiles(LAST('CCI20'), groups='sw1'), 
    'CCI5': CSQuantiles(LAST('CCI5'), groups='sw1'), 
    'CCI88': CSQuantiles(LAST('CCI88'), groups='sw1'), 
    'KDJ_K': CSQuantiles(LAST('KDJ_K'), groups='sw1'), 
    'KDJ_D': CSQuantiles(LAST('KDJ_D'), groups='sw1'), 
    'KDJ_J': CSQuantiles(LAST('KDJ_J'), groups='sw1'), 
    'ROC6': CSQuantiles(LAST('ROC6'), groups='sw1'), 
    'ROC20': CSQuantiles(LAST('ROC20'), groups='sw1'), 
    'SBM': CSQuantiles(LAST('SBM'), groups='sw1'), 
    'STM': CSQuantiles(LAST('STM'), groups='sw1'), 
    'UpRVI': CSQuantiles(LAST('UpRVI'), groups='sw1'), 
    'DownRVI': CSQuantiles(LAST('DownRVI'), groups='sw1'), 
    'RVI': CSQuantiles(LAST('RVI'), groups='sw1'), 
    'SRMI': CSQuantiles(LAST('SRMI'), groups='sw1'), 
    'ChandeSD': CSQuantiles(LAST('ChandeSD'), groups='sw1'), 
    'ChandeSU': CSQuantiles(LAST('ChandeSU'), groups='sw1'), 
    'CMO': CSQuantiles(LAST('CMO'), groups='sw1'), 
    'DBCD': CSQuantiles(LAST('DBCD'), groups='sw1'), 
    'ARC': CSQuantiles(LAST('ARC'), groups='sw1'), 
    'OBV': CSQuantiles(LAST('OBV'), groups='sw1'), 
    'OBV6': CSQuantiles(LAST('OBV6'), groups='sw1'), 
    'OBV20': CSQuantiles(LAST('OBV20'), groups='sw1'), 
    'TVMA20': CSQuantiles(LAST('TVMA20'), groups='sw1'), 
    'TVMA6': CSQuantiles(LAST('TVMA6'), groups='sw1'), 
    'TVSTD20': CSQuantiles(LAST('TVSTD20'), groups='sw1'), 
    'TVSTD6': CSQuantiles(LAST('TVSTD6'), groups='sw1'), 
    'VDEA': CSQuantiles(LAST('VDEA'), groups='sw1'), 
    'VDIFF': CSQuantiles(LAST('VDIFF'), groups='sw1'), 
    'VEMA10': CSQuantiles(LAST('VEMA10'), groups='sw1'), 
    'VEMA12': CSQuantiles(LAST('VEMA12'), groups='sw1'), 
    'VEMA26': CSQuantiles(LAST('VEMA26'), groups='sw1'), 
    'VEMA5': CSQuantiles(LAST('VEMA5'), groups='sw1'), 
    'VMACD': CSQuantiles(LAST('VMACD'), groups='sw1'), 
    'VR': CSQuantiles(LAST('VR'), groups='sw1'), 
    'VROC12': CSQuantiles(LAST('VROC12'), groups='sw1'), 
    'VROC6': CSQuantiles(LAST('VROC6'), groups='sw1'), 
    'VSTD10': CSQuantiles(LAST('VSTD10'), groups='sw1'), 
    'VSTD20': CSQuantiles(LAST('VSTD20'), groups='sw1'), 
    'KlingerOscillator': CSQuantiles(LAST('KlingerOscillator'), groups='sw1'), 
    'MoneyFlow20': CSQuantiles(LAST('MoneyFlow20'), groups='sw1'), 
    'AD': CSQuantiles(LAST('AD'), groups='sw1'), 
    'AD20': CSQuantiles(LAST('AD20'), groups='sw1'), 
    'AD6': CSQuantiles(LAST('AD6'), groups='sw1'), 
    'CoppockCurve': CSQuantiles(LAST('CoppockCurve'), groups='sw1'), 
    'ASI': CSQuantiles(LAST('ASI'), groups='sw1'), 
    'ChaikinOscillator': CSQuantiles(LAST('ChaikinOscillator'), groups='sw1'), 
    'ChaikinVolatility': CSQuantiles(LAST('ChaikinVolatility'), groups='sw1'), 
    'EMV14': CSQuantiles(LAST('EMV14'), groups='sw1'), 
    'EMV6': CSQuantiles(LAST('EMV6'), groups='sw1'), 
    'plusDI': CSQuantiles(LAST('plusDI'), groups='sw1'), 
    'minusDI': CSQuantiles(LAST('minusDI'), groups='sw1'), 
    'ADX': CSQuantiles(LAST('ADX'), groups='sw1'), 
    'ADXR': CSQuantiles(LAST('ADXR'), groups='sw1'), 
    'Aroon': CSQuantiles(LAST('Aroon'), groups='sw1'), 
    'AroonDown': CSQuantiles(LAST('AroonDown'), groups='sw1'), 
    'AroonUp': CSQuantiles(LAST('AroonUp'), groups='sw1'), 
    'DEA': CSQuantiles(LAST('DEA'), groups='sw1'), 
    'DIFF': CSQuantiles(LAST('DIFF'), groups='sw1'), 
    'DDI': CSQuantiles(LAST('DDI'), groups='sw1'), 
    'DIZ': CSQuantiles(LAST('DIZ'), groups='sw1'), 
    'DIF': CSQuantiles(LAST('DIF'), groups='sw1'), 
    'MTM': CSQuantiles(LAST('MTM'), groups='sw1'), 
    'MTMMA': CSQuantiles(LAST('MTMMA'), groups='sw1'), 
    'PVT': CSQuantiles(LAST('PVT'), groups='sw1'), 
    'PVT6': CSQuantiles(LAST('PVT6'), groups='sw1'), 
    'PVT12': CSQuantiles(LAST('PVT12'), groups='sw1'), 
    'TRIX5': CSQuantiles(LAST('TRIX5'), groups='sw1'), 
    'TRIX10': CSQuantiles(LAST('TRIX10'), groups='sw1'), 
    'UOS': CSQuantiles(LAST('UOS'), groups='sw1'), 
    'MA10RegressCoeff12': CSQuantiles(LAST('MA10RegressCoeff12'), groups='sw1'), 
    'MA10RegressCoeff6': CSQuantiles(LAST('MA10RegressCoeff6'), groups='sw1'), 
    'PLRC6': CSQuantiles(LAST('PLRC6'), groups='sw1'), 
    'PLRC12': CSQuantiles(LAST('PLRC12'), groups='sw1'), 
    'SwingIndex': CSQuantiles(LAST('SwingIndex'), groups='sw1'), 
    'Ulcer10': CSQuantiles(LAST('Ulcer10'), groups='sw1'), 
    'Ulcer5': CSQuantiles(LAST('Ulcer5'), groups='sw1'), 
    'Hurst': CSQuantiles(LAST('Hurst'), groups='sw1'), 
    'ACD6': CSQuantiles(LAST('ACD6'), groups='sw1'), 
    'ACD20': CSQuantiles(LAST('ACD20'), groups='sw1'), 
    'EMA12': CSQuantiles(LAST('EMA12'), groups='sw1'), 
    'EMA26': CSQuantiles(LAST('EMA26'), groups='sw1'), 
    'APBMA': CSQuantiles(LAST('APBMA'), groups='sw1'), 
    'BBI': CSQuantiles(LAST('APBMA'), groups='sw1'), 
    'BBIC': CSQuantiles(LAST('BBIC'), groups='sw1'), 
    'TEMA10': CSQuantiles(LAST('TEMA10'), groups='sw1'), 
    'TEMA5': CSQuantiles(LAST('TEMA5'), groups='sw1'), 
    'MA10Close': CSQuantiles(LAST('MA10Close'), groups='sw1'), 
    'AR': CSQuantiles(LAST('AR'), groups='sw1'), 
    'BR': CSQuantiles(LAST('BR'), groups='sw1'), 
    'ARBR': CSQuantiles(LAST('ARBR'), groups='sw1'), 
    'CR20': CSQuantiles(LAST('CR20'), groups='sw1'), 
    'MassIndex': CSQuantiles(LAST('MassIndex'), groups='sw1'), 
    'BearPower': CSQuantiles(LAST('BearPower'), groups='sw1'), 
    'BullPower': CSQuantiles(LAST('BullPower'), groups='sw1'), 
    'Elder': CSQuantiles(LAST('Elder'), groups='sw1'), 
    'NVI': CSQuantiles(LAST('NVI'), groups='sw1'), 
    'PVI': CSQuantiles(LAST('PVI'), groups='sw1'), 
    'RC12': CSQuantiles(LAST('RC12'), groups='sw1'), 
    'RC24': CSQuantiles(LAST('RC24'), groups='sw1'), 
    'JDQS20': CSQuantiles(LAST('JDQS20'), groups='sw1'), 
    'Variance20': CSQuantiles(LAST('Variance20'), groups='sw1'), 
    'Variance60': CSQuantiles(LAST('Variance60'), groups='sw1'), 
    'Variance120': CSQuantiles(LAST('Variance120'), groups='sw1'), 
    'Kurtosis20': CSQuantiles(LAST('Kurtosis20'), groups='sw1'), 
    'Kurtosis60': CSQuantiles(LAST('Kurtosis60'), groups='sw1'), 
    'Kurtosis120': CSQuantiles(LAST('Kurtosis120'), groups='sw1'), 
    'Alpha20': CSQuantiles(LAST('Alpha20'), groups='sw1'), 
    'Alpha60': CSQuantiles(LAST('Alpha60'), groups='sw1'), 
    'Alpha120': CSQuantiles(LAST('Alpha120'), groups='sw1'), 
    'Beta20': CSQuantiles(LAST('Beta20'), groups='sw1'), 
    'Beta60': CSQuantiles(LAST('Beta60'), groups='sw1'), 
    'Beta120': CSQuantiles(LAST('Beta60'), groups='sw1'), 
    'SharpeRatio20': CSQuantiles(LAST('SharpeRatio20'), groups='sw1'), 
    'SharpeRatio60': CSQuantiles(LAST('SharpeRatio60'), groups='sw1'), 
    'SharpeRatio120': CSQuantiles(LAST('SharpeRatio120'), groups='sw1'), 
    'TreynorRatio20': CSQuantiles(LAST('TreynorRatio20'), groups='sw1'), 
    'TreynorRatio60': CSQuantiles(LAST('TreynorRatio60'), groups='sw1'), 
    'TreynorRatio120': CSQuantiles(LAST('TreynorRatio120'), groups='sw1'), 
    'InformationRatio20': CSQuantiles(LAST('InformationRatio20'), groups='sw1'), 
    'InformationRatio60': CSQuantiles(LAST('InformationRatio60'), groups='sw1'), 
    'InformationRatio120': CSQuantiles(LAST('InformationRatio120'), groups='sw1'), 
    'GainVariance20': CSQuantiles(LAST('GainVariance20'), groups='sw1'), 
    'GainVariance60': CSQuantiles(LAST('GainVariance60'), groups='sw1'), 
    'GainVariance120': CSQuantiles(LAST('GainVariance120'), groups='sw1'), 
    'LossVariance20': CSQuantiles(LAST('LossVariance20'), groups='sw1'), 
    'LossVariance60': CSQuantiles(LAST('LossVariance60'), groups='sw1'), 
    'LossVariance120': CSQuantiles(LAST('LossVariance120'), groups='sw1'), 
    'GainLossVarianceRatio20': CSQuantiles(LAST('GainLossVarianceRatio20'), groups='sw1'), 
    'GainLossVarianceRatio60': CSQuantiles(LAST('GainLossVarianceRatio60'), groups='sw1'), 
    'GainLossVarianceRatio120': CSQuantiles(LAST('GainLossVarianceRatio120'), groups='sw1'), 
    'RealizedVolatility': CSQuantiles(LAST('RealizedVolatility'), groups='sw1'), 
    'REVS60': CSQuantiles(LAST('REVS60'), groups='sw1'), 
    'REVS120': CSQuantiles(LAST('REVS120'), groups='sw1'), 
    'REVS250': CSQuantiles(LAST('REVS250'), groups='sw1'), 
    'REVS750': CSQuantiles(LAST('REVS750'), groups='sw1'), 
    'REVS5m20': CSQuantiles(LAST('REVS5m20'), groups='sw1'), 
    'REVS5m60': CSQuantiles(LAST('REVS5m60'), groups='sw1'), 
    'REVS5Indu1': CSQuantiles(LAST('REVS5Indu1'), groups='sw1'), 
    'REVS20Indu1': CSQuantiles(LAST('REVS20Indu1'), groups='sw1'), 
    'Volumn1M': CSQuantiles(LAST('Volumn1M'), groups='sw1'), 
    'Volumn3M': CSQuantiles(LAST('Volumn3M'), groups='sw1'), 
    'Price1M': CSQuantiles(LAST('Price1M'), groups='sw1'), 
    'Price3M': CSQuantiles(LAST('Price3M'), groups='sw1'), 
    'Price1Y': CSQuantiles(LAST('Price1Y'), groups='sw1'), 
    'Rank1M': CSQuantiles(LAST('Rank1M'), groups='sw1'), 
    'CashDividendCover': CSQuantiles(LAST('CashDividendCover'), groups='sw1'), 
    'DividendCover': CSQuantiles(LAST('DividendCover'), groups='sw1'), 
    'DividendPaidRatio': CSQuantiles(LAST('DividendPaidRatio'), groups='sw1'), 
    'RetainedEarningRatio': CSQuantiles(LAST('RetainedEarningRatio'), groups='sw1'), 
    'CashEquivalentPS': CSQuantiles(LAST('CashEquivalentPS'), groups='sw1'), 
    'DividendPS': CSQuantiles(LAST('DividendPS'), groups='sw1'), 
    'EPSTTM': CSQuantiles(LAST('EPSTTM'), groups='sw1'), 
    'NetAssetPS': CSQuantiles(LAST('NetAssetPS'), groups='sw1'), 
    'TORPS': CSQuantiles(LAST('TORPS'), groups='sw1'), 
    'TORPSLatest': CSQuantiles(LAST('TORPSLatest'), groups='sw1'), 
    'OperatingRevenuePS': CSQuantiles(LAST('OperatingRevenuePS'), groups='sw1'), 
    'OperatingRevenuePSLatest': CSQuantiles(LAST('OperatingRevenuePSLatest'), groups='sw1'), 
    'OperatingProfitPS': CSQuantiles(LAST('OperatingProfitPS'), groups='sw1'), 
    'OperatingProfitPSLatest': CSQuantiles(LAST('OperatingProfitPSLatest'), groups='sw1'), 
    'CapitalSurplusFundPS': CSQuantiles(LAST('CapitalSurplusFundPS'), groups='sw1'), 
    'SurplusReserveFundPS': CSQuantiles(LAST('SurplusReserveFundPS'), groups='sw1'), 
    'UndividedProfitPS': CSQuantiles(LAST('UndividedProfitPS'), groups='sw1'), 
    'RetainedEarningsPS': CSQuantiles(LAST('RetainedEarningsPS'), groups='sw1'), 
    'OperCashFlowPS': CSQuantiles(LAST('OperCashFlowPS'), groups='sw1'), 
    'CashFlowPS': CSQuantiles(LAST('CashFlowPS'), groups='sw1'), 
    'NetNonOIToTP': CSQuantiles(LAST('NetNonOIToTP'), groups='sw1'), 
    'NetNonOIToTPLatest': CSQuantiles(LAST('NetNonOIToTPLatest'), groups='sw1'), 
    'PeriodCostsRate': CSQuantiles(LAST('PeriodCostsRate'), groups='sw1'), 
    'InterestCover': CSQuantiles(LAST('InterestCover'), groups='sw1'), 
    'NetProfitGrowRate3Y': CSQuantiles(LAST('NetProfitGrowRate3Y'), groups='sw1'), 
    'NetProfitGrowRate5Y': CSQuantiles(LAST('NetProfitGrowRate5Y'), groups='sw1'), 
    'OperatingRevenueGrowRate3Y': CSQuantiles(LAST('OperatingRevenueGrowRate3Y'), groups='sw1'), 
    'OperatingRevenueGrowRate5Y': CSQuantiles(LAST('OperatingRevenueGrowRate5Y'), groups='sw1'), 
    'NetCashFlowGrowRate': CSQuantiles(LAST('NetCashFlowGrowRate'), groups='sw1'), 
    'NetProfitCashCover': CSQuantiles(LAST('NetProfitCashCover'), groups='sw1'), 
    'OperCashInToAsset': CSQuantiles(LAST('OperCashInToAsset'), groups='sw1'), 
    'CashConversionCycle': CSQuantiles(LAST('CashConversionCycle'), groups='sw1'), 
    'OperatingCycle': CSQuantiles(LAST('OperatingCycle'), groups='sw1'), 
    'PEG3Y': CSQuantiles(LAST('PEG3Y'), groups='sw1'), 
    'PEG5Y': CSQuantiles(LAST('PEG5Y'), groups='sw1'), 
    'PEIndu': CSQuantiles(LAST('PEIndu'), groups='sw1'), 
    'PBIndu': CSQuantiles(LAST('PBIndu'), groups='sw1'), 
    'PSIndu': CSQuantiles(LAST('PSIndu'), groups='sw1'), 
    'PCFIndu': CSQuantiles(LAST('PCFIndu'), groups='sw1'), 
    'PEHist20': CSQuantiles(LAST('PEHist20'), groups='sw1'), 
    'PEHist60': CSQuantiles(LAST('PEHist60'), groups='sw1'), 
    'PEHist120': CSQuantiles(LAST('PEHist120'), groups='sw1'), 
    'PEHist250': CSQuantiles(LAST('PEHist250'), groups='sw1'), 
    'StaticPE': CSQuantiles(LAST('StaticPE'), groups='sw1'), 
    'ForwardPE': CSQuantiles(LAST('ForwardPE'), groups='sw1'), 
    'EnterpriseFCFPS': CSQuantiles(LAST('EnterpriseFCFPS'), groups='sw1'), 
    'ShareholderFCFPS': CSQuantiles(LAST('ShareholderFCFPS'), groups='sw1'), 
    'ROEDiluted': CSQuantiles(LAST('ROEDiluted'), groups='sw1'), 
    'ROEAvg': CSQuantiles(LAST('ROEAvg'), groups='sw1'), 
    'ROEWeighted': CSQuantiles(LAST('ROEWeighted'), groups='sw1'), 
    'ROECut': CSQuantiles(LAST('ROECut'), groups='sw1'), 
    'ROECutWeighted': CSQuantiles(LAST('ROECutWeighted'), groups='sw1'), 
    'ROIC': CSQuantiles(LAST('ROIC'), groups='sw1'), 
    'ROAEBIT': CSQuantiles(LAST('ROAEBIT'), groups='sw1'), 
    'ROAEBITTTM': CSQuantiles(LAST('ROAEBITTTM'), groups='sw1'), 
    'OperatingNIToTP': CSQuantiles(LAST('OperatingNIToTP'), groups='sw1'), 
    'OperatingNIToTPLatest': CSQuantiles(LAST('OperatingNIToTPLatest'), groups='sw1'), 
    'InvestRAssociatesToTP': CSQuantiles(LAST('InvestRAssociatesToTP'), groups='sw1'), 
    'InvestRAssociatesToTPLatest': CSQuantiles(LAST('InvestRAssociatesToTPLatest'), groups='sw1'), 
    'NPCutToNP': CSQuantiles(LAST('NPCutToNP'), groups='sw1'), 
    'SuperQuickRatio': CSQuantiles(LAST('SuperQuickRatio'), groups='sw1'), 
    'TSEPToInterestBearDebt': CSQuantiles(LAST('TSEPToInterestBearDebt'), groups='sw1'), 
    'DebtTangibleEquityRatio': CSQuantiles(LAST('DebtTangibleEquityRatio'), groups='sw1'), 
    'TangibleAToInteBearDebt': CSQuantiles(LAST('TangibleAToInteBearDebt'), groups='sw1'), 
    'TangibleAToNetDebt': CSQuantiles(LAST('TangibleAToNetDebt'), groups='sw1'), 
    'NOCFToTLiability': CSQuantiles(LAST('NOCFToTLiability'), groups='sw1'), 
    'NOCFToInterestBearDebt': CSQuantiles(LAST('NOCFToInterestBearDebt'), groups='sw1'), 
    'NOCFToNetDebt': CSQuantiles(LAST('NOCFToNetDebt'), groups='sw1'), 
    'TSEPToTotalCapital': CSQuantiles(LAST('TSEPToTotalCapital'), groups='sw1'), 
    'InteBearDebtToTotalCapital': CSQuantiles(LAST('InteBearDebtToTotalCapital'), groups='sw1'), 
    'NPParentCompanyCutYOY': CSQuantiles(LAST('NPParentCompanyCutYOY'), groups='sw1'), 
    'SalesServiceCashToORLatest': CSQuantiles(LAST('SalesServiceCashToORLatest'), groups='sw1'), 
    'CashRateOfSalesLatest': CSQuantiles(LAST('CashRateOfSalesLatest'), groups='sw1'), 
    'NOCFToOperatingNILatest': CSQuantiles(LAST('NOCFToOperatingNILatest'), groups='sw1'), 
    'TotalAssets': CSQuantiles(LAST('TotalAssets'), groups='sw1'), 
    'MktValue': CSQuantiles(LAST('MktValue'), groups='sw1'), 
    'NegMktValue': CSQuantiles(LAST('NegMktValue'), groups='sw1'), 
    'TEAP': CSQuantiles(LAST('TEAP'), groups='sw1'), 
    'NIAP': CSQuantiles(LAST('NIAP'), groups='sw1'), 
    'TotalFixedAssets': CSQuantiles(LAST('TotalFixedAssets'), groups='sw1'), 
    'IntFreeCL': CSQuantiles(LAST('IntFreeCL'), groups='sw1'), 
    'IntFreeNCL': CSQuantiles(LAST('IntFreeNCL'), groups='sw1'), 
    'IntCL': CSQuantiles(LAST('IntCL'), groups='sw1'), 
    'IntDebt': CSQuantiles(LAST('IntDebt'), groups='sw1'), 
    'NetDebt': CSQuantiles(LAST('NetDebt'), groups='sw1'), 
    'NetTangibleAssets': CSQuantiles(LAST('NetTangibleAssets'), groups='sw1'), 
    'WorkingCapital': CSQuantiles(LAST('WorkingCapital'), groups='sw1'), 
    'NetWorkingCapital': CSQuantiles(LAST('WorkingCapital'), groups='sw1'), 
    'TotalPaidinCapital': CSQuantiles(LAST('TotalPaidinCapital'), groups='sw1'), 
    'RetainedEarnings': CSQuantiles(LAST('RetainedEarnings'), groups='sw1'), 
    'OperateNetIncome': CSQuantiles(LAST('OperateNetIncome'), groups='sw1'), 
    'ValueChgProfit': CSQuantiles(LAST('ValueChgProfit'), groups='sw1'), 
    'NetIntExpense': CSQuantiles(LAST('NetIntExpense'), groups='sw1'), 
    'EBIT': CSQuantiles(LAST('EBIT'), groups='sw1'), 
    'EBITDA': CSQuantiles(LAST('EBITDA'), groups='sw1'), 
    'EBIAT': CSQuantiles(LAST('EBIAT'), groups='sw1'), 
    'NRProfitLoss': CSQuantiles(LAST('NRProfitLoss'), groups='sw1'), 
    'NIAPCut': CSQuantiles(LAST('NIAPCut'), groups='sw1'), 
    'FCFF': CSQuantiles(LAST('FCFF'), groups='sw1'), 
    'FCFE': CSQuantiles(LAST('FCFE'), groups='sw1'), 
    'DA': CSQuantiles(LAST('DA'), groups='sw1'), 
    'TRevenueTTM': CSQuantiles(LAST('TRevenueTTM'), groups='sw1'), 
    'TCostTTM': CSQuantiles(LAST('TCostTTM'), groups='sw1'), 
    'RevenueTTM': CSQuantiles(LAST('RevenueTTM'), groups='sw1'), 
    'CostTTM': CSQuantiles(LAST('CostTTM'), groups='sw1'), 
    'GrossProfitTTM': CSQuantiles(LAST('GrossProfitTTM'), groups='sw1'), 
    'SalesExpenseTTM': CSQuantiles(LAST('SalesExpenseTTM'), groups='sw1'), 
    'AdminExpenseTTM': CSQuantiles(LAST('AdminExpenseTTM'), groups='sw1'), 
    'FinanExpenseTTM': CSQuantiles(LAST('FinanExpenseTTM'), groups='sw1'), 
    'AssetImpairLossTTM': CSQuantiles(LAST('AssetImpairLossTTM'), groups='sw1'), 
    'NPFromOperatingTTM': CSQuantiles(LAST('NPFromOperatingTTM'), groups='sw1'), 
    'NPFromValueChgTTM': CSQuantiles(LAST('NPFromValueChgTTM'), groups='sw1'), 
    'OperateProfitTTM': CSQuantiles(LAST('OperateProfitTTM'), groups='sw1'), 
    'NonOperatingNPTTM': CSQuantiles(LAST('NonOperatingNPTTM'), groups='sw1'), 
    'TProfitTTM': CSQuantiles(LAST('TProfitTTM'), groups='sw1'), 
    'NetProfitTTM': CSQuantiles(LAST('NetProfitTTM'), groups='sw1'), 
    'NetProfitAPTTM': CSQuantiles(LAST('NetProfitAPTTM'), groups='sw1'), 
    'SaleServiceRenderCashTTM': CSQuantiles(LAST('SaleServiceRenderCashTTM'), groups='sw1'), 
    'NetOperateCFTTM': CSQuantiles(LAST('NetOperateCFTTM'), groups='sw1'), 
    'NetInvestCFTTM': CSQuantiles(LAST('NetInvestCFTTM'), groups='sw1'), 
    'NetFinanceCFTTM': CSQuantiles(LAST('NetFinanceCFTTM'), groups='sw1'), 
    'GrossProfit': CSQuantiles(LAST('GrossProfit'), groups='sw1'), 
    'Beta252': CSQuantiles(LAST('Beta252'), groups='sw1'), 
    'RSTR504': CSQuantiles(LAST('RSTR504'), groups='sw1'), 
    'EPIBS': CSQuantiles(LAST('EPIBS'), groups='sw1'), 
    'CETOP': CSQuantiles(LAST('CETOP'), groups='sw1'), 
    'DASTD': CSQuantiles(LAST('DASTD'), groups='sw1'), 
    'CmraCNE5': CSQuantiles(LAST('CmraCNE5'), groups='sw1'), 
    'HsigmaCNE5': CSQuantiles(LAST('HsigmaCNE5'), groups='sw1'), 
    'SGRO': CSQuantiles(LAST('SGRO'), groups='sw1'), 
    'EgibsLong': CSQuantiles(LAST('EgibsLong'), groups='sw1'), 
    'STOM': CSQuantiles(LAST('STOM'), groups='sw1'), 
    'STOQ': CSQuantiles(LAST('STOQ'), groups='sw1'), 
    'STOA': CSQuantiles(LAST('STOA'), groups='sw1'), 
    'NLSIZE': CSQuantiles(LAST('NLSIZE'), groups='sw1')}

# %%
# %%time
factor_data_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates)
# factor_data_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates, used_factor_tables=[Alpha191])
# Out:
# CPU times: user 2min 36s, sys: 5.15 s, total: 2min 41s
# Wall time: 2min 58s

# %%
# %%time
industry = engine.fetch_industry_range(universe, dates=ref_dates)
factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code']).fillna(0.)
risk_total = engine.fetch_risk_model_range(universe, dates=ref_dates)[1]
len(factor_data)
# Out:
# CPU times: user 1.91 s, sys: 91 ms, total: 2 s
# Wall time: 3.12 s

# %%
# %%time
return_data = engine.fetch_dx_return_range(universe, dates=ref_dates, horizon=horizon, offset=0,benchmark = benchmark_code)
len(return_data)
# Out:
# CPU times: user 535 ms, sys: 26 ms, total: 561 ms
# Wall time: 2.29 s

# %%
# %%time
benchmark_total = engine.fetch_benchmark_range(dates=ref_dates, benchmark=benchmark_code)
industry_total = engine.fetch_industry_matrix_range(universe, dates=ref_dates, category=industry_name, level=industry_level)
# Out:
# CPU times: user 494 ms, sys: 28.6 ms, total: 522 ms
# Wall time: 914 ms

# %%
# Constraintes settings

industry_names = industry_list(industry_name, industry_level)
constraint_risk = ['EARNYILD', 'LIQUIDTY', 'GROWTH', 'SIZE', 'BETA', 'MOMENTUM'] + industry_names
total_risk_names = constraint_risk + ['benchmark', 'total']

b_type = []
l_val = []
u_val = []

for name in total_risk_names:
    if name == 'benchmark':
        b_type.append(BoundaryType.RELATIVE)
        l_val.append(0.0)
        u_val.append(1.0)
    elif name == 'total':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(.0)
        u_val.append(.0)
    else:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.005)
        u_val.append(1.005)

bounds = create_box_bounds(total_risk_names, b_type, l_val, u_val)

# %%
train_data = pd.merge(factor_data, return_data, on=['trade_date', 'code']).dropna()
# train_data.head()

# %%
features = ['AccountsPayablesTDays', 'AccountsPayablesTRate', 'AdminiExpenseRate', 'ARTDays', 
            'ARTRate', 'ASSI', 'BLEV', 'BondsPayableToAsset', 'CashRateOfSales', 'CashToCurrentLiability', 
            'CMRA', 'CTOP', 'CTP5', 'CurrentAssetsRatio', 'CurrentAssetsTRate', 'CurrentRatio', 'DAVOL10', 
            'DAVOL20', 'DAVOL5', 'DDNBT', 'DDNCR', 'DDNSR', 'DebtEquityRatio', 'DebtsAssetRatio', 'DHILO', 
            'DilutedEPS', 'DVRAT', 'EBITToTOR', 'EGRO', 'EMA10', 'EMA120', 'EMA20', 'EMA5', 'EMA60', 'EPS',
            'EquityFixedAssetRatio', 'EquityToAsset', 'EquityTRate', 'ETOP', 'ETP5', 'FinancialExpenseRate', 
            'FinancingCashGrowRate', 'FixAssetRatio', 'FixedAssetsTRate', 'GrossIncomeRatio', 'HBETA', 
            'HSIGMA', 'IntangibleAssetRatio', 'InventoryTDays', 'InventoryTRate', 'InvestCashGrowRate', 
            'LCAP', 'LFLO', 'LongDebtToAsset', 'LongDebtToWorkingCapital', 'LongTermDebtToAsset', 
            'MA10', 'MA120', 'MA20', 'MA5', 'MA60', 'MAWVAD', 'MFI', 'MLEV', 'NetAssetGrowRate', 
            'NetProfitGrowRate', 'NetProfitRatio', 'NOCFToOperatingNI', 'NonCurrentAssetsRatio', 
            'NPParentCompanyGrowRate', 'NPToTOR', 'OperatingExpenseRate', 'OperatingProfitGrowRate', 
            'OperatingProfitRatio', 'OperatingProfitToTOR', 'OperatingRevenueGrowRate', 'OperCashGrowRate',
            'OperCashInToCurrentLiability', 'PB','PCF', 'PE','PS','PSY', 'QuickRatio', 'REVS10', 
            'REVS20', 'REVS5', 'ROA','ROA5', 'ROE', 'ROE5', 'RSI', 'RSTR12', 'RSTR24', 'SalesCostRatio', 
            'SaleServiceCashToOR' , 'SUE', 'TaxRatio', 'TOBT', 'TotalAssetGrowRate', 'TotalAssetsTRate', 
            'TotalProfitCostRatio', 'TotalProfitGrowRate', 'VOL10', 'VOL120', 'VOL20', 'VOL240', 'VOL5', 
            'VOL60', 'WVAD', 'REC', 'DAREC', 'GREC', 'FY12P', 'DAREV', 'GREV', 'SFY12P', 'DASREV', 'GSREV', 
            'FEARNG', 'FSALESG', 'TA2EV', 'CFO2EV', 'ACCA', 'DEGM', 'SUOI', 'EARNMOM', 'FiftyTwoWeekHigh', 
            'Volatility', 'Skewness', 'ILLIQUIDITY', 'BackwardADJ', 'MACD', 'ADTM', 'ATR14', 'ATR6', 'BIAS10', 
            'BIAS20', 'BIAS5', 'BIAS60', 'BollDown', 'BollUp', 'CCI10', 'CCI20', 'CCI5', 'CCI88', 'KDJ_K', 'KDJ_D', 
            'KDJ_J', 'ROC6', 'ROC20', 'SBM', 'STM', 'UpRVI', 'DownRVI', 'RVI', 'SRMI', 'ChandeSD', 'ChandeSU', 
            'CMO', 'DBCD', 'ARC', 'OBV', 'OBV6', 'OBV20', 'TVMA20', 'TVMA6', 'TVSTD20', 'TVSTD6', 'VDEA', 'VDIFF', 
            'VEMA10', 'VEMA12', 'VEMA26', 'VEMA5', 'VMACD', 'VR', 'VROC12', 'VROC6', 'VSTD10', 'VSTD20', 'KlingerOscillator' , 
            'MoneyFlow20', 'AD', 'AD20', 'AD6','CoppockCurve','ASI', 'ChaikinOscillator', 'ChaikinVolatility', 
            'EMV14', 'EMV6', 'plusDI', 'minusDI', 'ADX', 'ADXR', 'Aroon', 'AroonDown', 'AroonUp', 'DEA', 'DIFF', 'DDI', 'DIZ', 
            'DIF', 'MTM', 'MTMMA', 'PVT', 'PVT6', 'PVT12', 'TRIX5', 'TRIX10', 'UOS', 'MA10RegressCoeff12', 'MA10RegressCoeff6', 
            'PLRC6', 'PLRC12', 'SwingIndex', 'Ulcer10', 'Ulcer5', 'Hurst', 'ACD6', 'ACD20', 'EMA12', 'EMA26', 'APBMA', 
            'BBI', 'BBIC', 'TEMA10', 'TEMA5', 'MA10Close', 'AR', 'BR','ARBR', 'CR20', 'MassIndex', 'BearPower', 'BullPower', 
            'Elder', 'NVI', 'PVI', 'RC12', 'RC24', 'JDQS20', 'Variance20', 'Variance60', 'Variance120', 'Kurtosis20', 
            'Kurtosis60', 'Kurtosis120', 'Alpha20', 'Alpha60', 'Alpha120', 'Beta20', 'Beta60', 'Beta120', 'SharpeRatio20', 
            'SharpeRatio60', 'SharpeRatio120', 'TreynorRatio20', 'TreynorRatio60', 'TreynorRatio120', 'InformationRatio20', 
            'InformationRatio60', 'InformationRatio120', 'GainVariance20', 'GainVariance60', 'GainVariance120', 'LossVariance20', 
            'LossVariance60', 'LossVariance120', 'GainLossVarianceRatio20', 'GainLossVarianceRatio60', 'GainLossVarianceRatio120', 
            'RealizedVolatility', 'REVS60', 'REVS120', 'REVS250', 'REVS750', 'REVS5m20', 'REVS5m60', 'REVS5Indu1', 'REVS20Indu1', 
            'Volumn1M', 'Volumn3M', 'Price1M', 'Price3M', 'Price1Y', 'Rank1M', 'CashDividendCover', 'DividendCover', 
            'DividendPaidRatio', 'RetainedEarningRatio', 'CashEquivalentPS', 'DividendPS', 'EPSTTM', 'NetAssetPS', 'TORPS', 
            'TORPSLatest', 'OperatingRevenuePS', 'OperatingRevenuePSLatest', 'OperatingProfitPS', 'OperatingProfitPSLatest', 
            'CapitalSurplusFundPS', 'SurplusReserveFundPS','UndividedProfitPS', 'RetainedEarningsPS', 'OperCashFlowPS', 
            'CashFlowPS', 'NetNonOIToTP', 'NetNonOIToTPLatest', 'PeriodCostsRate', 'InterestCover', 'NetProfitGrowRate3Y', 
            'NetProfitGrowRate5Y', 'OperatingRevenueGrowRate3Y', 'OperatingRevenueGrowRate5Y', 'NetCashFlowGrowRate', 
            'NetProfitCashCover', 'OperCashInToAsset', 'CashConversionCycle', 'OperatingCycle', 'PEG3Y', 'PEG5Y', 'PEIndu', 
            'PBIndu', 'PSIndu', 'PCFIndu', 'PEHist20', 'PEHist60', 'PEHist120', 'PEHist250', 'StaticPE', 'ForwardPE', 
            'EnterpriseFCFPS', 'ShareholderFCFPS', 'ROEDiluted', 'ROEAvg', 'ROEWeighted', 'ROECut', 'ROECutWeighted', 
            'ROIC', 'ROAEBIT', 'ROAEBITTTM', 'OperatingNIToTP', 'OperatingNIToTPLatest', 'InvestRAssociatesToTP', 'InvestRAssociatesToTPLatest', 
            'NPCutToNP', 'SuperQuickRatio', 'TSEPToInterestBearDebt', 'DebtTangibleEquityRatio', 'TangibleAToInteBearDebt', 
            'TangibleAToNetDebt', 'NOCFToTLiability', 'NOCFToInterestBearDebt', 'NOCFToNetDebt', 'TSEPToTotalCapital',
            'InteBearDebtToTotalCapital', 'NPParentCompanyCutYOY', 'SalesServiceCashToORLatest', 'CashRateOfSalesLatest', 
            'NOCFToOperatingNILatest', 'TotalAssets', 'MktValue','NegMktValue', 'TEAP', 'NIAP', 'TotalFixedAssets', 
            'IntFreeCL', 'IntFreeNCL', 'IntCL', 'IntDebt', 'NetDebt','NetTangibleAssets', 'WorkingCapital', 'NetWorkingCapital', 
            'TotalPaidinCapital', 'RetainedEarnings', 'OperateNetIncome', 'ValueChgProfit', 'NetIntExpense', 'EBIT', 
            'EBITDA', 'EBIAT', 'NRProfitLoss', 'NIAPCut', 'FCFF', 'FCFE', 'DA','TRevenueTTM', 'TCostTTM','RevenueTTM', 
            'CostTTM', 'GrossProfitTTM', 'SalesExpenseTTM', 'AdminExpenseTTM', 'FinanExpenseTTM', 'AssetImpairLossTTM', 
            'NPFromOperatingTTM', 'NPFromValueChgTTM', 'OperateProfitTTM', 'NonOperatingNPTTM', 'TProfitTTM', 'NetProfitTTM', 
            'NetProfitAPTTM', 'SaleServiceRenderCashTTM', 'NetOperateCFTTM', 'NetInvestCFTTM', 'NetFinanceCFTTM', 'GrossProfit', 
            'Beta252', 'RSTR504', 'EPIBS', 'CETOP', 'DASTD', 'CmraCNE5', 'HsigmaCNE5', 'SGRO', 'EgibsLong', 'STOM', 'STOQ', 'STOA', 'NLSIZE']

label = ['dx']

# %%
# %%time
from datetime import datetime, timedelta
from m1_xgb import *
from src.conf.configuration import regress_conf
import xgboost as xgb
import gc

def create_scenario():
    weight_gap = 1
    transact_cost = 0.003

    executor = NaiveExecutor()
    turn_overs = []
    leverags = []
    trade_dates = []
    current_pos = pd.DataFrame()
    previous_pos = pd.DataFrame()
    tune_record = pd.DataFrame()  
    rets = []
    net_rets = []
    turn_overs = []
    leverags = []
    ics = []

    # take ref_dates[i] as an example
    for i, ref_date in enumerate(ref_dates):
        alpha_logger.info('{0} is start'.format(ref_date))

        # machine learning model
        # Filter Training data
        # train data
        trade_date_pre = ref_date - timedelta(days=1)
        trade_date_pre_80 = ref_date - timedelta(days=80)
        
        # train = train_data[(train_data.trade_date <= trade_date_pre) & (trade_date_pre_80 <= train_data.trade_date)].dropna()
        train = train_data[train_data.trade_date <= trade_date_pre].dropna()

        if len(train) <= 0:
            continue
        x_train = train[features]
        y_train = train[label]
        alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
        alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))

        # xgb_configuration
        regress_conf.xgb_config_r()
        regress_conf.cv_folds = None
        regress_conf.early_stop_round = 10
        regress_conf.max_round = 800
        tic = time.time()
        # training
        xgb_model = XGBooster(regress_conf)
#         xgb_model.set_params(tree_method='gpu_hist', max_depth=5)
        xgb_model.set_params(max_depth=5)
        print(xgb_model.get_params)
        best_score, best_round, cv_rounds, best_model = xgb_model.fit(x_train, y_train)
        alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
        alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
    
        # Test data
        total_data_test_excess = train_data[train_data.trade_date == ref_date]
        alpha_logger.info('{0} total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

        if len(total_data_test_excess) <= 0:
            alpha_logger.info('{0} HAS NO DATA!!!'.format(ref_date))
            continue

        industry_matrix = industry_total[industry_total.trade_date == ref_date]
        benchmark_w = benchmark_total[benchmark_total.trade_date == ref_date]
        risk_matrix = risk_total[risk_total.trade_date == ref_date]

        total_data = pd.merge(industry_matrix, benchmark_w, on=['code'], how='left').fillna(0.)
        total_data = pd.merge(total_data, risk_matrix, on=['code'])
        alpha_logger.info('{0} len_of_total_data: {1}'.format(ref_date, len(total_data)))

        total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
        alpha_logger.info('{0} len_of_total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))
        
        codes = total_data_test_excess.code.values.tolist()
        alpha_logger.info('{0} full re-balance: {1}'.format(ref_date, len(codes)))
        dx_returns = return_data[return_data.trade_date == ref_date][['code', 'dx']]

        benchmark_w = total_data_test_excess.weight.values
        alpha_logger.info('shape_of_benchmark_w: {}'.format(np.shape(benchmark_w)))
        is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))
        total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                         is_in_benchmark,
                                         np.ones_like(is_in_benchmark)],
                                         axis=1)
        alpha_logger.info('shape_of_total_risk_exp_pre: {}'.format(np.shape(total_risk_exp)))
        total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
        alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))
        constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
        alpha_logger.info('constraints: {0} in {1}'.format(np.shape(constraints.risk_targets()), ref_date))

        lbound = np.maximum(0., benchmark_w - weight_gap)
        ubound = weight_gap + benchmark_w
        alpha_logger.info('lbound: {0} in {1}'.format(np.shape(lbound), ref_date))
        alpha_logger.info('ubound: {0} in {1}'.format(np.shape(ubound), ref_date))

        # predict
        x_pred = total_data_test_excess[features]
        predict_xgboost = xgb_model.predict(best_model, x_pred)

        a = np.shape(predict_xgboost)
        predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
        alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))
        del xgb_model
        del best_model
        gc.collect()
        
        # backtest
        try:
            target_pos, _ = er_portfolio_analysis(predict_xgboost,
                                                  total_data_test_excess['industry'].values,
                                                  None,
                                                  constraints,
                                                  False,
                                                  benchmark_w,
                                                  method = 'risk_neutral',
                                                  lbound=lbound,
                                                  ubound=ubound)
        except:
            import pdb
            pdb.set_trace()
            alpha_logger.info('target_pos: {}'.format(target_pos))
        alpha_logger.info('target_pos_shape: {}'.format(np.shape(target_pos)))
        alpha_logger.info('len_codes:{}'.format(np.shape(codes)))
        target_pos['code'] = codes
        
        result = pd.merge(target_pos, dx_returns, on=['code'])
        result['trade_date'] = ref_date
        tune_record = tune_record.append(result)
        alpha_logger.info('len_result: {}'.format(len(result)))

        # excess_return = np.exp(result.dx.values) - 1. - index_return.loc[ref_date, 'dx']
        excess_return = np.exp(result.dx.values) - 1.
        ret = result.weight.values @ excess_return
        
        trade_dates.append(ref_date)
        rets.append(np.log(1. + ret))
        alpha_logger.info('len_rets: {}, len_trade_dates: {}'.format(len(rets), len(trade_dates)))
        
        turn_over_org, current_pos = executor.execute(target_pos=target_pos)
        turn_over = turn_over_org / sum(target_pos.weight.values)
        executor.set_current(current_pos)
        net_rets.append(np.log(1. + ret - transact_cost * turn_over))        
        alpha_logger.info('len_net_rets: {}, len_trade_dates: {}'.format(len(net_rets), len(trade_dates)))

        alpha_logger.info('{} is finished'.format(ref_date))
        
    # ret_df = pd.DataFrame({'xgb_regress': rets}, index=trade_dates)
    ret_df = pd.DataFrame({'xgb_regress': rets, 'net_xgb_regress':net_rets}, index=trade_dates)
    ret_df.loc[advanceDateByCalendar('china.sse', ref_dates[-1], freq).strftime('%Y-%m-%d')] = 0.
    ret_df = ret_df.shift(1)
    ret_df.iloc[0] = 0.
    return ret_df, tune_record
# Out:
# CPU times: user 1.68 ms, sys: 979 µs, total: 2.66 ms
# Wall time: 2.08 ms

# %%
ret_df, tune_record = create_scenario()
# Out:
# 2019-08-27 05:40:43,520 - ALPHA_MIND - INFO - 2018-01-02 00:00:00 is start
# 2019-08-27 05:40:43,524 - ALPHA_MIND - INFO - 2018-01-05 00:00:00 is start
# 2019-08-27 05:40:43,534 - ALPHA_MIND - INFO - len_x_train: 500, len_y_train: 500
# 2019-08-27 05:40:43,535 - ALPHA_MIND - INFO - X_train.shape=(500, 423), X_test.shape = (500, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7f2e894ac240>>
# non_cross_validation。。。。
# [0]	train-rmse:0.496501	valid-rmse:0.494858
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.491567	valid-rmse:0.489925
# [2]	train-rmse:0.486682	valid-rmse:0.485042
# [3]	train-rmse:0.481847	valid-rmse:0.480208
# [4]	train-rmse:0.477059	valid-rmse:0.475422
# [5]	train-rmse:0.47232	valid-rmse:0.470684
# [6]	train-rmse:0.467628	valid-rmse:0.465993
# [7]	train-rmse:0.462983	valid-rmse:0.46135
# [8]	train-rmse:0.458385	valid-rmse:0.456753
# [9]	train-rmse:0.453833	valid-rmse:0.452202
# [10]	train-rmse:0.449326	valid-rmse:0.447696
# [11]	train-rmse:0.444865	valid-rmse:0.443236
# [12]	train-rmse:0.440448	valid-rmse:0.438821
# [13]	train-rmse:0.436076	valid-rmse:0.43445
# [14]	train-rmse:0.431747	valid-rmse:0.430123
# [15]	train-rmse:0.427462	valid-rmse:0.425839
# [16]	train-rmse:0.423219	valid-rmse:0.421598
# [17]	train-rmse:0.419019	valid-rmse:0.4174
# [18]	train-rmse:0.414862	valid-rmse:0.413243
# [19]	train-rmse:0.410746	valid-rmse:0.409129
# [20]	train-rmse:0.406671	valid-rmse:0.405056
# [21]	train-rmse:0.402637	valid-rmse:0.401024
# [22]	train-rmse:0.398644	valid-rmse:0.397032
# [23]	train-rmse:0.394691	valid-rmse:0.39308
# [24]	train-rmse:0.390777	valid-rmse:0.389168
# [25]	train-rmse:0.386903	valid-rmse:0.385295
# [26]	train-rmse:0.383067	valid-rmse:0.381461
# [27]	train-rmse:0.37927	valid-rmse:0.377666
# [28]	train-rmse:0.375511	valid-rmse:0.373909
# [29]	train-rmse:0.37179	valid-rmse:0.370189
# [30]	train-rmse:0.368107	valid-rmse:0.366507
# [31]	train-rmse:0.36446	valid-rmse:0.362862
# [32]	train-rmse:0.36085	valid-rmse:0.359254
# [33]	train-rmse:0.357276	valid-rmse:0.355682
# [34]	train-rmse:0.353738	valid-rmse:0.352145
# [35]	train-rmse:0.350235	valid-rmse:0.348645
# [36]	train-rmse:0.346768	valid-rmse:0.345179
# [37]	train-rmse:0.343336	valid-rmse:0.341749
# [38]	train-rmse:0.339938	valid-rmse:0.338353
# [39]	train-rmse:0.336574	valid-rmse:0.334991
# [40]	train-rmse:0.333245	valid-rmse:0.331663
# [41]	train-rmse:0.329948	valid-rmse:0.328368
# [42]	train-rmse:0.326685	valid-rmse:0.325107
# [43]	train-rmse:0.323455	valid-rmse:0.321879
# [44]	train-rmse:0.320257	valid-rmse:0.318683
# [45]	train-rmse:0.317091	valid-rmse:0.315519
# [46]	train-rmse:0.313957	valid-rmse:0.312387
# [47]	train-rmse:0.310855	valid-rmse:0.309287
# [48]	train-rmse:0.307784	valid-rmse:0.306218
# [49]	train-rmse:0.304744	valid-rmse:0.30318
# [50]	train-rmse:0.301734	valid-rmse:0.300172
# [51]	train-rmse:0.298755	valid-rmse:0.297195
# [52]	train-rmse:0.295806	valid-rmse:0.294248
# [53]	train-rmse:0.292887	valid-rmse:0.291331
# [54]	train-rmse:0.289997	valid-rmse:0.288443
# [55]	train-rmse:0.287136	valid-rmse:0.285585
# [56]	train-rmse:0.284304	valid-rmse:0.282755
# [57]	train-rmse:0.2815	valid-rmse:0.279954
# [58]	train-rmse:0.278725	valid-rmse:0.277181
# [59]	train-rmse:0.275978	valid-rmse:0.274436
# [60]	train-rmse:0.273259	valid-rmse:0.271719
# [61]	train-rmse:0.270567	valid-rmse:0.269029
# [62]	train-rmse:0.267902	valid-rmse:0.266367
# [63]	train-rmse:0.265264	valid-rmse:0.263732
# [64]	train-rmse:0.262653	valid-rmse:0.261123
# [65]	train-rmse:0.260069	valid-rmse:0.258541
# [66]	train-rmse:0.25751	valid-rmse:0.255984
# [67]	train-rmse:0.254977	valid-rmse:0.253454
# [68]	train-rmse:0.25247	valid-rmse:0.25095
# [69]	train-rmse:0.249988	valid-rmse:0.24847
# [70]	train-rmse:0.247532	valid-rmse:0.246016
# [71]	train-rmse:0.2451	valid-rmse:0.243587
# [72]	train-rmse:0.242693	valid-rmse:0.241183
# [73]	train-rmse:0.24031	valid-rmse:0.238802
# [74]	train-rmse:0.237951	valid-rmse:0.236446
# [75]	train-rmse:0.235617	valid-rmse:0.234115
# [76]	train-rmse:0.233306	valid-rmse:0.231806
# [77]	train-rmse:0.231018	valid-rmse:0.229521
# [78]	train-rmse:0.228754	valid-rmse:0.227326
# [79]	train-rmse:0.226512	valid-rmse:0.225154
# [80]	train-rmse:0.224293	valid-rmse:0.222938
# [81]	train-rmse:0.222097	valid-rmse:0.22081
# [82]	train-rmse:0.219923	valid-rmse:0.218704
# [83]	train-rmse:0.217771	valid-rmse:0.216555
# [84]	train-rmse:0.215641	valid-rmse:0.214493
# [85]	train-rmse:0.213533	valid-rmse:0.212451
# [86]	train-rmse:0.211446	valid-rmse:0.210431
# [87]	train-rmse:0.20938	valid-rmse:0.208368
# [88]	train-rmse:0.207335	valid-rmse:0.206389
# [89]	train-rmse:0.205311	valid-rmse:0.204431
# [90]	train-rmse:0.203308	valid-rmse:0.202431
# [91]	train-rmse:0.201324	valid-rmse:0.200514
# [92]	train-rmse:0.199362	valid-rmse:0.198615
# [93]	train-rmse:0.197419	valid-rmse:0.196677
# [94]	train-rmse:0.195496	valid-rmse:0.194818
# [95]	train-rmse:0.193592	valid-rmse:0.192978
# [96]	train-rmse:0.191708	valid-rmse:0.191099
# [97]	train-rmse:0.189843	valid-rmse:0.189297
# [98]	train-rmse:0.187998	valid-rmse:0.187515
# [99]	train-rmse:0.186171	valid-rmse:0.185692
# [100]	train-rmse:0.184362	valid-rmse:0.183947
# [101]	train-rmse:0.182573	valid-rmse:0.18222
# [102]	train-rmse:0.180801	valid-rmse:0.180453
# [103]	train-rmse:0.179048	valid-rmse:0.178762
# [104]	train-rmse:0.177312	valid-rmse:0.177088
# [105]	train-rmse:0.175595	valid-rmse:0.175376
# [106]	train-rmse:0.173887	valid-rmse:0.173806
# [107]	train-rmse:0.172204	valid-rmse:0.172185
# [108]	train-rmse:0.170531	valid-rmse:0.170649
# [109]	train-rmse:0.168875	valid-rmse:0.169129
# [110]	train-rmse:0.167243	valid-rmse:0.167494
# [111]	train-rmse:0.165621	valid-rmse:0.166007
# [112]	train-rmse:0.164021	valid-rmse:0.164406
# [113]	train-rmse:0.162432	valid-rmse:0.162951
# [114]	train-rmse:0.160858	valid-rmse:0.161512
# [115]	train-rmse:0.159301	valid-rmse:0.159961
# [116]	train-rmse:0.157759	valid-rmse:0.158553
# [117]	train-rmse:0.156234	valid-rmse:0.157034
# [118]	train-rmse:0.154723	valid-rmse:0.155656
# [119]	train-rmse:0.153229	valid-rmse:0.154169
# [120]	train-rmse:0.151749	valid-rmse:0.152819
# [121]	train-rmse:0.150285	valid-rmse:0.151362
# [122]	train-rmse:0.148835	valid-rmse:0.150043
# [123]	train-rmse:0.1474	valid-rmse:0.148617
# [124]	train-rmse:0.14598	valid-rmse:0.147327
# [125]	train-rmse:0.144575	valid-rmse:0.145931
# [126]	train-rmse:0.143183	valid-rmse:0.144666
# [127]	train-rmse:0.141806	valid-rmse:0.143418
# [128]	train-rmse:0.140443	valid-rmse:0.142065
# [129]	train-rmse:0.139094	valid-rmse:0.140844
# [130]	train-rmse:0.137759	valid-rmse:0.13952
# [131]	train-rmse:0.136437	valid-rmse:0.138324
# [132]	train-rmse:0.135127	valid-rmse:0.13703
# [133]	train-rmse:0.133832	valid-rmse:0.135856
# [134]	train-rmse:0.132548	valid-rmse:0.13459
# [135]	train-rmse:0.13128	valid-rmse:0.133448
# [136]	train-rmse:0.130023	valid-rmse:0.132208
# [137]	train-rmse:0.128778	valid-rmse:0.130981
# [138]	train-rmse:0.127548	valid-rmse:0.129871
# [139]	train-rmse:0.12633	valid-rmse:0.128774
# [140]	train-rmse:0.125124	valid-rmse:0.127583
# [141]	train-rmse:0.123931	valid-rmse:0.126509
# [142]	train-rmse:0.122749	valid-rmse:0.125352
# [143]	train-rmse:0.12158	valid-rmse:0.124304
# [144]	train-rmse:0.120422	valid-rmse:0.12317
# [145]	train-rmse:0.119277	valid-rmse:0.122145
# [146]	train-rmse:0.118142	valid-rmse:0.121036
# [147]	train-rmse:0.117021	valid-rmse:0.120034
# [148]	train-rmse:0.115911	valid-rmse:0.119048
# [149]	train-rmse:0.114811	valid-rmse:0.117974
# [150]	train-rmse:0.113722	valid-rmse:0.116914
# [151]	train-rmse:0.112646	valid-rmse:0.115956
# [152]	train-rmse:0.11158	valid-rmse:0.114917
# [153]	train-rmse:0.110526	valid-rmse:0.113982
# [154]	train-rmse:0.10948	valid-rmse:0.112971
# [155]	train-rmse:0.108448	valid-rmse:0.11207
# [156]	train-rmse:0.107422	valid-rmse:0.111083
# [157]	train-rmse:0.106411	valid-rmse:0.110191
# [158]	train-rmse:0.105408	valid-rmse:0.1093
# [159]	train-rmse:0.10441	valid-rmse:0.108419
# [160]	train-rmse:0.103426	valid-rmse:0.107473
# [161]	train-rmse:0.102449	valid-rmse:0.106611
# [162]	train-rmse:0.101481	valid-rmse:0.10576
# [163]	train-rmse:0.100529	valid-rmse:0.104901
# [164]	train-rmse:0.099581	valid-rmse:0.104046
# [165]	train-rmse:0.098648	valid-rmse:0.103199
# [166]	train-rmse:0.097719	valid-rmse:0.102362
# [167]	train-rmse:0.0968	valid-rmse:0.101549
# [168]	train-rmse:0.095893	valid-rmse:0.100739
# [169]	train-rmse:0.094992	valid-rmse:0.099944
# [170]	train-rmse:0.094103	valid-rmse:0.099143
# [171]	train-rmse:0.093221	valid-rmse:0.098355
# [172]	train-rmse:0.092348	valid-rmse:0.097577
# [173]	train-rmse:0.091486	valid-rmse:0.096774
# [174]	train-rmse:0.090631	valid-rmse:0.096009
# [175]	train-rmse:0.089787	valid-rmse:0.095222
# [176]	train-rmse:0.088946	valid-rmse:0.094426
# [177]	train-rmse:0.088116	valid-rmse:0.093688
# [178]	train-rmse:0.087295	valid-rmse:0.092957
# [179]	train-rmse:0.086482	valid-rmse:0.092249
# [180]	train-rmse:0.085679	valid-rmse:0.091528
# [181]	train-rmse:0.084883	valid-rmse:0.090819
# [182]	train-rmse:0.084096	valid-rmse:0.090115
# [183]	train-rmse:0.083315	valid-rmse:0.089439
# [184]	train-rmse:0.08254	valid-rmse:0.08871
# [185]	train-rmse:0.081776	valid-rmse:0.088023
# [186]	train-rmse:0.08102	valid-rmse:0.087357
# [187]	train-rmse:0.080273	valid-rmse:0.086648
# [188]	train-rmse:0.079533	valid-rmse:0.085983
# [189]	train-rmse:0.078799	valid-rmse:0.08536
# [190]	train-rmse:0.078074	valid-rmse:0.084709
# [191]	train-rmse:0.077356	valid-rmse:0.084075
# [192]	train-rmse:0.076646	valid-rmse:0.083436
# [193]	train-rmse:0.075942	valid-rmse:0.082764
# [194]	train-rmse:0.075245	valid-rmse:0.082129
# [195]	train-rmse:0.074554	valid-rmse:0.081501
# [196]	train-rmse:0.073871	valid-rmse:0.080851
# [197]	train-rmse:0.073194	valid-rmse:0.080239
# [198]	train-rmse:0.072524	valid-rmse:0.079646
# [199]	train-rmse:0.071858	valid-rmse:0.079037
# [200]	train-rmse:0.071202	valid-rmse:0.078451
# [201]	train-rmse:0.070551	valid-rmse:0.077862
# [202]	train-rmse:0.069908	valid-rmse:0.077288
# [203]	train-rmse:0.069271	valid-rmse:0.076731
# [204]	train-rmse:0.06864	valid-rmse:0.076163
# [205]	train-rmse:0.068014	valid-rmse:0.07564
# [206]	train-rmse:0.067394	valid-rmse:0.075114
# [207]	train-rmse:0.066783	valid-rmse:0.074566
# [208]	train-rmse:0.066176	valid-rmse:0.07406
# [209]	train-rmse:0.065577	valid-rmse:0.073526
# [210]	train-rmse:0.064982	valid-rmse:0.07305
# [211]	train-rmse:0.064391	valid-rmse:0.072518
# [212]	train-rmse:0.06381	valid-rmse:0.071999
# [213]	train-rmse:0.063232	valid-rmse:0.071488
# [214]	train-rmse:0.062662	valid-rmse:0.070991
# [215]	train-rmse:0.062095	valid-rmse:0.070474
# [216]	train-rmse:0.061535	valid-rmse:0.06999
# [217]	train-rmse:0.060983	valid-rmse:0.069529
# [218]	train-rmse:0.060433	valid-rmse:0.069028
# [219]	train-rmse:0.05989	valid-rmse:0.068564
# [220]	train-rmse:0.059353	valid-rmse:0.068102
# [221]	train-rmse:0.05882	valid-rmse:0.067637
# [222]	train-rmse:0.058296	valid-rmse:0.067174
# [223]	train-rmse:0.057772	valid-rmse:0.066713
# [224]	train-rmse:0.057254	valid-rmse:0.066265
# [225]	train-rmse:0.056746	valid-rmse:0.065843
# [226]	train-rmse:0.056238	valid-rmse:0.065398
# [227]	train-rmse:0.055735	valid-rmse:0.064956
# [228]	train-rmse:0.055242	valid-rmse:0.064561
# [229]	train-rmse:0.05475	valid-rmse:0.06413
# [230]	train-rmse:0.054262	valid-rmse:0.063695
# [231]	train-rmse:0.053786	valid-rmse:0.063293
# [232]	train-rmse:0.053309	valid-rmse:0.062875
# [233]	train-rmse:0.052839	valid-rmse:0.062479
# [234]	train-rmse:0.052372	valid-rmse:0.062085
# [235]	train-rmse:0.051911	valid-rmse:0.061703
# [236]	train-rmse:0.051455	valid-rmse:0.061341
# [237]	train-rmse:0.051006	valid-rmse:0.060969
# [238]	train-rmse:0.050561	valid-rmse:0.060614
# [239]	train-rmse:0.050119	valid-rmse:0.06025
# [240]	train-rmse:0.04968	valid-rmse:0.05987
# [241]	train-rmse:0.049248	valid-rmse:0.059515
# [242]	train-rmse:0.048821	valid-rmse:0.059172
# [243]	train-rmse:0.048397	valid-rmse:0.058822
# [244]	train-rmse:0.047979	valid-rmse:0.058502
# [245]	train-rmse:0.047561	valid-rmse:0.058155
# [246]	train-rmse:0.04715	valid-rmse:0.057818
# [247]	train-rmse:0.046744	valid-rmse:0.057504
# [248]	train-rmse:0.046342	valid-rmse:0.057191
# [249]	train-rmse:0.045945	valid-rmse:0.056891
# [250]	train-rmse:0.045551	valid-rmse:0.056581
# [251]	train-rmse:0.045157	valid-rmse:0.056258
# [252]	train-rmse:0.044771	valid-rmse:0.05595
# [253]	train-rmse:0.04439	valid-rmse:0.055663
# [254]	train-rmse:0.044013	valid-rmse:0.055355
# [255]	train-rmse:0.043637	valid-rmse:0.055055
# [256]	train-rmse:0.043267	valid-rmse:0.054784
# [257]	train-rmse:0.042903	valid-rmse:0.054511
# [258]	train-rmse:0.04254	valid-rmse:0.054223
# [259]	train-rmse:0.042182	valid-rmse:0.053945
# [260]	train-rmse:0.041829	valid-rmse:0.053686
# [261]	train-rmse:0.041477	valid-rmse:0.053432
# [262]	train-rmse:0.041129	valid-rmse:0.053173
# [263]	train-rmse:0.040785	valid-rmse:0.05289
# [264]	train-rmse:0.04044	valid-rmse:0.052665
# [265]	train-rmse:0.040104	valid-rmse:0.052404
# [266]	train-rmse:0.039771	valid-rmse:0.052156
# [267]	train-rmse:0.039441	valid-rmse:0.051901
# [268]	train-rmse:0.039115	valid-rmse:0.051659
# [269]	train-rmse:0.038792	valid-rmse:0.051424
# [270]	train-rmse:0.038473	valid-rmse:0.051183
# [271]	train-rmse:0.038155	valid-rmse:0.050952
# [272]	train-rmse:0.037843	valid-rmse:0.050729
# [273]	train-rmse:0.037537	valid-rmse:0.050497
# [274]	train-rmse:0.037229	valid-rmse:0.050276
# [275]	train-rmse:0.036925	valid-rmse:0.050058
# [276]	train-rmse:0.036624	valid-rmse:0.04983
# [277]	train-rmse:0.036331	valid-rmse:0.049623
# [278]	train-rmse:0.036037	valid-rmse:0.049415
# [279]	train-rmse:0.035744	valid-rmse:0.049207
# [280]	train-rmse:0.035456	valid-rmse:0.048986
# [281]	train-rmse:0.035168	valid-rmse:0.048765
# [282]	train-rmse:0.034883	valid-rmse:0.048546
# [283]	train-rmse:0.034603	valid-rmse:0.048338
# [284]	train-rmse:0.034331	valid-rmse:0.048152
# [285]	train-rmse:0.034055	valid-rmse:0.047942
# [286]	train-rmse:0.033784	valid-rmse:0.047744
# [287]	train-rmse:0.03352	valid-rmse:0.047545
# [288]	train-rmse:0.033252	valid-rmse:0.04734
# [289]	train-rmse:0.032994	valid-rmse:0.047147
# [290]	train-rmse:0.032738	valid-rmse:0.046956
# [291]	train-rmse:0.032479	valid-rmse:0.046763
# [292]	train-rmse:0.032229	valid-rmse:0.046577
# [293]	train-rmse:0.031975	valid-rmse:0.046389
# [294]	train-rmse:0.03173	valid-rmse:0.046211
# [295]	train-rmse:0.031486	valid-rmse:0.046025
# [296]	train-rmse:0.03124	valid-rmse:0.045843
# [297]	train-rmse:0.031002	valid-rmse:0.045672
# [298]	train-rmse:0.030767	valid-rmse:0.045514
# [299]	train-rmse:0.030534	valid-rmse:0.045339
# [300]	train-rmse:0.030298	valid-rmse:0.045169
# [301]	train-rmse:0.03007	valid-rmse:0.045009
# [302]	train-rmse:0.029846	valid-rmse:0.044842
# [303]	train-rmse:0.029622	valid-rmse:0.044697
# [304]	train-rmse:0.029401	valid-rmse:0.044528
# [305]	train-rmse:0.029183	valid-rmse:0.044367
# [306]	train-rmse:0.028961	valid-rmse:0.044208
# [307]	train-rmse:0.028749	valid-rmse:0.044054
# [308]	train-rmse:0.028534	valid-rmse:0.043916
# [309]	train-rmse:0.028319	valid-rmse:0.043761
# [310]	train-rmse:0.028106	valid-rmse:0.043612
# [311]	train-rmse:0.027902	valid-rmse:0.043484
# [312]	train-rmse:0.027697	valid-rmse:0.043347
# [313]	train-rmse:0.027497	valid-rmse:0.043227
# [314]	train-rmse:0.027293	valid-rmse:0.043083
# [315]	train-rmse:0.027091	valid-rmse:0.042937
# [316]	train-rmse:0.026892	valid-rmse:0.0428
# [317]	train-rmse:0.026697	valid-rmse:0.042679
# [318]	train-rmse:0.026504	valid-rmse:0.042546
# [319]	train-rmse:0.026311	valid-rmse:0.042417
# [320]	train-rmse:0.026127	valid-rmse:0.042309
# [321]	train-rmse:0.025942	valid-rmse:0.042189
# [322]	train-rmse:0.025757	valid-rmse:0.042059
# [323]	train-rmse:0.025578	valid-rmse:0.041943
# [324]	train-rmse:0.025398	valid-rmse:0.041819
# [325]	train-rmse:0.025223	valid-rmse:0.041704
# [326]	train-rmse:0.025046	valid-rmse:0.041585
# [327]	train-rmse:0.024872	valid-rmse:0.041475
# [328]	train-rmse:0.024704	valid-rmse:0.041382
# [329]	train-rmse:0.024533	valid-rmse:0.041282
# [330]	train-rmse:0.024364	valid-rmse:0.041169
# [331]	train-rmse:0.0242	valid-rmse:0.04108
# [332]	train-rmse:0.024038	valid-rmse:0.041003
# [333]	train-rmse:0.023874	valid-rmse:0.040895
# [334]	train-rmse:0.023716	valid-rmse:0.040796
# [335]	train-rmse:0.023554	valid-rmse:0.040697
# [336]	train-rmse:0.023392	valid-rmse:0.040593
# [337]	train-rmse:0.02324	valid-rmse:0.040507
# [338]	train-rmse:0.023085	valid-rmse:0.040449
# [339]	train-rmse:0.02293	valid-rmse:0.040343
# [340]	train-rmse:0.022782	valid-rmse:0.040276
# [341]	train-rmse:0.022631	valid-rmse:0.040172
# [342]	train-rmse:0.022487	valid-rmse:0.040076
# [343]	train-rmse:0.022343	valid-rmse:0.03999
# [344]	train-rmse:0.022194	valid-rmse:0.039894
# [345]	train-rmse:0.022049	valid-rmse:0.039817
# [346]	train-rmse:0.021907	valid-rmse:0.039727
# [347]	train-rmse:0.021771	valid-rmse:0.039637
# [348]	train-rmse:0.021631	valid-rmse:0.039542
# [349]	train-rmse:0.021493	valid-rmse:0.039466
# [350]	train-rmse:0.021355	valid-rmse:0.039373
# [351]	train-rmse:0.021224	valid-rmse:0.039307
# [352]	train-rmse:0.02109	valid-rmse:0.039274
# [353]	train-rmse:0.020959	valid-rmse:0.039191
# [354]	train-rmse:0.020832	valid-rmse:0.039136
# [355]	train-rmse:0.020701	valid-rmse:0.039052
# [356]	train-rmse:0.020572	valid-rmse:0.039023
# [357]	train-rmse:0.020449	valid-rmse:0.038966
# [358]	train-rmse:0.020323	valid-rmse:0.038883
# [359]	train-rmse:0.020204	valid-rmse:0.038807
# [360]	train-rmse:0.020085	valid-rmse:0.038739
# [361]	train-rmse:0.019964	valid-rmse:0.038712
# [362]	train-rmse:0.019844	valid-rmse:0.038636
# [363]	train-rmse:0.019715	valid-rmse:0.038599
# [364]	train-rmse:0.019603	valid-rmse:0.038527
# [365]	train-rmse:0.019486	valid-rmse:0.038451
# [366]	train-rmse:0.019376	valid-rmse:0.038382
# [367]	train-rmse:0.019261	valid-rmse:0.038325
# [368]	train-rmse:0.019152	valid-rmse:0.038268
# [369]	train-rmse:0.01904	valid-rmse:0.038199
# [370]	train-rmse:0.018932	valid-rmse:0.038139
# [371]	train-rmse:0.018813	valid-rmse:0.038091
# [372]	train-rmse:0.018704	valid-rmse:0.038024
# [373]	train-rmse:0.018601	valid-rmse:0.037978
# [374]	train-rmse:0.018494	valid-rmse:0.037928
# [375]	train-rmse:0.01838	valid-rmse:0.0379
# [376]	train-rmse:0.01828	valid-rmse:0.037849
# [377]	train-rmse:0.018176	valid-rmse:0.037796
# [378]	train-rmse:0.018075	valid-rmse:0.037748
# [379]	train-rmse:0.017978	valid-rmse:0.0377
# [380]	train-rmse:0.01787	valid-rmse:0.037675
# [381]	train-rmse:0.017775	valid-rmse:0.037625
# [382]	train-rmse:0.017676	valid-rmse:0.037573
# [383]	train-rmse:0.01758	valid-rmse:0.037525
# [384]	train-rmse:0.017485	valid-rmse:0.037475
# [385]	train-rmse:0.01739	valid-rmse:0.037424
# [386]	train-rmse:0.0173	valid-rmse:0.037375
# [387]	train-rmse:0.0172	valid-rmse:0.037339
# [388]	train-rmse:0.017107	valid-rmse:0.037296
# [389]	train-rmse:0.017008	valid-rmse:0.037277
# [390]	train-rmse:0.01692	valid-rmse:0.037233
# [391]	train-rmse:0.016835	valid-rmse:0.037193
# [392]	train-rmse:0.016752	valid-rmse:0.03715
# [393]	train-rmse:0.016662	valid-rmse:0.037106
# [394]	train-rmse:0.016568	valid-rmse:0.03709
# [395]	train-rmse:0.016489	valid-rmse:0.037052
# [396]	train-rmse:0.016403	valid-rmse:0.037021
# [397]	train-rmse:0.016321	valid-rmse:0.03698
# [398]	train-rmse:0.016238	valid-rmse:0.036942
# [399]	train-rmse:0.016149	valid-rmse:0.036909
# [400]	train-rmse:0.016065	valid-rmse:0.036882
# [401]	train-rmse:0.015982	valid-rmse:0.036844
# [402]	train-rmse:0.015894	valid-rmse:0.036832
# [403]	train-rmse:0.015819	valid-rmse:0.036795
# [404]	train-rmse:0.015739	valid-rmse:0.036769
# [405]	train-rmse:0.01566	valid-rmse:0.036733
# [406]	train-rmse:0.01558	valid-rmse:0.036707
# [407]	train-rmse:0.015506	valid-rmse:0.03667
# [408]	train-rmse:0.015423	valid-rmse:0.036655
# [409]	train-rmse:0.015347	valid-rmse:0.036629
# [410]	train-rmse:0.015267	valid-rmse:0.036589
# [411]	train-rmse:0.015197	valid-rmse:0.036549
# [412]	train-rmse:0.015126	valid-rmse:0.036522
# [413]	train-rmse:0.015054	valid-rmse:0.036498
# [414]	train-rmse:0.014984	valid-rmse:0.036466
# [415]	train-rmse:0.014913	valid-rmse:0.036433
# [416]	train-rmse:0.014848	valid-rmse:0.036402
# [417]	train-rmse:0.01478	valid-rmse:0.036372
# [418]	train-rmse:0.01471	valid-rmse:0.03635
# [419]	train-rmse:0.014642	valid-rmse:0.03632
# [420]	train-rmse:0.014568	valid-rmse:0.036302
# [421]	train-rmse:0.014503	valid-rmse:0.036265
# [422]	train-rmse:0.014431	valid-rmse:0.036241
# [423]	train-rmse:0.014364	valid-rmse:0.036212
# [424]	train-rmse:0.014297	valid-rmse:0.036196
# [425]	train-rmse:0.014234	valid-rmse:0.036166
# [426]	train-rmse:0.014165	valid-rmse:0.03614
# [427]	train-rmse:0.014105	valid-rmse:0.036111
# [428]	train-rmse:0.014035	valid-rmse:0.036098
# [429]	train-rmse:0.013975	valid-rmse:0.036073
# [430]	train-rmse:0.013907	valid-rmse:0.036053
# [431]	train-rmse:0.013848	valid-rmse:0.036029
# [432]	train-rmse:0.013787	valid-rmse:0.036008
# [433]	train-rmse:0.013727	valid-rmse:0.035993
# [434]	train-rmse:0.013672	valid-rmse:0.035967
# [435]	train-rmse:0.013621	valid-rmse:0.035947
# [436]	train-rmse:0.013565	valid-rmse:0.035928
# [437]	train-rmse:0.013511	valid-rmse:0.035905
# [438]	train-rmse:0.013462	valid-rmse:0.035888
# [439]	train-rmse:0.013398	valid-rmse:0.035878
# [440]	train-rmse:0.013342	valid-rmse:0.03585
# [441]	train-rmse:0.013295	valid-rmse:0.035831
# [442]	train-rmse:0.013217	valid-rmse:0.035817
# [443]	train-rmse:0.013155	valid-rmse:0.035786
# [444]	train-rmse:0.013101	valid-rmse:0.03576
# [445]	train-rmse:0.013055	valid-rmse:0.03574
# [446]	train-rmse:0.012997	valid-rmse:0.035713
# [447]	train-rmse:0.012948	valid-rmse:0.035686
# [448]	train-rmse:0.012896	valid-rmse:0.035666
# [449]	train-rmse:0.012838	valid-rmse:0.035656
# [450]	train-rmse:0.012794	valid-rmse:0.035645
# [451]	train-rmse:0.012736	valid-rmse:0.035616
# [452]	train-rmse:0.012679	valid-rmse:0.035601
# [453]	train-rmse:0.012635	valid-rmse:0.035585
# [454]	train-rmse:0.012584	valid-rmse:0.035569
# [455]	train-rmse:0.012513	valid-rmse:0.035557
# [456]	train-rmse:0.012457	valid-rmse:0.035527
# [457]	train-rmse:0.012403	valid-rmse:0.035521
# [458]	train-rmse:0.012358	valid-rmse:0.035502
# [459]	train-rmse:0.012306	valid-rmse:0.035474
# [460]	train-rmse:0.012261	valid-rmse:0.035452
# [461]	train-rmse:0.012207	valid-rmse:0.035426
# [462]	train-rmse:0.012163	valid-rmse:0.03541
# [463]	train-rmse:0.012119	valid-rmse:0.035386
# [464]	train-rmse:0.012075	valid-rmse:0.035368
# [465]	train-rmse:0.012009	valid-rmse:0.035358
# [466]	train-rmse:0.011965	valid-rmse:0.035341
# [467]	train-rmse:0.011924	valid-rmse:0.035326
# [468]	train-rmse:0.011874	valid-rmse:0.035316
# [469]	train-rmse:0.01181	valid-rmse:0.035307
# [470]	train-rmse:0.011759	valid-rmse:0.035288
# [471]	train-rmse:0.011712	valid-rmse:0.035266
# [472]	train-rmse:0.01167	valid-rmse:0.035247
# [473]	train-rmse:0.011635	valid-rmse:0.035231
# [474]	train-rmse:0.011595	valid-rmse:0.035217
# [475]	train-rmse:0.011552	valid-rmse:0.035208
# [476]	train-rmse:0.011513	valid-rmse:0.035208
# [477]	train-rmse:0.011461	valid-rmse:0.035209
# [478]	train-rmse:0.011403	valid-rmse:0.035196
# [479]	train-rmse:0.011351	valid-rmse:0.035196
# [480]	train-rmse:0.011306	valid-rmse:0.035192
# [481]	train-rmse:0.011269	valid-rmse:0.035176
# [482]	train-rmse:0.011232	valid-rmse:0.035176
# [483]	train-rmse:0.011179	valid-rmse:0.035161
# [484]	train-rmse:0.011128	valid-rmse:0.035162
# [485]	train-rmse:0.011077	valid-rmse:0.035145
# [486]	train-rmse:0.011027	valid-rmse:0.035123
# [487]	train-rmse:0.010975	valid-rmse:0.035113
# [488]	train-rmse:0.010927	valid-rmse:0.03509
# [489]	train-rmse:0.01088	valid-rmse:0.035071
# [490]	train-rmse:0.01083	valid-rmse:0.035063
# [491]	train-rmse:0.010796	valid-rmse:0.035049
# [492]	train-rmse:0.010761	valid-rmse:0.035046
# [493]	train-rmse:0.010721	valid-rmse:0.035035
# [494]	train-rmse:0.010674	valid-rmse:0.035018
# [495]	train-rmse:0.010627	valid-rmse:0.035012
# [496]	train-rmse:0.010576	valid-rmse:0.034998
# [497]	train-rmse:0.010542	valid-rmse:0.034997
# [498]	train-rmse:0.010503	valid-rmse:0.034984
# [499]	train-rmse:0.010455	valid-rmse:0.034972
# [500]	train-rmse:0.010412	valid-rmse:0.03496
# [501]	train-rmse:0.010366	valid-rmse:0.034946
# [502]	train-rmse:0.010332	valid-rmse:0.034929
# [503]	train-rmse:0.010283	valid-rmse:0.034918
# [504]	train-rmse:0.01024	valid-rmse:0.034898
# [505]	train-rmse:0.010209	valid-rmse:0.034896
# [506]	train-rmse:0.010167	valid-rmse:0.034886
# [507]	train-rmse:0.010125	valid-rmse:0.034876
# [508]	train-rmse:0.010089	valid-rmse:0.034866
# [509]	train-rmse:0.010044	valid-rmse:0.034852
# [510]	train-rmse:0.010003	valid-rmse:0.034844
# [511]	train-rmse:0.009958	valid-rmse:0.034827
# [512]	train-rmse:0.009923	valid-rmse:0.034812
# [513]	train-rmse:0.009891	valid-rmse:0.034795
# [514]	train-rmse:0.009856	valid-rmse:0.034781
# [515]	train-rmse:0.009814	valid-rmse:0.03478
# [516]	train-rmse:0.009772	valid-rmse:0.034768
# [517]	train-rmse:0.009728	valid-rmse:0.034767
# [518]	train-rmse:0.009685	valid-rmse:0.034758
# [519]	train-rmse:0.009642	valid-rmse:0.034756
# [520]	train-rmse:0.009599	valid-rmse:0.034749
# [521]	train-rmse:0.009556	valid-rmse:0.034747
# [522]	train-rmse:0.009516	valid-rmse:0.034736
# [523]	train-rmse:0.009475	valid-rmse:0.034731
# [524]	train-rmse:0.009432	valid-rmse:0.034714
# [525]	train-rmse:0.009392	valid-rmse:0.034709
# [526]	train-rmse:0.009351	valid-rmse:0.034703
# [527]	train-rmse:0.009311	valid-rmse:0.034696
# [528]	train-rmse:0.009269	valid-rmse:0.034684
# [529]	train-rmse:0.009231	valid-rmse:0.034672
# [530]	train-rmse:0.009194	valid-rmse:0.034658
# [531]	train-rmse:0.009156	valid-rmse:0.03465
# [532]	train-rmse:0.009121	valid-rmse:0.034639
# [533]	train-rmse:0.009085	valid-rmse:0.034618
# [534]	train-rmse:0.009046	valid-rmse:0.034614
# [535]	train-rmse:0.00901	valid-rmse:0.034605
# [536]	train-rmse:0.008971	valid-rmse:0.034601
# [537]	train-rmse:0.008937	valid-rmse:0.034592
# [538]	train-rmse:0.008892	valid-rmse:0.034581
# [539]	train-rmse:0.008856	valid-rmse:0.034568
# [540]	train-rmse:0.008819	valid-rmse:0.034564
# [541]	train-rmse:0.008787	valid-rmse:0.034559
# [542]	train-rmse:0.008755	valid-rmse:0.034552
# [543]	train-rmse:0.008721	valid-rmse:0.034535
# [544]	train-rmse:0.008689	valid-rmse:0.03453
# [545]	train-rmse:0.008654	valid-rmse:0.034527
# [546]	train-rmse:0.008625	valid-rmse:0.034519
# [547]	train-rmse:0.00859	valid-rmse:0.034503
# [548]	train-rmse:0.008551	valid-rmse:0.034503
# [549]	train-rmse:0.008521	valid-rmse:0.034498
# [550]	train-rmse:0.008485	valid-rmse:0.034487
# [551]	train-rmse:0.008453	valid-rmse:0.034475
# [552]	train-rmse:0.008411	valid-rmse:0.034473
# [553]	train-rmse:0.008374	valid-rmse:0.034468
# [554]	train-rmse:0.008345	valid-rmse:0.034461
# [555]	train-rmse:0.008304	valid-rmse:0.034459
# [556]	train-rmse:0.008278	valid-rmse:0.034452
# [557]	train-rmse:0.008241	valid-rmse:0.034449
# [558]	train-rmse:0.008207	valid-rmse:0.034439
# [559]	train-rmse:0.008172	valid-rmse:0.034445
# [560]	train-rmse:0.008146	valid-rmse:0.03444
# [561]	train-rmse:0.008112	valid-rmse:0.034439
# [562]	train-rmse:0.008079	valid-rmse:0.034441
# [563]	train-rmse:0.008047	valid-rmse:0.03443
# [564]	train-rmse:0.008015	valid-rmse:0.034432
# [565]	train-rmse:0.007989	valid-rmse:0.034423
# [566]	train-rmse:0.007957	valid-rmse:0.034416
# [567]	train-rmse:0.007924	valid-rmse:0.034415
# [568]	train-rmse:0.007901	valid-rmse:0.034402
# [569]	train-rmse:0.007873	valid-rmse:0.03441
# [570]	train-rmse:0.007846	valid-rmse:0.034398
# [571]	train-rmse:0.007813	valid-rmse:0.034396
# [572]	train-rmse:0.007782	valid-rmse:0.034389
# [573]	train-rmse:0.007755	valid-rmse:0.034398
# [574]	train-rmse:0.00772	valid-rmse:0.0344
# [575]	train-rmse:0.007695	valid-rmse:0.034384
# [576]	train-rmse:0.007668	valid-rmse:0.034392
# [577]	train-rmse:0.007638	valid-rmse:0.034391
# [578]	train-rmse:0.007615	valid-rmse:0.03438
# [579]	train-rmse:0.007582	valid-rmse:0.034381
# [580]	train-rmse:0.007556	valid-rmse:0.034387
# [581]	train-rmse:0.007521	valid-rmse:0.034391
# [582]	train-rmse:0.007492	valid-rmse:0.034386
# [583]	train-rmse:0.007469	valid-rmse:0.034378
# [584]	train-rmse:0.007437	valid-rmse:0.034369
# [585]	train-rmse:0.00741	valid-rmse:0.034366
# [586]	train-rmse:0.007387	valid-rmse:0.034353
# [587]	train-rmse:0.007364	valid-rmse:0.034359
# [588]	train-rmse:0.007334	valid-rmse:0.034353
# [589]	train-rmse:0.007305	valid-rmse:0.034352
# [590]	train-rmse:0.007271	valid-rmse:0.034356
# [591]	train-rmse:0.007249	valid-rmse:0.034346
# [592]	train-rmse:0.007221	valid-rmse:0.034339
# [593]	train-rmse:0.007198	valid-rmse:0.034339
# [594]	train-rmse:0.007177	valid-rmse:0.034325
# [595]	train-rmse:0.007154	valid-rmse:0.03433
# [596]	train-rmse:0.007127	valid-rmse:0.034324
# [597]	train-rmse:0.007101	valid-rmse:0.034322
# [598]	train-rmse:0.007081	valid-rmse:0.034309
# [599]	train-rmse:0.007053	valid-rmse:0.034305
# [600]	train-rmse:0.007028	valid-rmse:0.034302
# [601]	train-rmse:0.007008	valid-rmse:0.034294
# [602]	train-rmse:0.006986	valid-rmse:0.034295
# [603]	train-rmse:0.006959	valid-rmse:0.034293
# [604]	train-rmse:0.006941	valid-rmse:0.034284
# [605]	train-rmse:0.006916	valid-rmse:0.034287
# [606]	train-rmse:0.006898	valid-rmse:0.034285
# [607]	train-rmse:0.006869	valid-rmse:0.034278
# [608]	train-rmse:0.006847	valid-rmse:0.034281
# [609]	train-rmse:0.006826	valid-rmse:0.034284
# [610]	train-rmse:0.006801	valid-rmse:0.03428
# [611]	train-rmse:0.006778	valid-rmse:0.034279
# [612]	train-rmse:0.006756	valid-rmse:0.034274
# [613]	train-rmse:0.006738	valid-rmse:0.034272
# [614]	train-rmse:0.006715	valid-rmse:0.03427
# [615]	train-rmse:0.006692	valid-rmse:0.034273
# [616]	train-rmse:0.006674	valid-rmse:0.034264
# [617]	train-rmse:0.006643	valid-rmse:0.034269
# [618]	train-rmse:0.006624	valid-rmse:0.034271
# [619]	train-rmse:0.006595	valid-rmse:0.034271
# [620]	train-rmse:0.006569	valid-rmse:0.034267
# [621]	train-rmse:0.00654	valid-rmse:0.034267
# [622]	train-rmse:0.006523	valid-rmse:0.034264
# [623]	train-rmse:0.006495	valid-rmse:0.034266
# [624]	train-rmse:0.006475	valid-rmse:0.034263
# [625]	train-rmse:0.006449	valid-rmse:0.034262
# [626]	train-rmse:0.00642	valid-rmse:0.034265
# [627]	train-rmse:0.006398	valid-rmse:0.034262
# [628]	train-rmse:0.006377	valid-rmse:0.034263
# [629]	train-rmse:0.00636	valid-rmse:0.034251
# [630]	train-rmse:0.006341	valid-rmse:0.034251
# [631]	train-rmse:0.006314	valid-rmse:0.034249
# [632]	train-rmse:0.0063	valid-rmse:0.034248
# [633]	train-rmse:0.006276	valid-rmse:0.034245
# [634]	train-rmse:0.00626	valid-rmse:0.034236
# [635]	train-rmse:0.006233	valid-rmse:0.034236
# [636]	train-rmse:0.006211	valid-rmse:0.03423
# [637]	train-rmse:0.006192	valid-rmse:0.034221
# [638]	train-rmse:0.00617	valid-rmse:0.034227
# [639]	train-rmse:0.006151	valid-rmse:0.034221
# [640]	train-rmse:0.006129	valid-rmse:0.034215
# [641]	train-rmse:0.006114	valid-rmse:0.034209
# [642]	train-rmse:0.006094	valid-rmse:0.03421
# [643]	train-rmse:0.006076	valid-rmse:0.034204
# [644]	train-rmse:0.006049	valid-rmse:0.034204
# [645]	train-rmse:0.00603	valid-rmse:0.034201
# [646]	train-rmse:0.006015	valid-rmse:0.03419
# [647]	train-rmse:0.005992	valid-rmse:0.034189
# [648]	train-rmse:0.00597	valid-rmse:0.034185
# [649]	train-rmse:0.005949	valid-rmse:0.034192
# [650]	train-rmse:0.005931	valid-rmse:0.034185
# [651]	train-rmse:0.005909	valid-rmse:0.034186
# [652]	train-rmse:0.00589	valid-rmse:0.034184
# [653]	train-rmse:0.005872	valid-rmse:0.034176
# [654]	train-rmse:0.005852	valid-rmse:0.034183
# [655]	train-rmse:0.005837	valid-rmse:0.034178
# [656]	train-rmse:0.00582	valid-rmse:0.034174
# [657]	train-rmse:0.005796	valid-rmse:0.034169
# [658]	train-rmse:0.005774	valid-rmse:0.034172
# [659]	train-rmse:0.005762	valid-rmse:0.034171
# [660]	train-rmse:0.005746	valid-rmse:0.034173
# [661]	train-rmse:0.005726	valid-rmse:0.034169
# [662]	train-rmse:0.00571	valid-rmse:0.034172
# [663]	train-rmse:0.005688	valid-rmse:0.034168
# [664]	train-rmse:0.005671	valid-rmse:0.03416
# [665]	train-rmse:0.005647	valid-rmse:0.034157
# [666]	train-rmse:0.005628	valid-rmse:0.034153
# [667]	train-rmse:0.005612	valid-rmse:0.034155
# [668]	train-rmse:0.005598	valid-rmse:0.034144
# [669]	train-rmse:0.005581	valid-rmse:0.034142
# [670]	train-rmse:0.005559	valid-rmse:0.034144
# [671]	train-rmse:0.005543	valid-rmse:0.034146
# [672]	train-rmse:0.005522	valid-rmse:0.034141
# [673]	train-rmse:0.005508	valid-rmse:0.034137
# [674]	train-rmse:0.005486	valid-rmse:0.034139
# [675]	train-rmse:0.005468	valid-rmse:0.034136
# [676]	train-rmse:0.005455	valid-rmse:0.034132
# [677]	train-rmse:0.005441	valid-rmse:0.034129
# [678]	train-rmse:0.005421	valid-rmse:0.034124
# [679]	train-rmse:0.005396	valid-rmse:0.034119
# [680]	train-rmse:0.005386	valid-rmse:0.034116
# [681]	train-rmse:0.005364	valid-rmse:0.034115
# [682]	train-rmse:0.005344	valid-rmse:0.034118
# [683]	train-rmse:0.005331	valid-rmse:0.034116
# [684]	train-rmse:0.005312	valid-rmse:0.034119
# [685]	train-rmse:0.005301	valid-rmse:0.034117
# [686]	train-rmse:0.005284	valid-rmse:0.034113
# [687]	train-rmse:0.005262	valid-rmse:0.03411
# [688]	train-rmse:0.005243	valid-rmse:0.034104
# [689]	train-rmse:0.00522	valid-rmse:0.034099
# [690]	train-rmse:0.0052	valid-rmse:0.034095
# [691]	train-rmse:0.005187	valid-rmse:0.034092
# [692]	train-rmse:0.005177	valid-rmse:0.034091
# [693]	train-rmse:0.005158	valid-rmse:0.034093
# [694]	train-rmse:0.005141	valid-rmse:0.03409
# [695]	train-rmse:0.005128	valid-rmse:0.034088
# [696]	train-rmse:0.005108	valid-rmse:0.034087
# [697]	train-rmse:0.005091	valid-rmse:0.034084
# [698]	train-rmse:0.005078	valid-rmse:0.034084
# [699]	train-rmse:0.005062	valid-rmse:0.034085
# [700]	train-rmse:0.005049	valid-rmse:0.034083
# [701]	train-rmse:0.005038	valid-rmse:0.034079
# [702]	train-rmse:0.005017	valid-rmse:0.034078
# [703]	train-rmse:0.005002	valid-rmse:0.034079
# [704]	train-rmse:0.004991	valid-rmse:0.034076
# [705]	train-rmse:0.004978	valid-rmse:0.034077
# [706]	train-rmse:0.004969	valid-rmse:0.034076
# [707]	train-rmse:0.004959	valid-rmse:0.034076
# [708]	train-rmse:0.004949	valid-rmse:0.034072
# [709]	train-rmse:0.004935	valid-rmse:0.034072
# [710]	train-rmse:0.004914	valid-rmse:0.034071
# [711]	train-rmse:0.004905	valid-rmse:0.03407
# [712]	train-rmse:0.004892	valid-rmse:0.034071
# [713]	train-rmse:0.004881	valid-rmse:0.034068
# [714]	train-rmse:0.004872	valid-rmse:0.034067
# [715]	train-rmse:0.004861	valid-rmse:0.034064
# [716]	train-rmse:0.004848	valid-rmse:0.034063
# [717]	train-rmse:0.004837	valid-rmse:0.034062
# [718]	train-rmse:0.004829	valid-rmse:0.034061
# [719]	train-rmse:0.004816	valid-rmse:0.034062
# [720]	train-rmse:0.004808	valid-rmse:0.03406
# [721]	train-rmse:0.004798	valid-rmse:0.034057
# [722]	train-rmse:0.004784	valid-rmse:0.03406
# [723]	train-rmse:0.004772	valid-rmse:0.034056
# [724]	train-rmse:0.004758	valid-rmse:0.034056
# [725]	train-rmse:0.004745	valid-rmse:0.034055
# [726]	train-rmse:0.004733	valid-rmse:0.034053
# [727]	train-rmse:0.004723	valid-rmse:0.03405
# [728]	train-rmse:0.00471	valid-rmse:0.034047
# [729]	train-rmse:0.004693	valid-rmse:0.034046
# [730]	train-rmse:0.004682	valid-rmse:0.034046
# [731]	train-rmse:0.004662	valid-rmse:0.03405
# [732]	train-rmse:0.004654	valid-rmse:0.03405
# [733]	train-rmse:0.004634	valid-rmse:0.034054
# [734]	train-rmse:0.004624	valid-rmse:0.034053
# [735]	train-rmse:0.004612	valid-rmse:0.034056
# [736]	train-rmse:0.004593	valid-rmse:0.034061
# [737]	train-rmse:0.004585	valid-rmse:0.03406
# [738]	train-rmse:0.004562	valid-rmse:0.034054
# [739]	train-rmse:0.00454	valid-rmse:0.034047
# Stopping. Best iteration:
# [729]	train-rmse:0.004693	valid-rmse:0.034046
# 2019-08-27 05:40:48,249 - ALPHA_MIND - INFO - Training time cost 4.713203191757202s
# 2019-08-27 05:40:48,249 - ALPHA_MIND - INFO - best_score = 0.034046, best_round = 729
# 2019-08-27 05:40:48,254 - ALPHA_MIND - INFO - 2018-01-05 00:00:00 total_data_test_excess: 500
# 2019-08-27 05:40:48,266 - ALPHA_MIND - INFO - 2018-01-05 00:00:00 len_of_total_data: 500
# 2019-08-27 05:40:48,277 - ALPHA_MIND - INFO - 2018-01-05 00:00:00 len_of_total_data_test_excess: 500
# 2019-08-27 05:40:48,279 - ALPHA_MIND - INFO - 2018-01-05 00:00:00 full re-balance: 500
# 2019-08-27 05:40:48,282 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-08-27 05:40:48,284 - ALPHA_MIND - INFO - shape_of_total_risk_exp_pre: (500, 36)
# 2019-08-27 05:40:48,285 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-08-27 05:40:48,287 - ALPHA_MIND - INFO - constraints: (2, 36) in 2018-01-05 00:00:00
# 2019-08-27 05:40:48,287 - ALPHA_MIND - INFO - lbound: (500,) in 2018-01-05 00:00:00
# 2019-08-27 05:40:48,288 - ALPHA_MIND - INFO - ubound: (500,) in 2018-01-05 00:00:00
# 2019-08-27 05:40:48,302 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-08-27 05:40:48,425 - ALPHA_MIND - INFO - target_pos_shape: (500, 3)
# 2019-08-27 05:40:48,426 - ALPHA_MIND - INFO - len_codes:(500,)
# 2019-08-27 05:40:48,433 - ALPHA_MIND - INFO - len_result: 500
# 2019-08-27 05:40:48,433 - ALPHA_MIND - INFO - len_rets: 1, len_trade_dates: 1
# 2019-08-27 05:40:48,435 - ALPHA_MIND - INFO - len_net_rets: 1, len_trade_dates: 1
# 2019-08-27 05:40:48,435 - ALPHA_MIND - INFO - 2018-01-05 00:00:00 is finished
# 2019-08-27 05:40:48,436 - ALPHA_MIND - INFO - 2018-01-10 00:00:00 is start
# 2019-08-27 05:40:48,448 - ALPHA_MIND - INFO - len_x_train: 1000, len_y_train: 1000
# 2019-08-27 05:40:48,448 - ALPHA_MIND - INFO - X_train.shape=(1000, 423), X_test.shape = (1000, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7f2e894ac278>>
# non_cross_validation。。。。
# [0]	train-rmse:0.496816	valid-rmse:0.496601
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.491873	valid-rmse:0.491662
# [2]	train-rmse:0.48698	valid-rmse:0.486773
# [3]	train-rmse:0.482137	valid-rmse:0.481932
# [4]	train-rmse:0.477341	valid-rmse:0.47714
# [5]	train-rmse:0.472594	valid-rmse:0.472397
# [6]	train-rmse:0.467895	valid-rmse:0.467701
# [7]	train-rmse:0.463242	valid-rmse:0.463052
# [8]	train-rmse:0.458637	valid-rmse:0.45845
# [9]	train-rmse:0.454077	valid-rmse:0.453894
# [10]	train-rmse:0.449564	valid-rmse:0.449384
# [11]	train-rmse:0.445095	valid-rmse:0.444919
# [12]	train-rmse:0.440671	valid-rmse:0.440499
# [13]	train-rmse:0.436292	valid-rmse:0.436123
# [14]	train-rmse:0.431957	valid-rmse:0.431792
# [15]	train-rmse:0.427665	valid-rmse:0.427504
# [16]	train-rmse:0.423417	valid-rmse:0.423259
# [17]	train-rmse:0.419211	valid-rmse:0.419057
# [18]	train-rmse:0.415047	valid-rmse:0.414897
# [19]	train-rmse:0.410925	valid-rmse:0.410779
# [20]	train-rmse:0.406844	valid-rmse:0.406703
# [21]	train-rmse:0.402805	valid-rmse:0.402667
# [22]	train-rmse:0.398806	valid-rmse:0.398672
# [23]	train-rmse:0.394847	valid-rmse:0.394718
# [24]	train-rmse:0.390928	valid-rmse:0.390803
# [25]	train-rmse:0.387049	valid-rmse:0.386928
# [26]	train-rmse:0.383208	valid-rmse:0.383091
# [27]	train-rmse:0.379406	valid-rmse:0.379294
# [28]	train-rmse:0.375642	valid-rmse:0.375534
# [29]	train-rmse:0.371917	valid-rmse:0.371813
# [30]	train-rmse:0.368228	valid-rmse:0.368129
# [31]	train-rmse:0.364577	valid-rmse:0.364482
# [32]	train-rmse:0.360962	valid-rmse:0.360872
# [33]	train-rmse:0.357384	valid-rmse:0.357298
# [34]	train-rmse:0.353842	valid-rmse:0.35376
# [35]	train-rmse:0.350335	valid-rmse:0.350258
# [36]	train-rmse:0.346864	valid-rmse:0.346792
# [37]	train-rmse:0.343427	valid-rmse:0.34336
# [38]	train-rmse:0.340026	valid-rmse:0.339963
# [39]	train-rmse:0.336658	valid-rmse:0.3366
# [40]	train-rmse:0.333325	valid-rmse:0.333272
# [41]	train-rmse:0.330025	valid-rmse:0.329977
# [42]	train-rmse:0.326758	valid-rmse:0.326715
# [43]	train-rmse:0.323524	valid-rmse:0.323486
# [44]	train-rmse:0.320323	valid-rmse:0.32029
# [45]	train-rmse:0.317154	valid-rmse:0.317126
# [46]	train-rmse:0.314017	valid-rmse:0.313994
# [47]	train-rmse:0.310912	valid-rmse:0.310894
# [48]	train-rmse:0.307838	valid-rmse:0.307825
# [49]	train-rmse:0.304795	valid-rmse:0.304788
# [50]	train-rmse:0.301782	valid-rmse:0.301787
# [51]	train-rmse:0.2988	valid-rmse:0.29881
# [52]	train-rmse:0.295848	valid-rmse:0.29587
# [53]	train-rmse:0.292926	valid-rmse:0.29296
# [54]	train-rmse:0.290034	valid-rmse:0.290073
# [55]	train-rmse:0.28717	valid-rmse:0.287221
# [56]	train-rmse:0.284336	valid-rmse:0.284398
# [57]	train-rmse:0.28153	valid-rmse:0.281598
# [58]	train-rmse:0.278753	valid-rmse:0.278832
# [59]	train-rmse:0.276003	valid-rmse:0.276089
# [60]	train-rmse:0.273281	valid-rmse:0.273379
# [61]	train-rmse:0.270587	valid-rmse:0.270697
# [62]	train-rmse:0.26792	valid-rmse:0.268036
# [63]	train-rmse:0.26528	valid-rmse:0.265408
# [64]	train-rmse:0.262667	valid-rmse:0.262807
# [65]	train-rmse:0.26008	valid-rmse:0.260227
# [66]	train-rmse:0.25752	valid-rmse:0.257678
# [67]	train-rmse:0.254985	valid-rmse:0.255156
# [68]	train-rmse:0.252476	valid-rmse:0.252653
# [69]	train-rmse:0.249993	valid-rmse:0.250182
# [70]	train-rmse:0.247534	valid-rmse:0.24773
# [71]	train-rmse:0.245101	valid-rmse:0.245309
# [72]	train-rmse:0.242692	valid-rmse:0.242913
# [73]	train-rmse:0.240307	valid-rmse:0.240536
# [74]	train-rmse:0.237947	valid-rmse:0.238188
# [75]	train-rmse:0.235611	valid-rmse:0.235864
# [76]	train-rmse:0.233298	valid-rmse:0.233559
# [77]	train-rmse:0.231009	valid-rmse:0.231283
# [78]	train-rmse:0.228743	valid-rmse:0.22903
# [79]	train-rmse:0.226501	valid-rmse:0.226795
# [80]	train-rmse:0.224281	valid-rmse:0.224587
# [81]	train-rmse:0.222083	valid-rmse:0.222398
# [82]	train-rmse:0.219908	valid-rmse:0.220236
# [83]	train-rmse:0.217755	valid-rmse:0.218096
# [84]	train-rmse:0.215624	valid-rmse:0.215973
# [85]	train-rmse:0.213515	valid-rmse:0.213877
# [86]	train-rmse:0.211427	valid-rmse:0.211802
# [87]	train-rmse:0.209361	valid-rmse:0.209744
# [88]	train-rmse:0.207315	valid-rmse:0.207712
# [89]	train-rmse:0.205291	valid-rmse:0.205696
# [90]	train-rmse:0.203287	valid-rmse:0.203706
# [91]	train-rmse:0.201303	valid-rmse:0.201736
# [92]	train-rmse:0.19934	valid-rmse:0.199788
# [93]	train-rmse:0.197397	valid-rmse:0.197853
# [94]	train-rmse:0.195473	valid-rmse:0.195945
# [95]	train-rmse:0.193569	valid-rmse:0.194057
# [96]	train-rmse:0.191685	valid-rmse:0.192183
# [97]	train-rmse:0.18982	valid-rmse:0.190333
# [98]	train-rmse:0.187974	valid-rmse:0.188497
# [99]	train-rmse:0.186143	valid-rmse:0.186702
# [100]	train-rmse:0.184334	valid-rmse:0.184903
# [101]	train-rmse:0.18254	valid-rmse:0.183149
# [102]	train-rmse:0.180764	valid-rmse:0.181414
# [103]	train-rmse:0.17901	valid-rmse:0.17967
# [104]	train-rmse:0.17727	valid-rmse:0.177971
# [105]	train-rmse:0.175548	valid-rmse:0.176289
# [106]	train-rmse:0.173843	valid-rmse:0.174626
# [107]	train-rmse:0.17216	valid-rmse:0.172953
# [108]	train-rmse:0.17049	valid-rmse:0.171328
# [109]	train-rmse:0.168837	valid-rmse:0.16972
# [110]	train-rmse:0.1672	valid-rmse:0.168123
# [111]	train-rmse:0.165585	valid-rmse:0.166519
# [112]	train-rmse:0.163982	valid-rmse:0.164962
# [113]	train-rmse:0.162395	valid-rmse:0.16342
# [114]	train-rmse:0.160824	valid-rmse:0.161894
# [115]	train-rmse:0.15927	valid-rmse:0.160375
# [116]	train-rmse:0.157736	valid-rmse:0.158853
# [117]	train-rmse:0.156213	valid-rmse:0.157374
# [118]	train-rmse:0.154705	valid-rmse:0.155911
# [119]	train-rmse:0.153213	valid-rmse:0.154464
# [120]	train-rmse:0.151741	valid-rmse:0.153003
# [121]	train-rmse:0.15028	valid-rmse:0.151587
# [122]	train-rmse:0.148833	valid-rmse:0.150184
# [123]	train-rmse:0.147401	valid-rmse:0.148787
# [124]	train-rmse:0.145984	valid-rmse:0.147415
# [125]	train-rmse:0.144586	valid-rmse:0.14603
# [126]	train-rmse:0.143198	valid-rmse:0.144688
# [127]	train-rmse:0.141825	valid-rmse:0.14336
# [128]	train-rmse:0.140465	valid-rmse:0.142037
# [129]	train-rmse:0.139124	valid-rmse:0.140709
# [130]	train-rmse:0.137793	valid-rmse:0.139423
# [131]	train-rmse:0.136475	valid-rmse:0.138149
# [132]	train-rmse:0.13517	valid-rmse:0.136886
# [133]	train-rmse:0.13388	valid-rmse:0.135638
# [134]	train-rmse:0.132607	valid-rmse:0.134379
# [135]	train-rmse:0.13134	valid-rmse:0.13315
# [136]	train-rmse:0.130084	valid-rmse:0.131933
# [137]	train-rmse:0.128844	valid-rmse:0.13073
# [138]	train-rmse:0.127615	valid-rmse:0.129529
# [139]	train-rmse:0.126402	valid-rmse:0.128361
# [140]	train-rmse:0.125198	valid-rmse:0.127194
# [141]	train-rmse:0.124007	valid-rmse:0.126031
# [142]	train-rmse:0.122827	valid-rmse:0.12489
# [143]	train-rmse:0.121662	valid-rmse:0.12377
# [144]	train-rmse:0.120506	valid-rmse:0.122658
# [145]	train-rmse:0.119363	valid-rmse:0.121557
# [146]	train-rmse:0.118231	valid-rmse:0.120468
# [147]	train-rmse:0.117113	valid-rmse:0.119405
# [148]	train-rmse:0.116004	valid-rmse:0.118342
# [149]	train-rmse:0.114907	valid-rmse:0.117289
# [150]	train-rmse:0.113821	valid-rmse:0.116249
# [151]	train-rmse:0.112745	valid-rmse:0.115216
# [152]	train-rmse:0.111681	valid-rmse:0.114198
# [153]	train-rmse:0.11063	valid-rmse:0.113204
# [154]	train-rmse:0.109587	valid-rmse:0.112211
# [155]	train-rmse:0.108555	valid-rmse:0.111219
# [156]	train-rmse:0.107534	valid-rmse:0.110242
# [157]	train-rmse:0.106525	valid-rmse:0.1093
# [158]	train-rmse:0.105524	valid-rmse:0.108343
# [159]	train-rmse:0.104534	valid-rmse:0.107401
# [160]	train-rmse:0.103553	valid-rmse:0.106462
# [161]	train-rmse:0.102586	valid-rmse:0.105562
# [162]	train-rmse:0.101626	valid-rmse:0.10465
# [163]	train-rmse:0.100675	valid-rmse:0.103745
# [164]	train-rmse:0.099734	valid-rmse:0.102851
# [165]	train-rmse:0.098804	valid-rmse:0.101965
# [166]	train-rmse:0.097886	valid-rmse:0.101102
# [167]	train-rmse:0.096974	valid-rmse:0.100241
# [168]	train-rmse:0.096072	valid-rmse:0.099391
# [169]	train-rmse:0.09518	valid-rmse:0.098544
# [170]	train-rmse:0.094297	valid-rmse:0.097716
# [171]	train-rmse:0.093426	valid-rmse:0.096893
# [172]	train-rmse:0.092561	valid-rmse:0.096086
# [173]	train-rmse:0.091704	valid-rmse:0.095291
# [174]	train-rmse:0.090861	valid-rmse:0.094514
# [175]	train-rmse:0.090024	valid-rmse:0.093723
# [176]	train-rmse:0.089198	valid-rmse:0.092947
# [177]	train-rmse:0.088377	valid-rmse:0.092189
# [178]	train-rmse:0.087568	valid-rmse:0.091443
# [179]	train-rmse:0.086768	valid-rmse:0.09069
# [180]	train-rmse:0.085972	valid-rmse:0.089958
# [181]	train-rmse:0.085184	valid-rmse:0.08922
# [182]	train-rmse:0.084409	valid-rmse:0.088492
# [183]	train-rmse:0.083636	valid-rmse:0.087777
# [184]	train-rmse:0.082877	valid-rmse:0.087087
# [185]	train-rmse:0.082124	valid-rmse:0.086374
# [186]	train-rmse:0.081376	valid-rmse:0.085679
# [187]	train-rmse:0.080637	valid-rmse:0.085005
# [188]	train-rmse:0.079902	valid-rmse:0.084351
# [189]	train-rmse:0.079178	valid-rmse:0.083716
# [190]	train-rmse:0.07846	valid-rmse:0.083059
# [191]	train-rmse:0.077755	valid-rmse:0.082411
# [192]	train-rmse:0.07705	valid-rmse:0.081775
# [193]	train-rmse:0.07636	valid-rmse:0.081142
# [194]	train-rmse:0.075673	valid-rmse:0.080543
# [195]	train-rmse:0.07499	valid-rmse:0.079929
# [196]	train-rmse:0.074322	valid-rmse:0.07932
# [197]	train-rmse:0.073654	valid-rmse:0.078721
# [198]	train-rmse:0.072996	valid-rmse:0.07815
# [199]	train-rmse:0.072344	valid-rmse:0.077561
# [200]	train-rmse:0.071695	valid-rmse:0.076984
# [201]	train-rmse:0.071059	valid-rmse:0.076419
# [202]	train-rmse:0.070428	valid-rmse:0.075851
# [203]	train-rmse:0.0698	valid-rmse:0.075299
# [204]	train-rmse:0.069184	valid-rmse:0.074756
# [205]	train-rmse:0.068569	valid-rmse:0.074214
# [206]	train-rmse:0.067966	valid-rmse:0.073684
# [207]	train-rmse:0.067364	valid-rmse:0.073159
# [208]	train-rmse:0.066768	valid-rmse:0.072647
# [209]	train-rmse:0.066183	valid-rmse:0.072132
# [210]	train-rmse:0.0656	valid-rmse:0.071633
# [211]	train-rmse:0.065027	valid-rmse:0.07113
# [212]	train-rmse:0.064461	valid-rmse:0.070635
# [213]	train-rmse:0.063896	valid-rmse:0.070154
# [214]	train-rmse:0.063338	valid-rmse:0.069665
# [215]	train-rmse:0.062785	valid-rmse:0.069188
# [216]	train-rmse:0.062238	valid-rmse:0.068728
# [217]	train-rmse:0.061699	valid-rmse:0.068268
# [218]	train-rmse:0.061163	valid-rmse:0.067807
# [219]	train-rmse:0.060634	valid-rmse:0.067363
# [220]	train-rmse:0.060112	valid-rmse:0.066922
# [221]	train-rmse:0.059591	valid-rmse:0.066482
# [222]	train-rmse:0.059078	valid-rmse:0.066053
# [223]	train-rmse:0.058566	valid-rmse:0.065604
# [224]	train-rmse:0.058065	valid-rmse:0.065186
# [225]	train-rmse:0.057571	valid-rmse:0.064773
# [226]	train-rmse:0.057084	valid-rmse:0.064368
# [227]	train-rmse:0.056594	valid-rmse:0.063954
# [228]	train-rmse:0.056111	valid-rmse:0.063552
# [229]	train-rmse:0.055639	valid-rmse:0.063162
# [230]	train-rmse:0.055164	valid-rmse:0.062768
# [231]	train-rmse:0.054699	valid-rmse:0.062385
# [232]	train-rmse:0.05424	valid-rmse:0.062018
# [233]	train-rmse:0.053781	valid-rmse:0.061642
# [234]	train-rmse:0.053334	valid-rmse:0.061279
# [235]	train-rmse:0.052885	valid-rmse:0.060911
# [236]	train-rmse:0.052437	valid-rmse:0.060541
# [237]	train-rmse:0.052001	valid-rmse:0.060188
# [238]	train-rmse:0.051566	valid-rmse:0.059832
# [239]	train-rmse:0.051139	valid-rmse:0.059479
# [240]	train-rmse:0.050717	valid-rmse:0.059136
# [241]	train-rmse:0.050298	valid-rmse:0.058796
# [242]	train-rmse:0.049875	valid-rmse:0.058451
# [243]	train-rmse:0.049462	valid-rmse:0.058117
# [244]	train-rmse:0.049057	valid-rmse:0.05778
# [245]	train-rmse:0.048654	valid-rmse:0.057463
# [246]	train-rmse:0.048259	valid-rmse:0.057148
# [247]	train-rmse:0.047869	valid-rmse:0.056831
# [248]	train-rmse:0.047478	valid-rmse:0.05652
# [249]	train-rmse:0.047094	valid-rmse:0.056202
# [250]	train-rmse:0.046709	valid-rmse:0.055917
# [251]	train-rmse:0.046334	valid-rmse:0.055613
# [252]	train-rmse:0.04596	valid-rmse:0.055324
# [253]	train-rmse:0.045585	valid-rmse:0.055027
# ...
# [558]	train-rmse:0.033238	valid-rmse:0.033346
# [559]	train-rmse:0.033229	valid-rmse:0.033346
# [560]	train-rmse:0.033222	valid-rmse:0.033344
# [561]	train-rmse:0.033217	valid-rmse:0.033344
# [562]	train-rmse:0.033209	valid-rmse:0.033342
# [563]	train-rmse:0.033202	valid-rmse:0.033343
# [564]	train-rmse:0.033196	valid-rmse:0.033341
# [565]	train-rmse:0.033189	valid-rmse:0.03334
# [566]	train-rmse:0.033183	valid-rmse:0.03334
# [567]	train-rmse:0.033177	valid-rmse:0.033341
# [568]	train-rmse:0.033172	valid-rmse:0.033342
# [569]	train-rmse:0.033166	valid-rmse:0.033341
# [570]	train-rmse:0.03316	valid-rmse:0.033342
# [571]	train-rmse:0.033154	valid-rmse:0.033343
# [572]	train-rmse:0.033148	valid-rmse:0.033343
# [573]	train-rmse:0.033141	valid-rmse:0.033341
# [574]	train-rmse:0.033135	valid-rmse:0.033341
# [575]	train-rmse:0.033127	valid-rmse:0.033339
# [576]	train-rmse:0.033121	valid-rmse:0.033338
# [577]	train-rmse:0.033113	valid-rmse:0.033338
# [578]	train-rmse:0.033106	valid-rmse:0.033339
# [579]	train-rmse:0.033101	valid-rmse:0.033339
# [580]	train-rmse:0.033095	valid-rmse:0.033338
# [581]	train-rmse:0.033089	valid-rmse:0.033338
# [582]	train-rmse:0.033084	valid-rmse:0.033336
# [583]	train-rmse:0.033078	valid-rmse:0.033336
# [584]	train-rmse:0.033072	valid-rmse:0.033336
# [585]	train-rmse:0.033066	valid-rmse:0.033335
# [586]	train-rmse:0.033061	valid-rmse:0.033335
# [587]	train-rmse:0.033054	valid-rmse:0.033336
# [588]	train-rmse:0.03305	valid-rmse:0.033338
# [589]	train-rmse:0.033044	valid-rmse:0.033337
# [590]	train-rmse:0.033038	valid-rmse:0.033337
# [591]	train-rmse:0.033032	valid-rmse:0.033337
# [592]	train-rmse:0.033027	valid-rmse:0.033336
# [593]	train-rmse:0.033021	valid-rmse:0.033334
# [594]	train-rmse:0.033015	valid-rmse:0.033332
# [595]	train-rmse:0.033009	valid-rmse:0.033332
# [596]	train-rmse:0.033004	valid-rmse:0.033332
# [597]	train-rmse:0.032998	valid-rmse:0.033331
# [598]	train-rmse:0.032992	valid-rmse:0.033332
# [599]	train-rmse:0.032988	valid-rmse:0.033333
# [600]	train-rmse:0.032982	valid-rmse:0.033331
# [601]	train-rmse:0.032977	valid-rmse:0.033331
# [602]	train-rmse:0.032972	valid-rmse:0.033332
# [603]	train-rmse:0.032965	valid-rmse:0.033334
# [604]	train-rmse:0.032958	valid-rmse:0.033335
# [605]	train-rmse:0.032954	valid-rmse:0.033334
# [606]	train-rmse:0.032948	valid-rmse:0.033336
# [607]	train-rmse:0.032943	valid-rmse:0.033338
# Stopping. Best iteration:
# [597]	train-rmse:0.032998	valid-rmse:0.033331
# 2019-08-27 05:57:25,890 - ALPHA_MIND - INFO - Training time cost 33.19014620780945s
# 2019-08-27 05:57:25,890 - ALPHA_MIND - INFO - best_score = 0.033331, best_round = 597
# 2019-08-27 05:57:25,895 - ALPHA_MIND - INFO - 2018-09-12 00:00:00 total_data_test_excess: 500
# 2019-08-27 05:57:25,907 - ALPHA_MIND - INFO - 2018-09-12 00:00:00 len_of_total_data: 500
# 2019-08-27 05:57:25,916 - ALPHA_MIND - INFO - 2018-09-12 00:00:00 len_of_total_data_test_excess: 500
# 2019-08-27 05:57:25,918 - ALPHA_MIND - INFO - 2018-09-12 00:00:00 full re-balance: 500
# 2019-08-27 05:57:25,921 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-08-27 05:57:25,923 - ALPHA_MIND - INFO - shape_of_total_risk_exp_pre: (500, 36)
# 2019-08-27 05:57:25,924 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-08-27 05:57:25,926 - ALPHA_MIND - INFO - constraints: (2, 36) in 2018-09-12 00:00:00
# 2019-08-27 05:57:25,926 - ALPHA_MIND - INFO - lbound: (500,) in 2018-09-12 00:00:00
# 2019-08-27 05:57:25,927 - ALPHA_MIND - INFO - ubound: (500,) in 2018-09-12 00:00:00
# 2019-08-27 05:57:25,939 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-08-27 05:57:26,026 - ALPHA_MIND - INFO - target_pos_shape: (500, 3)
# 2019-08-27 05:57:26,026 - ALPHA_MIND - INFO - len_codes:(500,)
# 2019-08-27 05:57:26,037 - ALPHA_MIND - INFO - len_result: 500
# 2019-08-27 05:57:26,038 - ALPHA_MIND - INFO - len_rets: 57, len_trade_dates: 57
# 2019-08-27 05:57:26,045 - ALPHA_MIND - INFO - len_net_rets: 57, len_trade_dates: 57
# 2019-08-27 05:57:26,046 - ALPHA_MIND - INFO - 2018-09-12 00:00:00 is finished
# 2019-08-27 05:57:26,047 - ALPHA_MIND - INFO - 2018-09-17 00:00:00 is start
# 2019-08-27 05:57:26,309 - ALPHA_MIND - INFO - len_x_train: 29000, len_y_train: 29000
# 2019-08-27 05:57:26,309 - ALPHA_MIND - INFO - X_train.shape=(29000, 423), X_test.shape = (29000, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7f2e9a5cdc50>>
# non_cross_validation。。。。
# [0]	train-rmse:0.496972	valid-rmse:0.496622
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.492029	valid-rmse:0.491678
# [2]	train-rmse:0.487136	valid-rmse:0.486784
# [3]	train-rmse:0.482292	valid-rmse:0.481939
# [4]	train-rmse:0.477497	valid-rmse:0.477142
# [5]	train-rmse:0.472749	valid-rmse:0.472394
# [6]	train-rmse:0.46805	valid-rmse:0.467693
# [7]	train-rmse:0.463398	valid-rmse:0.46304
# [8]	train-rmse:0.458793	valid-rmse:0.458433
# [9]	train-rmse:0.454233	valid-rmse:0.453873
# [10]	train-rmse:0.44972	valid-rmse:0.449359
# [11]	train-rmse:0.445253	valid-rmse:0.44489
# [12]	train-rmse:0.44083	valid-rmse:0.440466
# [13]	train-rmse:0.436452	valid-rmse:0.436086
# [14]	train-rmse:0.432118	valid-rmse:0.431751
# [15]	train-rmse:0.427827	valid-rmse:0.427459
# [16]	train-rmse:0.42358	valid-rmse:0.423211
# [17]	train-rmse:0.419375	valid-rmse:0.419005
# [18]	train-rmse:0.415213	valid-rmse:0.414841
# [19]	train-rmse:0.411093	valid-rmse:0.41072
# [20]	train-rmse:0.407014	valid-rmse:0.40664
# [21]	train-rmse:0.402977	valid-rmse:0.402601
# [22]	train-rmse:0.39898	valid-rmse:0.398602
# [23]	train-rmse:0.395023	valid-rmse:0.394644
# [24]	train-rmse:0.391107	valid-rmse:0.390726
# [25]	train-rmse:0.387229	valid-rmse:0.386848
# [26]	train-rmse:0.383391	valid-rmse:0.383008
# [27]	train-rmse:0.379592	valid-rmse:0.379207
# [28]	train-rmse:0.375831	valid-rmse:0.375445
# [29]	train-rmse:0.372108	valid-rmse:0.37172
# [30]	train-rmse:0.368423	valid-rmse:0.368033
# [31]	train-rmse:0.364774	valid-rmse:0.364383
# [32]	train-rmse:0.361163	valid-rmse:0.360771
# [33]	train-rmse:0.357588	valid-rmse:0.357194
# [34]	train-rmse:0.354049	valid-rmse:0.353654
# [35]	train-rmse:0.350546	valid-rmse:0.350149
# [36]	train-rmse:0.347078	valid-rmse:0.34668
# [37]	train-rmse:0.343646	valid-rmse:0.343245
# [38]	train-rmse:0.340248	valid-rmse:0.339846
# [39]	train-rmse:0.336884	valid-rmse:0.336481
# [40]	train-rmse:0.333554	valid-rmse:0.333149
# [41]	train-rmse:0.330259	valid-rmse:0.329852
# [42]	train-rmse:0.326996	valid-rmse:0.326588
# [43]	train-rmse:0.323767	valid-rmse:0.323356
# [44]	train-rmse:0.32057	valid-rmse:0.320158
# [45]	train-rmse:0.317405	valid-rmse:0.316992
# [46]	train-rmse:0.314273	valid-rmse:0.313858
# [47]	train-rmse:0.311172	valid-rmse:0.310755
# [48]	train-rmse:0.308103	valid-rmse:0.307684
# [49]	train-rmse:0.305065	valid-rmse:0.304644
# [50]	train-rmse:0.302058	valid-rmse:0.301635
# [51]	train-rmse:0.299081	valid-rmse:0.298657
# [52]	train-rmse:0.296134	valid-rmse:0.295708
# [53]	train-rmse:0.293218	valid-rmse:0.29279
# [54]	train-rmse:0.29033	valid-rmse:0.289901
# [55]	train-rmse:0.287473	valid-rmse:0.287041
# [56]	train-rmse:0.284644	valid-rmse:0.28421
# [57]	train-rmse:0.281844	valid-rmse:0.281408
# [58]	train-rmse:0.279072	valid-rmse:0.278633
# [59]	train-rmse:0.276329	valid-rmse:0.275885
# [60]	train-rmse:0.273614	valid-rmse:0.273165
# [61]	train-rmse:0.270926	valid-rmse:0.270473
# [62]	train-rmse:0.268265	valid-rmse:0.267808
# [63]	train-rmse:0.265632	valid-rmse:0.265171
# [64]	train-rmse:0.263025	valid-rmse:0.26256
# [65]	train-rmse:0.260445	valid-rmse:0.259976
# [66]	train-rmse:0.257892	valid-rmse:0.257418
# [67]	train-rmse:0.255364	valid-rmse:0.254886
# [68]	train-rmse:0.252862	valid-rmse:0.25238
# [69]	train-rmse:0.250385	valid-rmse:0.249899
# [70]	train-rmse:0.247934	valid-rmse:0.247444
# [71]	train-rmse:0.245508	valid-rmse:0.245013
# [72]	train-rmse:0.243107	valid-rmse:0.242608
# [73]	train-rmse:0.24073	valid-rmse:0.240227
# [74]	train-rmse:0.238378	valid-rmse:0.23787
# [75]	train-rmse:0.236049	valid-rmse:0.235538
# [76]	train-rmse:0.233745	valid-rmse:0.233229
# [77]	train-rmse:0.231464	valid-rmse:0.230945
# [78]	train-rmse:0.229206	valid-rmse:0.228683
# [79]	train-rmse:0.226971	valid-rmse:0.226446
# [80]	train-rmse:0.22476	valid-rmse:0.22423
# [81]	train-rmse:0.22257	valid-rmse:0.222038
# [82]	train-rmse:0.220404	valid-rmse:0.219868
# [83]	train-rmse:0.218259	valid-rmse:0.217718
# [84]	train-rmse:0.216136	valid-rmse:0.215593
# [85]	train-rmse:0.214035	valid-rmse:0.213489
# [86]	train-rmse:0.211956	valid-rmse:0.211405
# [87]	train-rmse:0.209898	valid-rmse:0.209344
# [88]	train-rmse:0.207861	valid-rmse:0.207303
# [89]	train-rmse:0.205845	valid-rmse:0.205284
# [90]	train-rmse:0.20385	valid-rmse:0.203288
# [91]	train-rmse:0.201876	valid-rmse:0.201308
# [92]	train-rmse:0.199921	valid-rmse:0.199351
# [93]	train-rmse:0.197987	valid-rmse:0.197413
# [94]	train-rmse:0.196073	valid-rmse:0.195503
# [95]	train-rmse:0.194179	valid-rmse:0.193606
# [96]	train-rmse:0.192304	valid-rmse:0.191726
# [97]	train-rmse:0.190448	valid-rmse:0.189876
# [98]	train-rmse:0.188612	valid-rmse:0.188036
# [99]	train-rmse:0.186795	valid-rmse:0.186222
# [100]	train-rmse:0.184997	valid-rmse:0.184421
# [101]	train-rmse:0.183217	valid-rmse:0.182647
# [102]	train-rmse:0.181455	valid-rmse:0.180884
# [103]	train-rmse:0.179711	valid-rmse:0.179138
# [104]	train-rmse:0.177987	valid-rmse:0.177412
# [105]	train-rmse:0.176279	valid-rmse:0.17571
# [106]	train-rmse:0.17459	valid-rmse:0.174018
# [107]	train-rmse:0.172918	valid-rmse:0.172351
# [108]	train-rmse:0.171263	valid-rmse:0.170702
# [109]	train-rmse:0.169626	valid-rmse:0.169064
# [110]	train-rmse:0.168006	valid-rmse:0.167441
# [111]	train-rmse:0.166403	valid-rmse:0.165843
# [112]	train-rmse:0.164817	valid-rmse:0.164255
# [113]	train-rmse:0.163246	valid-rmse:0.162689
# [114]	train-rmse:0.161692	valid-rmse:0.161134
# [115]	train-rmse:0.160155	valid-rmse:0.159596
# [116]	train-rmse:0.158633	valid-rmse:0.158079
# [117]	train-rmse:0.157128	valid-rmse:0.156573
# [118]	train-rmse:0.155638	valid-rmse:0.155087
# [119]	train-rmse:0.154164	valid-rmse:0.153617
# [120]	train-rmse:0.152706	valid-rmse:0.152155
# [121]	train-rmse:0.151262	valid-rmse:0.150712
# [122]	train-rmse:0.149834	valid-rmse:0.149285
# [123]	train-rmse:0.148421	valid-rmse:0.147871
# [124]	train-rmse:0.147023	valid-rmse:0.146472
# [125]	train-rmse:0.14564	valid-rmse:0.145092
# [126]	train-rmse:0.144271	valid-rmse:0.143727
# [127]	train-rmse:0.142916	valid-rmse:0.142374
# [128]	train-rmse:0.141576	valid-rmse:0.141033
# [129]	train-rmse:0.14025	valid-rmse:0.139705
# [130]	train-rmse:0.138938	valid-rmse:0.138396
# [131]	train-rmse:0.13764	valid-rmse:0.137097
# [132]	train-rmse:0.136355	valid-rmse:0.135816
# [133]	train-rmse:0.135085	valid-rmse:0.134547
# [134]	train-rmse:0.133828	valid-rmse:0.133286
# [135]	train-rmse:0.132584	valid-rmse:0.132049
# [136]	train-rmse:0.131354	valid-rmse:0.130816
# [137]	train-rmse:0.130136	valid-rmse:0.129595
# [138]	train-rmse:0.128932	valid-rmse:0.128395
# [139]	train-rmse:0.127741	valid-rmse:0.127206
# [140]	train-rmse:0.126562	valid-rmse:0.126042
# [141]	train-rmse:0.125396	valid-rmse:0.124875
# [142]	train-rmse:0.124243	valid-rmse:0.123725
# [143]	train-rmse:0.123102	valid-rmse:0.122585
# [144]	train-rmse:0.121973	valid-rmse:0.12146
# [145]	train-rmse:0.120857	valid-rmse:0.120348
# [146]	train-rmse:0.119752	valid-rmse:0.119243
# [147]	train-rmse:0.118659	valid-rmse:0.118153
# [148]	train-rmse:0.117578	valid-rmse:0.11708
# [149]	train-rmse:0.116509	valid-rmse:0.116012
# [150]	train-rmse:0.115452	valid-rmse:0.114959
# [151]	train-rmse:0.114406	valid-rmse:0.113916
# [152]	train-rmse:0.113371	valid-rmse:0.112894
# [153]	train-rmse:0.112348	valid-rmse:0.111871
# [154]	train-rmse:0.111336	valid-rmse:0.110861
# [155]	train-rmse:0.110335	valid-rmse:0.109865
# [156]	train-rmse:0.109345	valid-rmse:0.108887
# [157]	train-rmse:0.108366	valid-rmse:0.107907
# [158]	train-rmse:0.107397	valid-rmse:0.106939
# [159]	train-rmse:0.106439	valid-rmse:0.105986
# [160]	train-rmse:0.105492	valid-rmse:0.105039
# [161]	train-rmse:0.104555	valid-rmse:0.104118
# [162]	train-rmse:0.103628	valid-rmse:0.103194
# [163]	train-rmse:0.102712	valid-rmse:0.102277
# [164]	train-rmse:0.101806	valid-rmse:0.101372
# [165]	train-rmse:0.10091	valid-rmse:0.100486
# [166]	train-rmse:0.100023	valid-rmse:0.099602
# [167]	train-rmse:0.099147	valid-rmse:0.09873
# [168]	train-rmse:0.098281	valid-rmse:0.097863
# [169]	train-rmse:0.097425	valid-rmse:0.097008
# [170]	train-rmse:0.096578	valid-rmse:0.096178
# [171]	train-rmse:0.09574	valid-rmse:0.095339
# [172]	train-rmse:0.094912	valid-rmse:0.094513
# [173]	train-rmse:0.094093	valid-rmse:0.093695
# [174]	train-rmse:0.093284	valid-rmse:0.092898
# [175]	train-rmse:0.092483	valid-rmse:0.092099
# [176]	train-rmse:0.091692	valid-rmse:0.091312
# [177]	train-rmse:0.09091	valid-rmse:0.09053
# [178]	train-rmse:0.090137	valid-rmse:0.089757
# [179]	train-rmse:0.089373	valid-rmse:0.088993
# [180]	train-rmse:0.088617	valid-rmse:0.088243
# [181]	train-rmse:0.08787	valid-rmse:0.087498
# [182]	train-rmse:0.087131	valid-rmse:0.086759
# [183]	train-rmse:0.086402	valid-rmse:0.086033
# [184]	train-rmse:0.08568	valid-rmse:0.08532
# [185]	train-rmse:0.084967	valid-rmse:0.084608
# [186]	train-rmse:0.084262	valid-rmse:0.083909
# [187]	train-rmse:0.083565	valid-rmse:0.083215
# [188]	train-rmse:0.082877	valid-rmse:0.082536
# [189]	train-rmse:0.082196	valid-rmse:0.081858
# [190]	train-rmse:0.081524	valid-rmse:0.081188
# [191]	train-rmse:0.080859	valid-rmse:0.080529
# [192]	train-rmse:0.080202	valid-rmse:0.079879
# [193]	train-rmse:0.079553	valid-rmse:0.079239
# [194]	train-rmse:0.078911	valid-rmse:0.078597
# [195]	train-rmse:0.078277	valid-rmse:0.077972
# [196]	train-rmse:0.077651	valid-rmse:0.077348
# [197]	train-rmse:0.077032	valid-rmse:0.07673
# [198]	train-rmse:0.07642	valid-rmse:0.076118
# [199]	train-rmse:0.075816	valid-rmse:0.07552
# [200]	train-rmse:0.075219	valid-rmse:0.074931
# [201]	train-rmse:0.074629	valid-rmse:0.074339
# [202]	train-rmse:0.074048	valid-rmse:0.073763
# [203]	train-rmse:0.073472	valid-rmse:0.073196
# [204]	train-rmse:0.072903	valid-rmse:0.07263
# [205]	train-rmse:0.072342	valid-rmse:0.072068
# [206]	train-rmse:0.071787	valid-rmse:0.07152
# [207]	train-rmse:0.071238	valid-rmse:0.070968
# [208]	train-rmse:0.070698	valid-rmse:0.070433
# [209]	train-rmse:0.070163	valid-rmse:0.069908
# [210]	train-rmse:0.069634	valid-rmse:0.06938
# [211]	train-rmse:0.069112	valid-rmse:0.068859
# [212]	train-rmse:0.068597	valid-rmse:0.068344
# [213]	train-rmse:0.068089	valid-rmse:0.067842
# [214]	train-rmse:0.067587	valid-rmse:0.067349
# [215]	train-rmse:0.067091	valid-rmse:0.066857
# [216]	train-rmse:0.066602	valid-rmse:0.066374
# [217]	train-rmse:0.066118	valid-rmse:0.065891
# [218]	train-rmse:0.06564	valid-rmse:0.065413
# [219]	train-rmse:0.065168	valid-rmse:0.064942
# [220]	train-rmse:0.064702	valid-rmse:0.06448
# [221]	train-rmse:0.064244	valid-rmse:0.064027
# [222]	train-rmse:0.06379	valid-rmse:0.063577
# [223]	train-rmse:0.063342	valid-rmse:0.063139
# [224]	train-rmse:0.062899	valid-rmse:0.062698
# [225]	train-rmse:0.062462	valid-rmse:0.062261
# [226]	train-rmse:0.062032	valid-rmse:0.061837
# [227]	train-rmse:0.061607	valid-rmse:0.061416
# [228]	train-rmse:0.061186	valid-rmse:0.060997
# [229]	train-rmse:0.060772	valid-rmse:0.060584
# [230]	train-rmse:0.060363	valid-rmse:0.060176
# [231]	train-rmse:0.059958	valid-rmse:0.059772
# [232]	train-rmse:0.059561	valid-rmse:0.059381
# [233]	train-rmse:0.059168	valid-rmse:0.058998
# [234]	train-rmse:0.058781	valid-rmse:0.058611
# [235]	train-rmse:0.058397	valid-rmse:0.058228
# [236]	train-rmse:0.058019	valid-rmse:0.057853
# [237]	train-rmse:0.057646	valid-rmse:0.05748
# [238]	train-rmse:0.057278	valid-rmse:0.057112
# [239]	train-rmse:0.056916	valid-rmse:0.056757
# [240]	train-rmse:0.056558	valid-rmse:0.056403
# [241]	train-rmse:0.056205	valid-rmse:0.05606
# [242]	train-rmse:0.055858	valid-rmse:0.05572
# [243]	train-rmse:0.055514	valid-rmse:0.055377
# [244]	train-rmse:0.055176	valid-rmse:0.055044
# [245]	train-rmse:0.054841	valid-rmse:0.054714
# [246]	train-rmse:0.054511	valid-rmse:0.054386
# [247]	train-rmse:0.054185	valid-rmse:0.054063
# [248]	train-rmse:0.053865	valid-rmse:0.053747
# [249]	train-rmse:0.053548	valid-rmse:0.053432
# [250]	train-rmse:0.053237	valid-rmse:0.053127
# [251]	train-rmse:0.052929	valid-rmse:0.05282
# [252]	train-rmse:0.052627	valid-rmse:0.052525
# [253]	train-rmse:0.052328	valid-rmse:0.052232

# %%
from pyecharts import options as opts
from example.commons import Collector
from pyecharts.charts import Line

plot = ret_df[['xgb_regress', 'net_xgb_regress']].cumsum()
v1 = list(plot.index)
v2 = list(plot.xgb_regress)
v3 = list(plot.net_xgb_regress)

line_chart = (
    Line()
    .add_xaxis(v1)
    .add_yaxis("xgb_regress", v2)
    .add_yaxis("net_xgb_regress", v3)
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        datazoom_opts=[opts.DataZoomOpts(pos_bottom="-1%")],
        title_opts=opts.TitleOpts(title='Fixed freq rebalanced: {0}'.format(freq)),
    )
)

line_chart.render_notebook()

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['net_xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['net_xgb_regress']/ np.std(ret_df['net_xgb_regress']))))

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['xgb_regress']/ np.std(ret_df['xgb_regress']))))
