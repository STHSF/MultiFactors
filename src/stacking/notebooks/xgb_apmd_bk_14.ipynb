# %% [markdown]
# # 基础因子risk—netural回测结果

# %% [markdown]
# 添加费后曲线

# %%
# %matplotlib inline
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../../')
import pandas as pd
from PyFin.api import *
from alphamind.api import *
from src.conf.models import *
import numpy as np
from alphamind.execution.naiveexecutor import NaiveExecutor
from matplotlib import pyplot as plt

data_source = 'postgresql+psycopg2://alpha:alpha@180.166.26.82:8889/alpha'
engine = SqlEngine(data_source)

# %%
universe = Universe('zz500')
freq = '2b'
benchmark_code = 905
start_date = '2018-01-01'
end_date = '2019-08-01'
ref_dates = makeSchedule(start_date, end_date, freq, 'china.sse')
horizon = map_freq(freq)
industry_name = 'sw'
industry_level = 1

# %%
basic_factor_store = {
    'AccountsPayablesTDays': CSQuantiles(LAST('AccountsPayablesTDays'), groups='sw1'), 
    'AccountsPayablesTRate': CSQuantiles(LAST('AccountsPayablesTRate'), groups='sw1'), 
    'AdminiExpenseRate': CSQuantiles(LAST('AdminiExpenseRate'), groups='sw1'), 
    'ARTDays': CSQuantiles(LAST('ARTDays'), groups='sw1'), 
    'ARTRate': CSQuantiles(LAST('ARTRate'), groups='sw1'), 
    'ASSI': CSQuantiles(LAST('ASSI'), groups='sw1'), 
    'BLEV': CSQuantiles(LAST('BLEV'), groups='sw1'), 
    'BondsPayableToAsset': CSQuantiles(LAST('BondsPayableToAsset'), groups='sw1'), 
    'CashRateOfSales': CSQuantiles(LAST('CashRateOfSales'), groups='sw1'), 
    'CashToCurrentLiability': CSQuantiles(LAST('CashToCurrentLiability'), groups='sw1'), 
    'CMRA': CSQuantiles(LAST('CMRA'), groups='sw1'), 
    'CTOP': CSQuantiles(LAST('CTOP'), groups='sw1'), 
    'CTP5': CSQuantiles(LAST('CTP5'), groups='sw1'), 
    'CurrentAssetsRatio': CSQuantiles(LAST('CurrentAssetsRatio'), groups='sw1'), 
    'CurrentAssetsTRate': CSQuantiles(LAST('CurrentAssetsTRate'), groups='sw1'), 
    'CurrentRatio': CSQuantiles(LAST('CurrentRatio'), groups='sw1'), 
    'DAVOL10': CSQuantiles(LAST('DAVOL10'), groups='sw1'), 
    'DAVOL20': CSQuantiles(LAST('DAVOL20'), groups='sw1'), 
    'DAVOL5': CSQuantiles(LAST('DAVOL5'), groups='sw1'), 
    'DDNBT': CSQuantiles(LAST('DDNBT'), groups='sw1'), 
    'DDNCR': CSQuantiles(LAST('DDNCR'), groups='sw1'), 
    'DDNSR': CSQuantiles(LAST('DDNSR'), groups='sw1'), 
    'DebtEquityRatio': CSQuantiles(LAST('DebtEquityRatio'), groups='sw1'), 
    'DebtsAssetRatio': CSQuantiles(LAST('DebtsAssetRatio'), groups='sw1'), 
    'DHILO': CSQuantiles(LAST('DHILO'), groups='sw1'), 
    'DilutedEPS': CSQuantiles(LAST('DilutedEPS'), groups='sw1'), 
    'DVRAT': CSQuantiles(LAST('DVRAT'), groups='sw1'), 
    'EBITToTOR': CSQuantiles(LAST('EBITToTOR'), groups='sw1'), 
    'EGRO': CSQuantiles(LAST('EGRO'), groups='sw1'), 
    'EMA10': CSQuantiles(LAST('EMA10'), groups='sw1'), 
    'EMA120': CSQuantiles(LAST('EMA120'), groups='sw1'), 
    'EMA20': CSQuantiles(LAST('EMA20'), groups='sw1'), 
    'EMA5': CSQuantiles(LAST('EMA5'), groups='sw1'), 
    'EMA60': CSQuantiles(LAST('EMA60'), groups='sw1'), 
    'EPS': CSQuantiles(LAST('EPS'), groups='sw1'), 
    'EquityFixedAssetRatio': CSQuantiles(LAST('EquityFixedAssetRatio'), groups='sw1'), 
    'EquityToAsset': CSQuantiles(LAST('EquityToAsset'), groups='sw1'), 
    'EquityTRate': CSQuantiles(LAST('EquityTRate'), groups='sw1'), 
    'ETOP': CSQuantiles(LAST('ETOP'), groups='sw1'), 
    'ETP5': CSQuantiles(LAST('ETP5'), groups='sw1'), 
    'FinancialExpenseRate': CSQuantiles(LAST('FinancialExpenseRate'), groups='sw1'), 
    'FinancingCashGrowRate': CSQuantiles(LAST('FinancingCashGrowRate'), groups='sw1'), 
    'FixAssetRatio': CSQuantiles(LAST('FixAssetRatio'), groups='sw1'), 
    'FixedAssetsTRate': CSQuantiles(LAST('FixedAssetsTRate'), groups='sw1'), 
    'GrossIncomeRatio': CSQuantiles(LAST('GrossIncomeRatio'), groups='sw1'), 
    'HBETA': CSQuantiles(LAST('HBETA'), groups='sw1'), 
    'HSIGMA': CSQuantiles(LAST('HBETA'), groups='sw1'), 
    'IntangibleAssetRatio': CSQuantiles(LAST('IntangibleAssetRatio'), groups='sw1'), 
    'InventoryTDays': CSQuantiles(LAST('InventoryTDays'), groups='sw1'), 
    'InventoryTRate': CSQuantiles(LAST('InventoryTRate'), groups='sw1'), 
    'InvestCashGrowRate': CSQuantiles(LAST('InvestCashGrowRate'), groups='sw1'), 
    'LCAP': CSQuantiles(LAST('LCAP'), groups='sw1'), 
    'LFLO': CSQuantiles(LAST('LFLO'), groups='sw1'), 
    'LongDebtToAsset': CSQuantiles(LAST('LongDebtToAsset'), groups='sw1'), 
    'LongDebtToWorkingCapital': CSQuantiles(LAST('LongDebtToWorkingCapital'), groups='sw1'), 
    'LongTermDebtToAsset': CSQuantiles(LAST('LongTermDebtToAsset'), groups='sw1'), 
    'MA10': CSQuantiles(LAST('MA10'), groups='sw1'), 
    'MA120': CSQuantiles(LAST('MA120'), groups='sw1'), 
    'MA20': CSQuantiles(LAST('MA20'), groups='sw1'), 
    'MA5': CSQuantiles(LAST('MA5'), groups='sw1'), 
    'MA60': CSQuantiles(LAST('MA60'), groups='sw1'), 
    'MAWVAD': CSQuantiles(LAST('MAWVAD'), groups='sw1'), 
    'MFI': CSQuantiles(LAST('MFI'), groups='sw1'), 
    'MLEV': CSQuantiles(LAST('MLEV'), groups='sw1'), 
    'NetAssetGrowRate': CSQuantiles(LAST('NetAssetGrowRate'), groups='sw1'), 
    'NetProfitGrowRate': CSQuantiles(LAST('NetProfitGrowRate'), groups='sw1'), 
    'NetProfitRatio': CSQuantiles(LAST('NetProfitRatio'), groups='sw1'), 
    'NOCFToOperatingNI': CSQuantiles(LAST('NetProfitRatio'), groups='sw1'), 
    'NonCurrentAssetsRatio': CSQuantiles(LAST('NonCurrentAssetsRatio'), groups='sw1'), 
    'NPParentCompanyGrowRate': CSQuantiles(LAST('NPParentCompanyGrowRate'), groups='sw1'), 
    'NPToTOR': CSQuantiles(LAST('NPToTOR'), groups='sw1'), 
    'OperatingExpenseRate': CSQuantiles(LAST('OperatingExpenseRate'), groups='sw1'), 
    'OperatingProfitGrowRate': CSQuantiles(LAST('OperatingProfitGrowRate'), groups='sw1'), 
    'OperatingProfitRatio': CSQuantiles(LAST('OperatingProfitRatio'), groups='sw1'), 
    'OperatingProfitToTOR': CSQuantiles(LAST('OperatingProfitToTOR'), groups='sw1'), 
    'OperatingRevenueGrowRate': CSQuantiles(LAST('OperatingRevenueGrowRate'), groups='sw1'), 
    'OperCashGrowRate': CSQuantiles(LAST('OperCashGrowRate'), groups='sw1'), 
    'OperCashInToCurrentLiability': CSQuantiles(LAST('OperCashInToCurrentLiability'), groups='sw1'), 
    'PB': CSQuantiles(LAST('PB'), groups='sw1'), 
    'PCF': CSQuantiles(LAST('PCF'), groups='sw1'), 
    'PE': CSQuantiles(LAST('PE'), groups='sw1'), 
    'PS': CSQuantiles(LAST('PS'), groups='sw1'), 
    'PSY': CSQuantiles(LAST('PSY'), groups='sw1'), 
    'QuickRatio': CSQuantiles(LAST('QuickRatio'), groups='sw1'), 
    'REVS10': CSQuantiles(LAST('REVS10'), groups='sw1'), 
    'REVS20': CSQuantiles(LAST('REVS20'), groups='sw1'), 
    'REVS5': CSQuantiles(LAST('REVS5'), groups='sw1'), 
    'ROA': CSQuantiles(LAST('REVS5'), groups='sw1'), 
    'ROA5': CSQuantiles(LAST('ROA5'), groups='sw1'), 
    'ROE': CSQuantiles(LAST('ROE'), groups='sw1'), 
    'ROE5': CSQuantiles(LAST('ROE5'), groups='sw1'), 
    'RSI': CSQuantiles(LAST('RSI'), groups='sw1'), 
    'RSTR12': CSQuantiles(LAST('RSTR12'), groups='sw1'), 
    'RSTR24': CSQuantiles(LAST('RSTR24'), groups='sw1'), 
    'SalesCostRatio': CSQuantiles(LAST('SalesCostRatio'), groups='sw1'), 
    'SaleServiceCashToOR': CSQuantiles(LAST('SaleServiceCashToOR'), groups='sw1'), 
    'SUE': CSQuantiles(LAST('SUE'), groups='sw1'), 
    'TaxRatio': CSQuantiles(LAST('TaxRatio'), groups='sw1'), 
    'TOBT': CSQuantiles(LAST('TOBT'), groups='sw1'), 
    'TotalAssetGrowRate': CSQuantiles(LAST('TotalAssetGrowRate'), groups='sw1'), 
    'TotalAssetsTRate': CSQuantiles(LAST('TotalAssetsTRate'), groups='sw1'), 
    'TotalProfitCostRatio': CSQuantiles(LAST('TotalProfitCostRatio'), groups='sw1'), 
    'TotalProfitGrowRate': CSQuantiles(LAST('TotalProfitGrowRate'), groups='sw1'), 
    'VOL10': CSQuantiles(LAST('VOL10'), groups='sw1'), 
    'VOL120': CSQuantiles(LAST('VOL120'), groups='sw1'), 
    'VOL20': CSQuantiles(LAST('VOL20'), groups='sw1'), 
    'VOL240': CSQuantiles(LAST('VOL240'), groups='sw1'), 
    'VOL5': CSQuantiles(LAST('VOL5'), groups='sw1'), 
    'VOL60': CSQuantiles(LAST('VOL60'), groups='sw1'), 
    'WVAD': CSQuantiles(LAST('WVAD'), groups='sw1'), 
    'REC': CSQuantiles(LAST('REC'), groups='sw1'), 
    'DAREC': CSQuantiles(LAST('DAREC'), groups='sw1'), 
    'GREC': CSQuantiles(LAST('GREC'), groups='sw1'), 
    'FY12P': CSQuantiles(LAST('FY12P'), groups='sw1'), 
    'DAREV': CSQuantiles(LAST('DAREV'), groups='sw1'), 
    'GREV': CSQuantiles(LAST('GREV'), groups='sw1'), 
    'SFY12P': CSQuantiles(LAST('SFY12P'), groups='sw1'), 
    'DASREV': CSQuantiles(LAST('DASREV'), groups='sw1'), 
    'GSREV': CSQuantiles(LAST('GSREV'), groups='sw1'), 
    'FEARNG': CSQuantiles(LAST('FEARNG'), groups='sw1'), 
    'FSALESG': CSQuantiles(LAST('FSALESG'), groups='sw1'), 
    'TA2EV': CSQuantiles(LAST('TA2EV'), groups='sw1'), 
    'CFO2EV': CSQuantiles(LAST('CFO2EV'), groups='sw1'), 
    'ACCA': CSQuantiles(LAST('ACCA'), groups='sw1'), 
    'DEGM': CSQuantiles(LAST('DEGM'), groups='sw1'), 
    'SUOI': CSQuantiles(LAST('SUOI'), groups='sw1'), 
    'EARNMOM': CSQuantiles(LAST('EARNMOM'), groups='sw1'), 
    'FiftyTwoWeekHigh': CSQuantiles(LAST('FiftyTwoWeekHigh'), groups='sw1'), 
    'Volatility': CSQuantiles(LAST('Volatility'), groups='sw1'), 
    'Skewness': CSQuantiles(LAST('Skewness'), groups='sw1'), 
    'ILLIQUIDITY': CSQuantiles(LAST('ILLIQUIDITY'), groups='sw1'), 
    'BackwardADJ': CSQuantiles(LAST('BackwardADJ'), groups='sw1'), 
    'MACD': CSQuantiles(LAST('MACD'), groups='sw1'), 
    'ADTM': CSQuantiles(LAST('ADTM'), groups='sw1'), 
    'ATR14': CSQuantiles(LAST('ATR14'), groups='sw1'), 
    'ATR6': CSQuantiles(LAST('ATR6'), groups='sw1'), 
    'BIAS10': CSQuantiles(LAST('BIAS10'), groups='sw1'), 
    'BIAS20': CSQuantiles(LAST('BIAS20'), groups='sw1'), 
    'BIAS5': CSQuantiles(LAST('BIAS5'), groups='sw1'), 
    'BIAS60': CSQuantiles(LAST('BIAS60'), groups='sw1'), 
    'BollDown': CSQuantiles(LAST('BollDown'), groups='sw1'), 
    'BollUp': CSQuantiles(LAST('BollUp'), groups='sw1'), 
    'CCI10': CSQuantiles(LAST('CCI10'), groups='sw1'), 
    'CCI20': CSQuantiles(LAST('CCI20'), groups='sw1'), 
    'CCI5': CSQuantiles(LAST('CCI5'), groups='sw1'), 
    'CCI88': CSQuantiles(LAST('CCI88'), groups='sw1'), 
    'KDJ_K': CSQuantiles(LAST('KDJ_K'), groups='sw1'), 
    'KDJ_D': CSQuantiles(LAST('KDJ_D'), groups='sw1'), 
    'KDJ_J': CSQuantiles(LAST('KDJ_J'), groups='sw1'), 
    'ROC6': CSQuantiles(LAST('ROC6'), groups='sw1'), 
    'ROC20': CSQuantiles(LAST('ROC20'), groups='sw1'), 
    'SBM': CSQuantiles(LAST('SBM'), groups='sw1'), 
    'STM': CSQuantiles(LAST('STM'), groups='sw1'), 
    'UpRVI': CSQuantiles(LAST('UpRVI'), groups='sw1'), 
    'DownRVI': CSQuantiles(LAST('DownRVI'), groups='sw1'), 
    'RVI': CSQuantiles(LAST('RVI'), groups='sw1'), 
    'SRMI': CSQuantiles(LAST('SRMI'), groups='sw1'), 
    'ChandeSD': CSQuantiles(LAST('ChandeSD'), groups='sw1'), 
    'ChandeSU': CSQuantiles(LAST('ChandeSU'), groups='sw1'), 
    'CMO': CSQuantiles(LAST('CMO'), groups='sw1'), 
    'DBCD': CSQuantiles(LAST('DBCD'), groups='sw1'), 
    'ARC': CSQuantiles(LAST('ARC'), groups='sw1'), 
    'OBV': CSQuantiles(LAST('OBV'), groups='sw1'), 
    'OBV6': CSQuantiles(LAST('OBV6'), groups='sw1'), 
    'OBV20': CSQuantiles(LAST('OBV20'), groups='sw1'), 
    'TVMA20': CSQuantiles(LAST('TVMA20'), groups='sw1'), 
    'TVMA6': CSQuantiles(LAST('TVMA6'), groups='sw1'), 
    'TVSTD20': CSQuantiles(LAST('TVSTD20'), groups='sw1'), 
    'TVSTD6': CSQuantiles(LAST('TVSTD6'), groups='sw1'), 
    'VDEA': CSQuantiles(LAST('VDEA'), groups='sw1'), 
    'VDIFF': CSQuantiles(LAST('VDIFF'), groups='sw1'), 
    'VEMA10': CSQuantiles(LAST('VEMA10'), groups='sw1'), 
    'VEMA12': CSQuantiles(LAST('VEMA12'), groups='sw1'), 
    'VEMA26': CSQuantiles(LAST('VEMA26'), groups='sw1'), 
    'VEMA5': CSQuantiles(LAST('VEMA5'), groups='sw1'), 
    'VMACD': CSQuantiles(LAST('VMACD'), groups='sw1'), 
    'VR': CSQuantiles(LAST('VR'), groups='sw1'), 
    'VROC12': CSQuantiles(LAST('VROC12'), groups='sw1'), 
    'VROC6': CSQuantiles(LAST('VROC6'), groups='sw1'), 
    'VSTD10': CSQuantiles(LAST('VSTD10'), groups='sw1'), 
    'VSTD20': CSQuantiles(LAST('VSTD20'), groups='sw1'), 
    'KlingerOscillator': CSQuantiles(LAST('KlingerOscillator'), groups='sw1'), 
    'MoneyFlow20': CSQuantiles(LAST('MoneyFlow20'), groups='sw1'), 
    'AD': CSQuantiles(LAST('AD'), groups='sw1'), 
    'AD20': CSQuantiles(LAST('AD20'), groups='sw1'), 
    'AD6': CSQuantiles(LAST('AD6'), groups='sw1'), 
    'CoppockCurve': CSQuantiles(LAST('CoppockCurve'), groups='sw1'), 
    'ASI': CSQuantiles(LAST('ASI'), groups='sw1'), 
    'ChaikinOscillator': CSQuantiles(LAST('ChaikinOscillator'), groups='sw1'), 
    'ChaikinVolatility': CSQuantiles(LAST('ChaikinVolatility'), groups='sw1'), 
    'EMV14': CSQuantiles(LAST('EMV14'), groups='sw1'), 
    'EMV6': CSQuantiles(LAST('EMV6'), groups='sw1'), 
    'plusDI': CSQuantiles(LAST('plusDI'), groups='sw1'), 
    'minusDI': CSQuantiles(LAST('minusDI'), groups='sw1'), 
    'ADX': CSQuantiles(LAST('ADX'), groups='sw1'), 
    'ADXR': CSQuantiles(LAST('ADXR'), groups='sw1'), 
    'Aroon': CSQuantiles(LAST('Aroon'), groups='sw1'), 
    'AroonDown': CSQuantiles(LAST('AroonDown'), groups='sw1'), 
    'AroonUp': CSQuantiles(LAST('AroonUp'), groups='sw1'), 
    'DEA': CSQuantiles(LAST('DEA'), groups='sw1'), 
    'DIFF': CSQuantiles(LAST('DIFF'), groups='sw1'), 
    'DDI': CSQuantiles(LAST('DDI'), groups='sw1'), 
    'DIZ': CSQuantiles(LAST('DIZ'), groups='sw1'), 
    'DIF': CSQuantiles(LAST('DIF'), groups='sw1'), 
    'MTM': CSQuantiles(LAST('MTM'), groups='sw1'), 
    'MTMMA': CSQuantiles(LAST('MTMMA'), groups='sw1'), 
    'PVT': CSQuantiles(LAST('PVT'), groups='sw1'), 
    'PVT6': CSQuantiles(LAST('PVT6'), groups='sw1'), 
    'PVT12': CSQuantiles(LAST('PVT12'), groups='sw1'), 
    'TRIX5': CSQuantiles(LAST('TRIX5'), groups='sw1'), 
    'TRIX10': CSQuantiles(LAST('TRIX10'), groups='sw1'), 
    'UOS': CSQuantiles(LAST('UOS'), groups='sw1'), 
    'MA10RegressCoeff12': CSQuantiles(LAST('MA10RegressCoeff12'), groups='sw1'), 
    'MA10RegressCoeff6': CSQuantiles(LAST('MA10RegressCoeff6'), groups='sw1'), 
    'PLRC6': CSQuantiles(LAST('PLRC6'), groups='sw1'), 
    'PLRC12': CSQuantiles(LAST('PLRC12'), groups='sw1'), 
    'SwingIndex': CSQuantiles(LAST('SwingIndex'), groups='sw1'), 
    'Ulcer10': CSQuantiles(LAST('Ulcer10'), groups='sw1'), 
    'Ulcer5': CSQuantiles(LAST('Ulcer5'), groups='sw1'), 
    'Hurst': CSQuantiles(LAST('Hurst'), groups='sw1'), 
    'ACD6': CSQuantiles(LAST('ACD6'), groups='sw1'), 
    'ACD20': CSQuantiles(LAST('ACD20'), groups='sw1'), 
    'EMA12': CSQuantiles(LAST('EMA12'), groups='sw1'), 
    'EMA26': CSQuantiles(LAST('EMA26'), groups='sw1'), 
    'APBMA': CSQuantiles(LAST('APBMA'), groups='sw1'), 
    'BBI': CSQuantiles(LAST('APBMA'), groups='sw1'), 
    'BBIC': CSQuantiles(LAST('BBIC'), groups='sw1'), 
    'TEMA10': CSQuantiles(LAST('TEMA10'), groups='sw1'), 
    'TEMA5': CSQuantiles(LAST('TEMA5'), groups='sw1'), 
    'MA10Close': CSQuantiles(LAST('MA10Close'), groups='sw1'), 
    'AR': CSQuantiles(LAST('AR'), groups='sw1'), 
    'BR': CSQuantiles(LAST('BR'), groups='sw1'), 
    'ARBR': CSQuantiles(LAST('ARBR'), groups='sw1'), 
    'CR20': CSQuantiles(LAST('CR20'), groups='sw1'), 
    'MassIndex': CSQuantiles(LAST('MassIndex'), groups='sw1'), 
    'BearPower': CSQuantiles(LAST('BearPower'), groups='sw1'), 
    'BullPower': CSQuantiles(LAST('BullPower'), groups='sw1'), 
    'Elder': CSQuantiles(LAST('Elder'), groups='sw1'), 
    'NVI': CSQuantiles(LAST('NVI'), groups='sw1'), 
    'PVI': CSQuantiles(LAST('PVI'), groups='sw1'), 
    'RC12': CSQuantiles(LAST('RC12'), groups='sw1'), 
    'RC24': CSQuantiles(LAST('RC24'), groups='sw1'), 
    'JDQS20': CSQuantiles(LAST('JDQS20'), groups='sw1'), 
    'Variance20': CSQuantiles(LAST('Variance20'), groups='sw1'), 
    'Variance60': CSQuantiles(LAST('Variance60'), groups='sw1'), 
    'Variance120': CSQuantiles(LAST('Variance120'), groups='sw1'), 
    'Kurtosis20': CSQuantiles(LAST('Kurtosis20'), groups='sw1'), 
    'Kurtosis60': CSQuantiles(LAST('Kurtosis60'), groups='sw1'), 
    'Kurtosis120': CSQuantiles(LAST('Kurtosis120'), groups='sw1'), 
    'Alpha20': CSQuantiles(LAST('Alpha20'), groups='sw1'), 
    'Alpha60': CSQuantiles(LAST('Alpha60'), groups='sw1'), 
    'Alpha120': CSQuantiles(LAST('Alpha120'), groups='sw1'), 
    'Beta20': CSQuantiles(LAST('Beta20'), groups='sw1'), 
    'Beta60': CSQuantiles(LAST('Beta60'), groups='sw1'), 
    'Beta120': CSQuantiles(LAST('Beta60'), groups='sw1'), 
    'SharpeRatio20': CSQuantiles(LAST('SharpeRatio20'), groups='sw1'), 
    'SharpeRatio60': CSQuantiles(LAST('SharpeRatio60'), groups='sw1'), 
    'SharpeRatio120': CSQuantiles(LAST('SharpeRatio120'), groups='sw1'), 
    'TreynorRatio20': CSQuantiles(LAST('TreynorRatio20'), groups='sw1'), 
    'TreynorRatio60': CSQuantiles(LAST('TreynorRatio60'), groups='sw1'), 
    'TreynorRatio120': CSQuantiles(LAST('TreynorRatio120'), groups='sw1'), 
    'InformationRatio20': CSQuantiles(LAST('InformationRatio20'), groups='sw1'), 
    'InformationRatio60': CSQuantiles(LAST('InformationRatio60'), groups='sw1'), 
    'InformationRatio120': CSQuantiles(LAST('InformationRatio120'), groups='sw1'), 
    'GainVariance20': CSQuantiles(LAST('GainVariance20'), groups='sw1'), 
    'GainVariance60': CSQuantiles(LAST('GainVariance60'), groups='sw1'), 
    'GainVariance120': CSQuantiles(LAST('GainVariance120'), groups='sw1'), 
    'LossVariance20': CSQuantiles(LAST('LossVariance20'), groups='sw1'), 
    'LossVariance60': CSQuantiles(LAST('LossVariance60'), groups='sw1'), 
    'LossVariance120': CSQuantiles(LAST('LossVariance120'), groups='sw1'), 
    'GainLossVarianceRatio20': CSQuantiles(LAST('GainLossVarianceRatio20'), groups='sw1'), 
    'GainLossVarianceRatio60': CSQuantiles(LAST('GainLossVarianceRatio60'), groups='sw1'), 
    'GainLossVarianceRatio120': CSQuantiles(LAST('GainLossVarianceRatio120'), groups='sw1'), 
    'RealizedVolatility': CSQuantiles(LAST('RealizedVolatility'), groups='sw1'), 
    'REVS60': CSQuantiles(LAST('REVS60'), groups='sw1'), 
    'REVS120': CSQuantiles(LAST('REVS120'), groups='sw1'), 
    'REVS250': CSQuantiles(LAST('REVS250'), groups='sw1'), 
    'REVS750': CSQuantiles(LAST('REVS750'), groups='sw1'), 
    'REVS5m20': CSQuantiles(LAST('REVS5m20'), groups='sw1'), 
    'REVS5m60': CSQuantiles(LAST('REVS5m60'), groups='sw1'), 
    'REVS5Indu1': CSQuantiles(LAST('REVS5Indu1'), groups='sw1'), 
    'REVS20Indu1': CSQuantiles(LAST('REVS20Indu1'), groups='sw1'), 
    'Volumn1M': CSQuantiles(LAST('Volumn1M'), groups='sw1'), 
    'Volumn3M': CSQuantiles(LAST('Volumn3M'), groups='sw1'), 
    'Price1M': CSQuantiles(LAST('Price1M'), groups='sw1'), 
    'Price3M': CSQuantiles(LAST('Price3M'), groups='sw1'), 
    'Price1Y': CSQuantiles(LAST('Price1Y'), groups='sw1'), 
    'Rank1M': CSQuantiles(LAST('Rank1M'), groups='sw1'), 
    'CashDividendCover': CSQuantiles(LAST('CashDividendCover'), groups='sw1'), 
    'DividendCover': CSQuantiles(LAST('DividendCover'), groups='sw1'), 
    'DividendPaidRatio': CSQuantiles(LAST('DividendPaidRatio'), groups='sw1'), 
    'RetainedEarningRatio': CSQuantiles(LAST('RetainedEarningRatio'), groups='sw1'), 
    'CashEquivalentPS': CSQuantiles(LAST('CashEquivalentPS'), groups='sw1'), 
    'DividendPS': CSQuantiles(LAST('DividendPS'), groups='sw1'), 
    'EPSTTM': CSQuantiles(LAST('EPSTTM'), groups='sw1'), 
    'NetAssetPS': CSQuantiles(LAST('NetAssetPS'), groups='sw1'), 
    'TORPS': CSQuantiles(LAST('TORPS'), groups='sw1'), 
    'TORPSLatest': CSQuantiles(LAST('TORPSLatest'), groups='sw1'), 
    'OperatingRevenuePS': CSQuantiles(LAST('OperatingRevenuePS'), groups='sw1'), 
    'OperatingRevenuePSLatest': CSQuantiles(LAST('OperatingRevenuePSLatest'), groups='sw1'), 
    'OperatingProfitPS': CSQuantiles(LAST('OperatingProfitPS'), groups='sw1'), 
    'OperatingProfitPSLatest': CSQuantiles(LAST('OperatingProfitPSLatest'), groups='sw1'), 
    'CapitalSurplusFundPS': CSQuantiles(LAST('CapitalSurplusFundPS'), groups='sw1'), 
    'SurplusReserveFundPS': CSQuantiles(LAST('SurplusReserveFundPS'), groups='sw1'), 
    'UndividedProfitPS': CSQuantiles(LAST('UndividedProfitPS'), groups='sw1'), 
    'RetainedEarningsPS': CSQuantiles(LAST('RetainedEarningsPS'), groups='sw1'), 
    'OperCashFlowPS': CSQuantiles(LAST('OperCashFlowPS'), groups='sw1'), 
    'CashFlowPS': CSQuantiles(LAST('CashFlowPS'), groups='sw1'), 
    'NetNonOIToTP': CSQuantiles(LAST('NetNonOIToTP'), groups='sw1'), 
    'NetNonOIToTPLatest': CSQuantiles(LAST('NetNonOIToTPLatest'), groups='sw1'), 
    'PeriodCostsRate': CSQuantiles(LAST('PeriodCostsRate'), groups='sw1'), 
    'InterestCover': CSQuantiles(LAST('InterestCover'), groups='sw1'), 
    'NetProfitGrowRate3Y': CSQuantiles(LAST('NetProfitGrowRate3Y'), groups='sw1'), 
    'NetProfitGrowRate5Y': CSQuantiles(LAST('NetProfitGrowRate5Y'), groups='sw1'), 
    'OperatingRevenueGrowRate3Y': CSQuantiles(LAST('OperatingRevenueGrowRate3Y'), groups='sw1'), 
    'OperatingRevenueGrowRate5Y': CSQuantiles(LAST('OperatingRevenueGrowRate5Y'), groups='sw1'), 
    'NetCashFlowGrowRate': CSQuantiles(LAST('NetCashFlowGrowRate'), groups='sw1'), 
    'NetProfitCashCover': CSQuantiles(LAST('NetProfitCashCover'), groups='sw1'), 
    'OperCashInToAsset': CSQuantiles(LAST('OperCashInToAsset'), groups='sw1'), 
    'CashConversionCycle': CSQuantiles(LAST('CashConversionCycle'), groups='sw1'), 
    'OperatingCycle': CSQuantiles(LAST('OperatingCycle'), groups='sw1'), 
    'PEG3Y': CSQuantiles(LAST('PEG3Y'), groups='sw1'), 
    'PEG5Y': CSQuantiles(LAST('PEG5Y'), groups='sw1'), 
    'PEIndu': CSQuantiles(LAST('PEIndu'), groups='sw1'), 
    'PBIndu': CSQuantiles(LAST('PBIndu'), groups='sw1'), 
    'PSIndu': CSQuantiles(LAST('PSIndu'), groups='sw1'), 
    'PCFIndu': CSQuantiles(LAST('PCFIndu'), groups='sw1'), 
    'PEHist20': CSQuantiles(LAST('PEHist20'), groups='sw1'), 
    'PEHist60': CSQuantiles(LAST('PEHist60'), groups='sw1'), 
    'PEHist120': CSQuantiles(LAST('PEHist120'), groups='sw1'), 
    'PEHist250': CSQuantiles(LAST('PEHist250'), groups='sw1'), 
    'StaticPE': CSQuantiles(LAST('StaticPE'), groups='sw1'), 
    'ForwardPE': CSQuantiles(LAST('ForwardPE'), groups='sw1'), 
    'EnterpriseFCFPS': CSQuantiles(LAST('EnterpriseFCFPS'), groups='sw1'), 
    'ShareholderFCFPS': CSQuantiles(LAST('ShareholderFCFPS'), groups='sw1'), 
    'ROEDiluted': CSQuantiles(LAST('ROEDiluted'), groups='sw1'), 
    'ROEAvg': CSQuantiles(LAST('ROEAvg'), groups='sw1'), 
    'ROEWeighted': CSQuantiles(LAST('ROEWeighted'), groups='sw1'), 
    'ROECut': CSQuantiles(LAST('ROECut'), groups='sw1'), 
    'ROECutWeighted': CSQuantiles(LAST('ROECutWeighted'), groups='sw1'), 
    'ROIC': CSQuantiles(LAST('ROIC'), groups='sw1'), 
    'ROAEBIT': CSQuantiles(LAST('ROAEBIT'), groups='sw1'), 
    'ROAEBITTTM': CSQuantiles(LAST('ROAEBITTTM'), groups='sw1'), 
    'OperatingNIToTP': CSQuantiles(LAST('OperatingNIToTP'), groups='sw1'), 
    'OperatingNIToTPLatest': CSQuantiles(LAST('OperatingNIToTPLatest'), groups='sw1'), 
    'InvestRAssociatesToTP': CSQuantiles(LAST('InvestRAssociatesToTP'), groups='sw1'), 
    'InvestRAssociatesToTPLatest': CSQuantiles(LAST('InvestRAssociatesToTPLatest'), groups='sw1'), 
    'NPCutToNP': CSQuantiles(LAST('NPCutToNP'), groups='sw1'), 
    'SuperQuickRatio': CSQuantiles(LAST('SuperQuickRatio'), groups='sw1'), 
    'TSEPToInterestBearDebt': CSQuantiles(LAST('TSEPToInterestBearDebt'), groups='sw1'), 
    'DebtTangibleEquityRatio': CSQuantiles(LAST('DebtTangibleEquityRatio'), groups='sw1'), 
    'TangibleAToInteBearDebt': CSQuantiles(LAST('TangibleAToInteBearDebt'), groups='sw1'), 
    'TangibleAToNetDebt': CSQuantiles(LAST('TangibleAToNetDebt'), groups='sw1'), 
    'NOCFToTLiability': CSQuantiles(LAST('NOCFToTLiability'), groups='sw1'), 
    'NOCFToInterestBearDebt': CSQuantiles(LAST('NOCFToInterestBearDebt'), groups='sw1'), 
    'NOCFToNetDebt': CSQuantiles(LAST('NOCFToNetDebt'), groups='sw1'), 
    'TSEPToTotalCapital': CSQuantiles(LAST('TSEPToTotalCapital'), groups='sw1'), 
    'InteBearDebtToTotalCapital': CSQuantiles(LAST('InteBearDebtToTotalCapital'), groups='sw1'), 
    'NPParentCompanyCutYOY': CSQuantiles(LAST('NPParentCompanyCutYOY'), groups='sw1'), 
    'SalesServiceCashToORLatest': CSQuantiles(LAST('SalesServiceCashToORLatest'), groups='sw1'), 
    'CashRateOfSalesLatest': CSQuantiles(LAST('CashRateOfSalesLatest'), groups='sw1'), 
    'NOCFToOperatingNILatest': CSQuantiles(LAST('NOCFToOperatingNILatest'), groups='sw1'), 
    'TotalAssets': CSQuantiles(LAST('TotalAssets'), groups='sw1'), 
    'MktValue': CSQuantiles(LAST('MktValue'), groups='sw1'), 
    'NegMktValue': CSQuantiles(LAST('NegMktValue'), groups='sw1'), 
    'TEAP': CSQuantiles(LAST('TEAP'), groups='sw1'), 
    'NIAP': CSQuantiles(LAST('NIAP'), groups='sw1'), 
    'TotalFixedAssets': CSQuantiles(LAST('TotalFixedAssets'), groups='sw1'), 
    'IntFreeCL': CSQuantiles(LAST('IntFreeCL'), groups='sw1'), 
    'IntFreeNCL': CSQuantiles(LAST('IntFreeNCL'), groups='sw1'), 
    'IntCL': CSQuantiles(LAST('IntCL'), groups='sw1'), 
    'IntDebt': CSQuantiles(LAST('IntDebt'), groups='sw1'), 
    'NetDebt': CSQuantiles(LAST('NetDebt'), groups='sw1'), 
    'NetTangibleAssets': CSQuantiles(LAST('NetTangibleAssets'), groups='sw1'), 
    'WorkingCapital': CSQuantiles(LAST('WorkingCapital'), groups='sw1'), 
    'NetWorkingCapital': CSQuantiles(LAST('WorkingCapital'), groups='sw1'), 
    'TotalPaidinCapital': CSQuantiles(LAST('TotalPaidinCapital'), groups='sw1'), 
    'RetainedEarnings': CSQuantiles(LAST('RetainedEarnings'), groups='sw1'), 
    'OperateNetIncome': CSQuantiles(LAST('OperateNetIncome'), groups='sw1'), 
    'ValueChgProfit': CSQuantiles(LAST('ValueChgProfit'), groups='sw1'), 
    'NetIntExpense': CSQuantiles(LAST('NetIntExpense'), groups='sw1'), 
    'EBIT': CSQuantiles(LAST('EBIT'), groups='sw1'), 
    'EBITDA': CSQuantiles(LAST('EBITDA'), groups='sw1'), 
    'EBIAT': CSQuantiles(LAST('EBIAT'), groups='sw1'), 
    'NRProfitLoss': CSQuantiles(LAST('NRProfitLoss'), groups='sw1'), 
    'NIAPCut': CSQuantiles(LAST('NIAPCut'), groups='sw1'), 
    'FCFF': CSQuantiles(LAST('FCFF'), groups='sw1'), 
    'FCFE': CSQuantiles(LAST('FCFE'), groups='sw1'), 
    'DA': CSQuantiles(LAST('DA'), groups='sw1'), 
    'TRevenueTTM': CSQuantiles(LAST('TRevenueTTM'), groups='sw1'), 
    'TCostTTM': CSQuantiles(LAST('TCostTTM'), groups='sw1'), 
    'RevenueTTM': CSQuantiles(LAST('RevenueTTM'), groups='sw1'), 
    'CostTTM': CSQuantiles(LAST('CostTTM'), groups='sw1'), 
    'GrossProfitTTM': CSQuantiles(LAST('GrossProfitTTM'), groups='sw1'), 
    'SalesExpenseTTM': CSQuantiles(LAST('SalesExpenseTTM'), groups='sw1'), 
    'AdminExpenseTTM': CSQuantiles(LAST('AdminExpenseTTM'), groups='sw1'), 
    'FinanExpenseTTM': CSQuantiles(LAST('FinanExpenseTTM'), groups='sw1'), 
    'AssetImpairLossTTM': CSQuantiles(LAST('AssetImpairLossTTM'), groups='sw1'), 
    'NPFromOperatingTTM': CSQuantiles(LAST('NPFromOperatingTTM'), groups='sw1'), 
    'NPFromValueChgTTM': CSQuantiles(LAST('NPFromValueChgTTM'), groups='sw1'), 
    'OperateProfitTTM': CSQuantiles(LAST('OperateProfitTTM'), groups='sw1'), 
    'NonOperatingNPTTM': CSQuantiles(LAST('NonOperatingNPTTM'), groups='sw1'), 
    'TProfitTTM': CSQuantiles(LAST('TProfitTTM'), groups='sw1'), 
    'NetProfitTTM': CSQuantiles(LAST('NetProfitTTM'), groups='sw1'), 
    'NetProfitAPTTM': CSQuantiles(LAST('NetProfitAPTTM'), groups='sw1'), 
    'SaleServiceRenderCashTTM': CSQuantiles(LAST('SaleServiceRenderCashTTM'), groups='sw1'), 
    'NetOperateCFTTM': CSQuantiles(LAST('NetOperateCFTTM'), groups='sw1'), 
    'NetInvestCFTTM': CSQuantiles(LAST('NetInvestCFTTM'), groups='sw1'), 
    'NetFinanceCFTTM': CSQuantiles(LAST('NetFinanceCFTTM'), groups='sw1'), 
    'GrossProfit': CSQuantiles(LAST('GrossProfit'), groups='sw1'), 
    'Beta252': CSQuantiles(LAST('Beta252'), groups='sw1'), 
    'RSTR504': CSQuantiles(LAST('RSTR504'), groups='sw1'), 
    'EPIBS': CSQuantiles(LAST('EPIBS'), groups='sw1'), 
    'CETOP': CSQuantiles(LAST('CETOP'), groups='sw1'), 
    'DASTD': CSQuantiles(LAST('DASTD'), groups='sw1'), 
    'CmraCNE5': CSQuantiles(LAST('CmraCNE5'), groups='sw1'), 
    'HsigmaCNE5': CSQuantiles(LAST('HsigmaCNE5'), groups='sw1'), 
    'SGRO': CSQuantiles(LAST('SGRO'), groups='sw1'), 
    'EgibsLong': CSQuantiles(LAST('EgibsLong'), groups='sw1'), 
    'STOM': CSQuantiles(LAST('STOM'), groups='sw1'), 
    'STOQ': CSQuantiles(LAST('STOQ'), groups='sw1'), 
    'STOA': CSQuantiles(LAST('STOA'), groups='sw1'), 
    'NLSIZE': CSQuantiles(LAST('NLSIZE'), groups='sw1')}

# %%
# %%time
factor_data_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates)
# factor_data_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates, used_factor_tables=[Alpha191])
# Out:
# CPU times: user 3min 41s, sys: 6.38 s, total: 3min 47s
# Wall time: 4min 13s

# %%
# %%time
industry = engine.fetch_industry_range(universe, dates=ref_dates)
factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code']).fillna(0.)
risk_total = engine.fetch_risk_model_range(universe, dates=ref_dates)[1]
len(factor_data)
# Out:
# CPU times: user 2.68 s, sys: 89.9 ms, total: 2.77 s
# Wall time: 4.49 s

# %%
# %%time
return_data = engine.fetch_dx_return_range(universe, dates=ref_dates, horizon=horizon, offset=0,benchmark = benchmark_code)
len(return_data)
# Out:
# CPU times: user 766 ms, sys: 25.5 ms, total: 792 ms
# Wall time: 2.69 s

# %%
# %%time
benchmark_total = engine.fetch_benchmark_range(dates=ref_dates, benchmark=benchmark_code)
industry_total = engine.fetch_industry_matrix_range(universe, dates=ref_dates, category=industry_name, level=industry_level)
# Out:
# CPU times: user 757 ms, sys: 8.89 ms, total: 765 ms
# Wall time: 1.35 s

# %%
# Constraintes settings

industry_names = industry_list(industry_name, industry_level)
constraint_risk = ['EARNYILD', 'LIQUIDTY', 'GROWTH', 'SIZE', 'BETA', 'MOMENTUM'] + industry_names
total_risk_names = constraint_risk + ['benchmark', 'total']

b_type = []
l_val = []
u_val = []

for name in total_risk_names:
    if name == 'benchmark':
        b_type.append(BoundaryType.RELATIVE)
        l_val.append(0.0)
        u_val.append(1.0)
    elif name == 'total':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(.0)
        u_val.append(.0)
    else:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.005)
        u_val.append(1.005)

bounds = create_box_bounds(total_risk_names, b_type, l_val, u_val)

# %%
train_data = pd.merge(factor_data, return_data, on=['trade_date', 'code']).dropna()
# train_data.head()

# %%
features = ['AccountsPayablesTDays', 'AccountsPayablesTRate', 'AdminiExpenseRate', 'ARTDays', 
            'ARTRate', 'ASSI', 'BLEV', 'BondsPayableToAsset', 'CashRateOfSales', 'CashToCurrentLiability', 
            'CMRA', 'CTOP', 'CTP5', 'CurrentAssetsRatio', 'CurrentAssetsTRate', 'CurrentRatio', 'DAVOL10', 
            'DAVOL20', 'DAVOL5', 'DDNBT', 'DDNCR', 'DDNSR', 'DebtEquityRatio', 'DebtsAssetRatio', 'DHILO', 
            'DilutedEPS', 'DVRAT', 'EBITToTOR', 'EGRO', 'EMA10', 'EMA120', 'EMA20', 'EMA5', 'EMA60', 'EPS',
            'EquityFixedAssetRatio', 'EquityToAsset', 'EquityTRate', 'ETOP', 'ETP5', 'FinancialExpenseRate', 
            'FinancingCashGrowRate', 'FixAssetRatio', 'FixedAssetsTRate', 'GrossIncomeRatio', 'HBETA', 
            'HSIGMA', 'IntangibleAssetRatio', 'InventoryTDays', 'InventoryTRate', 'InvestCashGrowRate', 
            'LCAP', 'LFLO', 'LongDebtToAsset', 'LongDebtToWorkingCapital', 'LongTermDebtToAsset', 
            'MA10', 'MA120', 'MA20', 'MA5', 'MA60', 'MAWVAD', 'MFI', 'MLEV', 'NetAssetGrowRate', 
            'NetProfitGrowRate', 'NetProfitRatio', 'NOCFToOperatingNI', 'NonCurrentAssetsRatio', 
            'NPParentCompanyGrowRate', 'NPToTOR', 'OperatingExpenseRate', 'OperatingProfitGrowRate', 
            'OperatingProfitRatio', 'OperatingProfitToTOR', 'OperatingRevenueGrowRate', 'OperCashGrowRate',
            'OperCashInToCurrentLiability', 'PB','PCF', 'PE','PS','PSY', 'QuickRatio', 'REVS10', 
            'REVS20', 'REVS5', 'ROA','ROA5', 'ROE', 'ROE5', 'RSI', 'RSTR12', 'RSTR24', 'SalesCostRatio', 
            'SaleServiceCashToOR' , 'SUE', 'TaxRatio', 'TOBT', 'TotalAssetGrowRate', 'TotalAssetsTRate', 
            'TotalProfitCostRatio', 'TotalProfitGrowRate', 'VOL10', 'VOL120', 'VOL20', 'VOL240', 'VOL5', 
            'VOL60', 'WVAD', 'REC', 'DAREC', 'GREC', 'FY12P', 'DAREV', 'GREV', 'SFY12P', 'DASREV', 'GSREV', 
            'FEARNG', 'FSALESG', 'TA2EV', 'CFO2EV', 'ACCA', 'DEGM', 'SUOI', 'EARNMOM', 'FiftyTwoWeekHigh', 
            'Volatility', 'Skewness', 'ILLIQUIDITY', 'BackwardADJ', 'MACD', 'ADTM', 'ATR14', 'ATR6', 'BIAS10', 
            'BIAS20', 'BIAS5', 'BIAS60', 'BollDown', 'BollUp', 'CCI10', 'CCI20', 'CCI5', 'CCI88', 'KDJ_K', 'KDJ_D', 
            'KDJ_J', 'ROC6', 'ROC20', 'SBM', 'STM', 'UpRVI', 'DownRVI', 'RVI', 'SRMI', 'ChandeSD', 'ChandeSU', 
            'CMO', 'DBCD', 'ARC', 'OBV', 'OBV6', 'OBV20', 'TVMA20', 'TVMA6', 'TVSTD20', 'TVSTD6', 'VDEA', 'VDIFF', 
            'VEMA10', 'VEMA12', 'VEMA26', 'VEMA5', 'VMACD', 'VR', 'VROC12', 'VROC6', 'VSTD10', 'VSTD20', 'KlingerOscillator' , 
            'MoneyFlow20', 'AD', 'AD20', 'AD6','CoppockCurve','ASI', 'ChaikinOscillator', 'ChaikinVolatility', 
            'EMV14', 'EMV6', 'plusDI', 'minusDI', 'ADX', 'ADXR', 'Aroon', 'AroonDown', 'AroonUp', 'DEA', 'DIFF', 'DDI', 'DIZ', 
            'DIF', 'MTM', 'MTMMA', 'PVT', 'PVT6', 'PVT12', 'TRIX5', 'TRIX10', 'UOS', 'MA10RegressCoeff12', 'MA10RegressCoeff6', 
            'PLRC6', 'PLRC12', 'SwingIndex', 'Ulcer10', 'Ulcer5', 'Hurst', 'ACD6', 'ACD20', 'EMA12', 'EMA26', 'APBMA', 
            'BBI', 'BBIC', 'TEMA10', 'TEMA5', 'MA10Close', 'AR', 'BR','ARBR', 'CR20', 'MassIndex', 'BearPower', 'BullPower', 
            'Elder', 'NVI', 'PVI', 'RC12', 'RC24', 'JDQS20', 'Variance20', 'Variance60', 'Variance120', 'Kurtosis20', 
            'Kurtosis60', 'Kurtosis120', 'Alpha20', 'Alpha60', 'Alpha120', 'Beta20', 'Beta60', 'Beta120', 'SharpeRatio20', 
            'SharpeRatio60', 'SharpeRatio120', 'TreynorRatio20', 'TreynorRatio60', 'TreynorRatio120', 'InformationRatio20', 
            'InformationRatio60', 'InformationRatio120', 'GainVariance20', 'GainVariance60', 'GainVariance120', 'LossVariance20', 
            'LossVariance60', 'LossVariance120', 'GainLossVarianceRatio20', 'GainLossVarianceRatio60', 'GainLossVarianceRatio120', 
            'RealizedVolatility', 'REVS60', 'REVS120', 'REVS250', 'REVS750', 'REVS5m20', 'REVS5m60', 'REVS5Indu1', 'REVS20Indu1', 
            'Volumn1M', 'Volumn3M', 'Price1M', 'Price3M', 'Price1Y', 'Rank1M', 'CashDividendCover', 'DividendCover', 
            'DividendPaidRatio', 'RetainedEarningRatio', 'CashEquivalentPS', 'DividendPS', 'EPSTTM', 'NetAssetPS', 'TORPS', 
            'TORPSLatest', 'OperatingRevenuePS', 'OperatingRevenuePSLatest', 'OperatingProfitPS', 'OperatingProfitPSLatest', 
            'CapitalSurplusFundPS', 'SurplusReserveFundPS','UndividedProfitPS', 'RetainedEarningsPS', 'OperCashFlowPS', 
            'CashFlowPS', 'NetNonOIToTP', 'NetNonOIToTPLatest', 'PeriodCostsRate', 'InterestCover', 'NetProfitGrowRate3Y', 
            'NetProfitGrowRate5Y', 'OperatingRevenueGrowRate3Y', 'OperatingRevenueGrowRate5Y', 'NetCashFlowGrowRate', 
            'NetProfitCashCover', 'OperCashInToAsset', 'CashConversionCycle', 'OperatingCycle', 'PEG3Y', 'PEG5Y', 'PEIndu', 
            'PBIndu', 'PSIndu', 'PCFIndu', 'PEHist20', 'PEHist60', 'PEHist120', 'PEHist250', 'StaticPE', 'ForwardPE', 
            'EnterpriseFCFPS', 'ShareholderFCFPS', 'ROEDiluted', 'ROEAvg', 'ROEWeighted', 'ROECut', 'ROECutWeighted', 
            'ROIC', 'ROAEBIT', 'ROAEBITTTM', 'OperatingNIToTP', 'OperatingNIToTPLatest', 'InvestRAssociatesToTP', 'InvestRAssociatesToTPLatest', 
            'NPCutToNP', 'SuperQuickRatio', 'TSEPToInterestBearDebt', 'DebtTangibleEquityRatio', 'TangibleAToInteBearDebt', 
            'TangibleAToNetDebt', 'NOCFToTLiability', 'NOCFToInterestBearDebt', 'NOCFToNetDebt', 'TSEPToTotalCapital',
            'InteBearDebtToTotalCapital', 'NPParentCompanyCutYOY', 'SalesServiceCashToORLatest', 'CashRateOfSalesLatest', 
            'NOCFToOperatingNILatest', 'TotalAssets', 'MktValue','NegMktValue', 'TEAP', 'NIAP', 'TotalFixedAssets', 
            'IntFreeCL', 'IntFreeNCL', 'IntCL', 'IntDebt', 'NetDebt','NetTangibleAssets', 'WorkingCapital', 'NetWorkingCapital', 
            'TotalPaidinCapital', 'RetainedEarnings', 'OperateNetIncome', 'ValueChgProfit', 'NetIntExpense', 'EBIT', 
            'EBITDA', 'EBIAT', 'NRProfitLoss', 'NIAPCut', 'FCFF', 'FCFE', 'DA','TRevenueTTM', 'TCostTTM','RevenueTTM', 
            'CostTTM', 'GrossProfitTTM', 'SalesExpenseTTM', 'AdminExpenseTTM', 'FinanExpenseTTM', 'AssetImpairLossTTM', 
            'NPFromOperatingTTM', 'NPFromValueChgTTM', 'OperateProfitTTM', 'NonOperatingNPTTM', 'TProfitTTM', 'NetProfitTTM', 
            'NetProfitAPTTM', 'SaleServiceRenderCashTTM', 'NetOperateCFTTM', 'NetInvestCFTTM', 'NetFinanceCFTTM', 'GrossProfit', 
            'Beta252', 'RSTR504', 'EPIBS', 'CETOP', 'DASTD', 'CmraCNE5', 'HsigmaCNE5', 'SGRO', 'EgibsLong', 'STOM', 'STOQ', 'STOA', 'NLSIZE']

label = ['dx']

# %%
# %%time
from datetime import datetime, timedelta
from m1_xgb import *
from src.conf.configuration import regress_conf
import xgboost as xgb
import gc

def create_scenario():
    weight_gap = 1
    transact_cost = 0.003
    GPU_device = False

    executor = NaiveExecutor()
    turn_overs = []
    leverags = []
    trade_dates = []
    current_pos = pd.DataFrame()
    previous_pos = pd.DataFrame()
    tune_record = pd.DataFrame()  
    rets = []
    net_rets = []
    turn_overs = []
    leverags = []
    ics = []

    # take ref_dates[i] as an example
    for i, ref_date in enumerate(ref_dates):
        alpha_logger.info('{0} is start'.format(ref_date))

        # machine learning model
        # Filter Training data
        # train data
        trade_date_pre = ref_date - timedelta(days=1)
        trade_date_pre_80 = ref_date - timedelta(days=80)
        
        # train = train_data[(train_data.trade_date <= trade_date_pre) & (trade_date_pre_80 <= train_data.trade_date)].dropna()
        train = train_data[train_data.trade_date <= trade_date_pre].dropna()

        if len(train) <= 0:
            continue
        x_train = train[features]
        y_train = train[label]
        alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
        alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))

        # xgb_configuration
        regress_conf.xgb_config_r()
        regress_conf.cv_folds = None
        regress_conf.early_stop_round = 10
        regress_conf.max_round = 800
        tic = time.time()
        # training
        xgb_model = XGBooster(regress_conf)
        if GPU_device:
            xgb_model.set_params(tree_method='gpu_hist', max_depth=5)
        else:
            xgb_model.set_params(max_depth=5)
        print(xgb_model.get_params)
        best_score, best_round, cv_rounds, best_model = xgb_model.fit(x_train, y_train)
        alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
        alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
    
        # Test data
        total_data_test_excess = train_data[train_data.trade_date == ref_date]
        alpha_logger.info('{0} total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

        if len(total_data_test_excess) <= 0:
            alpha_logger.info('{0} HAS NO DATA!!!'.format(ref_date))
            continue

        industry_matrix = industry_total[industry_total.trade_date == ref_date]
        benchmark_w = benchmark_total[benchmark_total.trade_date == ref_date]
        risk_matrix = risk_total[risk_total.trade_date == ref_date]

        total_data = pd.merge(industry_matrix, benchmark_w, on=['code'], how='left').fillna(0.)
        total_data = pd.merge(total_data, risk_matrix, on=['code'])
        alpha_logger.info('{0} len_of_total_data: {1}'.format(ref_date, len(total_data)))

        total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
        alpha_logger.info('{0} len_of_total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))
        
        codes = total_data_test_excess.code.values.tolist()
        alpha_logger.info('{0} full re-balance: {1}'.format(ref_date, len(codes)))
        dx_returns = return_data[return_data.trade_date == ref_date][['code', 'dx']]

        benchmark_w = total_data_test_excess.weight.values
        alpha_logger.info('shape_of_benchmark_w: {}'.format(np.shape(benchmark_w)))
        is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))
        total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                         is_in_benchmark,
                                         np.ones_like(is_in_benchmark)],
                                         axis=1)
        alpha_logger.info('shape_of_total_risk_exp_pre: {}'.format(np.shape(total_risk_exp)))
        total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
        alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))
        constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
        alpha_logger.info('constraints: {0} in {1}'.format(np.shape(constraints.risk_targets()), ref_date))

        lbound = np.maximum(0., benchmark_w - weight_gap)
        ubound = weight_gap + benchmark_w
        alpha_logger.info('lbound: {0} in {1}'.format(np.shape(lbound), ref_date))
        alpha_logger.info('ubound: {0} in {1}'.format(np.shape(ubound), ref_date))

        # predict
        x_pred = total_data_test_excess[features]
        predict_xgboost = xgb_model.predict(best_model, x_pred)

        a = np.shape(predict_xgboost)
        predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
        alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))
        del xgb_model
        del best_model
        gc.collect()
        
        # backtest
        try:
            target_pos, _ = er_portfolio_analysis(predict_xgboost,
                                                  total_data_test_excess['industry'].values,
                                                  None,
                                                  constraints,
                                                  False,
                                                  benchmark_w,
                                                  method = 'risk_neutral',
                                                  lbound=lbound,
                                                  ubound=ubound)
        except:
            import pdb
            pdb.set_trace()
            alpha_logger.info('target_pos: {}'.format(target_pos))
        alpha_logger.info('target_pos_shape: {}'.format(np.shape(target_pos)))
        alpha_logger.info('len_codes:{}'.format(np.shape(codes)))
        target_pos['code'] = codes
        
        result = pd.merge(target_pos, dx_returns, on=['code'])
        result['trade_date'] = ref_date
        tune_record = tune_record.append(result)
        alpha_logger.info('len_result: {}'.format(len(result)))

        # excess_return = np.exp(result.dx.values) - 1. - index_return.loc[ref_date, 'dx']
        excess_return = np.exp(result.dx.values) - 1.
        ret = result.weight.values @ excess_return
        
        trade_dates.append(ref_date)
        rets.append(np.log(1. + ret))
        alpha_logger.info('len_rets: {}, len_trade_dates: {}'.format(len(rets), len(trade_dates)))
        
        turn_over_org, current_pos = executor.execute(target_pos=target_pos)
        turn_over = turn_over_org / sum(target_pos.weight.values)
        executor.set_current(current_pos)
        net_rets.append(np.log(1. + ret - transact_cost * turn_over))        
        alpha_logger.info('len_net_rets: {}, len_trade_dates: {}'.format(len(net_rets), len(trade_dates)))

        alpha_logger.info('{} is finished'.format(ref_date))
        
    # ret_df = pd.DataFrame({'xgb_regress': rets}, index=trade_dates)
    ret_df = pd.DataFrame({'xgb_regress': rets, 'net_xgb_regress':net_rets}, index=trade_dates)
    ret_df.loc[advanceDateByCalendar('china.sse', ref_dates[-1], freq).strftime('%Y-%m-%d')] = 0.
    ret_df = ret_df.shift(1)
    ret_df.iloc[0] = 0.
    return ret_df, tune_record
# Out:
# CPU times: user 936 µs, sys: 981 µs, total: 1.92 ms
# Wall time: 1.47 ms

# %%
ret_df, tune_record = create_scenario()
# Out:
# 2019-08-29 02:01:28,192 - ALPHA_MIND - INFO - 2018-01-02 00:00:00 is start
# 2019-08-29 02:01:28,197 - ALPHA_MIND - INFO - 2018-01-04 00:00:00 is start
# 2019-08-29 02:01:28,205 - ALPHA_MIND - INFO - len_x_train: 500, len_y_train: 500
# 2019-08-29 02:01:28,205 - ALPHA_MIND - INFO - X_train.shape=(500, 423), X_test.shape = (500, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7fe62c1e11d0>>
# non_cross_validation。。。。
# [0]	train-rmse:0.497752	valid-rmse:0.493633
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.492798	valid-rmse:0.488683
# [2]	train-rmse:0.487894	valid-rmse:0.483782
# [3]	train-rmse:0.483038	valid-rmse:0.478931
# [4]	train-rmse:0.478231	valid-rmse:0.474128
# [5]	train-rmse:0.473472	valid-rmse:0.469373
# [6]	train-rmse:0.468761	valid-rmse:0.464666
# [7]	train-rmse:0.464097	valid-rmse:0.460006
# [8]	train-rmse:0.459479	valid-rmse:0.455393
# [9]	train-rmse:0.454908	valid-rmse:0.450826
# [10]	train-rmse:0.450382	valid-rmse:0.446304
# [11]	train-rmse:0.445901	valid-rmse:0.441828
# [12]	train-rmse:0.441466	valid-rmse:0.437397
# [13]	train-rmse:0.437075	valid-rmse:0.43301
# [14]	train-rmse:0.432727	valid-rmse:0.428667
# [15]	train-rmse:0.428423	valid-rmse:0.424368
# [16]	train-rmse:0.424163	valid-rmse:0.420112
# [17]	train-rmse:0.419944	valid-rmse:0.415899
# [18]	train-rmse:0.415769	valid-rmse:0.411727
# [19]	train-rmse:0.411634	valid-rmse:0.407598
# [20]	train-rmse:0.407542	valid-rmse:0.40351
# [21]	train-rmse:0.40349	valid-rmse:0.399463
# [22]	train-rmse:0.399478	valid-rmse:0.395457
# [23]	train-rmse:0.395507	valid-rmse:0.391491
# [24]	train-rmse:0.391576	valid-rmse:0.387564
# [25]	train-rmse:0.387684	valid-rmse:0.383677
# [26]	train-rmse:0.383831	valid-rmse:0.37983
# [27]	train-rmse:0.380016	valid-rmse:0.37602
# [28]	train-rmse:0.37624	valid-rmse:0.372249
# [29]	train-rmse:0.372502	valid-rmse:0.368516
# [30]	train-rmse:0.368801	valid-rmse:0.36482
# [31]	train-rmse:0.365137	valid-rmse:0.361162
# [32]	train-rmse:0.361509	valid-rmse:0.35754
# [33]	train-rmse:0.357918	valid-rmse:0.353955
# [34]	train-rmse:0.354363	valid-rmse:0.350405
# [35]	train-rmse:0.350844	valid-rmse:0.346892
# [36]	train-rmse:0.34736	valid-rmse:0.343413
# [37]	train-rmse:0.343911	valid-rmse:0.33997
# [38]	train-rmse:0.340496	valid-rmse:0.336561
# [39]	train-rmse:0.337116	valid-rmse:0.333187
# [40]	train-rmse:0.333769	valid-rmse:0.329846
# [41]	train-rmse:0.330456	valid-rmse:0.326539
# [42]	train-rmse:0.327176	valid-rmse:0.323265
# [43]	train-rmse:0.32393	valid-rmse:0.320025
# [44]	train-rmse:0.320715	valid-rmse:0.316817
# [45]	train-rmse:0.317533	valid-rmse:0.313641
# [46]	train-rmse:0.314383	valid-rmse:0.310497
# [47]	train-rmse:0.311264	valid-rmse:0.307385
# [48]	train-rmse:0.308177	valid-rmse:0.304304
# [49]	train-rmse:0.305121	valid-rmse:0.301254
# [50]	train-rmse:0.302095	valid-rmse:0.298235
# [51]	train-rmse:0.2991	valid-rmse:0.295247
# [52]	train-rmse:0.296134	valid-rmse:0.292288
# [53]	train-rmse:0.293199	valid-rmse:0.289359
# [54]	train-rmse:0.290293	valid-rmse:0.28646
# [55]	train-rmse:0.287416	valid-rmse:0.283591
# [56]	train-rmse:0.284568	valid-rmse:0.28075
# [57]	train-rmse:0.281749	valid-rmse:0.277937
# [58]	train-rmse:0.278958	valid-rmse:0.275154
# [59]	train-rmse:0.276195	valid-rmse:0.272398
# [60]	train-rmse:0.273459	valid-rmse:0.26967
# [61]	train-rmse:0.270752	valid-rmse:0.26697
# [62]	train-rmse:0.268071	valid-rmse:0.264297
# [63]	train-rmse:0.265418	valid-rmse:0.261651
# [64]	train-rmse:0.262791	valid-rmse:0.259031
# [65]	train-rmse:0.26019	valid-rmse:0.256439
# [66]	train-rmse:0.257616	valid-rmse:0.253872
# [67]	train-rmse:0.255067	valid-rmse:0.251331
# [68]	train-rmse:0.252544	valid-rmse:0.248817
# [69]	train-rmse:0.250047	valid-rmse:0.246327
# [70]	train-rmse:0.247574	valid-rmse:0.243863
# [71]	train-rmse:0.245127	valid-rmse:0.241424
# [72]	train-rmse:0.242704	valid-rmse:0.239009
# [73]	train-rmse:0.240306	valid-rmse:0.236619
# [74]	train-rmse:0.237931	valid-rmse:0.234254
# [75]	train-rmse:0.235581	valid-rmse:0.231912
# [76]	train-rmse:0.233254	valid-rmse:0.229594
# [77]	train-rmse:0.230951	valid-rmse:0.227299
# [78]	train-rmse:0.228671	valid-rmse:0.225028
# [79]	train-rmse:0.226414	valid-rmse:0.22278
# [80]	train-rmse:0.224179	valid-rmse:0.220555
# [81]	train-rmse:0.221968	valid-rmse:0.218352
# [82]	train-rmse:0.219778	valid-rmse:0.216172
# [83]	train-rmse:0.217611	valid-rmse:0.214014
# [84]	train-rmse:0.215465	valid-rmse:0.211878
# [85]	train-rmse:0.213341	valid-rmse:0.209764
# [86]	train-rmse:0.211239	valid-rmse:0.207742
# [87]	train-rmse:0.209158	valid-rmse:0.205671
# [88]	train-rmse:0.207097	valid-rmse:0.203692
# [89]	train-rmse:0.205058	valid-rmse:0.201733
# [90]	train-rmse:0.203039	valid-rmse:0.199724
# [91]	train-rmse:0.20104	valid-rmse:0.197805
# [92]	train-rmse:0.199062	valid-rmse:0.195906
# [93]	train-rmse:0.197103	valid-rmse:0.193959
# [94]	train-rmse:0.195165	valid-rmse:0.192099
# [95]	train-rmse:0.193246	valid-rmse:0.190259
# [96]	train-rmse:0.191346	valid-rmse:0.18837
# [97]	train-rmse:0.189466	valid-rmse:0.186568
# [98]	train-rmse:0.187604	valid-rmse:0.184718
# [99]	train-rmse:0.185762	valid-rmse:0.182953
# [100]	train-rmse:0.183938	valid-rmse:0.181207
# [101]	train-rmse:0.182132	valid-rmse:0.179413
# [102]	train-rmse:0.180345	valid-rmse:0.177703
# [103]	train-rmse:0.178576	valid-rmse:0.176011
# [104]	train-rmse:0.176825	valid-rmse:0.174272
# [105]	train-rmse:0.175091	valid-rmse:0.172615
# [106]	train-rmse:0.173375	valid-rmse:0.170975
# [107]	train-rmse:0.171677	valid-rmse:0.16929
# [108]	train-rmse:0.169995	valid-rmse:0.167684
# [109]	train-rmse:0.168331	valid-rmse:0.166033
# [110]	train-rmse:0.166684	valid-rmse:0.164461
# [111]	train-rmse:0.165053	valid-rmse:0.162835
# [112]	train-rmse:0.163438	valid-rmse:0.161225
# [113]	train-rmse:0.16184	valid-rmse:0.159702
# [114]	train-rmse:0.160259	valid-rmse:0.158125
# [115]	train-rmse:0.158693	valid-rmse:0.156565
# [116]	train-rmse:0.157143	valid-rmse:0.15503
# [117]	train-rmse:0.155609	valid-rmse:0.153502
# [118]	train-rmse:0.15409	valid-rmse:0.152057
# [119]	train-rmse:0.152587	valid-rmse:0.15056
# [120]	train-rmse:0.151099	valid-rmse:0.149079
# [121]	train-rmse:0.149626	valid-rmse:0.147679
# [122]	train-rmse:0.148168	valid-rmse:0.146229
# [123]	train-rmse:0.146725	valid-rmse:0.144794
# [124]	train-rmse:0.145297	valid-rmse:0.143438
# [125]	train-rmse:0.143883	valid-rmse:0.142032
# [126]	train-rmse:0.14248	valid-rmse:0.140672
# [127]	train-rmse:0.141095	valid-rmse:0.139296
# [128]	train-rmse:0.139721	valid-rmse:0.137964
# [129]	train-rmse:0.138363	valid-rmse:0.136617
# [130]	train-rmse:0.137017	valid-rmse:0.135313
# [131]	train-rmse:0.135687	valid-rmse:0.134054
# [132]	train-rmse:0.134368	valid-rmse:0.132778
# [133]	train-rmse:0.133065	valid-rmse:0.131486
# [134]	train-rmse:0.131775	valid-rmse:0.130241
# [135]	train-rmse:0.130499	valid-rmse:0.129008
# [136]	train-rmse:0.129235	valid-rmse:0.127756
# [137]	train-rmse:0.127981	valid-rmse:0.126546
# [138]	train-rmse:0.126743	valid-rmse:0.125346
# [139]	train-rmse:0.125515	valid-rmse:0.124162
# [140]	train-rmse:0.124302	valid-rmse:0.122962
# [141]	train-rmse:0.123102	valid-rmse:0.1218
# [142]	train-rmse:0.12191	valid-rmse:0.120651
# [143]	train-rmse:0.120735	valid-rmse:0.119513
# [144]	train-rmse:0.11957	valid-rmse:0.118363
# [145]	train-rmse:0.118415	valid-rmse:0.117251
# [146]	train-rmse:0.117275	valid-rmse:0.116149
# [147]	train-rmse:0.116143	valid-rmse:0.115062
# [148]	train-rmse:0.115025	valid-rmse:0.11396
# [149]	train-rmse:0.11392	valid-rmse:0.112897
# [150]	train-rmse:0.112822	valid-rmse:0.111843
# [151]	train-rmse:0.111739	valid-rmse:0.110803
# [152]	train-rmse:0.11066	valid-rmse:0.109761
# [153]	train-rmse:0.109596	valid-rmse:0.108741
# [154]	train-rmse:0.108544	valid-rmse:0.10774
# [155]	train-rmse:0.107497	valid-rmse:0.106737
# [156]	train-rmse:0.106461	valid-rmse:0.105738
# [157]	train-rmse:0.105436	valid-rmse:0.104751
# [158]	train-rmse:0.104426	valid-rmse:0.103791
# [159]	train-rmse:0.103421	valid-rmse:0.10283
# [160]	train-rmse:0.102425	valid-rmse:0.101893
# [161]	train-rmse:0.101438	valid-rmse:0.100967
# [162]	train-rmse:0.100468	valid-rmse:0.100048
# [163]	train-rmse:0.099502	valid-rmse:0.099142
# [164]	train-rmse:0.098548	valid-rmse:0.098266
# [165]	train-rmse:0.097601	valid-rmse:0.09738
# [166]	train-rmse:0.096664	valid-rmse:0.096504
# [167]	train-rmse:0.095742	valid-rmse:0.095631
# [168]	train-rmse:0.094827	valid-rmse:0.094794
# [169]	train-rmse:0.093918	valid-rmse:0.093946
# [170]	train-rmse:0.093018	valid-rmse:0.093108
# [171]	train-rmse:0.092128	valid-rmse:0.092282
# [172]	train-rmse:0.091249	valid-rmse:0.091494
# [173]	train-rmse:0.090383	valid-rmse:0.090672
# [174]	train-rmse:0.089525	valid-rmse:0.089856
# [175]	train-rmse:0.088673	valid-rmse:0.089095
# [176]	train-rmse:0.087833	valid-rmse:0.088305
# [177]	train-rmse:0.086994	valid-rmse:0.087554
# [178]	train-rmse:0.086163	valid-rmse:0.086813
# [179]	train-rmse:0.085342	valid-rmse:0.086062
# [180]	train-rmse:0.084531	valid-rmse:0.0853
# [181]	train-rmse:0.083725	valid-rmse:0.084583
# [182]	train-rmse:0.082932	valid-rmse:0.083851
# [183]	train-rmse:0.082143	valid-rmse:0.08315
# [184]	train-rmse:0.08136	valid-rmse:0.082437
# [185]	train-rmse:0.080587	valid-rmse:0.081754
# [186]	train-rmse:0.07982	valid-rmse:0.081057
# [187]	train-rmse:0.079065	valid-rmse:0.080353
# [188]	train-rmse:0.078313	valid-rmse:0.07967
# [189]	train-rmse:0.07757	valid-rmse:0.079019
# [190]	train-rmse:0.076834	valid-rmse:0.07835
# [191]	train-rmse:0.076106	valid-rmse:0.077713
# [192]	train-rmse:0.075385	valid-rmse:0.07706
# [193]	train-rmse:0.074672	valid-rmse:0.076408
# [194]	train-rmse:0.073968	valid-rmse:0.075739
# [195]	train-rmse:0.073269	valid-rmse:0.075106
# [196]	train-rmse:0.072577	valid-rmse:0.074491
# [197]	train-rmse:0.071892	valid-rmse:0.073882
# [198]	train-rmse:0.071214	valid-rmse:0.07327
# [199]	train-rmse:0.070542	valid-rmse:0.072675
# [200]	train-rmse:0.069878	valid-rmse:0.072088
# [201]	train-rmse:0.06922	valid-rmse:0.071522
# [202]	train-rmse:0.068569	valid-rmse:0.070938
# [203]	train-rmse:0.067927	valid-rmse:0.070335
# [204]	train-rmse:0.067288	valid-rmse:0.069783
# [205]	train-rmse:0.066657	valid-rmse:0.06923
# [206]	train-rmse:0.066033	valid-rmse:0.06869
# [207]	train-rmse:0.065415	valid-rmse:0.068143
# [208]	train-rmse:0.064803	valid-rmse:0.067598
# [209]	train-rmse:0.064196	valid-rmse:0.067075
# [210]	train-rmse:0.063594	valid-rmse:0.06657
# [211]	train-rmse:0.063001	valid-rmse:0.066059
# [212]	train-rmse:0.062413	valid-rmse:0.065544
# [213]	train-rmse:0.06183	valid-rmse:0.065047
# [214]	train-rmse:0.061252	valid-rmse:0.064567
# [215]	train-rmse:0.060683	valid-rmse:0.064069
# [216]	train-rmse:0.060121	valid-rmse:0.06358
# [217]	train-rmse:0.059561	valid-rmse:0.063111
# [218]	train-rmse:0.059009	valid-rmse:0.062643
# [219]	train-rmse:0.058465	valid-rmse:0.062171
# [220]	train-rmse:0.057922	valid-rmse:0.061725
# [221]	train-rmse:0.057388	valid-rmse:0.061251
# [222]	train-rmse:0.056858	valid-rmse:0.060797
# [223]	train-rmse:0.056331	valid-rmse:0.060355
# [224]	train-rmse:0.055809	valid-rmse:0.059935
# [225]	train-rmse:0.055296	valid-rmse:0.059485
# [226]	train-rmse:0.054788	valid-rmse:0.059031
# [227]	train-rmse:0.054282	valid-rmse:0.058626
# [228]	train-rmse:0.053786	valid-rmse:0.058195
# [229]	train-rmse:0.053292	valid-rmse:0.057829
# [230]	train-rmse:0.052804	valid-rmse:0.057397
# [231]	train-rmse:0.052315	valid-rmse:0.056991
# [232]	train-rmse:0.051838	valid-rmse:0.056596
# [233]	train-rmse:0.05136	valid-rmse:0.0562
# [234]	train-rmse:0.050889	valid-rmse:0.055821
# [235]	train-rmse:0.050427	valid-rmse:0.055441
# [236]	train-rmse:0.049965	valid-rmse:0.055061
# [237]	train-rmse:0.049506	valid-rmse:0.054707
# [238]	train-rmse:0.049053	valid-rmse:0.054347
# [239]	train-rmse:0.048604	valid-rmse:0.054001
# [240]	train-rmse:0.048162	valid-rmse:0.05365
# [241]	train-rmse:0.047723	valid-rmse:0.053306
# [242]	train-rmse:0.047288	valid-rmse:0.052979
# [243]	train-rmse:0.046858	valid-rmse:0.052644
# [244]	train-rmse:0.046435	valid-rmse:0.052295
# [245]	train-rmse:0.046011	valid-rmse:0.051957
# [246]	train-rmse:0.045593	valid-rmse:0.051635
# [247]	train-rmse:0.045183	valid-rmse:0.0513
# [248]	train-rmse:0.044772	valid-rmse:0.050994
# [249]	train-rmse:0.044367	valid-rmse:0.0507
# [250]	train-rmse:0.04397	valid-rmse:0.05038
# [251]	train-rmse:0.043574	valid-rmse:0.050112
# [252]	train-rmse:0.043182	valid-rmse:0.049813
# [253]	train-rmse:0.04279	valid-rmse:0.049504
# [254]	train-rmse:0.042407	valid-rmse:0.049202
# [255]	train-rmse:0.042026	valid-rmse:0.048932
# [256]	train-rmse:0.041648	valid-rmse:0.048661
# [257]	train-rmse:0.041277	valid-rmse:0.048389
# [258]	train-rmse:0.040908	valid-rmse:0.048132
# [259]	train-rmse:0.040542	valid-rmse:0.047879
# [260]	train-rmse:0.04018	valid-rmse:0.047643
# [261]	train-rmse:0.039819	valid-rmse:0.047373
# [262]	train-rmse:0.039465	valid-rmse:0.047135
# [263]	train-rmse:0.039114	valid-rmse:0.046903
# [264]	train-rmse:0.038767	valid-rmse:0.046668
# [265]	train-rmse:0.038424	valid-rmse:0.046429
# [266]	train-rmse:0.038083	valid-rmse:0.04619
# [267]	train-rmse:0.037745	valid-rmse:0.045975
# [268]	train-rmse:0.037411	valid-rmse:0.045719
# [269]	train-rmse:0.037078	valid-rmse:0.04548
# [270]	train-rmse:0.036752	valid-rmse:0.045239
# [271]	train-rmse:0.036424	valid-rmse:0.045003
# [272]	train-rmse:0.036103	valid-rmse:0.044801
# [273]	train-rmse:0.035785	valid-rmse:0.044623
# [274]	train-rmse:0.035469	valid-rmse:0.044391
# [275]	train-rmse:0.035154	valid-rmse:0.044176
# [276]	train-rmse:0.034842	valid-rmse:0.043963
# [277]	train-rmse:0.034535	valid-rmse:0.043745
# [278]	train-rmse:0.03423	valid-rmse:0.04353
# [279]	train-rmse:0.033928	valid-rmse:0.043328
# [280]	train-rmse:0.033627	valid-rmse:0.043122
# [281]	train-rmse:0.033333	valid-rmse:0.042919
# [282]	train-rmse:0.03304	valid-rmse:0.042725
# [283]	train-rmse:0.03275	valid-rmse:0.042557
# [284]	train-rmse:0.032462	valid-rmse:0.042371
# [285]	train-rmse:0.032178	valid-rmse:0.042167
# [286]	train-rmse:0.031896	valid-rmse:0.041992
# [287]	train-rmse:0.031616	valid-rmse:0.041815
# [288]	train-rmse:0.031342	valid-rmse:0.041642
# [289]	train-rmse:0.03107	valid-rmse:0.041459
# [290]	train-rmse:0.030801	valid-rmse:0.041296
# [291]	train-rmse:0.030531	valid-rmse:0.041117
# [292]	train-rmse:0.030268	valid-rmse:0.040983
# [293]	train-rmse:0.030005	valid-rmse:0.040819
# [294]	train-rmse:0.029745	valid-rmse:0.04066
# [295]	train-rmse:0.029485	valid-rmse:0.040511
# [296]	train-rmse:0.02923	valid-rmse:0.040343
# [297]	train-rmse:0.028977	valid-rmse:0.040192
# [298]	train-rmse:0.028727	valid-rmse:0.040042
# [299]	train-rmse:0.028481	valid-rmse:0.039876
# [300]	train-rmse:0.028241	valid-rmse:0.039714
# [301]	train-rmse:0.027999	valid-rmse:0.039561
# [302]	train-rmse:0.027757	valid-rmse:0.039409
# [303]	train-rmse:0.027519	valid-rmse:0.039276
# [304]	train-rmse:0.027288	valid-rmse:0.039122
# [305]	train-rmse:0.027061	valid-rmse:0.038979
# [306]	train-rmse:0.026829	valid-rmse:0.038831
# [307]	train-rmse:0.0266	valid-rmse:0.038703
# [308]	train-rmse:0.026378	valid-rmse:0.038578
# [309]	train-rmse:0.026155	valid-rmse:0.038449
# [310]	train-rmse:0.025939	valid-rmse:0.03832
# [311]	train-rmse:0.025718	valid-rmse:0.038194
# [312]	train-rmse:0.025501	valid-rmse:0.038062
# [313]	train-rmse:0.025291	valid-rmse:0.037939
# [314]	train-rmse:0.025077	valid-rmse:0.037811
# [315]	train-rmse:0.024868	valid-rmse:0.037708
# [316]	train-rmse:0.024659	valid-rmse:0.037587
# [317]	train-rmse:0.024457	valid-rmse:0.037485
# [318]	train-rmse:0.024251	valid-rmse:0.037373
# [319]	train-rmse:0.024049	valid-rmse:0.037271
# [320]	train-rmse:0.02385	valid-rmse:0.037179
# [321]	train-rmse:0.023653	valid-rmse:0.037089
# [322]	train-rmse:0.023457	valid-rmse:0.036993
# [323]	train-rmse:0.02326	valid-rmse:0.036891
# [324]	train-rmse:0.023069	valid-rmse:0.0368
# [325]	train-rmse:0.022878	valid-rmse:0.036693
# [326]	train-rmse:0.022694	valid-rmse:0.036589
# [327]	train-rmse:0.022512	valid-rmse:0.036495
# [328]	train-rmse:0.022331	valid-rmse:0.036402
# [329]	train-rmse:0.022155	valid-rmse:0.036311
# [330]	train-rmse:0.021981	valid-rmse:0.036224
# [331]	train-rmse:0.021801	valid-rmse:0.03614
# [332]	train-rmse:0.021622	valid-rmse:0.036056
# [333]	train-rmse:0.021453	valid-rmse:0.035971
# [334]	train-rmse:0.021279	valid-rmse:0.035883
# [335]	train-rmse:0.021114	valid-rmse:0.035801
# [336]	train-rmse:0.020951	valid-rmse:0.035721
# [337]	train-rmse:0.020781	valid-rmse:0.035644
# [338]	train-rmse:0.020614	valid-rmse:0.03556
# [339]	train-rmse:0.020456	valid-rmse:0.035482
# [340]	train-rmse:0.0203	valid-rmse:0.035409
# [341]	train-rmse:0.020138	valid-rmse:0.035334
# [342]	train-rmse:0.019986	valid-rmse:0.03525
# [343]	train-rmse:0.019824	valid-rmse:0.035179
# [344]	train-rmse:0.019667	valid-rmse:0.035104
# [345]	train-rmse:0.019519	valid-rmse:0.035034
# [346]	train-rmse:0.019366	valid-rmse:0.034969
# [347]	train-rmse:0.01921	valid-rmse:0.034912
# [348]	train-rmse:0.019067	valid-rmse:0.034849
# [349]	train-rmse:0.018925	valid-rmse:0.034776
# [350]	train-rmse:0.018774	valid-rmse:0.034722
# [351]	train-rmse:0.018635	valid-rmse:0.034655
# [352]	train-rmse:0.018494	valid-rmse:0.034586
# [353]	train-rmse:0.018358	valid-rmse:0.034521
# [354]	train-rmse:0.018213	valid-rmse:0.034471
# [355]	train-rmse:0.01808	valid-rmse:0.034404
# [356]	train-rmse:0.017938	valid-rmse:0.034352
# [357]	train-rmse:0.017796	valid-rmse:0.034306
# [358]	train-rmse:0.017668	valid-rmse:0.034247
# [359]	train-rmse:0.017531	valid-rmse:0.034203
# [360]	train-rmse:0.017395	valid-rmse:0.034156
# [361]	train-rmse:0.01727	valid-rmse:0.034092
# [362]	train-rmse:0.017147	valid-rmse:0.034034
# [363]	train-rmse:0.017016	valid-rmse:0.033995
# [364]	train-rmse:0.016884	valid-rmse:0.033941
# [365]	train-rmse:0.016765	valid-rmse:0.033883
# [366]	train-rmse:0.016648	valid-rmse:0.033831
# [367]	train-rmse:0.016522	valid-rmse:0.033787
# [368]	train-rmse:0.016407	valid-rmse:0.033737
# [369]	train-rmse:0.016291	valid-rmse:0.033684
# [370]	train-rmse:0.016174	valid-rmse:0.033648
# [371]	train-rmse:0.016052	valid-rmse:0.033613
# [372]	train-rmse:0.01593	valid-rmse:0.03358
# [373]	train-rmse:0.015821	valid-rmse:0.03353
# [374]	train-rmse:0.015703	valid-rmse:0.03348
# [375]	train-rmse:0.015592	valid-rmse:0.033446
# [376]	train-rmse:0.015486	valid-rmse:0.033404
# [377]	train-rmse:0.015382	valid-rmse:0.033364
# [378]	train-rmse:0.015275	valid-rmse:0.033318
# [379]	train-rmse:0.015164	valid-rmse:0.033279
# [380]	train-rmse:0.015063	valid-rmse:0.033238
# [381]	train-rmse:0.014959	valid-rmse:0.033193
# [382]	train-rmse:0.014853	valid-rmse:0.033152
# [383]	train-rmse:0.014755	valid-rmse:0.033118
# [384]	train-rmse:0.014648	valid-rmse:0.033091
# [385]	train-rmse:0.014547	valid-rmse:0.033063
# [386]	train-rmse:0.01445	valid-rmse:0.033026
# [387]	train-rmse:0.014353	valid-rmse:0.032989
# [388]	train-rmse:0.014255	valid-rmse:0.032958
# [389]	train-rmse:0.01415	valid-rmse:0.032924
# [390]	train-rmse:0.014055	valid-rmse:0.03289
# [391]	train-rmse:0.013963	valid-rmse:0.032856
# [392]	train-rmse:0.01387	valid-rmse:0.032834
# [393]	train-rmse:0.013779	valid-rmse:0.0328
# [394]	train-rmse:0.01368	valid-rmse:0.032771
# [395]	train-rmse:0.013588	valid-rmse:0.032744
# [396]	train-rmse:0.013489	valid-rmse:0.032718
# [397]	train-rmse:0.013404	valid-rmse:0.032693
# [398]	train-rmse:0.013319	valid-rmse:0.032662
# [399]	train-rmse:0.013224	valid-rmse:0.032639
# [400]	train-rmse:0.013133	valid-rmse:0.03261
# [401]	train-rmse:0.013053	valid-rmse:0.032581
# [402]	train-rmse:0.01297	valid-rmse:0.032557
# [403]	train-rmse:0.012882	valid-rmse:0.032528
# [404]	train-rmse:0.012801	valid-rmse:0.032505
# [405]	train-rmse:0.012719	valid-rmse:0.032485
# [406]	train-rmse:0.012643	valid-rmse:0.032459
# [407]	train-rmse:0.012553	valid-rmse:0.032433
# [408]	train-rmse:0.012469	valid-rmse:0.032408
# [409]	train-rmse:0.012393	valid-rmse:0.032386
# [410]	train-rmse:0.012313	valid-rmse:0.03237
# [411]	train-rmse:0.012227	valid-rmse:0.032346
# [412]	train-rmse:0.012148	valid-rmse:0.03233
# [413]	train-rmse:0.012064	valid-rmse:0.032311
# [414]	train-rmse:0.011984	valid-rmse:0.03229
# [415]	train-rmse:0.011913	valid-rmse:0.032276
# [416]	train-rmse:0.01184	valid-rmse:0.032257
# [417]	train-rmse:0.011773	valid-rmse:0.032237
# [418]	train-rmse:0.011693	valid-rmse:0.032216
# [419]	train-rmse:0.011613	valid-rmse:0.0322
# [420]	train-rmse:0.011539	valid-rmse:0.032186
# [421]	train-rmse:0.011461	valid-rmse:0.032169
# [422]	train-rmse:0.011392	valid-rmse:0.032152
# [423]	train-rmse:0.011315	valid-rmse:0.032138
# [424]	train-rmse:0.011247	valid-rmse:0.032125
# [425]	train-rmse:0.01118	valid-rmse:0.03211
# [426]	train-rmse:0.011113	valid-rmse:0.032097
# [427]	train-rmse:0.011046	valid-rmse:0.032077
# [428]	train-rmse:0.010972	valid-rmse:0.032064
# [429]	train-rmse:0.010908	valid-rmse:0.032054
# [430]	train-rmse:0.010845	valid-rmse:0.03204
# [431]	train-rmse:0.010782	valid-rmse:0.03203
# [432]	train-rmse:0.010713	valid-rmse:0.032023
# [433]	train-rmse:0.010649	valid-rmse:0.032006
# [434]	train-rmse:0.010588	valid-rmse:0.031996
# [435]	train-rmse:0.010521	valid-rmse:0.031991
# [436]	train-rmse:0.010456	valid-rmse:0.031978
# [437]	train-rmse:0.010392	valid-rmse:0.031965
# [438]	train-rmse:0.010334	valid-rmse:0.031956
# [439]	train-rmse:0.010277	valid-rmse:0.031938
# [440]	train-rmse:0.010215	valid-rmse:0.031925
# [441]	train-rmse:0.010159	valid-rmse:0.031918
# [442]	train-rmse:0.010104	valid-rmse:0.031901
# [443]	train-rmse:0.010041	valid-rmse:0.031897
# [444]	train-rmse:0.009982	valid-rmse:0.031886
# [445]	train-rmse:0.009928	valid-rmse:0.03188
# [446]	train-rmse:0.00987	valid-rmse:0.03187
# [447]	train-rmse:0.009817	valid-rmse:0.031857
# [448]	train-rmse:0.009764	valid-rmse:0.031841
# [449]	train-rmse:0.009708	valid-rmse:0.031819
# [450]	train-rmse:0.009657	valid-rmse:0.031812
# [451]	train-rmse:0.009597	valid-rmse:0.031802
# [452]	train-rmse:0.009542	valid-rmse:0.031792
# [453]	train-rmse:0.009492	valid-rmse:0.031778
# [454]	train-rmse:0.009444	valid-rmse:0.031775
# [455]	train-rmse:0.00939	valid-rmse:0.031769
# [456]	train-rmse:0.009337	valid-rmse:0.031759
# [457]	train-rmse:0.009284	valid-rmse:0.031748
# [458]	train-rmse:0.009231	valid-rmse:0.031744
# [459]	train-rmse:0.009184	valid-rmse:0.031741
# [460]	train-rmse:0.009133	valid-rmse:0.031732
# [461]	train-rmse:0.009084	valid-rmse:0.031729
# [462]	train-rmse:0.009035	valid-rmse:0.031721
# [463]	train-rmse:0.008986	valid-rmse:0.031714
# [464]	train-rmse:0.00894	valid-rmse:0.031702
# [465]	train-rmse:0.008891	valid-rmse:0.031697
# [466]	train-rmse:0.008843	valid-rmse:0.031688
# [467]	train-rmse:0.0088	valid-rmse:0.031684
# [468]	train-rmse:0.008752	valid-rmse:0.031671
# [469]	train-rmse:0.008709	valid-rmse:0.03166
# [470]	train-rmse:0.008662	valid-rmse:0.031648
# [471]	train-rmse:0.008616	valid-rmse:0.031642
# [472]	train-rmse:0.008576	valid-rmse:0.031638
# [473]	train-rmse:0.008532	valid-rmse:0.031633
# [474]	train-rmse:0.008489	valid-rmse:0.03163
# [475]	train-rmse:0.008445	valid-rmse:0.031622
# [476]	train-rmse:0.008399	valid-rmse:0.03162
# [477]	train-rmse:0.008355	valid-rmse:0.031604
# [478]	train-rmse:0.00831	valid-rmse:0.031604
# [479]	train-rmse:0.008272	valid-rmse:0.031595
# [480]	train-rmse:0.008235	valid-rmse:0.031591
# [481]	train-rmse:0.008192	valid-rmse:0.031581
# [482]	train-rmse:0.008154	valid-rmse:0.031573
# [483]	train-rmse:0.008114	valid-rmse:0.031561
# [484]	train-rmse:0.008072	valid-rmse:0.031557
# [485]	train-rmse:0.008038	valid-rmse:0.031556
# [486]	train-rmse:0.007996	valid-rmse:0.031549
# [487]	train-rmse:0.007956	valid-rmse:0.031542
# [488]	train-rmse:0.007923	valid-rmse:0.03154
# [489]	train-rmse:0.007877	valid-rmse:0.031535
# [490]	train-rmse:0.007837	valid-rmse:0.031524
# [491]	train-rmse:0.007792	valid-rmse:0.031527
# [492]	train-rmse:0.007754	valid-rmse:0.03152
# [493]	train-rmse:0.007722	valid-rmse:0.031519
# [494]	train-rmse:0.007678	valid-rmse:0.031517
# [495]	train-rmse:0.00764	valid-rmse:0.031507
# [496]	train-rmse:0.007598	valid-rmse:0.031508
# [497]	train-rmse:0.007567	valid-rmse:0.031507
# [498]	train-rmse:0.007524	valid-rmse:0.031507
# [499]	train-rmse:0.007487	valid-rmse:0.031506
# [500]	train-rmse:0.007451	valid-rmse:0.0315
# [501]	train-rmse:0.007422	valid-rmse:0.031501
# [502]	train-rmse:0.007387	valid-rmse:0.031492
# [503]	train-rmse:0.007351	valid-rmse:0.031486
# [504]	train-rmse:0.007319	valid-rmse:0.031485
# [505]	train-rmse:0.00728	valid-rmse:0.031488
# [506]	train-rmse:0.007245	valid-rmse:0.031479
# [507]	train-rmse:0.00721	valid-rmse:0.031478
# [508]	train-rmse:0.007181	valid-rmse:0.03147
# [509]	train-rmse:0.00715	valid-rmse:0.031467
# [510]	train-rmse:0.007118	valid-rmse:0.031465
# [511]	train-rmse:0.007085	valid-rmse:0.031453
# [512]	train-rmse:0.007055	valid-rmse:0.031449
# [513]	train-rmse:0.007024	valid-rmse:0.031439
# [514]	train-rmse:0.006996	valid-rmse:0.031437
# [515]	train-rmse:0.006961	valid-rmse:0.031446
# [516]	train-rmse:0.006933	valid-rmse:0.031439
# [517]	train-rmse:0.006904	valid-rmse:0.031442
# [518]	train-rmse:0.006875	valid-rmse:0.031441
# [519]	train-rmse:0.006845	valid-rmse:0.031427
# [520]	train-rmse:0.00681	valid-rmse:0.031429
# [521]	train-rmse:0.006784	valid-rmse:0.031429
# [522]	train-rmse:0.006752	valid-rmse:0.031437
# [523]	train-rmse:0.006725	valid-rmse:0.031433
# [524]	train-rmse:0.006695	valid-rmse:0.03143
# [525]	train-rmse:0.006665	valid-rmse:0.031429
# [526]	train-rmse:0.006635	valid-rmse:0.031429
# [527]	train-rmse:0.00661	valid-rmse:0.031426
# [528]	train-rmse:0.006581	valid-rmse:0.031425
# [529]	train-rmse:0.006555	valid-rmse:0.031422
# [530]	train-rmse:0.00653	valid-rmse:0.031422
# [531]	train-rmse:0.006501	valid-rmse:0.031422
# [532]	train-rmse:0.006474	valid-rmse:0.031416
# [533]	train-rmse:0.006446	valid-rmse:0.031416
# [534]	train-rmse:0.006422	valid-rmse:0.031413
# [535]	train-rmse:0.006397	valid-rmse:0.031416
# [536]	train-rmse:0.006369	valid-rmse:0.031399
# [537]	train-rmse:0.006342	valid-rmse:0.031394
# [538]	train-rmse:0.006315	valid-rmse:0.031391
# [539]	train-rmse:0.006287	valid-rmse:0.031376
# [540]	train-rmse:0.00626	valid-rmse:0.031375
# [541]	train-rmse:0.006233	valid-rmse:0.031372
# [542]	train-rmse:0.006206	valid-rmse:0.031358
# [543]	train-rmse:0.006179	valid-rmse:0.031355
# [544]	train-rmse:0.006153	valid-rmse:0.031353
# [545]	train-rmse:0.006127	valid-rmse:0.031339
# [546]	train-rmse:0.006101	valid-rmse:0.031336
# [547]	train-rmse:0.006079	valid-rmse:0.031337
# [548]	train-rmse:0.006054	valid-rmse:0.031334
# [549]	train-rmse:0.006033	valid-rmse:0.031331
# [550]	train-rmse:0.006008	valid-rmse:0.031328
# [551]	train-rmse:0.005986	valid-rmse:0.031325
# [552]	train-rmse:0.00596	valid-rmse:0.031314
# [553]	train-rmse:0.005936	valid-rmse:0.031311
# [554]	train-rmse:0.005912	valid-rmse:0.031312
# [555]	train-rmse:0.005892	valid-rmse:0.031306
# [556]	train-rmse:0.005868	valid-rmse:0.031293
# [557]	train-rmse:0.005846	valid-rmse:0.03129
# [558]	train-rmse:0.005822	valid-rmse:0.03128
# [559]	train-rmse:0.005795	valid-rmse:0.03128
# [560]	train-rmse:0.005773	valid-rmse:0.031268
# [561]	train-rmse:0.005745	valid-rmse:0.031268
# [562]	train-rmse:0.005721	valid-rmse:0.031261
# [563]	train-rmse:0.005701	valid-rmse:0.031265
# [564]	train-rmse:0.00568	valid-rmse:0.031261
# [565]	train-rmse:0.005658	valid-rmse:0.031262
# [566]	train-rmse:0.005636	valid-rmse:0.031262
# [567]	train-rmse:0.005609	valid-rmse:0.031261
# [568]	train-rmse:0.005586	valid-rmse:0.031259
# [569]	train-rmse:0.005567	valid-rmse:0.031258
# [570]	train-rmse:0.005545	valid-rmse:0.031253
# [571]	train-rmse:0.00552	valid-rmse:0.031253
# [572]	train-rmse:0.0055	valid-rmse:0.031254
# [573]	train-rmse:0.005475	valid-rmse:0.031253
# [574]	train-rmse:0.005453	valid-rmse:0.031252
# [575]	train-rmse:0.005434	valid-rmse:0.031254
# [576]	train-rmse:0.005411	valid-rmse:0.031255
# [577]	train-rmse:0.005391	valid-rmse:0.031249
# [578]	train-rmse:0.005371	valid-rmse:0.03125
# [579]	train-rmse:0.005349	valid-rmse:0.031247
# [580]	train-rmse:0.005326	valid-rmse:0.031244
# [581]	train-rmse:0.005304	valid-rmse:0.031247
# [582]	train-rmse:0.005287	valid-rmse:0.031248
# [583]	train-rmse:0.005263	valid-rmse:0.031247
# [584]	train-rmse:0.005241	valid-rmse:0.03125
# [585]	train-rmse:0.005221	valid-rmse:0.031249
# [586]	train-rmse:0.0052	valid-rmse:0.031246
# [587]	train-rmse:0.005179	valid-rmse:0.03124
# [588]	train-rmse:0.005157	valid-rmse:0.031244
# [589]	train-rmse:0.005135	valid-rmse:0.031242
# [590]	train-rmse:0.005118	valid-rmse:0.031242
# [591]	train-rmse:0.005101	valid-rmse:0.031237
# [592]	train-rmse:0.005082	valid-rmse:0.031236
# [593]	train-rmse:0.005061	valid-rmse:0.031233
# [594]	train-rmse:0.005044	valid-rmse:0.031229
# [595]	train-rmse:0.005024	valid-rmse:0.031234
# [596]	train-rmse:0.005005	valid-rmse:0.031232
# [597]	train-rmse:0.004985	valid-rmse:0.031231
# [598]	train-rmse:0.004965	valid-rmse:0.031228
# [599]	train-rmse:0.004945	valid-rmse:0.031233
# [600]	train-rmse:0.004925	valid-rmse:0.031233
# [601]	train-rmse:0.004907	valid-rmse:0.031232
# [602]	train-rmse:0.004887	valid-rmse:0.031224
# [603]	train-rmse:0.004867	valid-rmse:0.031221
# [604]	train-rmse:0.004848	valid-rmse:0.031215
# [605]	train-rmse:0.004829	valid-rmse:0.031221
# [606]	train-rmse:0.00481	valid-rmse:0.03122
# [607]	train-rmse:0.004792	valid-rmse:0.031227
# [608]	train-rmse:0.004773	valid-rmse:0.031228
# [609]	train-rmse:0.004756	valid-rmse:0.031231
# [610]	train-rmse:0.004737	valid-rmse:0.031224
# [611]	train-rmse:0.004719	valid-rmse:0.03123
# [612]	train-rmse:0.004703	valid-rmse:0.031233
# [613]	train-rmse:0.004684	valid-rmse:0.031227
# [614]	train-rmse:0.004666	valid-rmse:0.031232
# Stopping. Best iteration:
# [604]	train-rmse:0.004848	valid-rmse:0.031215
# 2019-08-29 02:02:39,905 - ALPHA_MIND - INFO - Training time cost 71.69956588745117s
# 2019-08-29 02:02:39,906 - ALPHA_MIND - INFO - best_score = 0.031215, best_round = 604
# 2019-08-29 02:02:39,909 - ALPHA_MIND - INFO - 2018-01-04 00:00:00 total_data_test_excess: 500
# 2019-08-29 02:02:39,922 - ALPHA_MIND - INFO - 2018-01-04 00:00:00 len_of_total_data: 500
# 2019-08-29 02:02:39,931 - ALPHA_MIND - INFO - 2018-01-04 00:00:00 len_of_total_data_test_excess: 500
# 2019-08-29 02:02:39,933 - ALPHA_MIND - INFO - 2018-01-04 00:00:00 full re-balance: 500
# 2019-08-29 02:02:39,935 - ALPHA_MIND - INFO - shape_of_benchmark_w: (500,)
# 2019-08-29 02:02:39,937 - ALPHA_MIND - INFO - shape_of_total_risk_exp_pre: (500, 36)
# 2019-08-29 02:02:39,938 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 36)
# 2019-08-29 02:02:39,940 - ALPHA_MIND - INFO - constraints: (2, 36) in 2018-01-04 00:00:00
# 2019-08-29 02:02:39,940 - ALPHA_MIND - INFO - lbound: (500,) in 2018-01-04 00:00:00
# 2019-08-29 02:02:39,941 - ALPHA_MIND - INFO - ubound: (500,) in 2018-01-04 00:00:00
# 2019-08-29 02:02:39,954 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)
# 2019-08-29 02:02:40,041 - ALPHA_MIND - INFO - target_pos_shape: (500, 3)
# 2019-08-29 02:02:40,042 - ALPHA_MIND - INFO - len_codes:(500,)
# 2019-08-29 02:02:40,048 - ALPHA_MIND - INFO - len_result: 500
# 2019-08-29 02:02:40,048 - ALPHA_MIND - INFO - len_rets: 1, len_trade_dates: 1
# 2019-08-29 02:02:40,050 - ALPHA_MIND - INFO - len_net_rets: 1, len_trade_dates: 1
# 2019-08-29 02:02:40,050 - ALPHA_MIND - INFO - 2018-01-04 00:00:00 is finished
# 2019-08-29 02:02:40,051 - ALPHA_MIND - INFO - 2018-01-08 00:00:00 is start
# 2019-08-29 02:02:40,063 - ALPHA_MIND - INFO - len_x_train: 1000, len_y_train: 1000
# 2019-08-29 02:02:40,063 - ALPHA_MIND - INFO - X_train.shape=(1000, 423), X_test.shape = (1000, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7fe5fa8a53c8>>
# non_cross_validation。。。。
# [0]	train-rmse:0.496778	valid-rmse:0.493923
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.49183	valid-rmse:0.488976
# [2]	train-rmse:0.486932	valid-rmse:0.484079
# [3]	train-rmse:0.482083	valid-rmse:0.479232
# [4]	train-rmse:0.477282	valid-rmse:0.474432
# [5]	train-rmse:0.47253	valid-rmse:0.469681
# [6]	train-rmse:0.467825	valid-rmse:0.464978
# [7]	train-rmse:0.463167	valid-rmse:0.460321
# [8]	train-rmse:0.458556	valid-rmse:0.455711
# [9]	train-rmse:0.453991	valid-rmse:0.451148
# [10]	train-rmse:0.449472	valid-rmse:0.44663
# [11]	train-rmse:0.444998	valid-rmse:0.442158
# [12]	train-rmse:0.440569	valid-rmse:0.43773
# [13]	train-rmse:0.436184	valid-rmse:0.433347
# [14]	train-rmse:0.431844	valid-rmse:0.429008
# [15]	train-rmse:0.427547	valid-rmse:0.424712
# [16]	train-rmse:0.423293	valid-rmse:0.420459
# [17]	train-rmse:0.419081	valid-rmse:0.416249
# [18]	train-rmse:0.414912	valid-rmse:0.412082
# [19]	train-rmse:0.410784	valid-rmse:0.407956
# [20]	train-rmse:0.406698	valid-rmse:0.403871
# [21]	train-rmse:0.402653	valid-rmse:0.399828
# [22]	train-rmse:0.398649	valid-rmse:0.395825
# [23]	train-rmse:0.394685	valid-rmse:0.391862
# [24]	train-rmse:0.39076	valid-rmse:0.387939
# [25]	train-rmse:0.386875	valid-rmse:0.384056
# [26]	train-rmse:0.383029	valid-rmse:0.380211
# [27]	train-rmse:0.379221	valid-rmse:0.376406
# [28]	train-rmse:0.375452	valid-rmse:0.372638
# [29]	train-rmse:0.37172	valid-rmse:0.368908
# [30]	train-rmse:0.368026	valid-rmse:0.365216
# [31]	train-rmse:0.364369	valid-rmse:0.36156
# [32]	train-rmse:0.360748	valid-rmse:0.357942
# [33]	train-rmse:0.357165	valid-rmse:0.35436
# [34]	train-rmse:0.353617	valid-rmse:0.350813
# [35]	train-rmse:0.350104	valid-rmse:0.347303
# [36]	train-rmse:0.346627	valid-rmse:0.343828
# [37]	train-rmse:0.343185	valid-rmse:0.340387
# [38]	train-rmse:0.339777	valid-rmse:0.336982
# [39]	train-rmse:0.336404	valid-rmse:0.33361
# [40]	train-rmse:0.333064	valid-rmse:0.330273
# [41]	train-rmse:0.329759	valid-rmse:0.326969
# [42]	train-rmse:0.326486	valid-rmse:0.323698
# [43]	train-rmse:0.323246	valid-rmse:0.32046
# [44]	train-rmse:0.320039	valid-rmse:0.317255
# [45]	train-rmse:0.316864	valid-rmse:0.314082
# [46]	train-rmse:0.313721	valid-rmse:0.310941
# [47]	train-rmse:0.310609	valid-rmse:0.307832
# [48]	train-rmse:0.307529	valid-rmse:0.304754
# [49]	train-rmse:0.30448	valid-rmse:0.301707
# [50]	train-rmse:0.301462	valid-rmse:0.298691
# [51]	train-rmse:0.298473	valid-rmse:0.295705
# [52]	train-rmse:0.295515	valid-rmse:0.292749
# [53]	train-rmse:0.292587	valid-rmse:0.289823
# [54]	train-rmse:0.289688	valid-rmse:0.286926
# [55]	train-rmse:0.286819	valid-rmse:0.284059
# [56]	train-rmse:0.283978	valid-rmse:0.281221
# [57]	train-rmse:0.281166	valid-rmse:0.278411
# [58]	train-rmse:0.278382	valid-rmse:0.275629
# [59]	train-rmse:0.275626	valid-rmse:0.272876
# [60]	train-rmse:0.272898	valid-rmse:0.270151
# [61]	train-rmse:0.270198	valid-rmse:0.267453
# [62]	train-rmse:0.267525	valid-rmse:0.264782
# [63]	train-rmse:0.264878	valid-rmse:0.262138
# [64]	train-rmse:0.262259	valid-rmse:0.259521
# [65]	train-rmse:0.259666	valid-rmse:0.25693
# [66]	train-rmse:0.257099	valid-rmse:0.254366
# [67]	train-rmse:0.254557	valid-rmse:0.251827
# [68]	train-rmse:0.252042	valid-rmse:0.249315
# [69]	train-rmse:0.249552	valid-rmse:0.246827
# [70]	train-rmse:0.247087	valid-rmse:0.244365
# [71]	train-rmse:0.244647	valid-rmse:0.241928
# [72]	train-rmse:0.242232	valid-rmse:0.239515
# [73]	train-rmse:0.239841	valid-rmse:0.237127
# [74]	train-rmse:0.237474	valid-rmse:0.234763
# [75]	train-rmse:0.235131	valid-rmse:0.232423
# [76]	train-rmse:0.232812	valid-rmse:0.230107
# [77]	train-rmse:0.230516	valid-rmse:0.227814
# [78]	train-rmse:0.228243	valid-rmse:0.225544
# [79]	train-rmse:0.225994	valid-rmse:0.223298
# [80]	train-rmse:0.223767	valid-rmse:0.221074
# [81]	train-rmse:0.221563	valid-rmse:0.218873
# [82]	train-rmse:0.219381	valid-rmse:0.216694
# [83]	train-rmse:0.217221	valid-rmse:0.214537
# [84]	train-rmse:0.215083	valid-rmse:0.212402
# [85]	train-rmse:0.212967	valid-rmse:0.210289
# [86]	train-rmse:0.210872	valid-rmse:0.208198
# [87]	train-rmse:0.208798	valid-rmse:0.206127
# [88]	train-rmse:0.206746	valid-rmse:0.204078
# [89]	train-rmse:0.204714	valid-rmse:0.20205
# [90]	train-rmse:0.202703	valid-rmse:0.200042
# [91]	train-rmse:0.200712	valid-rmse:0.198055
# [92]	train-rmse:0.198742	valid-rmse:0.196088
# [93]	train-rmse:0.196791	valid-rmse:0.194141
# [94]	train-rmse:0.194861	valid-rmse:0.192214
# [95]	train-rmse:0.19295	valid-rmse:0.190306
# [96]	train-rmse:0.191058	valid-rmse:0.188418
# [97]	train-rmse:0.189186	valid-rmse:0.18655
# [98]	train-rmse:0.187332	valid-rmse:0.1847
# [99]	train-rmse:0.185498	valid-rmse:0.18287
# [100]	train-rmse:0.183682	valid-rmse:0.181058
# [101]	train-rmse:0.181885	valid-rmse:0.179264
# [102]	train-rmse:0.180106	valid-rmse:0.177494
# [103]	train-rmse:0.178343	valid-rmse:0.175747
# [104]	train-rmse:0.1766	valid-rmse:0.174008
# [105]	train-rmse:0.174872	valid-rmse:0.172297
# [106]	train-rmse:0.173162	valid-rmse:0.170603
# [107]	train-rmse:0.171469	valid-rmse:0.168922
# [108]	train-rmse:0.169796	valid-rmse:0.167254
# [109]	train-rmse:0.168137	valid-rmse:0.165612
# [110]	train-rmse:0.166495	valid-rmse:0.163987
# [111]	train-rmse:0.164873	valid-rmse:0.162369
# [112]	train-rmse:0.163265	valid-rmse:0.160777
# [113]	train-rmse:0.161672	valid-rmse:0.159202
# [114]	train-rmse:0.160097	valid-rmse:0.157638
# [115]	train-rmse:0.158539	valid-rmse:0.15609
# [116]	train-rmse:0.156994	valid-rmse:0.154567
# [117]	train-rmse:0.155464	valid-rmse:0.153056
# [118]	train-rmse:0.15395	valid-rmse:0.151566
# [119]	train-rmse:0.152455	valid-rmse:0.150077
# [120]	train-rmse:0.150971	valid-rmse:0.148616
# [121]	train-rmse:0.149502	valid-rmse:0.147166
# [122]	train-rmse:0.148048	valid-rmse:0.145732
# [123]	train-rmse:0.146614	valid-rmse:0.144303
# [124]	train-rmse:0.145188	valid-rmse:0.142898
# [125]	train-rmse:0.143779	valid-rmse:0.141512
# [126]	train-rmse:0.142383	valid-rmse:0.140136
# [127]	train-rmse:0.141002	valid-rmse:0.138775
# [128]	train-rmse:0.139634	valid-rmse:0.13744
# [129]	train-rmse:0.13828	valid-rmse:0.136122
# [130]	train-rmse:0.136939	valid-rmse:0.134813
# [131]	train-rmse:0.135613	valid-rmse:0.133511
# [132]	train-rmse:0.134299	valid-rmse:0.132239
# [133]	train-rmse:0.133001	valid-rmse:0.13096
# [134]	train-rmse:0.131714	valid-rmse:0.129715
# [135]	train-rmse:0.13044	valid-rmse:0.128475
# [136]	train-rmse:0.129179	valid-rmse:0.127257
# [137]	train-rmse:0.127931	valid-rmse:0.126052
# [138]	train-rmse:0.126698	valid-rmse:0.124843
# [139]	train-rmse:0.125475	valid-rmse:0.123663
# [140]	train-rmse:0.124266	valid-rmse:0.122487
# [141]	train-rmse:0.123073	valid-rmse:0.121309
# [142]	train-rmse:0.121888	valid-rmse:0.120161
# [143]	train-rmse:0.120716	valid-rmse:0.119025
# [144]	train-rmse:0.119554	valid-rmse:0.117908
# [145]	train-rmse:0.118404	valid-rmse:0.116803
# [146]	train-rmse:0.117269	valid-rmse:0.11569
# [147]	train-rmse:0.116142	valid-rmse:0.114608
# [148]	train-rmse:0.115027	valid-rmse:0.113538
# [149]	train-rmse:0.113927	valid-rmse:0.112479
# [150]	train-rmse:0.112835	valid-rmse:0.111431
# [151]	train-rmse:0.111756	valid-rmse:0.110374
# [152]	train-rmse:0.110686	valid-rmse:0.109349
# [153]	train-rmse:0.109627	valid-rmse:0.108318
# [154]	train-rmse:0.108579	valid-rmse:0.107316
# [155]	train-rmse:0.107541	valid-rmse:0.106307
# [156]	train-rmse:0.106515	valid-rmse:0.105326
# [157]	train-rmse:0.105498	valid-rmse:0.104342
# [158]	train-rmse:0.104495	valid-rmse:0.103383
# [159]	train-rmse:0.103499	valid-rmse:0.10244
# [160]	train-rmse:0.102513	valid-rmse:0.10151
# [161]	train-rmse:0.101537	valid-rmse:0.100568
# [162]	train-rmse:0.100571	valid-rmse:0.099658
# [163]	train-rmse:0.099616	valid-rmse:0.098756
# [164]	train-rmse:0.098671	valid-rmse:0.097859
# [165]	train-rmse:0.097735	valid-rmse:0.096978
# [166]	train-rmse:0.096807	valid-rmse:0.096094
# [167]	train-rmse:0.095889	valid-rmse:0.095238
# [168]	train-rmse:0.094981	valid-rmse:0.094374
# [169]	train-rmse:0.094081	valid-rmse:0.093517
# [170]	train-rmse:0.093191	valid-rmse:0.092672
# [171]	train-rmse:0.092313	valid-rmse:0.091842
# [172]	train-rmse:0.091441	valid-rmse:0.091017
# [173]	train-rmse:0.090578	valid-rmse:0.090213
# [174]	train-rmse:0.089724	valid-rmse:0.0894
# [175]	train-rmse:0.088881	valid-rmse:0.088603
# [176]	train-rmse:0.088045	valid-rmse:0.087814
# [177]	train-rmse:0.087216	valid-rmse:0.087035
# [178]	train-rmse:0.086397	valid-rmse:0.086265
# [179]	train-rmse:0.085586	valid-rmse:0.085515
# [180]	train-rmse:0.084781	valid-rmse:0.084759
# [181]	train-rmse:0.083987	valid-rmse:0.084025
# [182]	train-rmse:0.083201	valid-rmse:0.083283
# [183]	train-rmse:0.082421	valid-rmse:0.082552
# [184]	train-rmse:0.081651	valid-rmse:0.081846
# [185]	train-rmse:0.080887	valid-rmse:0.081132
# [186]	train-rmse:0.080133	valid-rmse:0.080441
# [187]	train-rmse:0.079386	valid-rmse:0.079733
# [188]	train-rmse:0.078648	valid-rmse:0.079057
# [189]	train-rmse:0.077917	valid-rmse:0.078379
# [190]	train-rmse:0.077192	valid-rmse:0.07772
# [191]	train-rmse:0.076474	valid-rmse:0.07706
# [192]	train-rmse:0.075764	valid-rmse:0.076392
# [193]	train-rmse:0.075063	valid-rmse:0.07575
# [194]	train-rmse:0.07437	valid-rmse:0.075101
# [195]	train-rmse:0.073682	valid-rmse:0.07447
# [196]	train-rmse:0.072999	valid-rmse:0.073848
# [197]	train-rmse:0.072325	valid-rmse:0.073234
# [198]	train-rmse:0.071655	valid-rmse:0.072646
# [199]	train-rmse:0.070996	valid-rmse:0.072038
# [200]	train-rmse:0.070343	valid-rmse:0.071444
# [201]	train-rmse:0.069694	valid-rmse:0.070871
# [202]	train-rmse:0.069053	valid-rmse:0.070283
# [203]	train-rmse:0.06842	valid-rmse:0.069704
# [204]	train-rmse:0.06779	valid-rmse:0.069146
# [205]	train-rmse:0.067172	valid-rmse:0.068587
# [206]	train-rmse:0.066557	valid-rmse:0.068029
# [207]	train-rmse:0.065946	valid-rmse:0.067477
# [208]	train-rmse:0.065346	valid-rmse:0.066938
# [209]	train-rmse:0.064753	valid-rmse:0.066408
# [210]	train-rmse:0.06416	valid-rmse:0.065882
# [211]	train-rmse:0.063573	valid-rmse:0.065368
# [212]	train-rmse:0.062997	valid-rmse:0.064854
# [213]	train-rmse:0.062424	valid-rmse:0.064352
# [214]	train-rmse:0.061855	valid-rmse:0.063851
# [215]	train-rmse:0.061298	valid-rmse:0.063355
# [216]	train-rmse:0.060742	valid-rmse:0.062872
# [217]	train-rmse:0.060191	valid-rmse:0.06239
# [218]	train-rmse:0.05965	valid-rmse:0.061914
# [219]	train-rmse:0.059111	valid-rmse:0.061449
# [220]	train-rmse:0.058577	valid-rmse:0.060978
# [221]	train-rmse:0.058051	valid-rmse:0.060512
# [222]	train-rmse:0.057529	valid-rmse:0.060064
# [223]	train-rmse:0.057015	valid-rmse:0.059611
# [224]	train-rmse:0.056508	valid-rmse:0.059167
# [225]	train-rmse:0.056001	valid-rmse:0.058732
# [226]	train-rmse:0.055502	valid-rmse:0.058297
# [227]	train-rmse:0.055002	valid-rmse:0.057878
# [228]	train-rmse:0.054514	valid-rmse:0.057449
# [229]	train-rmse:0.054027	valid-rmse:0.057039
# [230]	train-rmse:0.053549	valid-rmse:0.056621
# [231]	train-rmse:0.05307	valid-rmse:0.056212
# [232]	train-rmse:0.052598	valid-rmse:0.055784
# [233]	train-rmse:0.052133	valid-rmse:0.055388
# [234]	train-rmse:0.05167	valid-rmse:0.055002
# [235]	train-rmse:0.051213	valid-rmse:0.054591
# [236]	train-rmse:0.050757	valid-rmse:0.054232
# [237]	train-rmse:0.050309	valid-rmse:0.053833
# [238]	train-rmse:0.049862	valid-rmse:0.053463
# [239]	train-rmse:0.049423	valid-rmse:0.053104
# [240]	train-rmse:0.048986	valid-rmse:0.052765
# [241]	train-rmse:0.048556	valid-rmse:0.052409
# [242]	train-rmse:0.048131	valid-rmse:0.052031
# [243]	train-rmse:0.047707	valid-rmse:0.051702
# [244]	train-rmse:0.04729	valid-rmse:0.051369
# [245]	train-rmse:0.046875	valid-rmse:0.051034
# [246]	train-rmse:0.046468	valid-rmse:0.050701
# [247]	train-rmse:0.046062	valid-rmse:0.05035
# [248]	train-rmse:0.045663	valid-rmse:0.050033
# [249]	train-rmse:0.045264	valid-rmse:0.049719
# [250]	train-rmse:0.044871	valid-rmse:0.049383
# [251]	train-rmse:0.044485	valid-rmse:0.049062
# [252]	train-rmse:0.0441	valid-rmse:0.048734
# [253]	train-rmse:0.043725	valid-rmse:0.048442
# [254]	train-rmse:0.043351	valid-rmse:0.048134
# [255]	train-rmse:0.042979	valid-rmse:0.047833
# [256]	train-rmse:0.042607	valid-rmse:0.047533
# [257]	train-rmse:0.042244	valid-rmse:0.047253
# [258]	train-rmse:0.04188	valid-rmse:0.046981
# [259]	train-rmse:0.041524	valid-rmse:0.046701
# [260]	train-rmse:0.04117	valid-rmse:0.046408
# [261]	train-rmse:0.040817	valid-rmse:0.046148
# [262]	train-rmse:0.040472	valid-rmse:0.045878
# [263]	train-rmse:0.040126	valid-rmse:0.045603
# [264]	train-rmse:0.039792	valid-rmse:0.045339
# [265]	train-rmse:0.039458	valid-rmse:0.045079
# [266]	train-rmse:0.039127	valid-rmse:0.044826
# [267]	train-rmse:0.038796	valid-rmse:0.044584
# [268]	train-rmse:0.038468	valid-rmse:0.044344
# [269]	train-rmse:0.038142	valid-rmse:0.044089
# [270]	train-rmse:0.037825	valid-rmse:0.043861
# [271]	train-rmse:0.037513	valid-rmse:0.043623
# [272]	train-rmse:0.037204	valid-rmse:0.043389
# [273]	train-rmse:0.036899	valid-rmse:0.043163
# [274]	train-rmse:0.036592	valid-rmse:0.042949
# [275]	train-rmse:0.036288	valid-rmse:0.042732
# [276]	train-rmse:0.035987	valid-rmse:0.042503
# [277]	train-rmse:0.035694	valid-rmse:0.042282
# [278]	train-rmse:0.035406	valid-rmse:0.042079
# [279]	train-rmse:0.035113	valid-rmse:0.041874
# [280]	train-rmse:0.03483	valid-rmse:0.041669
# [281]	train-rmse:0.034543	valid-rmse:0.041474
# [282]	train-rmse:0.034261	valid-rmse:0.041277
# [283]	train-rmse:0.033986	valid-rmse:0.04108
# [284]	train-rmse:0.033709	valid-rmse:0.040889
# [285]	train-rmse:0.03344	valid-rmse:0.040708
# [286]	train-rmse:0.033167	valid-rmse:0.040527
# [287]	train-rmse:0.032902	valid-rmse:0.040354
# [288]	train-rmse:0.032641	valid-rmse:0.040171
# [289]	train-rmse:0.032383	valid-rmse:0.040002
# [290]	train-rmse:0.032127	valid-rmse:0.039825
# [291]	train-rmse:0.031873	valid-rmse:0.039655
# [292]	train-rmse:0.031619	valid-rmse:0.039489
# [293]	train-rmse:0.031368	valid-rmse:0.039323
# [294]	train-rmse:0.031118	valid-rmse:0.039163
# [295]	train-rmse:0.030874	valid-rmse:0.038996
# [296]	train-rmse:0.030635	valid-rmse:0.038837
# [297]	train-rmse:0.030395	valid-rmse:0.038688
# [298]	train-rmse:0.03016	valid-rmse:0.038534
# [299]	train-rmse:0.029924	valid-rmse:0.038385
# [300]	train-rmse:0.029698	valid-rmse:0.038233
# [301]	train-rmse:0.02947	valid-rmse:0.038072
# [302]	train-rmse:0.02924	valid-rmse:0.037921
# [303]	train-rmse:0.029014	valid-rmse:0.037783
# [304]	train-rmse:0.028789	valid-rmse:0.037637
# [305]	train-rmse:0.028575	valid-rmse:0.037499
# [306]	train-rmse:0.028363	valid-rmse:0.037363
# [307]	train-rmse:0.028145	valid-rmse:0.037222
# [308]	train-rmse:0.027931	valid-rmse:0.037094
# [309]	train-rmse:0.027726	valid-rmse:0.036965
# [310]	train-rmse:0.027515	valid-rmse:0.036833
# [311]	train-rmse:0.02731	valid-rmse:0.036723
# [312]	train-rmse:0.027112	valid-rmse:0.036601
# [313]	train-rmse:0.026909	valid-rmse:0.036466
# [314]	train-rmse:0.026712	valid-rmse:0.036351
# [315]	train-rmse:0.026512	valid-rmse:0.036229
# [316]	train-rmse:0.026322	valid-rmse:0.036115
# [317]	train-rmse:0.026134	valid-rmse:0.036006
# [318]	train-rmse:0.025949	valid-rmse:0.035895
# [319]	train-rmse:0.025757	valid-rmse:0.035776
# [320]	train-rmse:0.025577	valid-rmse:0.03567
# [321]	train-rmse:0.02539	valid-rmse:0.035564
# [322]	train-rmse:0.025202	valid-rmse:0.035464
# [323]	train-rmse:0.025027	valid-rmse:0.035364
# [324]	train-rmse:0.02485	valid-rmse:0.035274
# [325]	train-rmse:0.024667	valid-rmse:0.03518
# [326]	train-rmse:0.024499	valid-rmse:0.035078
# [327]	train-rmse:0.024329	valid-rmse:0.034978
# [328]	train-rmse:0.024156	valid-rmse:0.034879
# [329]	train-rmse:0.023995	valid-rmse:0.034773
# [330]	train-rmse:0.023834	valid-rmse:0.034676
# [331]	train-rmse:0.023663	valid-rmse:0.034585
# [332]	train-rmse:0.023497	valid-rmse:0.034491
# [333]	train-rmse:0.023342	valid-rmse:0.034396
# [334]	train-rmse:0.023185	valid-rmse:0.034311
# [335]	train-rmse:0.023021	valid-rmse:0.034229
# [336]	train-rmse:0.022864	valid-rmse:0.034149
# [337]	train-rmse:0.022717	valid-rmse:0.034057
# [338]	train-rmse:0.022561	valid-rmse:0.033975
# [339]	train-rmse:0.022417	valid-rmse:0.033891
# [340]	train-rmse:0.022266	valid-rmse:0.033817
# [341]	train-rmse:0.022123	valid-rmse:0.033734
# [342]	train-rmse:0.021978	valid-rmse:0.033656
# [343]	train-rmse:0.02183	valid-rmse:0.03358
# [344]	train-rmse:0.021694	valid-rmse:0.033496
# [345]	train-rmse:0.021546	valid-rmse:0.03343
# [346]	train-rmse:0.021407	valid-rmse:0.033357
# [347]	train-rmse:0.021268	valid-rmse:0.033302
# [348]	train-rmse:0.021138	valid-rmse:0.033228
# [349]	train-rmse:0.020996	valid-rmse:0.03317
# [350]	train-rmse:0.020869	valid-rmse:0.033098
# [351]	train-rmse:0.020732	valid-rmse:0.033035
# [352]	train-rmse:0.020598	valid-rmse:0.032973
# [353]	train-rmse:0.02047	valid-rmse:0.032909
# [354]	train-rmse:0.020349	valid-rmse:0.032845
# [355]	train-rmse:0.020219	valid-rmse:0.032788
# [356]	train-rmse:0.020101	valid-rmse:0.032719
# [357]	train-rmse:0.019977	valid-rmse:0.032661
# [358]	train-rmse:0.019852	valid-rmse:0.032597
# [359]	train-rmse:0.019735	valid-rmse:0.032537
# [360]	train-rmse:0.019616	valid-rmse:0.032481
# [361]	train-rmse:0.019498	valid-rmse:0.032429
# [362]	train-rmse:0.019375	valid-rmse:0.032383
# [363]	train-rmse:0.019258	valid-rmse:0.032331
# [364]	train-rmse:0.019141	valid-rmse:0.032265
# [365]	train-rmse:0.019022	valid-rmse:0.032217
# [366]	train-rmse:0.018909	valid-rmse:0.032151
# [367]	train-rmse:0.018798	valid-rmse:0.032103
# [368]	train-rmse:0.01869	valid-rmse:0.03205
# [369]	train-rmse:0.018578	valid-rmse:0.03201
# [370]	train-rmse:0.018469	valid-rmse:0.031949
# [371]	train-rmse:0.018362	valid-rmse:0.031891
# [372]	train-rmse:0.018258	valid-rmse:0.031847
# [373]	train-rmse:0.01815	valid-rmse:0.031811
# [374]	train-rmse:0.018047	valid-rmse:0.031755
# [375]	train-rmse:0.017939	valid-rmse:0.031709
# [376]	train-rmse:0.017845	valid-rmse:0.031665
# [377]	train-rmse:0.017747	valid-rmse:0.031625
# [378]	train-rmse:0.017645	valid-rmse:0.03158
# ...
# [53]	train-rmse:0.291991	valid-rmse:0.29472
# [54]	train-rmse:0.289097	valid-rmse:0.291836
# [55]	train-rmse:0.286231	valid-rmse:0.288982
# [56]	train-rmse:0.283394	valid-rmse:0.286156
# [57]	train-rmse:0.280586	valid-rmse:0.283359
# [58]	train-rmse:0.277806	valid-rmse:0.28059
# [59]	train-rmse:0.275054	valid-rmse:0.27785
# [60]	train-rmse:0.27233	valid-rmse:0.275138
# [61]	train-rmse:0.269634	valid-rmse:0.272453
# [62]	train-rmse:0.266964	valid-rmse:0.269795
# [63]	train-rmse:0.264322	valid-rmse:0.267164
# [64]	train-rmse:0.261706	valid-rmse:0.264561
# [65]	train-rmse:0.259116	valid-rmse:0.261983
# [66]	train-rmse:0.256553	valid-rmse:0.259432
# [67]	train-rmse:0.254016	valid-rmse:0.256907
# [68]	train-rmse:0.251504	valid-rmse:0.254408
# [69]	train-rmse:0.249018	valid-rmse:0.251934
# [70]	train-rmse:0.246556	valid-rmse:0.249486
# [71]	train-rmse:0.24412	valid-rmse:0.247062
# [72]	train-rmse:0.241708	valid-rmse:0.244663
# [73]	train-rmse:0.239321	valid-rmse:0.242289
# [74]	train-rmse:0.236958	valid-rmse:0.239939
# [75]	train-rmse:0.234619	valid-rmse:0.237613
# [76]	train-rmse:0.232303	valid-rmse:0.235311
# [77]	train-rmse:0.230011	valid-rmse:0.233032
# [78]	train-rmse:0.227742	valid-rmse:0.230777
# [79]	train-rmse:0.225496	valid-rmse:0.228544
# [80]	train-rmse:0.223273	valid-rmse:0.226335
# [81]	train-rmse:0.221072	valid-rmse:0.224148
# [82]	train-rmse:0.218893	valid-rmse:0.221984
# [83]	train-rmse:0.216737	valid-rmse:0.219842
# [84]	train-rmse:0.214603	valid-rmse:0.217722
# [85]	train-rmse:0.21249	valid-rmse:0.215624
# [86]	train-rmse:0.210398	valid-rmse:0.213547
# [87]	train-rmse:0.208328	valid-rmse:0.211492
# [88]	train-rmse:0.206279	valid-rmse:0.209458
# [89]	train-rmse:0.204251	valid-rmse:0.207444
# [90]	train-rmse:0.202243	valid-rmse:0.205452
# [91]	train-rmse:0.200256	valid-rmse:0.20348
# [92]	train-rmse:0.198289	valid-rmse:0.201528
# [93]	train-rmse:0.196341	valid-rmse:0.199597
# [94]	train-rmse:0.194414	valid-rmse:0.197685
# [95]	train-rmse:0.192506	valid-rmse:0.195794
# [96]	train-rmse:0.190618	valid-rmse:0.193922
# [97]	train-rmse:0.188749	valid-rmse:0.192069
# [98]	train-rmse:0.186899	valid-rmse:0.190236
# [99]	train-rmse:0.185068	valid-rmse:0.188421
# [100]	train-rmse:0.183255	valid-rmse:0.186625
# [101]	train-rmse:0.181461	valid-rmse:0.184848
# [102]	train-rmse:0.179685	valid-rmse:0.18309
# [103]	train-rmse:0.177927	valid-rmse:0.181349
# [104]	train-rmse:0.176187	valid-rmse:0.179627
# [105]	train-rmse:0.174465	valid-rmse:0.177923
# [106]	train-rmse:0.172761	valid-rmse:0.176236
# [107]	train-rmse:0.171074	valid-rmse:0.174567
# [108]	train-rmse:0.169404	valid-rmse:0.172915
# [109]	train-rmse:0.167751	valid-rmse:0.171281
# [110]	train-rmse:0.166115	valid-rmse:0.169663
# [111]	train-rmse:0.164496	valid-rmse:0.168063
# [112]	train-rmse:0.162894	valid-rmse:0.166479
# [113]	train-rmse:0.161308	valid-rmse:0.164912
# [114]	train-rmse:0.159738	valid-rmse:0.163361
# [115]	train-rmse:0.158184	valid-rmse:0.161827
# [116]	train-rmse:0.156646	valid-rmse:0.160308
# [117]	train-rmse:0.155124	valid-rmse:0.158806
# [118]	train-rmse:0.153618	valid-rmse:0.15732
# [119]	train-rmse:0.152127	valid-rmse:0.155848
# [120]	train-rmse:0.150651	valid-rmse:0.154393
# [121]	train-rmse:0.149191	valid-rmse:0.152953
# [122]	train-rmse:0.147746	valid-rmse:0.151528
# [123]	train-rmse:0.146315	valid-rmse:0.150118
# [124]	train-rmse:0.144899	valid-rmse:0.148723
# [125]	train-rmse:0.143498	valid-rmse:0.147343
# [126]	train-rmse:0.142111	valid-rmse:0.145977
# [127]	train-rmse:0.140739	valid-rmse:0.144626
# [128]	train-rmse:0.139381	valid-rmse:0.143291
# [129]	train-rmse:0.138037	valid-rmse:0.141968
# [130]	train-rmse:0.136706	valid-rmse:0.140661
# [131]	train-rmse:0.13539	valid-rmse:0.139367
# [132]	train-rmse:0.134086	valid-rmse:0.138087
# [133]	train-rmse:0.132797	valid-rmse:0.13682
# [134]	train-rmse:0.13152	valid-rmse:0.13557
# [135]	train-rmse:0.130255	valid-rmse:0.134331
# [136]	train-rmse:0.129004	valid-rmse:0.133107
# [137]	train-rmse:0.127766	valid-rmse:0.131896
# [138]	train-rmse:0.12654	valid-rmse:0.130697
# [139]	train-rmse:0.125328	valid-rmse:0.129514
# [140]	train-rmse:0.124127	valid-rmse:0.128341
# [141]	train-rmse:0.12294	valid-rmse:0.127183
# [142]	train-rmse:0.121764	valid-rmse:0.126038
# [143]	train-rmse:0.120601	valid-rmse:0.124902
# [144]	train-rmse:0.119449	valid-rmse:0.123781
# [145]	train-rmse:0.118308	valid-rmse:0.122669
# [146]	train-rmse:0.117179	valid-rmse:0.121572
# [147]	train-rmse:0.116059	valid-rmse:0.120492
# [148]	train-rmse:0.114953	valid-rmse:0.119419
# [149]	train-rmse:0.11386	valid-rmse:0.118356
# [150]	train-rmse:0.112774	valid-rmse:0.117313
# [151]	train-rmse:0.111703	valid-rmse:0.116272
# [152]	train-rmse:0.11064	valid-rmse:0.115252
# [153]	train-rmse:0.109591	valid-rmse:0.114235
# [154]	train-rmse:0.108553	valid-rmse:0.113228
# [155]	train-rmse:0.107524	valid-rmse:0.112239
# [156]	train-rmse:0.106505	valid-rmse:0.111251
# [157]	train-rmse:0.105496	valid-rmse:0.110285
# [158]	train-rmse:0.104499	valid-rmse:0.109329
# [159]	train-rmse:0.103511	valid-rmse:0.108375
# [160]	train-rmse:0.102533	valid-rmse:0.10743
# [161]	train-rmse:0.101568	valid-rmse:0.106501
# [162]	train-rmse:0.100611	valid-rmse:0.105578
# [163]	train-rmse:0.099666	valid-rmse:0.104666
# [164]	train-rmse:0.098729	valid-rmse:0.103762
# [165]	train-rmse:0.097801	valid-rmse:0.102878
# [166]	train-rmse:0.096886	valid-rmse:0.101996
# [167]	train-rmse:0.095977	valid-rmse:0.101125
# [168]	train-rmse:0.095079	valid-rmse:0.100268
# [169]	train-rmse:0.094191	valid-rmse:0.09942
# [170]	train-rmse:0.09331	valid-rmse:0.098578
# [171]	train-rmse:0.09244	valid-rmse:0.097749
# [172]	train-rmse:0.091579	valid-rmse:0.096923
# [173]	train-rmse:0.090725	valid-rmse:0.096119
# [174]	train-rmse:0.089882	valid-rmse:0.095319
# [175]	train-rmse:0.089045	valid-rmse:0.094533
# [176]	train-rmse:0.088221	valid-rmse:0.093747
# [177]	train-rmse:0.087404	valid-rmse:0.092976
# [178]	train-rmse:0.086595	valid-rmse:0.092208
# [179]	train-rmse:0.085796	valid-rmse:0.091453
# [180]	train-rmse:0.085005	valid-rmse:0.090703
# [181]	train-rmse:0.084221	valid-rmse:0.089957
# [182]	train-rmse:0.083444	valid-rmse:0.089233
# [183]	train-rmse:0.082678	valid-rmse:0.088509
# [184]	train-rmse:0.08192	valid-rmse:0.087798
# [185]	train-rmse:0.081169	valid-rmse:0.087086
# [186]	train-rmse:0.080424	valid-rmse:0.08639
# [187]	train-rmse:0.07969	valid-rmse:0.0857
# [188]	train-rmse:0.078964	valid-rmse:0.085012
# [189]	train-rmse:0.078245	valid-rmse:0.084331
# [190]	train-rmse:0.077532	valid-rmse:0.083659
# [191]	train-rmse:0.076829	valid-rmse:0.083001
# [192]	train-rmse:0.076133	valid-rmse:0.082357
# [193]	train-rmse:0.075444	valid-rmse:0.081707
# [194]	train-rmse:0.074759	valid-rmse:0.081074
# [195]	train-rmse:0.074086	valid-rmse:0.080442
# [196]	train-rmse:0.073417	valid-rmse:0.079827
# [197]	train-rmse:0.072757	valid-rmse:0.079207
# [198]	train-rmse:0.072104	valid-rmse:0.078598
# [199]	train-rmse:0.071459	valid-rmse:0.077999
# [200]	train-rmse:0.070819	valid-rmse:0.077407
# [201]	train-rmse:0.07019	valid-rmse:0.076821
# [202]	train-rmse:0.069562	valid-rmse:0.076247
# [203]	train-rmse:0.068943	valid-rmse:0.075676
# [204]	train-rmse:0.068332	valid-rmse:0.075113
# [205]	train-rmse:0.067724	valid-rmse:0.07456
# [206]	train-rmse:0.067125	valid-rmse:0.074005
# [207]	train-rmse:0.066531	valid-rmse:0.07347
# [208]	train-rmse:0.065944	valid-rmse:0.072935
# [209]	train-rmse:0.065362	valid-rmse:0.072412
# [210]	train-rmse:0.06479	valid-rmse:0.071886
# [211]	train-rmse:0.06422	valid-rmse:0.071376
# [212]	train-rmse:0.063658	valid-rmse:0.070867
# [213]	train-rmse:0.063102	valid-rmse:0.070365
# [214]	train-rmse:0.062553	valid-rmse:0.069869
# [215]	train-rmse:0.062009	valid-rmse:0.069385
# [216]	train-rmse:0.061473	valid-rmse:0.0689
# [217]	train-rmse:0.060942	valid-rmse:0.068422
# [218]	train-rmse:0.060414	valid-rmse:0.067951
# [219]	train-rmse:0.059889	valid-rmse:0.06749
# [220]	train-rmse:0.059375	valid-rmse:0.06703
# [221]	train-rmse:0.058869	valid-rmse:0.066575
# [222]	train-rmse:0.058364	valid-rmse:0.066132
# [223]	train-rmse:0.057864	valid-rmse:0.065693
# [224]	train-rmse:0.057366	valid-rmse:0.065252
# [225]	train-rmse:0.05688	valid-rmse:0.064821
# [226]	train-rmse:0.056397	valid-rmse:0.064402
# [227]	train-rmse:0.055915	valid-rmse:0.06398
# [228]	train-rmse:0.055444	valid-rmse:0.063562
# [229]	train-rmse:0.054979	valid-rmse:0.063152
# [230]	train-rmse:0.054518	valid-rmse:0.062753
# [231]	train-rmse:0.054061	valid-rmse:0.062356
# [232]	train-rmse:0.053612	valid-rmse:0.061963
# [233]	train-rmse:0.053167	valid-rmse:0.061576
# [234]	train-rmse:0.052725	valid-rmse:0.061198
# [235]	train-rmse:0.05229	valid-rmse:0.060819
# [236]	train-rmse:0.051856	valid-rmse:0.060446
# [237]	train-rmse:0.051431	valid-rmse:0.06008
# [238]	train-rmse:0.051009	valid-rmse:0.059717
# [239]	train-rmse:0.050595	valid-rmse:0.059361
# [240]	train-rmse:0.050183	valid-rmse:0.059011
# [241]	train-rmse:0.049773	valid-rmse:0.058665
# [242]	train-rmse:0.049368	valid-rmse:0.058312
# [243]	train-rmse:0.048969	valid-rmse:0.057972
# [244]	train-rmse:0.048575	valid-rmse:0.057642
# [245]	train-rmse:0.048184	valid-rmse:0.057304
# [246]	train-rmse:0.047796	valid-rmse:0.05698
# [247]	train-rmse:0.047417	valid-rmse:0.056661
# [248]	train-rmse:0.047039	valid-rmse:0.056343
# [249]	train-rmse:0.046667	valid-rmse:0.056035
# [250]	train-rmse:0.046301	valid-rmse:0.055729
# [251]	train-rmse:0.045937	valid-rmse:0.055418
# [252]	train-rmse:0.045574	valid-rmse:0.055121
# [253]	train-rmse:0.045218	valid-rmse:0.054833
# [254]	train-rmse:0.044866	valid-rmse:0.054541
# [255]	train-rmse:0.044521	valid-rmse:0.054256
# [256]	train-rmse:0.044177	valid-rmse:0.053973
# [257]	train-rmse:0.043838	valid-rmse:0.053693
# [258]	train-rmse:0.0435	valid-rmse:0.05342
# [259]	train-rmse:0.043166	valid-rmse:0.053152
# [260]	train-rmse:0.042836	valid-rmse:0.052891
# [261]	train-rmse:0.042514	valid-rmse:0.052622
# [262]	train-rmse:0.042192	valid-rmse:0.052362
# [263]	train-rmse:0.041876	valid-rmse:0.052104
# [264]	train-rmse:0.041562	valid-rmse:0.051863
# [265]	train-rmse:0.041248	valid-rmse:0.051616
# [266]	train-rmse:0.040941	valid-rmse:0.051371
# [267]	train-rmse:0.040632	valid-rmse:0.051133
# [268]	train-rmse:0.040332	valid-rmse:0.05089
# [269]	train-rmse:0.040037	valid-rmse:0.050655
# [270]	train-rmse:0.039744	valid-rmse:0.050428
# [271]	train-rmse:0.039459	valid-rmse:0.050206
# [272]	train-rmse:0.039167	valid-rmse:0.049983
# [273]	train-rmse:0.038882	valid-rmse:0.049762
# [274]	train-rmse:0.038607	valid-rmse:0.049547
# [275]	train-rmse:0.038333	valid-rmse:0.049334
# [276]	train-rmse:0.038055	valid-rmse:0.049124
# [277]	train-rmse:0.037784	valid-rmse:0.04892
# [278]	train-rmse:0.037518	valid-rmse:0.048715
# [279]	train-rmse:0.037256	valid-rmse:0.048509
# [280]	train-rmse:0.036989	valid-rmse:0.048308
# [281]	train-rmse:0.036737	valid-rmse:0.048117
# [282]	train-rmse:0.036483	valid-rmse:0.04793
# [283]	train-rmse:0.036231	valid-rmse:0.047745
# [284]	train-rmse:0.035977	valid-rmse:0.047559
# [285]	train-rmse:0.035737	valid-rmse:0.04738
# [286]	train-rmse:0.035498	valid-rmse:0.047197
# [287]	train-rmse:0.035258	valid-rmse:0.04702
# [288]	train-rmse:0.035023	valid-rmse:0.046845
# [289]	train-rmse:0.034791	valid-rmse:0.04667
# [290]	train-rmse:0.034558	valid-rmse:0.046504
# [291]	train-rmse:0.034327	valid-rmse:0.046342
# [292]	train-rmse:0.034095	valid-rmse:0.046176
# [293]	train-rmse:0.033869	valid-rmse:0.046022
# [294]	train-rmse:0.033649	valid-rmse:0.045867
# [295]	train-rmse:0.03343	valid-rmse:0.045711
# [296]	train-rmse:0.033209	valid-rmse:0.045555
# [297]	train-rmse:0.033003	valid-rmse:0.045408
# [298]	train-rmse:0.032794	valid-rmse:0.04526
# [299]	train-rmse:0.032584	valid-rmse:0.045118
# [300]	train-rmse:0.032378	valid-rmse:0.044975
# [301]	train-rmse:0.032171	valid-rmse:0.044832
# [302]	train-rmse:0.031968	valid-rmse:0.044695
# [303]	train-rmse:0.031768	valid-rmse:0.044562
# [304]	train-rmse:0.03157	valid-rmse:0.044428
# [305]	train-rmse:0.03138	valid-rmse:0.044292
# [306]	train-rmse:0.031191	valid-rmse:0.044158
# [307]	train-rmse:0.031001	valid-rmse:0.044026
# [308]	train-rmse:0.030812	valid-rmse:0.043905
# [309]	train-rmse:0.030623	valid-rmse:0.043779
# [310]	train-rmse:0.030439	valid-rmse:0.04366
# [311]	train-rmse:0.030257	valid-rmse:0.043546
# [312]	train-rmse:0.030083	valid-rmse:0.043423
# [313]	train-rmse:0.029911	valid-rmse:0.043301
# [314]	train-rmse:0.029735	valid-rmse:0.043187
# [315]	train-rmse:0.029565	valid-rmse:0.043067
# [316]	train-rmse:0.029398	valid-rmse:0.042955
# [317]	train-rmse:0.029227	valid-rmse:0.042849
# [318]	train-rmse:0.029066	valid-rmse:0.042738
# [319]	train-rmse:0.028901	valid-rmse:0.042634
# [320]	train-rmse:0.028743	valid-rmse:0.042526
# [321]	train-rmse:0.02858	valid-rmse:0.042424
# [322]	train-rmse:0.02842	valid-rmse:0.042322
# [323]	train-rmse:0.028267	valid-rmse:0.042219
# [324]	train-rmse:0.028118	valid-rmse:0.042117
# [325]	train-rmse:0.027965	valid-rmse:0.042024
# [326]	train-rmse:0.02782	valid-rmse:0.041925
# [327]	train-rmse:0.027668	valid-rmse:0.041829
# [328]	train-rmse:0.02752	valid-rmse:0.04174
# [329]	train-rmse:0.027371	valid-rmse:0.04165
# [330]	train-rmse:0.027225	valid-rmse:0.041561
# [331]	train-rmse:0.027089	valid-rmse:0.041471
# [332]	train-rmse:0.026954	valid-rmse:0.041384
# [333]	train-rmse:0.026817	valid-rmse:0.041304
# [334]	train-rmse:0.026684	valid-rmse:0.041212
# [335]	train-rmse:0.026548	valid-rmse:0.041133
# [336]	train-rmse:0.026411	valid-rmse:0.04105
# [337]	train-rmse:0.026284	valid-rmse:0.040969
# [338]	train-rmse:0.026151	valid-rmse:0.040891
# [339]	train-rmse:0.026029	valid-rmse:0.040812
# [340]	train-rmse:0.025906	valid-rmse:0.040739
# [341]	train-rmse:0.025784	valid-rmse:0.040665
# [342]	train-rmse:0.025659	valid-rmse:0.040591
# [343]	train-rmse:0.025541	valid-rmse:0.040517
# [344]	train-rmse:0.025427	valid-rmse:0.040447
# [345]	train-rmse:0.025314	valid-rmse:0.040387
# [346]	train-rmse:0.0252	valid-rmse:0.040312
# [347]	train-rmse:0.025082	valid-rmse:0.040246
# [348]	train-rmse:0.024971	valid-rmse:0.040177
# [349]	train-rmse:0.024863	valid-rmse:0.040119
# [350]	train-rmse:0.024746	valid-rmse:0.04006
# [351]	train-rmse:0.024643	valid-rmse:0.040007
# [352]	train-rmse:0.024536	valid-rmse:0.039945
# [353]	train-rmse:0.024425	valid-rmse:0.039886
# [354]	train-rmse:0.024324	valid-rmse:0.039831
# [355]	train-rmse:0.024217	valid-rmse:0.039774
# [356]	train-rmse:0.02412	valid-rmse:0.039725
# [357]	train-rmse:0.024021	valid-rmse:0.03967
# [358]	train-rmse:0.023925	valid-rmse:0.039612
# [359]	train-rmse:0.023825	valid-rmse:0.039554
# [360]	train-rmse:0.023731	valid-rmse:0.039508
# [361]	train-rmse:0.023636	valid-rmse:0.039455
# [362]	train-rmse:0.023545	valid-rmse:0.039401
# [363]	train-rmse:0.023449	valid-rmse:0.039351
# [364]	train-rmse:0.023357	valid-rmse:0.039303
# [365]	train-rmse:0.02327	valid-rmse:0.039264
# [366]	train-rmse:0.023183	valid-rmse:0.03922
# [367]	train-rmse:0.02309	valid-rmse:0.039178
# [368]	train-rmse:0.023006	valid-rmse:0.039134
# [369]	train-rmse:0.022922	valid-rmse:0.039088
# [370]	train-rmse:0.022841	valid-rmse:0.039053
# [371]	train-rmse:0.022758	valid-rmse:0.039009
# [372]	train-rmse:0.022674	valid-rmse:0.038965
# [373]	train-rmse:0.022596	valid-rmse:0.038927
# [374]	train-rmse:0.022512	valid-rmse:0.038889
# [375]	train-rmse:0.022433	valid-rmse:0.038848
# [376]	train-rmse:0.022351	valid-rmse:0.038808
# [377]	train-rmse:0.022277	valid-rmse:0.038778
# [378]	train-rmse:0.022202	valid-rmse:0.038743
# [379]	train-rmse:0.022128	valid-rmse:0.038705
# [380]	train-rmse:0.022052	valid-rmse:0.038666
# [381]	train-rmse:0.02198	valid-rmse:0.038631
# [382]	train-rmse:0.021905	valid-rmse:0.038597
# [383]	train-rmse:0.021833	valid-rmse:0.038561
# [384]	train-rmse:0.021766	valid-rmse:0.038536
# [385]	train-rmse:0.021699	valid-rmse:0.038507
# [386]	train-rmse:0.021627	valid-rmse:0.038474
# [387]	train-rmse:0.021556	valid-rmse:0.038443
# [388]	train-rmse:0.02149	valid-rmse:0.038411
# [389]	train-rmse:0.021425	valid-rmse:0.038373
# [390]	train-rmse:0.021362	valid-rmse:0.038353
# [391]	train-rmse:0.021294	valid-rmse:0.038323
# [392]	train-rmse:0.021226	valid-rmse:0.038296
# [393]	train-rmse:0.021167	valid-rmse:0.038276
# [394]	train-rmse:0.021102	valid-rmse:0.038246
# [395]	train-rmse:0.02104	valid-rmse:0.038218
# [396]	train-rmse:0.02098	valid-rmse:0.038184
# [397]	train-rmse:0.020915	valid-rmse:0.038158
# [398]	train-rmse:0.020857	valid-rmse:0.038135
# [399]	train-rmse:0.020794	valid-rmse:0.038109
# [400]	train-rmse:0.020735	valid-rmse:0.038085
# [401]	train-rmse:0.020676	valid-rmse:0.038062
# [402]	train-rmse:0.020621	valid-rmse:0.038036

# %%
from pyecharts import options as opts
from example.commons import Collector
from pyecharts.charts import Line

plot = ret_df[['xgb_regress', 'net_xgb_regress']].cumsum()
v1 = list(plot.index)
v2 = list(plot.xgb_regress)
v3 = list(plot.net_xgb_regress)

line_chart = (
    Line()
    .add_xaxis(v1)
    .add_yaxis("xgb_regress", v2)
    .add_yaxis("net_xgb_regress", v3)
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        datazoom_opts=[opts.DataZoomOpts(pos_bottom="-1%")],
        title_opts=opts.TitleOpts(title='Fixed freq rebalanced: {0}'.format(freq)),
    )
)

line_chart.render_notebook()

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['net_xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['net_xgb_regress']/ np.std(ret_df['net_xgb_regress']))))

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['xgb_regress']/ np.std(ret_df['xgb_regress']))))
