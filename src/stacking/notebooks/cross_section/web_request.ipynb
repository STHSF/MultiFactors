# %%
import requests
import json
import pandas as pd
import numpy as np
from pyecharts import options as opts
from example.commons import Collector
from pyecharts.charts import Line

# %%
# 回测参数
start_date =  '2019-01-01'
end_date = '2019-08-01'
freq = '1b'
# ML模型参数
max_round = 800
gpus = True
r = requests.post('http://10.63.6.110:8987/backtest', data={'start_date': start_date,
                                                            'end_date': end_date,
                                                            'freq': freq,
                                                            'max_round': max_round,
                                                            'GPUs': gpus})

# %%
result = json.loads(r.text)

# %%
ret_df = pd.DataFrame(json.loads(result['ret_df']))

# %%
ret_df[['xgb_regress', 'net_xgb_regress']].cumsum().plot(figsize=(12, 6), 
                                                         title='Fixed freq rebalanced: {0}'.format('1b'))

# %%
from pyecharts import options as opts
from example.commons import Collector
from pyecharts.charts import Line

plot = ret_df[['xgb_regress', 'net_xgb_regress']].cumsum()
v1 = list(plot.index)
v2 = list(plot.xgb_regress)
v3 = list(plot.net_xgb_regress)

line_chart = (
    Line()
    .add_xaxis(v1)
    .add_yaxis("xgb_regress", v2)
    .add_yaxis("net_xgb_regress", v3)
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        datazoom_opts=[opts.DataZoomOpts(pos_bottom="-1%")],
        title_opts=opts.TitleOpts(title='Fixed freq rebalanced: {0}'.format(freq)),
    )
)

line_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="9362a996ae9f493bbaf1e48e21096aaa" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_9362a996ae9f493bbaf1e48e21096aaa = echarts.init(
#             document.getElementById('9362a996ae9f493bbaf1e48e21096aaa'), 'white', {renderer: 'canvas'});
#         var option_9362a996ae9f493bbaf1e48e21096aaa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "xgb_regress",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1546473600000",
#                     0.0
#                 ],
#                 [
#                     "1546560000000",
#                     0.061459727
#                 ],
#                 [
#                     "1546819200000",
#                     0.09677276409999999
#                 ],
#                 [
#                     "1546905600000",
#                     0.13203671909999998
#                 ],
#                 [
#                     "1546992000000",
#                     0.12904075299999998
#                 ],
#                 [
#                     "1547078400000",
#                     0.07470851369999998
#                 ],
#                 [
#                     "1547164800000",
#                     0.06739194359999998
#                 ],
#                 [
#                     "1547424000000",
#                     0.09414658249999998
#                 ],
#                 [
#                     "1547510400000",
#                     0.05842022809999998
#                 ],
#                 [
#                     "1547596800000",
#                     0.05606504449999998
#                 ],
#                 [
#                     "1547683200000",
#                     0.04799661719999998
#                 ],
#                 [
#                     "1547769600000",
#                     0.04518677249999998
#                 ],
#                 [
#                     "1548028800000",
#                     0.030238860899999977
#                 ],
#                 [
#                     "1548115200000",
#                     0.04519819779999998
#                 ],
#                 [
#                     "1548201600000",
#                     0.03558138429999998
#                 ],
#                 [
#                     "1548288000000",
#                     0.027262476599999978
#                 ],
#                 [
#                     "1548374400000",
#                     -0.01932920870000002
#                 ],
#                 [
#                     "1548633600000",
#                     -0.01975625340000002
#                 ],
#                 [
#                     "1548720000000",
#                     -0.01923886200000002
#                 ],
#                 [
#                     "1548806400000",
#                     -0.016519369900000018
#                 ],
#                 [
#                     "1548892800000",
#                     -0.03849250240000002
#                 ],
#                 [
#                     "1548979200000",
#                     -0.03533856140000002
#                 ],
#                 [
#                     "1549843200000",
#                     -0.03187140350000002
#                 ],
#                 [
#                     "1549929600000",
#                     -0.03581817900000002
#                 ],
#                 [
#                     "1550016000000",
#                     -0.03968550320000002
#                 ],
#                 [
#                     "1550102400000",
#                     -0.02062161140000002
#                 ],
#                 [
#                     "1550188800000",
#                     -0.02157882920000002
#                 ],
#                 [
#                     "1550448000000",
#                     -0.02778231990000002
#                 ],
#                 [
#                     "1550534400000",
#                     -0.02846374470000002
#                 ],
#                 [
#                     "1550620800000",
#                     -0.03368716660000002
#                 ],
#                 [
#                     "1550707200000",
#                     -0.014131736900000018
#                 ],
#                 [
#                     "1550793600000",
#                     -0.017512195100000016
#                 ],
#                 [
#                     "1551052800000",
#                     -0.03316527840000001
#                 ],
#                 [
#                     "1551139200000",
#                     -0.030079695100000012
#                 ],
#                 [
#                     "1551225600000",
#                     -0.04740813510000001
#                 ],
#                 [
#                     "1551312000000",
#                     -0.03023015880000001
#                 ],
#                 [
#                     "1551398400000",
#                     -0.03244506840000001
#                 ],
#                 [
#                     "1551657600000",
#                     -0.03053863520000001
#                 ],
#                 [
#                     "1551744000000",
#                     -0.01459173170000001
#                 ],
#                 [
#                     "1551830400000",
#                     0.03818031799999999
#                 ],
#                 [
#                     "1551916800000",
#                     0.0004375186999999933
#                 ],
#                 [
#                     "1552003200000",
#                     -0.05623098470000001
#                 ],
#                 [
#                     "1552262400000",
#                     -0.08325675900000001
#                 ],
#                 [
#                     "1552348800000",
#                     -0.09329160840000002
#                 ],
#                 [
#                     "1552435200000",
#                     -0.12399833840000002
#                 ],
#                 [
#                     "1552521600000",
#                     -0.12814067140000002
#                 ],
#                 [
#                     "1552608000000",
#                     -0.12168646210000002
#                 ],
#                 [
#                     "1552867200000",
#                     -0.11931552780000002
#                 ],
#                 [
#                     "1552953600000",
#                     -0.06521235630000002
#                 ],
#                 [
#                     "1553040000000",
#                     -0.06224028080000003
#                 ],
#                 [
#                     "1553126400000",
#                     -0.08287795620000002
#                 ],
#                 [
#                     "1553212800000",
#                     -0.11645433520000002
#                 ],
#                 [
#                     "1553472000000",
#                     -0.11501341020000003
#                 ],
#                 [
#                     "1553558400000",
#                     -0.10877475560000002
#                 ],
#                 [
#                     "1553644800000",
#                     -0.10838466750000002
#                 ],
#                 [
#                     "1553731200000",
#                     -0.1431516982
#                 ],
#                 [
#                     "1553817600000",
#                     -0.14242329

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['net_xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['net_xgb_regress']/ np.std(ret_df['net_xgb_regress']))))
# Out:
# 年化收益: -1.06
# 夏普比率: -3.71

# %%
plot.head()
# Out:
#                xgb_regress  net_xgb_regress
# 1546473600000     0.000000         0.000000
# 1546560000000     0.061460         0.058635
# 1546819200000     0.096773         0.092626
# 1546905600000     0.132037         0.127415
# 1546992000000     0.129041         0.119232

# %%
plot.tail()
# Out:
#                xgb_regress  net_xgb_regress
# 1564358400000    -0.516351        -1.031268
# 1564444800000    -0.530834        -1.051857
# 1564531200000    -0.525303        -1.047514
# 1564617600000    -0.513187        -1.041343
# 2019-08-02       -0.523383        -1.057619

# %%
import pandas as pd
a = pd.DataFrame({'a':[1,2,3,4,5], 'b':[2,3,4,5,6]})

# %%
a['a'] = a['a'] / a['a'].sum()

# %%
a
# Out:
#           a  b
# 0  0.066667  2
# 1  0.133333  3
# 2  0.200000  4
# 3  0.266667  5
# 4  0.333333  6
