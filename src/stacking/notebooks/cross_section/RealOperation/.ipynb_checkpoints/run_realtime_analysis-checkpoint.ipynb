# %% [markdown]
# # 基础因子实时计算

# %% [markdown]
# zz500模拟盘操作, 每5天更新.

# %%
# %matplotlib inline
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../../')
sys.path.append('../../../../')

import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt

from PyFin.api import *
from alphamind.api import *
from conf.models import *
from conf.config import*
from data.engines.model import Record
from alphamind.execution.naiveexecutor import NaiveExecutor
from stacking import factor_store, feature_list
from optimization.bayes_optimization_xgb import *
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',100)

# %% [markdown]
# ## 因子数据准备

# %%
# 设置train和predict日期
start_date = '2019-11-02'  # trainning起始时间
end_date = '2020-01-13'   # predict时间, 调仓日

# 设置交易日
trade_end_date = '2020-01-14'        # 当前交易日期[predict的下一个交易日作为下单调仓日]

# 设置保存的文件目录
weekly = 's2'  # 测试文件目录
freq = '5b'

# 换手率控制
turn_over_rate = 0.3  # {s1:0.5, s2:0.3, s3:0.6, s4:0.8, s5:0.5}

# 组合优化参数
weight_gap = 0.02

# %%
universe = Universe('zz500')
benchmark_code = 905
ref_dates = makeSchedule(start_date, end_date, freq, 'china.sse')
horizon = map_freq(freq)
industry_name = 'sw'
industry_level = 1

# 根据索引删除某些特殊日期{节假日, 零时停盘日等}
trash_date_list = [datetime(2020, 1, 1, 0, 0)]
a = []
for i in trash_date_list:
    try:
        del(ref_dates[ref_dates.index(i)])
    except:
        continue

# 前一个调仓日
ref_date_pre = ref_dates[-2]
# 当前调仓日
ref_date = ref_dates[-1]
print('前一个调仓日: %s' % ref_date_pre)
print('当前调仓日: %s' % ref_date)

# 获取前一个交易日, 用于获取前一个调仓日的持仓信息
date_range = makeSchedule(ref_date_pre, trade_end_date, '1d', 'china.sse')
# 前一个交易日, 如果遇到上一个调仓日存在空缺如[2020.01.01], 需要特殊指定
# adjusted_date_pre = datetime(2020, 1, 11, 0, 0)
adjusted_date_pre = date_range[1]
# 当前交易日
adjusted_date = date_range[-1]

print('前一个交易日: %s' % adjusted_date_pre)
print('当前交易日: %s' % adjusted_date)
# Out:
# 前一个调仓日: 2020-01-06 00:00:00
# 当前调仓日: 2020-01-13 00:00:00
# 前一个交易日: 2020-01-07 00:00:00
# 当前交易日: 2020-01-14 00:00:00

# %%
# 因子数据库
data_source = alpha_db
engine = SqlEngine(data_source)

# uqer因子列表
basic_factor_store = factor_store.basic_factor_store
# alpha191因子列表
alpha_factor_store = factor_store.alpha_factor_store

# %%
# %%time
# 提取Uqer因子
basic_factor_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates)
# 提取alpha191因子
# alpha191_factor_org = engine.fetch_factor_range(universe, 
#                                                 alpha_factor_store, 
#                                                 dates=ref_dates, 
#                                                 used_factor_tables=[Alpha191]).drop(['chgPct','secShortName'], axis=1)
# # 合并所有的因子
# factor_data_org = pd.merge(basic_factor_org, alpha191_factor_org, on=['trade_date', 'code'], how='outer')
factor_data_org = basic_factor_org
# Out:
# CPU times: user 10.6 s, sys: 318 ms, total: 10.9 s
# Wall time: 12.3 s

# %%
set(factor_data_org['trade_date'])
# Out:
# {Timestamp('2019-11-04 00:00:00'),
#  Timestamp('2019-11-11 00:00:00'),
#  Timestamp('2019-11-18 00:00:00'),
#  Timestamp('2019-11-25 00:00:00'),
#  Timestamp('2019-12-02 00:00:00'),
#  Timestamp('2019-12-09 00:00:00'),
#  Timestamp('2019-12-16 00:00:00'),
#  Timestamp('2019-12-23 00:00:00'),
#  Timestamp('2019-12-30 00:00:00'),
#  Timestamp('2020-01-06 00:00:00'),
#  Timestamp('2020-01-13 00:00:00')}

# %%
assert len(set(factor_data_org['trade_date'])) == len(ref_dates)

# %%
# Plot factor value over time on code
from matplotlib import pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 2 # width 10, height 8

ax = factor_data_org[factor_data_org['code'] == 6].plot(x='trade_date', y='ACCA', style='b-', grid=True)
ax.set_xlabel("date")
ax.set_ylabel("ACCA")
# Out:
# Text(0, 0.5, 'ACCA')

# %%
# 因子预处理
## 确失值填充
factor_mean = factor_data_org.mean()
factor_std = factor_data_org.std()
factor_data_org = factor_data_org.fillna(factor_mean)

# %%
# %%time
# 获取所属行业
industry = engine.fetch_industry_range(universe, dates=ref_dates)
# factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code']).fillna(0.)
factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code'])

# 获取风险因子
risk_total = engine.fetch_risk_model_range(universe, dates=ref_dates)[1]
# Out:
# CPU times: user 150 ms, sys: 3.99 ms, total: 154 ms
# Wall time: 268 ms

# %%
# %%time
return_data = engine.fetch_dx_return_range(universe, dates=ref_dates, horizon=horizon, offset=0, benchmark=benchmark_code)
# Out:
# CPU times: user 55.9 ms, sys: 2.46 ms, total: 58.4 ms
# Wall time: 276 ms

# %%
return_data.head()
# Out:
#    trade_date  code        dx
# 0  2019-11-04     6 -0.006109
# 10 2019-11-04     8 -0.003731
# 20 2019-11-04     9  0.018258
# 30 2019-11-04    12 -0.007150
# 40 2019-11-04    21 -0.025596

# %%
# %%time
benchmark_total = engine.fetch_benchmark_range(dates=ref_dates, benchmark=benchmark_code)
industry_total = engine.fetch_industry_matrix_range(universe, dates=ref_dates, category=industry_name, level=industry_level)

train_data = pd.merge(factor_data, return_data, on=['trade_date', 'code']).dropna()
# Out:
# CPU times: user 87.2 ms, sys: 5.6 ms, total: 92.8 ms
# Wall time: 132 ms

# %%
# Plot adjusted close over time on code
from matplotlib import pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 2 # width 10, height 8

ax = train_data[train_data['code'] == 6].plot(x='trade_date', y='dx', style='b-', grid=True)
ax.set_xlabel("date")
ax.set_ylabel("dx")
# Out:
# Text(0, 0.5, 'dx')

# %%
# 获取特征名
features = list(basic_factor_store.keys())
alpha_features = list(alpha_factor_store.keys())
# features = feature_list.uqer_features
# alpha_features = feature_list.alpha_features
# features.extend(alpha_features)

label = ['dx']

# %% [markdown]
# ## 模型训练

# %%
from datetime import datetime, timedelta
from models.m1_xgb import *
from conf.configuration import xgb_conf
from data.engines.model import Record
import xgboost as xgb
import gc

alpha_logger.info('{0} is start'.format(ref_date))

# machine learning model
## Filter Training data
## 训练集构造
trade_date_pre = ref_date - timedelta(days=1)
# trade_date_pre_80 = ref_date - timedelta(days=80)

## 1、选择调仓日当天之前(不含当天)并且在80天以内的因子数据作为训练集.
# train = train_data[(train_data.trade_date <= trade_date_pre) & (trade_date_pre_80 <= train_data.trade_date)].dropna()
## 2、选择调仓日当天之前(不含当天)的因子数据作为训练集.
train = train_data[train_data.trade_date <= trade_date_pre].dropna()
alpha_logger.info('trade_date_pre {0}'.format(trade_date_pre))

if len(train) <= 0:
    alpha_logger.info('{0} HAS NO TRAIN DATA!!!'.format(ref_date))

x_train = train[features]
y_train = train[label]
alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))
# Out:
# 2020-01-14 02:44:46,615 - ALPHA_MIND - INFO - 2020-01-13 00:00:00 is start
# 2020-01-14 02:44:46,649 - ALPHA_MIND - INFO - trade_date_pre 2020-01-12 00:00:00
# 2020-01-14 02:44:46,656 - ALPHA_MIND - INFO - len_x_train: 5000, len_y_train: 5000
# 2020-01-14 02:44:46,657 - ALPHA_MIND - INFO - X_train.shape=(5000, 423), X_test.shape = (5000, 1)

# %% [markdown]
# ## 超参寻优

# %%
# load xgboost regression configuration
xgb_conf.xgb_config_r()
xgb_conf.cv_folds = None
xgb_conf.early_stop_round = 100
xgb_conf.max_round = 800
xgb_conf.params.update({'nthread': 12})

GPU_device = False
if GPU_device:
    # use GPUs
    xgb_conf.params.update({'tree_method': 'gpu_hist'})
alpha_logger.info("params before: {}".format(xgb_conf.params))
tic = time.time()

# hyper_parameters optimization
# opt_parameters = {'max_depth': (2, 12),
#                   'gamma': (0.001, 10.0),
#                   'min_child_weight': (0, 20),
#                   'max_delta_step': (0, 10),
#                   'subsample': (0.01, 0.99),
#                   'colsample_bytree': (0.01, 0.99)
#                  }

# opt_xgb = BayesOptimizationXGB('regression', x_train, y_train)
# params_op = opt_xgb.train_opt(opt_parameters)
# xgb_conf.params.update(params_op)
alpha_logger.info("params after: {}".format(xgb_conf.params))
alpha_logger.info("hyper params optimize time : {}".format(time.time() - tic))
# Out:
# 2020-01-14 02:44:46,663 - ALPHA_MIND - INFO - params before: {'booster': 'gbtree', 'objective': 'reg:linear', 'eval_metric': ['rmse', 'logloss'], 'nthread': 12, 'silent': 1, 'learning_rate': 0.01, 'max_depth': 5, 'eta': 0.03, 'alpha': 0, 'lambda': 0, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'seed': 2019}
# 2020-01-14 02:44:46,663 - ALPHA_MIND - INFO - params after: {'booster': 'gbtree', 'objective': 'reg:linear', 'eval_metric': ['rmse', 'logloss'], 'nthread': 12, 'silent': 1, 'learning_rate': 0.01, 'max_depth': 5, 'eta': 0.03, 'alpha': 0, 'lambda': 0, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'seed': 2019}
# 2020-01-14 02:44:46,664 - ALPHA_MIND - INFO - hyper params optimize time : 0.0005245208740234375

# %% [markdown]
# ## 模型训练

# %%
# model training
xgb_model = XGBooster(xgb_conf)
alpha_logger.info('xgb_model params: \n{0}'.format(xgb_model.get_params()))

best_score, best_round, best_model = xgb_model.fit(x_train, y_train)
alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
# Out:
# 2020-01-14 02:44:46,669 - ALPHA_MIND - INFO - xgb_model params:
# {'booster': 'gbtree', 'objective': 'reg:linear', 'eval_metric': ['rmse', 'logloss'], 'nthread': 12, 'silent': 1, 'learning_rate': 0.01, 'max_depth': 5, 'eta': 0.03, 'alpha': 0, 'lambda': 0, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'seed': 2019}
# 2020-01-14 02:44:46,669 - ../../../../models/m1_xgb.py[line:95] - INFO: NonCrossValidation。。。。
# [0]	train-rmse:0.498122	train-logloss:0.683132
# Multiple eval metrics have been passed: 'train-logloss' will be used for early stopping.
#
# Will train until train-logloss hasn't improved in 100 rounds.
# [5]	train-rmse:0.473855	train-logloss:0.635894
# [10]	train-rmse:0.450782	train-logloss:0.592931
# [15]	train-rmse:0.428859	train-logloss:0.553724
# [20]	train-rmse:0.408019	train-logloss:0.5178
# [25]	train-rmse:0.388203	train-logloss:0.484772
# [30]	train-rmse:0.36937	train-logloss:0.454335
# [35]	train-rmse:0.351476	train-logloss:0.426225
# [40]	train-rmse:0.334453	train-logloss:0.400172
# [45]	train-rmse:0.318289	train-logloss:0.37602
# [50]	train-rmse:0.302907	train-logloss:0.35354
# [55]	train-rmse:0.288286	train-logloss:0.332604
# [60]	train-rmse:0.274404	train-logloss:0.313097
# [65]	train-rmse:0.2612	train-logloss:0.294864
# [70]	train-rmse:0.248679	train-logloss:0.277847
# [75]	train-rmse:0.236769	train-logloss:0.261897
# [80]	train-rmse:0.225457	train-logloss:0.246952
# [85]	train-rmse:0.214722	train-logloss:0.232944
# [90]	train-rmse:0.204526	train-logloss:0.219789
# [95]	train-rmse:0.194847	train-logloss:0.207429
# [100]	train-rmse:0.185643	train-logloss:0.195785
# [105]	train-rmse:0.176899	train-logloss:0.184813
# [110]	train-rmse:0.168603	train-logloss:0.174482
# [115]	train-rmse:0.160742	train-logloss:0.164755
# [120]	train-rmse:0.153285	train-logloss:0.15558
# [125]	train-rmse:0.146198	train-logloss:0.146901
# [130]	train-rmse:0.139473	train-logloss:0.138698
# [135]	train-rmse:0.133102	train-logloss:0.130948
# [140]	train-rmse:0.127051	train-logloss:0.123602
# [145]	train-rmse:0.121336	train-logloss:0.116672
# [150]	train-rmse:0.115923	train-logloss:0.110105
# [155]	train-rmse:0.110788	train-logloss:0.103873
# [160]	train-rmse:0.105935	train-logloss:0.09797
# [165]	train-rmse:0.101343	train-logloss:0.092366
# [170]	train-rmse:0.097011	train-logloss:0.087055
# [175]	train-rmse:0.092909	train-logloss:0.081994
# [180]	train-rmse:0.089023	train-logloss:0.07717
# [185]	train-rmse:0.085364	train-logloss:0.072584
# [190]	train-rmse:0.081899	train-logloss:0.068155
# [195]	train-rmse:0.07864	train-logloss:0.062703
# [200]	train-rmse:0.075567	train-logloss:0.058743
# [205]	train-rmse:0.072669	train-logloss:0.054931
# [210]	train-rmse:0.069946	train-logloss:0.051242
# [215]	train-rmse:0.067375	train-logloss:0.046521
# [220]	train-rmse:0.064951	train-logloss:0.041941
# [225]	train-rmse:0.062686	train-logloss:0.037796
# [230]	train-rmse:0.060558	train-logloss:0.034023
# [235]	train-rmse:0.058549	train-logloss:0.027889
# [240]	train-rmse:0.056665	train-logloss:0.023891
# [245]	train-rmse:0.054914	train-logloss:0.020506
# [250]	train-rmse:0.053282	train-logloss:0.016423
# [255]	train-rmse:0.051754	train-logloss:0.012442
# [260]	train-rmse:0.050313	train-logloss:0.008776
# [265]	train-rmse:0.048976	train-logloss:0.005208
# [270]	train-rmse:0.047719	train-logloss:0.001974
# [275]	train-rmse:0.046542	train-logloss:-0.00378
# [280]	train-rmse:0.045449	train-logloss:-0.006948
# [285]	train-rmse:0.044431	train-logloss:-0.011526
# [290]	train-rmse:0.043492	train-logloss:-0.01635
# [295]	train-rmse:0.042621	train-logloss:-0.020594
# [300]	train-rmse:0.041802	train-logloss:-0.027143
# [305]	train-rmse:0.041062	train-logloss:-0.031555
# [310]	train-rmse:0.040366	train-logloss:-0.037516
# [315]	train-rmse:0.039712	train-logloss:-0.043175
# [320]	train-rmse:0.039119	train-logloss:-0.049332
# [325]	train-rmse:0.038561	train-logloss:-0.054611
# [330]	train-rmse:0.038039	train-logloss:-0.062005
# [335]	train-rmse:0.03756	train-logloss:-0.065963
# [340]	train-rmse:0.037127	train-logloss:-0.072253
# [345]	train-rmse:0.0367	train-logloss:-0.081208
# [350]	train-rmse:0.036307	train-logloss:-0.088863
# [355]	train-rmse:0.035948	train-logloss:-0.095528
# [360]	train-rmse:0.035614	train-logloss:-0.103897
# [365]	train-rmse:0.035284	train-logloss:-0.111427
# [370]	train-rmse:0.034992	train-logloss:-0.121936
# [375]	train-rmse:0.034728	train-logloss:-0.130295
# [380]	train-rmse:0.034471	train-logloss:-0.140605
# [385]	train-rmse:0.034238	train-logloss:-0.149515
# [390]	train-rmse:0.034016	train-logloss:-0.161786
# [395]	train-rmse:0.033805	train-logloss:-0.168022
# [400]	train-rmse:0.03361	train-logloss:-0.177851
# [405]	train-rmse:0.033419	train-logloss:-0.186581
# [410]	train-rmse:0.033232	train-logloss:-0.196907
# [415]	train-rmse:0.033058	train-logloss:-0.204248
# [420]	train-rmse:0.032895	train-logloss:-0.215929
# [425]	train-rmse:0.032748	train-logloss:-0.22306
# [430]	train-rmse:0.032607	train-logloss:-0.23257
# [435]	train-rmse:0.032477	train-logloss:-0.241275
# [440]	train-rmse:0.032356	train-logloss:-0.252724
# [445]	train-rmse:0.032226	train-logloss:-0.264095
# [450]	train-rmse:0.032111	train-logloss:-0.27489
# [455]	train-rmse:0.031988	train-logloss:-0.284825
# [460]	train-rmse:0.031888	train-logloss:-0.293201
# [465]	train-rmse:0.031785	train-logloss:-0.300061
# [470]	train-rmse:0.031676	train-logloss:-0.306531
# [475]	train-rmse:0.031574	train-logloss:-0.31729
# [480]	train-rmse:0.031493	train-logloss:-0.323817
# [485]	train-rmse:0.031402	train-logloss:-0.328578
# [490]	train-rmse:0.031315	train-logloss:-0.33624
# [495]	train-rmse:0.031225	train-logloss:-0.341163
# [500]	train-rmse:0.031147	train-logloss:-0.344597
# [505]	train-rmse:0.03106	train-logloss:-0.347273
# [510]	train-rmse:0.030977	train-logloss:-0.350559
# [515]	train-rmse:0.030897	train-logloss:-0.353666
# [520]	train-rmse:0.030804	train-logloss:-0.355837
# [525]	train-rmse:0.030722	train-logloss:-0.358756
# [530]	train-rmse:0.030644	train-logloss:-0.363069
# [535]	train-rmse:0.030556	train-logloss:-0.365353
# [540]	train-rmse:0.03048	train-logloss:-0.369291
# [545]	train-rmse:0.030413	train-logloss:-0.369983
# [550]	train-rmse:0.030335	train-logloss:-0.371156
# [555]	train-rmse:0.030263	train-logloss:-0.373187
# [560]	train-rmse:0.030178	train-logloss:-0.374188
# [565]	train-rmse:0.030111	train-logloss:-0.375535
# [570]	train-rmse:0.030036	train-logloss:-0.376228
# [575]	train-rmse:0.029958	train-logloss:-0.376374
# [580]	train-rmse:0.029894	train-logloss:-0.375792
# [585]	train-rmse:0.029818	train-logloss:-0.377029
# [590]	train-rmse:0.029749	train-logloss:-0.377727
# [595]	train-rmse:0.029686	train-logloss:-0.377667
# [600]	train-rmse:0.029626	train-logloss:-0.377672
# [605]	train-rmse:0.029554	train-logloss:-0.379773
# [610]	train-rmse:0.029487	train-logloss:-0.379925
# [615]	train-rmse:0.029413	train-logloss:-0.379808
# [620]	train-rmse:0.029355	train-logloss:-0.37995
# [625]	train-rmse:0.02929	train-logloss:-0.380567
# [630]	train-rmse:0.029226	train-logloss:-0.38201
# [635]	train-rmse:0.029169	train-logloss:-0.381632
# [640]	train-rmse:0.029096	train-logloss:-0.38206
# [645]	train-rmse:0.029024	train-logloss:-0.382625
# [650]	train-rmse:0.028951	train-logloss:-0.382635
# [655]	train-rmse:0.028885	train-logloss:-0.383437
# [660]	train-rmse:0.028827	train-logloss:-0.384174
# [665]	train-rmse:0.028772	train-logloss:-0.384466
# [670]	train-rmse:0.028699	train-logloss:-0.384636
# [675]	train-rmse:0.028642	train-logloss:-0.385299
# [680]	train-rmse:0.028582	train-logloss:-0.38554
# [685]	train-rmse:0.028528	train-logloss:-0.385665
# [690]	train-rmse:0.028487	train-logloss:-0.386636
# [695]	train-rmse:0.028422	train-logloss:-0.388289
# [700]	train-rmse:0.028375	train-logloss:-0.387413
# [705]	train-rmse:0.028321	train-logloss:-0.38776
# [710]	train-rmse:0.028246	train-logloss:-0.388382
# [715]	train-rmse:0.028197	train-logloss:-0.388189
# [720]	train-rmse:0.028138	train-logloss:-0.389463
# [725]	train-rmse:0.028072	train-logloss:-0.390185
# [730]	train-rmse:0.028009	train-logloss:-0.390628
# [735]	train-rmse:0.027959	train-logloss:-0.390498
# [740]	train-rmse:0.027907	train-logloss:-0.390954
# [745]	train-rmse:0.027838	train-logloss:-0.391555
# [750]	train-rmse:0.027782	train-logloss:-0.390764
# [755]	train-rmse:0.027731	train-logloss:-0.391539
# [760]	train-rmse:0.027666	train-logloss:-0.392099
# [765]	train-rmse:0.027601	train-logloss:-0.39251
# [770]	train-rmse:0.027554	train-logloss:-0.393523
# [775]	train-rmse:0.027508	train-logloss:-0.394019
# [780]	train-rmse:0.027456	train-logloss:-0.394133
# [785]	train-rmse:0.027391	train-logloss:-0.394783
# [790]	train-rmse:0.027342	train-logloss:-0.396007
# [795]	train-rmse:0.027284	train-logloss:-0.396911
# [799]	train-rmse:0.027245	train-logloss:-0.396414
# 2020-01-14 02:44:50,838 - ALPHA_MIND - INFO - Training time cost 4.175006151199341s
# 2020-01-14 02:44:50,839 - ALPHA_MIND - INFO - best_score = {'best_score': -0.397219}, best_round = 796

# %% [markdown]
# ## 当天数据预测

# %%
# 取调仓日当天的因子数据作为输入.
# total_data_test_excess = train_data[train_data.trade_date == str(ref_date)]
total_data_test_excess = factor_data[factor_data.trade_date == ref_date]

if len(total_data_test_excess) <=0:
    alpha_logger.info('{} HAS NO DATA!!!'.format(ref_date))
    sys.exit()

alpha_logger.info('{0} total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

# 获取调仓日当天的行业, 风险模型和基准权重数据
industry_matrix = industry_total[industry_total.trade_date == ref_date]
benchmark_weight = benchmark_total[benchmark_total.trade_date == ref_date]
risk_matrix = risk_total[risk_total.trade_date == ref_date]

total_data = pd.merge(industry_matrix, benchmark_weight, on=['code'], how='left').fillna(0.)
total_data = pd.merge(total_data, risk_matrix, on=['code'])
alpha_logger.info('{0} type_of_total_data: {1}'.format(ref_date, type(total_data)))
alpha_logger.info('{0} shape_of_total_data: {1}'.format(ref_date, np.shape(total_data)))
    
total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
alpha_logger.info('{0} len_of_total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

# 股票代码
codes = total_data_test_excess.code.values.tolist()
   
# predict
# alpha_logger.info('total_data_test_excess: \n{}'.format(total_data_test_excess[['weight', 'code', 'industry']]))
x_pred = total_data_test_excess[features]
predict_xgboost = xgb_model.predict(best_model, x_pred)
# alpha_logger.info('predict_xgboost: {}'.format(predict_xgboost))

a = np.shape(predict_xgboost)
predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))

# 收益率预测结果    
predict_xgboost_df = pd.DataFrame({'xgb_pre': list(predict_xgboost.reshape(-1))})
predict_xgboost_df['trade_date'] = ref_date
predict_xgboost_df['code'] = codes
predict_xgboost_df['code'] = predict_xgboost_df['code'].apply(lambda x: "{:06d}".format(x) + '.XSHG'
                                                              if len(str(x))==6 and str(x)[0] in '6' 
                                                              else "{:06d}".format(x) + '.XSHE')
# Out:
# 2020-01-14 02:44:50,874 - ALPHA_MIND - INFO - 2020-01-13 00:00:00 total_data_test_excess: 500
# 2020-01-14 02:44:50,887 - ALPHA_MIND - INFO - 2020-01-13 00:00:00 type_of_total_data: <class 'pandas.core.frame.DataFrame'>
# 2020-01-14 02:44:50,887 - ALPHA_MIND - INFO - 2020-01-13 00:00:00 shape_of_total_data: (500, 74)
# 2020-01-14 02:44:50,894 - ALPHA_MIND - INFO - 2020-01-13 00:00:00 len_of_total_data_test_excess: 500
# 2020-01-14 02:44:50,907 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)

# %% [markdown]
# ## 获取昨持仓信息

# %%
from data.engines.sqlengine import SQLEngine

# 获取当前持仓
record_engine = SQLEngine('sqlite:///./{}/real_tune_record_without_alpha.db'.format(weekly))

try:
    pos_record = record_engine.fetch_record('pos_record')
    previous_pos = pos_record[pos_record['trade_date'] == adjusted_date_pre]
    # previous_pos = record_engine.fetch_record_meta(Record, adjusted_date_pre)
    
except Exception as e:
    alpha_logger.info('pos_record Exception:{0}'.format(e))
    previous_pos = pd.DataFrame({'trade_date':[], 'weight':[],'industry':[], 'er':[],'code':[]})

alpha_logger.info('previous_pos_data: {0}, pos_len: {1}'.format(adjusted_date_pre, len(previous_pos)))

# 股票过滤, 组合优化之前过滤掉(未完成)
## 9:00--9:25之间进行涨跌停股票的实时筛选

# 导入昨持仓并与股票池中所有股票合并, 
if len(previous_pos) <= 0:
    previous_position = None
else:
    previous_pos = total_data_test_excess[['code']].merge(previous_pos, on=['code'], how='left',).fillna(0)
    previous_position = previous_pos.weight.values
# alpha_logger.info('previous_position:\n {}'.format(previous_position))

# previous_pos = total_data_test_excess[['code']].merge(previous_pos, on=['code'], how='left').fillna(0)
# previous_position = previous_pos.weight.values

# print(previous_position.shape)
# print(total_data_test_excess.shape)
# print(previous_position.shape)
# Out:
# 2020-01-14 02:44:50,938 - ALPHA_MIND - INFO - previous_pos_data: 2020-01-07 00:00:00, pos_len: 50

# %% [markdown]
# ## 组合优化

# %%
# Constraintes settings
industry_names = industry_list(industry_name, industry_level)
constraint_risk = ['EARNYILD', 'LIQUIDTY', 'GROWTH', 'SIZE', 'SIZENL', 'BETA', 'MOMENTUM'] + industry_names

total_risk_names = constraint_risk + ['benchmark', 'total']

b_type = []
l_val = []
u_val = []

for name in total_risk_names:
    if name == 'benchmark':
        b_type.append(BoundaryType.RELATIVE)
        l_val.append(0.0)
        u_val.append(1.0)
    elif name == 'total':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-0.0)
        u_val.append(0.0)
    elif name == 'SIZE':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.0)
        u_val.append(1.0)
    elif name == 'SIZENL':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.0)
        u_val.append(1.0)
    elif name in industry_names:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-0.005)
        u_val.append(0.005)
    else:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-2.0)
        u_val.append(2.0)
bounds = create_box_bounds(total_risk_names, b_type, l_val, u_val)

# %%
benchmark_w = total_data_test_excess.weight.values
alpha_logger.info('type_of_benchmark_w: {}, shape_of_benchmark_w: {}'.format(type(benchmark_w), 
                                                                             np.shape(benchmark_w)))
is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))

# 风险模型数据合并
# weight_gap = 0.02
# turn_over_rate = 0.2
total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                 is_in_benchmark,
                                 np.ones_like(is_in_benchmark)],
                                axis=1)

alpha_logger.info('shape_of_total_risk_exp_pre: {}'.format(np.shape(total_risk_exp)))
total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))

constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
alpha_logger.info('constraints: {0} in {1}'.format(np.shape(constraints.risk_targets()), ref_date))

lbound = np.maximum(0., benchmark_w - weight_gap)
ubound = weight_gap + benchmark_w
alpha_logger.info('lbound: {0} in {1}'.format(np.shape(lbound), ref_date))
alpha_logger.info('ubound: {0} in {1}'.format(np.shape(ubound), ref_date))

# 组合优化
executor = NaiveExecutor()
current_pos = pd.DataFrame()

target_pos, _ = er_portfolio_analysis(predict_xgboost, 
                                      total_data_test_excess['industry'].values,
                                      None,
                                      constraints,
                                      False,
                                      benchmark_w,
                                      method='risk_neutral',
                                      lbound=lbound,
                                      ubound=ubound,
                                      turn_over_target=turn_over_rate,
                                      current_position=previous_position)
                  
alpha_logger.info('shape_of_target_pos: {}'.format(np.shape(target_pos)))
alpha_logger.info('len_codes:{}'.format(np.shape(codes)))
target_pos['code'] = codes
# alpha_logger.info('target_pos: \n{}'.format(target_pos))

# 换手率计算
executor.set_current(previous_pos)
turn_over_org, current_pos = executor.execute(target_pos=target_pos)
alpha_logger.info('turn_over_org: {}'.format(turn_over_org))
turn_over = turn_over_org / sum(target_pos.weight.values)
alpha_logger.info('turn_over: {}'.format(turn_over))

# 优化后仓位信息
## 调仓日
current_pos['adjust_date'] = ref_date
## 交易日
current_pos['trade_date'] = adjusted_date
alpha_logger.info('{} is finished'.format(adjusted_date))
# Out:
# 2020-01-14 02:44:50,963 - ALPHA_MIND - INFO - type_of_benchmark_w: <class 'numpy.ndarray'>, shape_of_benchmark_w: (500,)
# 2020-01-14 02:44:50,965 - ALPHA_MIND - INFO - shape_of_total_risk_exp_pre: (500, 37)
# 2020-01-14 02:44:50,965 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 37)
# 2020-01-14 02:44:50,968 - ALPHA_MIND - INFO - constraints: (2, 37) in 2020-01-13 00:00:00
# 2020-01-14 02:44:50,968 - ALPHA_MIND - INFO - lbound: (500,) in 2020-01-13 00:00:00
# 2020-01-14 02:44:50,969 - ALPHA_MIND - INFO - ubound: (500,) in 2020-01-13 00:00:00
# 2020-01-14 02:44:51,009 - ALPHA_MIND - INFO - shape_of_target_pos: (500, 3)
# 2020-01-14 02:44:51,010 - ALPHA_MIND - INFO - len_codes:(500,)
# 2020-01-14 02:44:51,019 - ALPHA_MIND - INFO - turn_over_org: 0.3000000000001344
# 2020-01-14 02:44:51,020 - ALPHA_MIND - INFO - turn_over: 0.29996700362973544
# 2020-01-14 02:44:51,022 - ALPHA_MIND - INFO - 2020-01-14 00:00:00 is finished

# %%
## 修改code格式
## 取TOP N作为真实的下单股票
real_pos = current_pos.sort_values(by='weight', ascending=False)[:50]
real_pos['weight'] = real_pos['weight'] / real_pos['weight'].sum()
real_pos
# Out:
#        weight industry        er    code adjust_date trade_date
# 143  0.026198       电子  0.029556    2371  2020-01-13 2020-01-14
# 333  0.026125      计算机  0.010440  600536  2020-01-13 2020-01-14
# 195  0.025895       化工  0.020492    2812  2020-01-13 2020-01-14
# 220  0.025570       电子  0.026773  300088  2020-01-13 2020-01-14
# 116  0.025204      计算机  0.022566    2180  2020-01-13 2020-01-14
# 242  0.025089       传媒  0.020950  300315  2020-01-13 2020-01-14
# 358  0.024702     医药生物  0.003038  600673  2020-01-13 2020-01-14
# 403  0.024691     电气设备  0.003574  600885  2020-01-13 2020-01-14
# 227  0.024252      计算机  0.007480  300168  2020-01-13 2020-01-14
# 324  0.024053       化工  0.017107  600486  2020-01-13 2020-01-14
# 435  0.024000       电子  0.009499  601231  2020-01-13 2020-01-14
# 149  0.023990     农林牧渔  0.015038    2385  2020-01-13 2020-01-14
# 114  0.023959       传媒  0.058066    2174  2020-01-13 2020-01-14
# 118  0.023383     轻工制造 -0.000072    2191  2020-01-13 2020-01-14
# 276  0.023320     非银金融 -0.007420  600155  2020-01-13 2020-01-14
# 290  0.023163      房地产 -0.002303  600266  2020-01-13 2020-01-14
# 285  0.023132     医药生物  0.012404  600216  2020-01-13 2020-01-14
# 485  0.023111     医药生物  0.020866  603707  2020-01-13 2020-01-14
# 255  0.023058     交通运输  0.015698  600026  2020-01-13 2020-01-14
# 137  0.022954     医药生物  0.019036    2317  2020-01-13 2020-01-14
# 444  0.022724       汽车  0.017294  601689  2020-01-13 2020-01-14
# 44   0.022713     公用事业 -0.001199     685  2020-01-13 2020-01-14
# 120  0.022399     有色金属  0.001139    2203  2020-01-13 2020-01-14
# 182  0.022336       电子  0.035945    2635  2020-01-13 2020-01-14
# 191  0.022315       化工  0.006122    2709  2020-01-13 2020-01-14
# 188  0.022043       电子  0.029612    2681  2020-01-13 2020-01-14
# 156  0.021855     商业贸易  0.011764    2416  2020-01-13 2020-01-14
# 304  0.021771     有色金属  0.004346  600338  2020-01-13 2020-01-14
# 488  0.021718     电气设备  0.020296  603806  2020-01-13 2020-01-14
# 418  0.021645       钢铁  0.000769  601003  2020-01-13 2020-01-14
# 246  0.020990       通信  0.001409  300383  2020-01-13 2020-01-14
# 139  0.019894     机械设备 -0.006704    2353  2020-01-13 2020-01-14
# 152  0.018568     医药生物  0.001517    2399  2020-01-13 2020-01-14
# 96   0.018275     建筑装饰 -0.001387    2051  2020-01-13 2020-01-14
# 2    0.017417       综合  0.010404       9  2020-01-13 2020-01-14
# 168  0.015962       化工  0.015524    2470  2020-01-13 2020-01-14
# 322  0.015565      房地产  0.008652  600466  2020-01-13 2020-01-14
# 66   0.015012     建筑材料  0.000869     877  2020-01-13 2020-01-14
# 38   0.014748       汽车  0.001384     581  2020-01-13 2020-01-14
# 167  0.014212     国防军工  0.001375    2465  2020-01-13 2020-01-14
# 460  0.014109       采掘 -0.004300  601969  2020-01-13 2020-01-14
# 477  0.013869       传媒  0.027018  603444  2020-01-13 2020-01-14
# 189  0.013725     机械设备 -0.006286    2690  2020-01-13 2020-01-14
# 33   0.012404     国防军工  0.003148     547  2020-01-13 2020-01-14
# 14   0.012236      计算机  0.000898      66  2020-01-13 2020-01-14
# 381  0.012227     食品饮料  0.004580  600779  2020-01-13 2020-01-14
# 287  0.011744     休闲服务  0.011690  600258  2020-01-13 2020-01-14
# 361  0.010720     交通运输 -0.001104  600704  2020-01-13 2020-01-14
# 384  0.010642     建筑材料  0.007408  600801  2020-01-13 2020-01-14
# 204  0.010311     非银金融 -0.001584    2926  2020-01-13 2020-01-14

# %%
## 保存记录当前持仓信息, 写入数据库
previous_record = record_engine.fetch_record_meta(Record, adjusted_date)
if len(previous_record) == 0:
    record_engine.write_data('pos_record', real_pos)
else:
    record_engine.del_historical_data(Record, adjusted_date)  # 删除同日期的历史数据
    tmp_record = record_engine.fetch_record_meta(Record, adjusted_date)
    if len(tmp_record) == 0:  # 删除成功
        record_engine.write_data('pos_record', real_pos)
    else:
        print('{} 的数据没有删除: {}'.format(adjusted_date, len(previous_record)))

# %%
# 生成交易记录
## 修改code格式
real_pos['code'] = real_pos['code'].apply(lambda x: "{:06d}".format(x) + '.SH' 
                                          if len(str(x))==6 and str(x)[0] in '6' 
                                          else "{:06d}".format(x) + '.SZ')

real_pos = real_pos.loc[:, ['code', 'weight', 'trade_date']]
# real_pos = real_pos.loc[:, ['code', 'weight']]
# real_pos['trade_date'] = adjust_date

real_pos.rename(columns={"code": "证券代码", "weight": "持仓权重", "trade_date": "成分日期"}, inplace=True)
real_pos['交易价格'] = 0

real_pos = real_pos[['证券代码', '持仓权重', '交易价格', '成分日期']].copy()
real_pos.to_csv('./{}/base_{}.csv'.format(weekly, str(adjusted_date.date())), encoding='utf_8_sig', index=False)

# %%
# 查看持仓记录
previous_record = record_engine.fetch_record_meta(Record, adjusted_date)
# previous_record = record_engine.fetch_record('pos_record')
# previous_record = current_record[current_record['trade_date'] == adjusted_date]
previous_record
# Out:
#     trade_date adjust_date    weight industry        er    code
# 0   2020-01-14  2020-01-13  0.026198       电子  0.029556    2371
# 1   2020-01-14  2020-01-13  0.026125      计算机  0.010440  600536
# 2   2020-01-14  2020-01-13  0.025895       化工  0.020492    2812
# 3   2020-01-14  2020-01-13  0.025570       电子  0.026773  300088
# 4   2020-01-14  2020-01-13  0.025204      计算机  0.022566    2180
# 5   2020-01-14  2020-01-13  0.025089       传媒  0.020950  300315
# 6   2020-01-14  2020-01-13  0.024702     医药生物  0.003038  600673
# 7   2020-01-14  2020-01-13  0.024691     电气设备  0.003574  600885
# 8   2020-01-14  2020-01-13  0.024252      计算机  0.007480  300168
# 9   2020-01-14  2020-01-13  0.024053       化工  0.017107  600486
# 10  2020-01-14  2020-01-13  0.024000       电子  0.009499  601231
# 11  2020-01-14  2020-01-13  0.023990     农林牧渔  0.015038    2385
# 12  2020-01-14  2020-01-13  0.023959       传媒  0.058066    2174
# 13  2020-01-14  2020-01-13  0.023383     轻工制造 -0.000072    2191
# 14  2020-01-14  2020-01-13  0.023320     非银金融 -0.007420  600155
# 15  2020-01-14  2020-01-13  0.023163      房地产 -0.002303  600266
# 16  2020-01-14  2020-01-13  0.023132     医药生物  0.012404  600216
# 17  2020-01-14  2020-01-13  0.023111     医药生物  0.020866  603707
# 18  2020-01-14  2020-01-13  0.023058     交通运输  0.015698  600026
# 19  2020-01-14  2020-01-13  0.022954     医药生物  0.019036    2317
# 20  2020-01-14  2020-01-13  0.022724       汽车  0.017294  601689
# 21  2020-01-14  2020-01-13  0.022713     公用事业 -0.001199     685
# 22  2020-01-14  2020-01-13  0.022399     有色金属  0.001139    2203
# 23  2020-01-14  2020-01-13  0.022336       电子  0.035945    2635
# 24  2020-01-14  2020-01-13  0.022315       化工  0.006122    2709
# 25  2020-01-14  2020-01-13  0.022043       电子  0.029612    2681
# 26  2020-01-14  2020-01-13  0.021855     商业贸易  0.011764    2416
# 27  2020-01-14  2020-01-13  0.021771     有色金属  0.004346  600338
# 28  2020-01-14  2020-01-13  0.021718     电气设备  0.020296  603806
# 29  2020-01-14  2020-01-13  0.021645       钢铁  0.000769  601003
# 30  2020-01-14  2020-01-13  0.020990       通信  0.001409  300383
# 31  2020-01-14  2020-01-13  0.019894     机械设备 -0.006704    2353
# 32  2020-01-14  2020-01-13  0.018568     医药生物  0.001517    2399
# 33  2020-01-14  2020-01-13  0.018275     建筑装饰 -0.001387    2051
# 34  2020-01-14  2020-01-13  0.017417       综合  0.010404       9
# 35  2020-01-14  2020-01-13  0.015962       化工  0.015524    2470
# 36  2020-01-14  2020-01-13  0.015565      房地产  0.008652  600466
# 37  2020-01-14  2020-01-13  0.015012     建筑材料  0.000869     877
# 38  2020-01-14  2020-01-13  0.014748       汽车  0.001384     581
# 39  2020-01-14  2020-01-13  0.014212     国防军工  0.001375    2465
# 40  2020-01-14  2020-01-13  0.014109       采掘 -0.004300  601969
# 41  2020-01-14  2020-01-13  0.013869       传媒  0.027018  603444
# 42  2020-01-14  2020-01-13  0.013725     机械设备 -0.006286    2690
# 43  2020-01-14  2020-01-13  0.012404     国防军工  0.003148     547
# 44  2020-01-14  2020-01-13  0.012236      计算机  0.000898      66
# 45  2020-01-14  2020-01-13  0.012227     食品饮料  0.004580  600779
# 46  2020-01-14  2020-01-13  0.011744     休闲服务  0.011690  600258
# 47  2020-01-14  2020-01-13  0.010720     交通运输 -0.001104  600704
# 48  2020-01-14  2020-01-13  0.010642     建筑材料  0.007408  600801
# 49  2020-01-14  2020-01-13  0.010311     非银金融 -0.001584    2926

# %%
str(adjusted_date.date())
# Out:
# '2020-01-14'
