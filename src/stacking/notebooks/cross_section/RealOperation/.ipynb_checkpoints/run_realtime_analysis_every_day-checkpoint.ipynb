# %% [markdown]
# # 基础因子实时计算

# %% [markdown]
# zz500模拟盘操作

# %%
# %matplotlib inline
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../../')
sys.path.append('../../../../')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from PyFin.api import *
from alphamind.api import *
from conf.models import *
from conf.config import*
from data.engines.model import Record
from alphamind.execution.naiveexecutor import NaiveExecutor
from stacking import factor_store, feature_list
from optimization.bayes_optimization_xgb import *
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',100)

# %% [markdown]
# ## 因子数据准备

# %%
# 指定需要执行的日期和保存的文件夹
# start_date = '2010-01-19'  # 训练集的起始时间
start_date = '2019-10-18'  # 训练集的起始时间
end_date = '2019-12-27'
# 设置保存的文件目录
weekly = 's_1'  # {s1: 周一, s2: 周二,  s3: 周三, s4: 周四, s5: 周五}

# 优化器参数设定
weight_gap = 0.02
turn_over_rate = 0.1

# %%
universe = Universe('zz500')
freq = '1b'
benchmark_code = 905
ref_dates = makeSchedule(start_date, end_date, freq, 'china.sse')
horizon = map_freq(freq)
industry_name = 'sw'
industry_level = 1

# 前一个调仓日, 用于获取前一个调仓日的持仓信息
ref_date_pre = ref_dates[-2]
# 当前调仓日
ref_date = ref_dates[-1]

# 因子数据库
data_source = alpha_db
engine = SqlEngine(data_source)
ref_dates
# Out:
# [datetime.datetime(2019, 10, 18, 0, 0),
#  datetime.datetime(2019, 10, 21, 0, 0),
#  datetime.datetime(2019, 10, 22, 0, 0),
#  datetime.datetime(2019, 10, 23, 0, 0),
#  datetime.datetime(2019, 10, 24, 0, 0),
#  datetime.datetime(2019, 10, 25, 0, 0),
#  datetime.datetime(2019, 10, 28, 0, 0),
#  datetime.datetime(2019, 10, 29, 0, 0),
#  datetime.datetime(2019, 10, 30, 0, 0),
#  datetime.datetime(2019, 10, 31, 0, 0),
#  datetime.datetime(2019, 11, 1, 0, 0),
#  datetime.datetime(2019, 11, 4, 0, 0),
#  datetime.datetime(2019, 11, 5, 0, 0),
#  datetime.datetime(2019, 11, 6, 0, 0),
#  datetime.datetime(2019, 11, 7, 0, 0),
#  datetime.datetime(2019, 11, 8, 0, 0),
#  datetime.datetime(2019, 11, 11, 0, 0),
#  datetime.datetime(2019, 11, 12, 0, 0),
#  datetime.datetime(2019, 11, 13, 0, 0),
#  datetime.datetime(2019, 11, 14, 0, 0),
#  datetime.datetime(2019, 11, 15, 0, 0),
#  datetime.datetime(2019, 11, 18, 0, 0),
#  datetime.datetime(2019, 11, 19, 0, 0),
#  datetime.datetime(2019, 11, 20, 0, 0),
#  datetime.datetime(2019, 11, 21, 0, 0),
#  datetime.datetime(2019, 11, 22, 0, 0),
#  datetime.datetime(2019, 11, 25, 0, 0),
#  datetime.datetime(2019, 11, 26, 0, 0),
#  datetime.datetime(2019, 11, 27, 0, 0),
#  datetime.datetime(2019, 11, 28, 0, 0),
#  datetime.datetime(2019, 11, 29, 0, 0),
#  datetime.datetime(2019, 12, 2, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2019, 12, 4, 0, 0),
#  datetime.datetime(2019, 12, 5, 0, 0),
#  datetime.datetime(2019, 12, 6, 0, 0),
#  datetime.datetime(2019, 12, 9, 0, 0),
#  datetime.datetime(2019, 12, 10, 0, 0),
#  datetime.datetime(2019, 12, 11, 0, 0),
#  datetime.datetime(2019, 12, 12, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2019, 12, 16, 0, 0),
#  datetime.datetime(2019, 12, 17, 0, 0),
#  datetime.datetime(2019, 12, 18, 0, 0),
#  datetime.datetime(2019, 12, 19, 0, 0),
#  datetime.datetime(2019, 12, 20, 0, 0),
#  datetime.datetime(2019, 12, 23, 0, 0),
#  datetime.datetime(2019, 12, 24, 0, 0),
#  datetime.datetime(2019, 12, 25, 0, 0),
#  datetime.datetime(2019, 12, 26, 0, 0),
#  datetime.datetime(2019, 12, 27, 0, 0)]

# %%
# uqer因子列表
basic_factor_store = factor_store.basic_factor_store
# alpha191因子列表
alpha_factor_store = factor_store.alpha_factor_store

# %%
# %%time
# 提取Uqer因子
basic_factor_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates)
# 提取alpha191因子
# alpha191_factor_org = engine.fetch_factor_range(universe, 
#                                                 alpha_factor_store, 
#                                                 dates=ref_dates, 
#                                                 used_factor_tables=[Alpha191]).drop(['chgPct','secShortName'], axis=1)
# # 合并所有的因子
# factor_data_org = pd.merge(basic_factor_org, alpha191_factor_org, on=['trade_date', 'code'], how='outer')
factor_data_org = basic_factor_org
# Out:
# CPU times: user 53 s, sys: 1.73 s, total: 54.7 s
# Wall time: 1min

# %%
len(set(factor_data_org['trade_date']))
# Out:
# 51

# %%
assert len(set(factor_data_org['trade_date'])) == len(ref_dates)

# %%
# Plot factor value over time on code
from matplotlib import pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 2 # width 10, height 8

ax = factor_data_org[factor_data_org['code'] == 6].plot(x='trade_date', y='ACCA', style='b-', grid=True)
ax.set_xlabel("date")
ax.set_ylabel("ACCA")
# Out:
# Text(0, 0.5, 'ACCA')

# %%
# 因子预处理
## 确失值填充
factor_mean = factor_data_org.mean()
factor_std = factor_data_org.std()
factor_data_org = factor_data_org.fillna(factor_mean)

# %%
# %%time
# 获取所属行业
industry = engine.fetch_industry_range(universe, dates=ref_dates)
# factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code']).fillna(0.)
factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code'])

# 获取风险因子
risk_total = engine.fetch_risk_model_range(universe, dates=ref_dates)[1]
# Out:
# CPU times: user 722 ms, sys: 61.5 ms, total: 784 ms
# Wall time: 1.27 s

# %%
# %%time
return_data = engine.fetch_dx_return_range(universe, dates=ref_dates, horizon=horizon, offset=0,benchmark = benchmark_code)
# Out:
# CPU times: user 276 ms, sys: 5.5 ms, total: 281 ms
# Wall time: 569 ms

# %%
return_data.head()
# Out:
#     trade_date  code        dx
# 0   2019-10-18     6  0.004171
# 50  2019-10-18     8  0.004969
# 100 2019-10-18     9 -0.008685
# 150 2019-10-18    12 -0.002337
# 200 2019-10-18    21  0.015484

# %%
# %%time
benchmark_total = engine.fetch_benchmark_range(dates=ref_dates, benchmark=benchmark_code)
industry_total = engine.fetch_industry_matrix_range(universe, dates=ref_dates, category=industry_name, level=industry_level)

train_data = pd.merge(factor_data, return_data, on=['trade_date', 'code']).dropna()
# Out:
# CPU times: user 497 ms, sys: 110 ms, total: 607 ms
# Wall time: 777 ms

# %%
# Plot adjusted close over time on code
from matplotlib import pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 2 # width 10, height 8

ax = train_data[train_data['code'] == 6].plot(x='trade_date', y='dx', style='b-', grid=True)
ax.set_xlabel("date")
ax.set_ylabel("dx")
# Out:
# Text(0, 0.5, 'dx')

# %%
# 获取特征名
features = list(basic_factor_store.keys())
alpha_features = list(alpha_factor_store.keys())
# features = feature_list.uqer_features
# alpha_features = feature_list.alpha_features
# features.extend(alpha_features)

label = ['dx']

# %% [markdown]
# ## 模型训练

# %%
from datetime import datetime, timedelta
from models.m1_xgb import *
from conf.configuration import xgb_conf
from data.engines.model import Record
import xgboost as xgb
import gc

alpha_logger.info('{0} is start'.format(ref_date))

# machine learning model
## Filter Training data
## 训练集构造
trade_date_pre = ref_date - timedelta(days=1)
# trade_date_pre_80 = ref_date - timedelta(days=80)

## 1、选择调仓日当天之前(不含当天)并且在80天以内的因子数据作为训练集.
# train = train_data[(train_data.trade_date <= trade_date_pre) & (trade_date_pre_80 <= train_data.trade_date)].dropna()
## 2、选择调仓日当天之前(不含当天)的因子数据作为训练集.
train = train_data[train_data.trade_date <= trade_date_pre].dropna()
alpha_logger.info('trade_date_pre {0}'.format(trade_date_pre))

if len(train) <= 0:
    alpha_logger.info('{0} HAS NO TRAIN DATA!!!'.format(ref_date))

x_train = train[features]
y_train = train[label]
alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))
# Out:
# 2019-12-30 05:31:45,388 - ALPHA_MIND - INFO - 2019-12-27 00:00:00 is start
# 2019-12-30 05:31:45,614 - ALPHA_MIND - INFO - trade_date_pre 2019-12-26 00:00:00
# 2019-12-30 05:31:45,667 - ALPHA_MIND - INFO - len_x_train: 25000, len_y_train: 25000
# 2019-12-30 05:31:45,669 - ALPHA_MIND - INFO - X_train.shape=(25000, 423), X_test.shape = (25000, 1)

# %% [markdown]
# ## 超参寻优

# %%
# load xgboost regression configuration
xgb_conf.xgb_config_r()
xgb_conf.cv_folds = None
xgb_conf.early_stop_round = 100
xgb_conf.max_round = 800
xgb_conf.params.update({'nthread': 12})

GPU_device = False
if GPU_device:
    # use GPUs
    xgb_conf.params.update({'tree_method': 'gpu_hist'})
alpha_logger.info("params before: {}".format(xgb_conf.params))
tic = time.time()

# hyper_parameters optimization
# opt_parameters = {'max_depth': (2, 12),
#                   'gamma': (0.001, 10.0),
#                   'min_child_weight': (0, 20),
#                   'max_delta_step': (0, 10),
#                   'subsample': (0.01, 0.99),
#                   'colsample_bytree': (0.01, 0.99)
#                  }

# opt_xgb = BayesOptimizationXGB('regression', x_train, y_train)
# params_op = opt_xgb.train_opt(opt_parameters)
# xgb_conf.params.update(params_op)
alpha_logger.info("params after: {}".format(xgb_conf.params))
alpha_logger.info("hyper params optimize time : {}".format(time.time() - tic))
# Out:
# 2019-12-30 05:31:45,676 - ALPHA_MIND - INFO - params before: {'booster': 'gbtree', 'objective': 'reg:linear', 'eval_metric': ['rmse', 'logloss'], 'nthread': 12, 'silent': 1, 'learning_rate': 0.01, 'max_depth': 5, 'eta': 0.03, 'alpha': 0, 'lambda': 0, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'seed': 2019}
# 2019-12-30 05:31:45,677 - ALPHA_MIND - INFO - params after: {'booster': 'gbtree', 'objective': 'reg:linear', 'eval_metric': ['rmse', 'logloss'], 'nthread': 12, 'silent': 1, 'learning_rate': 0.01, 'max_depth': 5, 'eta': 0.03, 'alpha': 0, 'lambda': 0, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'seed': 2019}
# 2019-12-30 05:31:45,677 - ALPHA_MIND - INFO - hyper params optimize time : 0.0007524490356445312

# %% [markdown]
# ## 模型训练

# %%
# model training
xgb_model = XGBooster(xgb_conf)
alpha_logger.info('xgb_model params: \n{0}'.format(xgb_model.get_params()))

best_score, best_round, best_model = xgb_model.fit(x_train, y_train)
alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
# Out:
# 2019-12-30 05:31:45,683 - ALPHA_MIND - INFO - xgb_model params:
# {'booster': 'gbtree', 'objective': 'reg:linear', 'eval_metric': ['rmse', 'logloss'], 'nthread': 12, 'silent': 1, 'learning_rate': 0.01, 'max_depth': 5, 'eta': 0.03, 'alpha': 0, 'lambda': 0, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'seed': 2019}
# 2019-12-30 05:31:45,684 - ../../../../models/m1_xgb.py[line:95] - INFO: NonCrossValidation。。。。
# [0]	train-rmse:0.495576	train-logloss:0.683187
# Multiple eval metrics have been passed: 'train-logloss' will be used for early stopping.
#
# Will train until train-logloss hasn't improved in 100 rounds.
# [5]	train-rmse:0.47132	train-logloss:0.636217
# [10]	train-rmse:0.448254	train-logloss:0.593504
# [15]	train-rmse:0.426321	train-logloss:0.554509
# [20]	train-rmse:0.405462	train-logloss:0.518778
# [25]	train-rmse:0.385629	train-logloss:0.485946
# [30]	train-rmse:0.366768	train-logloss:0.455686
# [35]	train-rmse:0.348836	train-logloss:0.427737
# [40]	train-rmse:0.331785	train-logloss:0.401862
# [45]	train-rmse:0.315573	train-logloss:0.37786
# [50]	train-rmse:0.300155	train-logloss:0.355552
# [55]	train-rmse:0.285496	train-logloss:0.334789
# [60]	train-rmse:0.271556	train-logloss:0.315431
# [65]	train-rmse:0.258304	train-logloss:0.297365
# [70]	train-rmse:0.245705	train-logloss:0.28048
# [75]	train-rmse:0.233725	train-logloss:0.26468
# [80]	train-rmse:0.222335	train-logloss:0.249882
# [85]	train-rmse:0.211509	train-logloss:0.23601
# [90]	train-rmse:0.201214	train-logloss:0.22299
# [95]	train-rmse:0.191431	train-logloss:0.210765
# [100]	train-rmse:0.182127	train-logloss:0.199271
# [105]	train-rmse:0.173283	train-logloss:0.18846
# [110]	train-rmse:0.164879	train-logloss:0.178287
# [115]	train-rmse:0.156889	train-logloss:0.168705
# [120]	train-rmse:0.149298	train-logloss:0.159677
# [125]	train-rmse:0.142082	train-logloss:0.151164
# [130]	train-rmse:0.135225	train-logloss:0.143133
# [135]	train-rmse:0.128709	train-logloss:0.135554
# [140]	train-rmse:0.122516	train-logloss:0.128395
# [145]	train-rmse:0.116631	train-logloss:0.121632
# [150]	train-rmse:0.111043	train-logloss:0.115243
# [155]	train-rmse:0.105736	train-logloss:0.109204
# [160]	train-rmse:0.100696	train-logloss:0.103494
# [165]	train-rmse:0.09591	train-logloss:0.098092
# [170]	train-rmse:0.091366	train-logloss:0.09298
# [175]	train-rmse:0.087052	train-logloss:0.088141
# [180]	train-rmse:0.082957	train-logloss:0.083557
# [185]	train-rmse:0.079068	train-logloss:0.079214
# [190]	train-rmse:0.07538	train-logloss:0.0751
# [195]	train-rmse:0.07188	train-logloss:0.071199
# [200]	train-rmse:0.068559	train-logloss:0.0675
# [205]	train-rmse:0.065414	train-logloss:0.063996
# [210]	train-rmse:0.062433	train-logloss:0.060671
# [215]	train-rmse:0.05961	train-logloss:0.05752
# [220]	train-rmse:0.056933	train-logloss:0.054526
# [225]	train-rmse:0.054397	train-logloss:0.051683
# [230]	train-rmse:0.052	train-logloss:0.048985
# [235]	train-rmse:0.049732	train-logloss:0.046424
# [240]	train-rmse:0.047583	train-logloss:0.043984
# [245]	train-rmse:0.045553	train-logloss:0.041667
# [250]	train-rmse:0.043637	train-logloss:0.039465
# [255]	train-rmse:0.041827	train-logloss:0.037365
# [260]	train-rmse:0.040122	train-logloss:0.035147
# [265]	train-rmse:0.038514	train-logloss:0.033256
# [270]	train-rmse:0.036996	train-logloss:0.031449
# [275]	train-rmse:0.035572	train-logloss:0.029732
# [280]	train-rmse:0.034228	train-logloss:0.027965
# [285]	train-rmse:0.032966	train-logloss:0.026321
# [290]	train-rmse:0.031783	train-logloss:0.02462
# [295]	train-rmse:0.030673	train-logloss:0.022875
# [300]	train-rmse:0.029632	train-logloss:0.021346
# [305]	train-rmse:0.028655	train-logloss:0.02005
# [310]	train-rmse:0.027744	train-logloss:0.018544
# [315]	train-rmse:0.026894	train-logloss:0.017227
# [320]	train-rmse:0.026101	train-logloss:0.016009
# [325]	train-rmse:0.025359	train-logloss:0.014886
# [330]	train-rmse:0.024666	train-logloss:0.013639
# [335]	train-rmse:0.024024	train-logloss:0.012402
# [340]	train-rmse:0.023428	train-logloss:0.011181
# [345]	train-rmse:0.022874	train-logloss:0.009623
# [350]	train-rmse:0.022361	train-logloss:0.007998
# [355]	train-rmse:0.021885	train-logloss:0.006929
# [360]	train-rmse:0.021446	train-logloss:0.005454
# [365]	train-rmse:0.02104	train-logloss:0.004118
# [370]	train-rmse:0.020664	train-logloss:0.002982
# [375]	train-rmse:0.020318	train-logloss:0.001873
# [380]	train-rmse:0.020001	train-logloss:0.000811
# [385]	train-rmse:0.019709	train-logloss:-0.00038
# [390]	train-rmse:0.019439	train-logloss:-0.001614
# [395]	train-rmse:0.019188	train-logloss:-0.003382
# [400]	train-rmse:0.018959	train-logloss:-0.004624
# [405]	train-rmse:0.018748	train-logloss:-0.005882
# [410]	train-rmse:0.018553	train-logloss:-0.007509
# [415]	train-rmse:0.018377	train-logloss:-0.008765
# [420]	train-rmse:0.018213	train-logloss:-0.01009
# [425]	train-rmse:0.018063	train-logloss:-0.011771
# [430]	train-rmse:0.017924	train-logloss:-0.013063
# [435]	train-rmse:0.017801	train-logloss:-0.014353
# [440]	train-rmse:0.017683	train-logloss:-0.015921
# [445]	train-rmse:0.017574	train-logloss:-0.017669
# [450]	train-rmse:0.017478	train-logloss:-0.019025
# [455]	train-rmse:0.017387	train-logloss:-0.020889
# [460]	train-rmse:0.017305	train-logloss:-0.022596
# [465]	train-rmse:0.017229	train-logloss:-0.024317
# [470]	train-rmse:0.017158	train-logloss:-0.025906
# [475]	train-rmse:0.017095	train-logloss:-0.027492
# [480]	train-rmse:0.017036	train-logloss:-0.029293
# [485]	train-rmse:0.01698	train-logloss:-0.030762
# [490]	train-rmse:0.016928	train-logloss:-0.033002
# [495]	train-rmse:0.016884	train-logloss:-0.034986
# [500]	train-rmse:0.016839	train-logloss:-0.036914
# [505]	train-rmse:0.016797	train-logloss:-0.038621
# [510]	train-rmse:0.016758	train-logloss:-0.040598
# [515]	train-rmse:0.016721	train-logloss:-0.042675
# [520]	train-rmse:0.016688	train-logloss:-0.044727
# [525]	train-rmse:0.016658	train-logloss:-0.046802
# [530]	train-rmse:0.016627	train-logloss:-0.049334
# [535]	train-rmse:0.016602	train-logloss:-0.051362
# [540]	train-rmse:0.016576	train-logloss:-0.053842
# [545]	train-rmse:0.016552	train-logloss:-0.055817
# [550]	train-rmse:0.016528	train-logloss:-0.057935
# [555]	train-rmse:0.016507	train-logloss:-0.060537
# [560]	train-rmse:0.016486	train-logloss:-0.062478
# [565]	train-rmse:0.016468	train-logloss:-0.064921
# [570]	train-rmse:0.016449	train-logloss:-0.067085
# [575]	train-rmse:0.01643	train-logloss:-0.068876
# [580]	train-rmse:0.016413	train-logloss:-0.070803
# [585]	train-rmse:0.016395	train-logloss:-0.072654
# [590]	train-rmse:0.01638	train-logloss:-0.074703
# [595]	train-rmse:0.016365	train-logloss:-0.076628
# [600]	train-rmse:0.016352	train-logloss:-0.078036
# [605]	train-rmse:0.016338	train-logloss:-0.079252
# [610]	train-rmse:0.016324	train-logloss:-0.080552
# [615]	train-rmse:0.016308	train-logloss:-0.082298
# [620]	train-rmse:0.016294	train-logloss:-0.083627
# [625]	train-rmse:0.016281	train-logloss:-0.085099
# [630]	train-rmse:0.01627	train-logloss:-0.086199
# [635]	train-rmse:0.016257	train-logloss:-0.087309
# [640]	train-rmse:0.016246	train-logloss:-0.088081
# [645]	train-rmse:0.016234	train-logloss:-0.089246
# [650]	train-rmse:0.016222	train-logloss:-0.090369
# [655]	train-rmse:0.016211	train-logloss:-0.090937
# [660]	train-rmse:0.016199	train-logloss:-0.092043
# [665]	train-rmse:0.01619	train-logloss:-0.092518
# [670]	train-rmse:0.016179	train-logloss:-0.093192
# [675]	train-rmse:0.01617	train-logloss:-0.093956
# [680]	train-rmse:0.016158	train-logloss:-0.094407
# [685]	train-rmse:0.016146	train-logloss:-0.095102
# [690]	train-rmse:0.016136	train-logloss:-0.095398
# [695]	train-rmse:0.016128	train-logloss:-0.09581
# [700]	train-rmse:0.016117	train-logloss:-0.096523
# [705]	train-rmse:0.016107	train-logloss:-0.097237
# [710]	train-rmse:0.016099	train-logloss:-0.097372
# [715]	train-rmse:0.016089	train-logloss:-0.097754
# [720]	train-rmse:0.016077	train-logloss:-0.098106
# [725]	train-rmse:0.016068	train-logloss:-0.09872
# [730]	train-rmse:0.016057	train-logloss:-0.099045
# [735]	train-rmse:0.016046	train-logloss:-0.099362
# [740]	train-rmse:0.016037	train-logloss:-0.099876
# [745]	train-rmse:0.016027	train-logloss:-0.100165
# [750]	train-rmse:0.016017	train-logloss:-0.100901
# [755]	train-rmse:0.016006	train-logloss:-0.10115
# [760]	train-rmse:0.015997	train-logloss:-0.101439
# [765]	train-rmse:0.015988	train-logloss:-0.101328
# [770]	train-rmse:0.015978	train-logloss:-0.101654
# [775]	train-rmse:0.015969	train-logloss:-0.101877
# [780]	train-rmse:0.01596	train-logloss:-0.101883
# [785]	train-rmse:0.015951	train-logloss:-0.102148
# [790]	train-rmse:0.015941	train-logloss:-0.102057
# [795]	train-rmse:0.015931	train-logloss:-0.102295
# [799]	train-rmse:0.015923	train-logloss:-0.102438
# 2019-12-30 05:32:05,503 - ALPHA_MIND - INFO - Training time cost 19.82669758796692s
# 2019-12-30 05:32:05,504 - ALPHA_MIND - INFO - best_score = {'best_score': -0.102438}, best_round = 799

# %% [markdown]
# ## 当天数据预测

# %%
# 取调仓日当天的因子数据作为输入.
# total_data_test_excess = train_data[train_data.trade_date == str(ref_date)]
total_data_test_excess = factor_data[factor_data.trade_date == ref_date]

if len(total_data_test_excess) <=0:
    alpha_logger.info('{} HAS NO DATA!!!'.format(ref_date))
    sys.exit()

alpha_logger.info('{0} total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

# 获取调仓日当天的行业, 风险模型和基准权重数据
industry_matrix = industry_total[industry_total.trade_date == ref_date]
benchmark_weight = benchmark_total[benchmark_total.trade_date == ref_date]
risk_matrix = risk_total[risk_total.trade_date == ref_date]

total_data = pd.merge(industry_matrix, benchmark_weight, on=['code'], how='left').fillna(0.)
total_data = pd.merge(total_data, risk_matrix, on=['code'])
alpha_logger.info('{0} type_of_total_data: {1}'.format(ref_date, type(total_data)))
alpha_logger.info('{0} shape_of_total_data: {1}'.format(ref_date, np.shape(total_data)))
    
total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
alpha_logger.info('{0} len_of_total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

# 股票代码
codes = total_data_test_excess.code.values.tolist()
   
# predict
# alpha_logger.info('total_data_test_excess: \n{}'.format(total_data_test_excess[['weight', 'code', 'industry']]))
x_pred = total_data_test_excess[features]
predict_xgboost = xgb_model.predict(best_model, x_pred)
# alpha_logger.info('predict_xgboost: {}'.format(predict_xgboost))

a = np.shape(predict_xgboost)
predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))

# 收益率预测结果    
predict_xgboost_df = pd.DataFrame({'xgb_pre': list(predict_xgboost.reshape(-1))})
predict_xgboost_df['trade_date'] = ref_date
predict_xgboost_df['code'] = codes
predict_xgboost_df['code'] = predict_xgboost_df['code'].apply(lambda x: "{:06d}".format(x) + '.XSHG'
                                                              if len(str(x))==6 and str(x)[0] in '6' 
                                                              else "{:06d}".format(x) + '.XSHE')
# Out:
# 2019-12-30 05:32:05,664 - ALPHA_MIND - INFO - 2019-12-27 00:00:00 total_data_test_excess: 500
# 2019-12-30 05:32:05,679 - ALPHA_MIND - INFO - 2019-12-27 00:00:00 type_of_total_data: <class 'pandas.core.frame.DataFrame'>
# 2019-12-30 05:32:05,679 - ALPHA_MIND - INFO - 2019-12-27 00:00:00 shape_of_total_data: (500, 74)
# 2019-12-30 05:32:05,688 - ALPHA_MIND - INFO - 2019-12-27 00:00:00 len_of_total_data_test_excess: 500
# 2019-12-30 05:32:05,704 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (500, 1)

# %% [markdown]
# ## 获取昨持仓信息

# %%
from data.engines.sqlengine import SQLEngine

# 获取当前持仓
record_engine = SQLEngine('sqlite:///./{}/real_tune_record_without_alpha.db'.format(weekly))

try:
#     pos_record = record_engine.fetch_record('pos_record')
#     previous_pos = pos_record[pos_record['trade_date'] == ref_date_pre]
    previous_pos = record_engine.fetch_record_meta(Record, ref_date_pre)
    
except Exception as e:
    alpha_logger.info('pos_record Exception:{0}'.format(e))
    previous_pos = pd.DataFrame({'trade_date':[], 'weight':[],'industry':[], 'er':[],'code':[]})

alpha_logger.info('previous_pos_data: {0}, pos_len: {1}'.format(ref_date_pre, len(previous_pos)))

# 股票过滤, 组合优化之前过滤掉(未完成)
## 9:00--9:25之间进行涨跌停股票的实时筛选

# 导入昨持仓并与股票池中所有股票合并, 
if len(previous_pos) <= 0:
    current_position = None
else:
    previous_pos = total_data_test_excess[['code']].merge(previous_pos, on=['code'], how='left',).fillna(0)
    current_position = previous_pos.weight.values
alpha_logger.info('previous_pos:\n {}'.format(previous_pos))

# previous_pos = total_data_test_excess[['code']].merge(previous_pos, on=['code'], how='left').fillna(0)
# current_position = previous_pos.weight.values

# print(current_position.shape)
# print(total_data_test_excess.shape)
# print(previous_pos.shape)
# Out:
# 2019-12-30 05:32:05,778 - ALPHA_MIND - INFO - previous_pos_data: 2019-12-26 00:00:00, pos_len: 0
# 2019-12-30 05:32:05,779 - ALPHA_MIND - INFO - previous_pos:
#  Empty DataFrame
# Columns: [trade_date, weight, industry, er, code]
# Index: []

# %% [markdown]
# ## 组合优化

# %%
# Constraintes settings
industry_names = industry_list(industry_name, industry_level)
constraint_risk = ['EARNYILD', 'LIQUIDTY', 'GROWTH', 'SIZE', 'SIZENL', 'BETA', 'MOMENTUM'] + industry_names

total_risk_names = constraint_risk + ['benchmark', 'total']

b_type = []
l_val = []
u_val = []

for name in total_risk_names:
    if name == 'benchmark':
        b_type.append(BoundaryType.RELATIVE)
        l_val.append(0.0)
        u_val.append(1.0)
    elif name == 'total':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-0.0)
        u_val.append(0.0)
    elif name == 'SIZE':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.0)
        u_val.append(1.0)
    elif name == 'SIZENL':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.0)
        u_val.append(1.0)
    elif name in industry_names:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-0.005)
        u_val.append(0.005)
    else:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-2.0)
        u_val.append(2.0)
bounds = create_box_bounds(total_risk_names, b_type, l_val, u_val)

# %%
benchmark_w = total_data_test_excess.weight.values
alpha_logger.info('type_of_benchmark_w: {}, shape_of_benchmark_w: {}'.format(type(benchmark_w), 
                                                                             np.shape(benchmark_w)))
is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))

# 风险模型数据合并
## 组合优化参数
# weight_gap = 0.02
# turn_over_rate = 0.1
total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                 is_in_benchmark,
                                 np.ones_like(is_in_benchmark)],
                                axis=1)

alpha_logger.info('shape_of_total_risk_exp_pre: {}'.format(np.shape(total_risk_exp)))
total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))

constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
alpha_logger.info('constraints: {0} in {1}'.format(np.shape(constraints.risk_targets()), ref_date))

lbound = np.maximum(0., benchmark_w - weight_gap)
ubound = weight_gap + benchmark_w
alpha_logger.info('lbound: {0} in {1}'.format(np.shape(lbound), ref_date))
alpha_logger.info('ubound: {0} in {1}'.format(np.shape(ubound), ref_date))

# 组合优化
executor = NaiveExecutor()
current_pos = pd.DataFrame()

target_pos, _ = er_portfolio_analysis(predict_xgboost, 
                                      total_data_test_excess['industry'].values,
                                      None,
                                      constraints,
                                      False,
                                      benchmark_w,
                                      method='risk_neutral',
                                      lbound=lbound,
                                      ubound=ubound,
                                      turn_over_target=turn_over_rate,
                                      current_position=current_position)
                  
alpha_logger.info('shape_of_target_pos: {}'.format(np.shape(target_pos)))
alpha_logger.info('len_codes:{}'.format(np.shape(codes)))
target_pos['code'] = codes
# alpha_logger.info('target_pos: \n{}'.format(target_pos))

# 换手率计算
executor.set_current(previous_pos)
turn_over_org, current_pos = executor.execute(target_pos=target_pos)
alpha_logger.info('turn_over_org: {}'.format(turn_over_org))
turn_over = turn_over_org / sum(target_pos.weight.values)
alpha_logger.info('turn_over: {}'.format(turn_over))

# 优化后仓位信息
current_pos['trade_date'] = ref_date
alpha_logger.info('{} is finished'.format(ref_date))
# Out:
# 2019-12-30 05:32:05,799 - ALPHA_MIND - INFO - type_of_benchmark_w: <class 'numpy.ndarray'>, shape_of_benchmark_w: (500,)
# 2019-12-30 05:32:05,801 - ALPHA_MIND - INFO - shape_of_total_risk_exp_pre: (500, 37)
# 2019-12-30 05:32:05,802 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (500, 37)
# 2019-12-30 05:32:05,805 - ALPHA_MIND - INFO - constraints: (2, 37) in 2019-12-27 00:00:00
# 2019-12-30 05:32:05,805 - ALPHA_MIND - INFO - lbound: (500,) in 2019-12-27 00:00:00
# 2019-12-30 05:32:05,806 - ALPHA_MIND - INFO - ubound: (500,) in 2019-12-27 00:00:00
# 2019-12-30 05:32:05,818 - ALPHA_MIND - INFO - shape_of_target_pos: (500, 3)
# 2019-12-30 05:32:05,819 - ALPHA_MIND - INFO - len_codes:(500,)
# 2019-12-30 05:32:05,821 - ALPHA_MIND - INFO - turn_over_org: 0.9999300000000002
# 2019-12-30 05:32:05,822 - ALPHA_MIND - INFO - turn_over: 0.9999999999999993
# 2019-12-30 05:32:05,824 - ALPHA_MIND - INFO - 2019-12-27 00:00:00 is finished

# %%
## 修改code格式
## 取TOP N作为真实的下单股票
real_pos = current_pos.sort_values(by='weight', ascending=False)[:50]
real_pos['weight'] = real_pos['weight'] / real_pos['weight'].sum()
real_pos
# Out:
#        weight industry        er    code trade_date
# 481  0.026101       电子  0.008423  603501 2019-12-27
# 252  0.025664     机械设备  0.006470  300450 2019-12-27
# 208  0.024882     医药生物  0.004850    2821 2019-12-27
# 250  0.024474       通信  0.001900  300383 2019-12-27
# 301  0.024313     农林牧渔  0.001548  600298 2019-12-27
# 246  0.024313       传媒  0.003057  300315 2019-12-27
# 390  0.024294     建筑材料  0.002653  600801 2019-12-27
# 132  0.024294       电子  0.002139    2273 2019-12-27
# 226  0.024223       电子  0.007123  300088 2019-12-27
# 461  0.024172     交通运输  0.003986  601872 2019-12-27
# 180  0.023918     食品饮料  0.001971    2507 2019-12-27
# 411  0.023786     电气设备  0.004709  600885 2019-12-27
# 307  0.023471      房地产  0.001945  600325 2019-12-27
# 441  0.023075     有色金属  0.006819  601168 2019-12-27
# 50   0.023045       采掘  0.002366     723 2019-12-27
# 205  0.022984       化工  0.004837    2812 2019-12-27
# 465  0.022943       化工  0.003371  601966 2019-12-27
# 488  0.022750       电子  0.002270  603659 2019-12-27
# 194  0.022608     非银金融  0.004363    2670 2019-12-27
# 145  0.022578      计算机  0.001840    2368 2019-12-27
# 291  0.022558     医药生物  0.003940  600216 2019-12-27
# 114  0.022537       传媒  0.007797    2174 2019-12-27
# 349  0.022446     电气设备  0.003096  600580 2019-12-27
# 221  0.022243      计算机  0.001650  300010 2019-12-27
# 4    0.022192       电子  0.002442      21 2019-12-27
# 7    0.022050     医药生物  0.002795      28 2019-12-27
# 133  0.021948      计算机  0.001786    2280 2019-12-27
# 452  0.021888       汽车  0.004940  601689 2019-12-27
# 402  0.021745     国防军工  0.004523  600862 2019-12-27
# 174  0.021542     轻工制造  0.001949    2489 2019-12-27
# 440  0.021380     公用事业  0.002029  601139 2019-12-27
# 29   0.021329      房地产  0.004674     537 2019-12-27
# 56   0.021085     有色金属  0.003052     758 2019-12-27
# 106  0.021065     医药生物  0.005444    2118 2019-12-27
# 429  0.020994       钢铁  0.001654  601003 2019-12-27
# 160  0.020903     商业贸易  0.003770    2416 2019-12-27
# 127  0.020628       化工  0.002180    2250 2019-12-27
# 155  0.019715     医药生物  0.002496    2399 2019-12-27
# 413  0.018426     非银金融  0.002210  600901 2019-12-27
# 251  0.016031       传媒  0.003052  300418 2019-12-27
# 265  0.012517     家用电器  0.002816  600060 2019-12-27
# 284  0.012294     公用事业  0.001426  600167 2019-12-27
# 397  0.012081     机械设备  0.001559  600835 2019-12-27
# 2    0.011837       综合  0.030812       9 2019-12-27
# 379  0.011634     休闲服务  0.004949  600754 2019-12-27
# 477  0.010497     食品饮料  0.000973  603369 2019-12-27
# 394  0.009665     建筑装饰  0.001156  600820 2019-12-27
# 305  0.006974     国防军工  0.002243  600316 2019-12-27
# 486  0.006589     交通运输  0.001381  603569 2019-12-27
# 156  0.005319      计算机  0.001340    2405 2019-12-27

# %%
## 保存记录当前持仓信息, 写入数据库
previous_record = record_engine.fetch_record_meta(Record, ref_date)
if len(previous_record) == 0:
    record_engine.write_data('pos_record', real_pos)
else:
    record_engine.del_historical_data(Record, ref_date)  # 删除同日期的历史数据
    tmp_record = record_engine.fetch_record_meta(Record, ref_date)
    if len(tmp_record) == 0:  # 删除成功
        record_engine.write_data('pos_record', real_pos)
    else:
        print('{} 的数据没有删除: {}'.format(ref_date, len(previous_record)))

# %%
# 生成交易记录
## 修改code格式
real_pos['code'] = real_pos['code'].apply(lambda x: "{:06d}".format(x) + '.SH' 
                                          if len(str(x))==6 and str(x)[0] in '6' 
                                          else "{:06d}".format(x) + '.SZ')

real_pos = real_pos.loc[:, ['code', 'weight', 'trade_date']]
real_pos.rename(columns={"code": "证券代码", "weight": "持仓权重", "trade_date": "成分日期"}, inplace=True)
real_pos['交易价格'] = 0

real_pos = real_pos[['证券代码', '持仓权重', '交易价格', '成分日期']].copy()
real_pos.to_csv('./{}/every_day_{}.csv'.format(weekly, end_date), encoding='utf_8_sig', index=False)

# %%
# 查看持仓记录
current_record = record_engine.fetch_record_meta(Record, ref_date)
# current_record = current_record[current_record['trade_date'] == ref_date]
current_record
# Out:
#                     trade_date    weight industry        er    code
# 0   2019-12-27 00:00:00.000000  0.026101       电子  0.008423  603501
# 1   2019-12-27 00:00:00.000000  0.025664     机械设备  0.006470  300450
# 2   2019-12-27 00:00:00.000000  0.024882     医药生物  0.004850    2821
# 3   2019-12-27 00:00:00.000000  0.024474       通信  0.001900  300383
# 4   2019-12-27 00:00:00.000000  0.024313     农林牧渔  0.001548  600298
# 5   2019-12-27 00:00:00.000000  0.024313       传媒  0.003057  300315
# 6   2019-12-27 00:00:00.000000  0.024294     建筑材料  0.002653  600801
# 7   2019-12-27 00:00:00.000000  0.024294       电子  0.002139    2273
# 8   2019-12-27 00:00:00.000000  0.024223       电子  0.007123  300088
# 9   2019-12-27 00:00:00.000000  0.024172     交通运输  0.003986  601872
# 10  2019-12-27 00:00:00.000000  0.023918     食品饮料  0.001971    2507
# 11  2019-12-27 00:00:00.000000  0.023786     电气设备  0.004709  600885
# 12  2019-12-27 00:00:00.000000  0.023471      房地产  0.001945  600325
# 13  2019-12-27 00:00:00.000000  0.023075     有色金属  0.006819  601168
# 14  2019-12-27 00:00:00.000000  0.023045       采掘  0.002366     723
# 15  2019-12-27 00:00:00.000000  0.022984       化工  0.004837    2812
# 16  2019-12-27 00:00:00.000000  0.022943       化工  0.003371  601966
# 17  2019-12-27 00:00:00.000000  0.022750       电子  0.002270  603659
# 18  2019-12-27 00:00:00.000000  0.022608     非银金融  0.004363    2670
# 19  2019-12-27 00:00:00.000000  0.022578      计算机  0.001840    2368
# 20  2019-12-27 00:00:00.000000  0.022558     医药生物  0.003940  600216
# 21  2019-12-27 00:00:00.000000  0.022537       传媒  0.007797    2174
# 22  2019-12-27 00:00:00.000000  0.022446     电气设备  0.003096  600580
# 23  2019-12-27 00:00:00.000000  0.022243      计算机  0.001650  300010
# 24  2019-12-27 00:00:00.000000  0.022192       电子  0.002442      21
# 25  2019-12-27 00:00:00.000000  0.022050     医药生物  0.002795      28
# 26  2019-12-27 00:00:00.000000  0.021948      计算机  0.001786    2280
# 27  2019-12-27 00:00:00.000000  0.021888       汽车  0.004940  601689
# 28  2019-12-27 00:00:00.000000  0.021745     国防军工  0.004523  600862
# 29  2019-12-27 00:00:00.000000  0.021542     轻工制造  0.001949    2489
# 30  2019-12-27 00:00:00.000000  0.021380     公用事业  0.002029  601139
# 31  2019-12-27 00:00:00.000000  0.021329      房地产  0.004674     537
# 32  2019-12-27 00:00:00.000000  0.021085     有色金属  0.003052     758
# 33  2019-12-27 00:00:00.000000  0.021065     医药生物  0.005444    2118
# 34  2019-12-27 00:00:00.000000  0.020994       钢铁  0.001654  601003
# 35  2019-12-27 00:00:00.000000  0.020903     商业贸易  0.003770    2416
# 36  2019-12-27 00:00:00.000000  0.020628       化工  0.002180    2250
# 37  2019-12-27 00:00:00.000000  0.019715     医药生物  0.002496    2399
# 38  2019-12-27 00:00:00.000000  0.018426     非银金融  0.002210  600901
# 39  2019-12-27 00:00:00.000000  0.016031       传媒  0.003052  300418
# 40  2019-12-27 00:00:00.000000  0.012517     家用电器  0.002816  600060
# 41  2019-12-27 00:00:00.000000  0.012294     公用事业  0.001426  600167
# 42  2019-12-27 00:00:00.000000  0.012081     机械设备  0.001559  600835
# 43  2019-12-27 00:00:00.000000  0.011837       综合  0.030812       9
# 44  2019-12-27 00:00:00.000000  0.011634     休闲服务  0.004949  600754
# 45  2019-12-27 00:00:00.000000  0.010497     食品饮料  0.000973  603369
# 46  2019-12-27 00:00:00.000000  0.009665     建筑装饰  0.001156  600820
# 47  2019-12-27 00:00:00.000000  0.006974     国防军工  0.002243  600316
# 48  2019-12-27 00:00:00.000000  0.006589     交通运输  0.001381  603569
# 49  2019-12-27 00:00:00.000000  0.005319      计算机  0.001340    2405

# %%
current_record['trade_date'][0]
# Out:
# '2019-12-27 00:00:00.000000'
