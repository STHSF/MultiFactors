# %% [markdown]
# # 基础因子加alpha191回测结果

# %% [markdown]
# 添加费后曲线

# %%
# %matplotlib inline
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../../')
import pandas as pd
from PyFin.api import *
from alphamind.api import *
from src.conf.models import *
from datetime import datetime, timedelta
import sqlite3
import numpy as np
from alphamind.execution.naiveexecutor import NaiveExecutor
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %% [markdown]
# ### 导入调仓记录

# %%
con = sqlite3.connect('./tune_record.db')
sql = 'select * from tune_record_loose' # 回测时间: 2010-01~2019-10, 组合优化条件宽松
# sql = 'select * from tune_record__whole_loose' # 回测时间: 2010-01~2019-10, 组合优化条件较松

# sql = 'select * from tune_record_strict' # 回测时间: 2017-01~2019-10, 组合优化条件严格, 
# sql = 'select * from tune_record_whole_strict' # 回测时间: 2010-01~2019-10, 组合优化条件严格

tune_record = pd.read_sql(sql, con)

# %% [markdown]
# ## 回测参数设置

# %%
# 资金总量
total_funds = 2000000000

# %%
 ##--------------因子组合回测--------------
import json
import pdb
from rqalpha.api import *
from rqalpha import run_func
class DailyDefaultStrategy(object):
    def __init__(self, session, stock_sets_ob):
        self._stock_sets_ob = json.loads(stock_sets_ob)
        self._session = session
        self._start_time_str = datetime.now().strftime('%m-%d %H:%M')
    
    
    def init(self,context):
        #读取股票池文件
        context.stock_sets = pd.DataFrame(self._stock_sets_ob)
        context.trade_date_list= list(set(context.stock_sets.trade_date))
        context.holding_stock_df = None
        
        # 是否已发送了order
        context.fired = False

    #盘前处理
    def before_trading(self, context, bar_dict):
        context.trade_signal = False
        date = context.now.date()
        if str(date) in context.trade_date_list:
            context.trade_signal = True

    #盘后处理
    def after_trading(self, context):
        pass
    
    # 你选择的证券的数据更新将会触发此段逻辑，例如日或分钟历史数据切片或者是实时数据切片更新
    def handle_bar(self, context, bar_dict):
        # 开始编写你的主要的算法逻辑
        if context.trade_signal == False:
            return
        date = context.now.date()
        # stock_dict = context.stock_sets.set_index('trade_date').loc[str(date)]
        stock_set = context.stock_sets
        stock_dict = stock_set[stock_set['trade_date'] == str(date)].set_index('trade_date')
        stock_df = self.filter_specials(stock_dict, context)
        #剔除后的股票
        if 'portfolio_weight' in list(set(stock_df.columns)):
            self.rebalance_weight(context, stock_df)
        else:
            self.rebalance_equal(context, stock_df)
   
    def _industry_distribute(self, stock_positions, industries):
        industry_sets_dict = {}
        industries = industries.rename(columns={'symbol':'code'})
        stock_positions = stock_positions.reset_index().rename(
            columns={'symbol':'name','order_book_id':'code','date':'trade_date'})
        stock_positions['trade_date'] = stock_positions['trade_date'].apply(lambda x: x.strftime('%Y-%m-%d'))
        industries['trade_date'] = industries['trade_date'].apply(lambda x: x.strftime('%Y-%m-%d'))
        stock_positions = stock_positions.merge(industries, on=['trade_date','code'])
        industry_grouped = stock_positions.dropna().groupby(['trade_date'])
        for k, g in industry_grouped:
            gt = g.groupby(['industry_code','industry']).count().reset_index()[['industry_code','industry','code']]
            gt['ratio'] = gt['code']/gt['code'].values.sum()
            gt=gt.rename(columns={'industry':'industry_name'})
            industry_sets_dict[k] = gt[['industry_code','industry_name','ratio']].to_dict(orient='records')
        return industry_sets_dict
    
    def _month_profit(self, portfolio, stock_capital):
        pd.DataFrame(portfolio.reset_index()).shift(1)
        month_profit = portfolio['total_value'].resample('M').mean()
        month_profit = pd.DataFrame(month_profit.reset_index())
        month_profit['last_total'] = month_profit['total_value'].shift(1)
        month_profit = month_profit.fillna(stock_capital)
        month_profit['month_ratio'] = np.log(month_profit.total_value / month_profit.last_total)
        return month_profit.rename(columns={'date':'trade_date'})
    
    def set_result(self, result):
        #summary 结算信息
        summary = result['sys_analyser']['summary']
        #trades 交易记录
        trades = result['sys_analyser']['trades']
        #portfolio 收益曲线
        portfolio = result['sys_analyser']['portfolio']
        # benchmark_portfolio 基础收益曲线benchmark_portfolio
        benchmark_portfolio = result['sys_analyser']['benchmark_portfolio']
        # stock_account 个人收益
        stock_account = result['sys_analyser']['stock_account']
        # stock_positions 股票持仓情况
        stock_positions = result['sys_analyser']['stock_positions']
        
        
    def filter_specials(self, stock_dict, context):
        stock_df = pd.DataFrame(stock_dict)
        stock_list = list(stock_df.code)
        stock_list=[stock for stock in stock_list]
        
        return stock_df.set_index('code').loc[stock_list,:] 
    
    def rebalance_equal(self, context, stock_df):
        holding_list = list(set(stock_df.index))
        if len(holding_list) > 0:
            every_stock = context.portfolio.portfolio_value/len(holding_list) 
        # 空仓只有买入操作
        if len(list(context.portfolio.positions.keys()))==0:
            for stock_to_buy in list(holding_list):
                #print(stock_to_buy)
                order_target_value(stock_to_buy,every_stock)
        else:
            for stock_to_sell in list(context.portfolio.positions.keys()):
                if stock_to_sell not in list(holding_list):
                    order_target_value(stock_to_sell, 0)
            for stock_to_buy in list(holding_list):
                order_target_value(stock_to_buy, every_stock)
                
        
    def rebalance_weight(self, context, stock_df):
        #没有持仓则全部下单
        if len(list(context.portfolio.positions.keys())) == 0:
            weight_sum = stock_df.portfolio_weight.sum()
            every_values = context.portfolio.total_value / weight_sum
            for index, weight in stock_df.iterrows():
                order_target_value(index, weight.portfolio_weight * every_values)
            context.holding_stock_df = stock_df
        else:
            now_df = context.holding_stock_df #当前持有的股票
            # 做交集查看上次实际成交股票
            intersect = list(set(now_df.index).intersection(set(context.portfolio.stock_account.positions.keys())))
            if len(intersect) <= 0:
                now_df = pd.DataFrame({'now_weight':[]})
            else:
                now_df = now_df.loc[context.portfolio.stock_account.positions.keys()]
                now_df = now_df.rename(columns={'portfolio_weight':'now_weight'}) #持仓
            # 做并集
            stock_df = stock_df.rename(columns={'portfolio_weight':'next_weight'}) #调仓
            now_df = pd.merge(now_df, stock_df, left_index=True, right_index=True, how='outer')
            now_df = now_df.fillna(0)
            now_df['diff_weight'] = now_df.next_weight - now_df.now_weight #调仓股票和持仓股票进行对比
            buy_stock = now_df[now_df['diff_weight'] > 0] #当前需买进
            sell_stock = now_df[now_df['diff_weight'] < 0]
            
            # 根据当前权重分配，目的是持仓达到和调仓的权重一样
            weight_sum = stock_df.next_weight.sum()
            every_values = context.portfolio.total_value/ weight_sum
            
            # 平掉不需要股票
            for index, weight in sell_stock.iterrows():
                if weight.now_weight == abs(weight.diff_weight): #全部清仓
                    order_target_value(index, 0)
                else:# 调整权重，此处会有误差，每期的every_values不一样
                    order_target_value(index, weight.diff_weight * every_values)
            # 新建增仓
            for index, weight in buy_stock.iterrows():
                order_target_value(index, abs(weight.diff_weight) * every_values)
            stock_df = stock_df.rename(columns={'next_weight':'portfolio_weight'})
            context.holding_stock_df = stock_df

# %%
def ricequant_backtesting(conmbine):
    benchmark_info = '000905.XSHG'
    conmbine = conmbine.copy()
    conmbine['trade_date'] = conmbine['trade_date'].apply(lambda x: x.split(' ')[0] if type(x) is str else x.date().strftime("%Y-%m-%d"))
    #stk_result = stk_data[stk_data['portfolio_weight']>0.001]#.set_index('trade_date').loc['2018-04-12']
    conmbine['code'] = conmbine['code'].apply(lambda x: "{:06d}".format(x) + '.XSHG' 
                                              if len(str(x))==6 and str(x)[0] in '6' 
                                              else "{:06d}".format(x)+ '.XSHE')
    backtesting = DailyDefaultStrategy(1234412, json.dumps(conmbine.to_dict(orient='records')))
    trade_date_list = list(set(conmbine.trade_date))
    trade_date_list.sort(reverse=False)
    base_config = {}
    base_config['start_date'] = trade_date_list[0]
    base_config['end_date'] = trade_date_list[-1]
    base_config['benchmark'] = benchmark_info
            
    accounts_config = {}
    accounts_config['stock'] = total_funds
    base_config['accounts'] = accounts_config
    base_config['frequency'] = '1d'
    base_config['skip_suspended'] = True
    
    extra_config = {}

    mod_config = {}
    sys_analyser_config = {}
    sys_analyser_config['enabled'] = True
    sys_analyser_config['plot'] = True
    mod_config['sys_analyser'] = sys_analyser_config
        
    config = {}
    config['base'] = base_config
    config['extra'] = extra_config
    config['mod'] = mod_config
    result = run_func(init=backtesting.init, before_trading=backtesting.before_trading, 
                  after_trading=backtesting.after_trading, handle_bar=backtesting.handle_bar, config=config)
    return result

# %%
# %matplotlib inline
tune_record  = tune_record.rename(columns={'weight':'portfolio_weight'})
# 筛选到权重小的股票
tune_record = tune_record[tune_record['portfolio_weight'] >= 0.05]
result = ricequant_backtesting(tune_record[['trade_date','code','portfolio_weight']])
# Out:
# 2017-01-03 WARN [Deprecated]在before_trading函数中，第二个参数bar_dict已经不再使用了。
# 2017-01-03 WARN 订单被拒单: [000547.XSHE] 已涨停。
# 2017-01-03 WARN 002122.XSHE 下单量 8591300 超过当前 Bar 成交量的 25.0%，实际成交 2978400.0
# 2017-01-10 WARN 600053.XSHG 下单量 18787800 超过当前 Bar 成交量的 25.0%，实际成交 394900.0
# 2017-01-10 WARN 600597.XSHG 下单量 87057100 超过当前 Bar 成交量的 25.0%，实际成交 1186400.0
# 2017-01-17 WARN 600597.XSHG 下单量 1186400.0 超过当前 Bar 成交量的 25.0%，实际成交 616300.0
# 2017-01-17 WARN 002595.XSHE 下单量 13754000 超过当前 Bar 成交量的 25.0%，实际成交 173500.0
# 2017-01-17 WARN 603528.XSHG 下单量 28991300 超过当前 Bar 成交量的 25.0%，实际成交 346400.0
# 2017-01-24 WARN 002368.XSHE 下单量 67167800 超过当前 Bar 成交量的 25.0%，实际成交 2584400.0
# 2017-02-07 WARN 002368.XSHE 下单量 2584400.0 超过当前 Bar 成交量的 25.0%，实际成交 578300.0
# 2017-02-07 WARN 订单创建失败: 600859.XSHG 在 2017-02-07 15:00:00 时停牌
# 2017-02-14 WARN 订单创建失败: 600161.XSHG 在 2017-02-14 15:00:00 时停牌
# 2017-02-14 WARN 订单创建失败: 600171.XSHG 在 2017-02-14 15:00:00 时停牌
# 2017-02-14 WARN 订单创建失败: 600736.XSHG 在 2017-02-14 15:00:00 时停牌
# 2017-02-21 WARN 002161.XSHE 下单量 42022300 超过当前 Bar 成交量的 25.0%，实际成交 1517900.0
# 2017-02-21 WARN 订单创建失败: 600736.XSHG 在 2017-02-21 15:00:00 时停牌
# 2017-02-28 WARN 002161.XSHE 下单量 1517900.0 超过当前 Bar 成交量的 25.0%，实际成交 1357300.0
# 2017-02-28 WARN 002642.XSHE 下单量 7422000 超过当前 Bar 成交量的 25.0%，实际成交 1682200.0
# 2017-02-28 WARN 603866.XSHG 下单量 43670100 超过当前 Bar 成交量的 25.0%，实际成交 63100.0
# 2017-03-07 WARN 订单创建失败: 002745.XSHE 在 2017-03-07 15:00:00 时停牌
# 2017-03-14 WARN 订单创建失败: 002745.XSHE 在 2017-03-14 15:00:00 时停牌
# 2017-03-14 WARN 订单创建失败: 600655.XSHG 在 2017-03-14 15:00:00 时停牌
# 2017-03-21 WARN 订单创建失败: 002505.XSHE 在 2017-03-21 15:00:00 时停牌
# 2017-03-21 WARN 订单创建失败: 600859.XSHG 在 2017-03-21 15:00:00 时停牌
# 2017-03-28 WARN 002399.XSHE 下单量 57022600 超过当前 Bar 成交量的 25.0%，实际成交 605000.0
# 2017-03-28 WARN 订单创建失败: 002670.XSHE 在 2017-03-28 15:00:00 时停牌
# 2017-04-06 WARN 订单被拒单: [000401.XSHE] 已涨停。
# 2017-04-06 WARN 订单被拒单: [002342.XSHE] 已涨停。
# 2017-04-06 WARN 订单被拒单: [600717.XSHG] 已涨停。
# 2017-04-13 WARN 订单被拒单: [002233.XSHE] 已涨停。
# 2017-04-13 WARN 订单创建失败: 601000.XSHG 在 2017-04-13 15:00:00 时停牌
# 2017-04-20 WARN 订单创建失败: 002505.XSHE 在 2017-04-20 15:00:00 时停牌
# 2017-04-20 WARN 600425.XSHG 下单量 284246800 超过当前 Bar 成交量的 25.0%，实际成交 12561800.0
# 2017-04-27 WARN 000690.XSHE 下单量 276998600 超过当前 Bar 成交量的 25.0%，实际成交 24561000.0
# 2017-04-27 WARN 002407.XSHE 下单量 11605500 超过当前 Bar 成交量的 25.0%，实际成交 5826700.0
# 2017-05-05 WARN 000690.XSHE 下单量 24561000.0 超过当前 Bar 成交量的 25.0%，实际成交 3586100.0
# 2017-05-05 WARN 002407.XSHE 下单量 5826700.0 超过当前 Bar 成交量的 25.0%，实际成交 3279300.0
# 2017-05-05 WARN 订单创建失败: 002505.XSHE 在 2017-05-05 15:00:00 时停牌
# 2017-05-05 WARN 600112.XSHG 下单量 112691800 超过当前 Bar 成交量的 25.0%，实际成交 5986900.0
# 2017-05-05 WARN 600575.XSHG 下单量 36448000 超过当前 Bar 成交量的 25.0%，实际成交 2637700.0
# 2017-05-12 WARN 600112.XSHG 下单量 5986900.0 超过当前 Bar 成交量的 25.0%，实际成交 2270500.0
# 2017-05-12 WARN 000547.XSHE 下单量 39197600 超过当前 Bar 成交量的 25.0%，实际成交 3718200.0
# 2017-05-12 WARN 订单创建失败: 002505.XSHE 在 2017-05-12 15:00:00 时停牌
# 2017-05-12 WARN 600575.XSHG 下单量 53656700 超过当前 Bar 成交量的 25.0%，实际成交 1853000.0
# 2017-05-19 WARN 600575.XSHG 下单量 4490700.0 超过当前 Bar 成交量的 25.0%，实际成交 2003500.0
# 2017-05-19 WARN 000616.XSHE 下单量 73620800 超过当前 Bar 成交量的 25.0%，实际成交 3126600.0
# 2017-05-19 WARN 002051.XSHE 下单量 9622400 超过当前 Bar 成交量的 25.0%，实际成交 3738800.0
# 2017-05-19 WARN 订单创建失败: 002505.XSHE 在 2017-05-19 15:00:00 时停牌
# 2017-05-26 WARN 002051.XSHE 下单量 3738800.0 超过当前 Bar 成交量的 25.0%，实际成交 2306800.0
# 2017-05-26 WARN 订单被拒单: [002342.XSHE] 已涨停。
# 2017-05-26 WARN 订单创建失败: 002505.XSHE 在 2017-05-26 15:00:00 时停牌
# 2017-06-06 WARN 订单创建失败: 300291.XSHE 在 2017-06-06 15:00:00 时停牌
# 2017-06-06 WARN 600575.XSHG 下单量 57592400 超过当前 Bar 成交量的 25.0%，实际成交 1017100.0
# 2017-06-13 WARN 600575.XSHG 下单量 3504300.0 超过当前 Bar 成交量的 25.0%，实际成交 1043600.0
# 2017-06-13 WARN 订单创建失败: 002358.XSHE 在 2017-06-13 15:00:00 时停牌
# 2017-06-20 WARN 订单创建失败: 002358.XSHE 在 2017-06-20 15:00:00 时停牌
# 2017-06-27 WARN 订单创建失败: 002358.XSHE 在 2017-06-27 15:00:00 时停牌
# 2017-07-04 WARN 订单创建失败: 002358.XSHE 在 2017-07-04 15:00:00 时停牌
# 2017-07-11 WARN 订单创建失败: 002358.XSHE 在 2017-07-11 15:00:00 时停牌
# 2017-07-18 WARN 000616.XSHE 下单量 50225100 超过当前 Bar 成交量的 25.0%，实际成交 2999300.0
# 2017-07-18 WARN 订单创建失败: 002122.XSHE 在 2017-07-18 15:00:00 时停牌
# 2017-07-18 WARN 订单创建失败: 002505.XSHE 在 2017-07-18 15:00:00 时停牌
# 2017-07-25 WARN 订单创建失败: 601717.XSHG 在 2017-07-25 15:00:00 时停牌
# 2017-08-01 WARN 订单创建失败: 600460.XSHG 在 2017-08-01 15:00:00 时停牌
# 2017-08-08 WARN 订单被拒单: [000600.XSHE] 已涨停。
# 2017-08-08 WARN 订单创建失败: 600460.XSHG 在 2017-08-08 15:00:00 时停牌
# 2017-08-15 WARN 订单被拒单: [002128.XSHE] 已涨停。
# 2017-08-15 WARN 订单被拒单: [002373.XSHE] 已涨停。
# 2017-08-15 WARN 600086.XSHG 下单量 16811200 超过当前 Bar 成交量的 25.0%，实际成交 1875600.0
# 2017-08-22 WARN 订单创建失败: 002373.XSHE 在 2017-08-22 15:00:00 时停牌
# 2017-08-22 WARN 订单创建失败: 300291.XSHE 在 2017-08-22 15:00:00 时停牌
# 2017-08-22 WARN 600525.XSHG 下单量 23817400 超过当前 Bar 成交量的 25.0%，实际成交 4763600.0
# 2017-08-29 WARN 订单创建失败: 002373.XSHE 在 2017-08-29 15:00:00 时停牌
# 2017-08-29 WARN 订单创建失败: 002505.XSHE 在 2017-08-29 15:00:00 时停牌
# 2017-09-05 WARN 订单创建失败: 002505.XSHE 在 2017-09-05 15:00:00 时停牌
# 2017-09-05 WARN 订单被拒单: [600496.XSHG] 已涨停。
# 2017-09-12 WARN 订单创建失败: 002373.XSHE 在 2017-09-12 15:00:00 时停牌
# 2017-09-19 WARN 订单创建失败: 002373.XSHE 在 2017-09-19 15:00:00 时停牌
# 2017-09-26 WARN 订单创建失败: 002373.XSHE 在 2017-09-26 15:00:00 时停牌
# 2017-10-10 WARN 订单被拒单: [000572.XSHE] 已涨停。
# 2017-10-10 WARN 订单创建失败: 002373.XSHE 在 2017-10-10 15:00:00 时停牌
# 2017-10-17 WARN 订单创建失败: 002373.XSHE 在 2017-10-17 15:00:00 时停牌
# 2017-10-24 WARN 订单创建失败: 002373.XSHE 在 2017-10-24 15:00:00 时停牌
# 2017-10-31 WARN 订单创建失败: 002373.XSHE 在 2017-10-31 15:00:00 时停牌
# 2017-11-07 WARN 订单创建失败: 002373.XSHE 在 2017-11-07 15:00:00 时停牌
# 2017-11-14 WARN 订单创建失败: 002373.XSHE 在 2017-11-14 15:00:00 时停牌
# 2017-11-21 WARN 订单创建失败: 002373.XSHE 在 2017-11-21 15:00:00 时停牌
# 2017-11-28 WARN 订单被拒单: [002373.XSHE] 已涨停。
# 2017-11-28 WARN 300291.XSHE 下单量 8806200 超过当前 Bar 成交量的 25.0%，实际成交 2785500.0
# 2017-12-05 WARN 300291.XSHE 下单量 2785500.0 超过当前 Bar 成交量的 25.0%，实际成交 1999600.0
# 2017-12-05 WARN 002366.XSHE 下单量 63053800 超过当前 Bar 成交量的 25.0%，实际成交 2513500.0
# 2017-12-12 WARN 订单创建失败: 002366.XSHE 在 2017-12-12 15:00:00 时停牌
# 2017-12-12 WARN 000652.XSHE 下单量 358230700 超过当前 Bar 成交量的 25.0%，实际成交 1161900.0
# 2017-12-26 WARN 订单创建失败: 300032.XSHE 在 2017-12-26 15:00:00 时停牌
# 2017-12-26 WARN 600171.XSHG 下单量 31073700 超过当前 Bar 成交量的 25.0%，实际成交 15109600.0
# 2017-12-26 WARN 601233.XSHG 下单量 11806900 超过当前 Bar 成交量的 25.0%，实际成交 4516700.0
# 2018-01-03 WARN 600171.XSHG 下单量 15109600.0 超过当前 Bar 成交量的 25.0%，实际成交 11057800.0
# 2018-01-03 WARN 000039.XSHE 下单量 8806300 超过当前 Bar 成交量的 25.0%，实际成交 6583600.0
# 2018-01-03 WARN 600289.XSHG 下单量 156546800 超过当前 Bar 成交量的 25.0%，实际成交 9000.0
# 2018-01-10 WARN 000039.XSHE 下单量 6583600.0 超过当前 Bar 成交量的 25.0%，实际成交 3890700.0
# 2018-01-10 WARN 订单被拒单: [600289.XSHG] 已跌停。
# 2018-01-10 WARN 订单创建失败: 300032.XSHE 在 2018-01-10 15:00:00 时停牌
# 2018-01-10 WARN 600183.XSHG 下单量 31236600 超过当前 Bar 成交量的 25.0%，实际成交 8716000.0
# 2018-01-17 WARN 600183.XSHG 下单量 8716000.0 超过当前 Bar 成交量的 25.0%，实际成交 7855200.0
# 2018-01-17 WARN 订单创建失败: 300032.XSHE 在 2018-01-17 15:00:00 时停牌
# 2018-01-17 WARN 600289.XSHG 下单量 201726900 超过当前 Bar 成交量的 25.0%，实际成交 372200.0
# 2018-01-17 WARN 601233.XSHG 下单量 12701700 超过当前 Bar 成交量的 25.0%，实际成交 6465200.0
# 2018-01-24 WARN 601233.XSHG 下单量 6465200.0 超过当前 Bar 成交量的 25.0%，实际成交 5294500.0
# 2018-01-24 WARN 002285.XSHE 下单量 29546500 超过当前 Bar 成交量的 25.0%，实际成交 9775700.0
# 2018-01-24 WARN 订单创建失败: 300032.XSHE 在 2018-01-24 15:00:00 时停牌
# 2018-01-24 WARN 订单创建失败: 600187.XSHG 在 2018-01-24 15:00:00 时停牌
# 2018-01-31 WARN 002285.XSHE 下单量 9775700.0 超过当前 Bar 成交量的 25.0%，实际成交 8887200.0
# 2018-01-31 WARN 订单创建失败: 300032.XSHE 在 2018-01-31 15:00:00 时停牌
# 2018-01-31 WARN 600289.XSHG 下单量 209186500 超过当前 Bar 成交量的 25.0%，实际成交 425400.0
# 2018-01-31 WARN 600426.XSHG 下单量 12086900 超过当前 Bar 成交量的 25.0%，实际成交 9433500.0
# 2018-02-07 WARN 订单被拒单: [600289.XSHG] 已跌停。
# 2018-02-07 WARN 订单被拒单: [600053.XSHG] 已涨停。
# 2018-02-07 WARN 600438.XSHG 下单量 60842900 超过当前 Bar 成交量的 25.0%，实际成交 8485300.0
# 2018-02-14 WARN 600438.XSHG 下单量 8485300.0 超过当前 Bar 成交量的 25.0%，实际成交 7485700.0
# 2018-02-14 WARN 订单创建失败: 002004.XSHE 在 2018-02-14 15:00:00 时停牌
# 2018-02-14 WARN 603444.XSHG 下单量 3387300 超过当前 Bar 成交量的 25.0%，实际成交 222100.0
# 2018-02-28 WARN 603444.XSHG 下单量 222100.0 超过当前 Bar 成交量的 25.0%，实际成交 209700.0
# 2018-02-28 WARN 订单创建失败: 002005.XSHE 在 2018-02-28 15:00:00 时停牌
# 2018-02-28 WARN 订单创建失败: 300032.XSHE 在 2018-02-28 15:00:00 时停牌
# 2018-03-07 WARN 订单创建失败: 000031.XSHE 在 2018-03-07 15:00:00 时停牌
# 2018-03-07 WARN 订单创建失败: 002005.XSHE 在 2018-03-07 15:00:00 时停牌
# 2018-03-14 WARN 订单创建失败: 002005.XSHE 在 2018-03-14 15:00:00 时停牌
# 2018-03-14 WARN 300297.XSHE 下单量 51612500 超过当前 Bar 成交量的 25.0%，实际成交 2166100.0
# 2018-03-21 WARN 300297.XSHE 下单量 2166100.0 超过当前 Bar 成交量的 25.0%，实际成交 1574100.0
# 2018-03-21 WARN 订单创建失败: 002005.XSHE 在 2018-03-21 15:00:00 时停牌
# 2018-03-21 WARN 订单创建失败: 300032.XSHE 在 2018-03-21 15:00:00 时停牌
# 2018-03-28 WARN 订单创建失败: 002005.XSHE 在 2018-03-28 15:00:00 时停牌
# 2018-03-28 WARN 002635.XSHE 下单量 26658200 超过当前 Bar 成交量的 25.0%，实际成交 4287600.0
# 2018-04-04 WARN 002635.XSHE 下单量 4287600.0 超过当前 Bar 成交量的 25.0%，实际成交 2541700.0
# 2018-04-04 WARN 订单创建失败: 002005.XSHE 在 2018-04-04 15:00:00 时停牌
# 2018-04-04 WARN 300088.XSHE 下单量 68338600 超过当前 Bar 成交量的 25.0%，实际成交 9895600.0
# 2018-04-13 WARN 300088.XSHE 下单量 9895600.0 超过当前 Bar 成交量的 25.0%，实际成交 5378100.0
# 2018-04-13 WARN 订单创建失败: 000766.XSHE 在 2018-04-13 15:00:00 时停牌
# 2018-04-13 WARN 订单创建失败: 002005.XSHE 在 2018-04-13 15:00:00 时停牌
# 2018-04-13 WARN 订单创建失败: 300032.XSHE 在 2018-04-13 15:00:00 时停牌
# 2018-04-20 WARN 订单创建失败: 300032.XSHE 在 2018-04-20 15:00:00 时停牌
# 2018-04-20 WARN 600651.XSHG 下单量 217508400 超过当前 Bar 成交量的 25.0%，实际成交 4690800.0
# 2018-04-27 WARN 600575.XSHG 下单量 38629100 超过当前 Bar 成交量的 25.0%，实际成交 1819400.0
# 2018-04-27 WARN 600651.XSHG 下单量 70595100 超过当前 Bar 成交量的 25.0%，实际成交 4367800.0
# 2018-05-08 WARN 600575.XSHG 下单量 4280100.0 超过当前 Bar 成交量的 25.0%，实际成交 1568300.0
# 2018-05-08 WARN 600651.XSHG 下单量 9058600.0 超过当前 Bar 成交量的 25.0%，实际成交 1831200.0
# 2018-05-08 WARN 订单创建失败: 002437.XSHE 在 2018-05-08 15:00:00 时停牌
# 2018-05-15 WARN 000807.XSHE 下单量 26602000 超过当前 Bar 成交量的 25.0%，实际成交 9100700.0
# 2018-05-15 WARN 002122.XSHE 下单量 134309600 超过当前 Bar 成交量的 25.0%，实际成交 19300.0
# 2018-05-15 WARN 300032.XSHE 下单量 57921600 超过当前 Bar 成交量的 25.0%，实际成交 29200.0
# 2018-05-22 WARN 000807.XSHE 下单量 9100700.0 超过当前 Bar 成交量的 25.0%，实际成交 7789600.0
# 2018-05-22 WARN 订单被拒单: [300032.XSHE] 已跌停。
# 2018-05-22 WARN 002122.XSHE 下单量 42036000 超过当前 Bar 成交量的 25.0%，实际成交 33900.0
# 2018-05-22 WARN 600575.XSHG 下单量 39051700 超过当前 Bar 成交量的 25.0%，实际成交 779300.0
# 2018-05-29 WARN 600575.XSHG 下单量 3491100.0 超过当前 Bar 成交量的 25.0%，实际成交 825100.0
# 2018-05-29 WARN 002122.XSHE 下单量 51528500 超过当前 Bar 成交量的 25.0%，实际成交 11600.0
# 2018-05-29 WARN 600058.XSHG 下单量 37123700 超过当前 Bar 成交量的 25.0%，实际成交 685100.0
# 2018-06-05 WARN 订单被拒单: [002122.XSHE] 已跌停。
# 2018-06-05 WARN 600058.XSHG 下单量 685100.0 超过当前 Bar 成交量的 25.0%，实际成交 370600.0
# 2018-06-05 WARN 600600.XSHG 下单量 4459000 超过当前 Bar 成交量的 25.0%，实际成交 2098800.0
# 2018-06-12 WARN 订单被拒单: [002122.XSHE] 已跌停。
# 2018-06-12 WARN 600438.XSHG 下单量 46886600 超过当前 Bar 成交量的 25.0%，实际成交 16658700.0
# 2018-06-20 WARN 订单被拒单: [002122.XSHE] 已跌停。
# 2018-06-20 WARN 订单创建失败: 002005.XSHE 在 2018-06-20 15:00:00 时停牌
# 2018-06-27 WARN 600438.XSHG 下单量 24073100.0 超过当前 Bar 成交量的 25.0%，实际成交 9961000.0
# 2018-06-27 WARN 300202.XSHE 下单量 102053000 超过当前 Bar 成交量的 25.0%，实际成交 1660600.0
# 2018-06-27 WARN 600525.XSHG 下单量 20070000 超过当前 Bar 成交量的 25.0%，实际成交 6826000.0
# 2018-07-04 WARN 600525.XSHG 下单量 6826000.0 超过当前 Bar 成交量的 25.0%，实际成交 4113500.0
# 2018-07-04 WARN 600141.XSHG 下单量 14067200 超过当前 Bar 成交量的 25.0%，实际成交 1549700.0
# 2018-07-04 WARN 603377.XSHG 下单量 82366900 超过当前 Bar 成交量的 25.0%，实际成交 3176700.0
# 2018-07-11 WARN 603377.XSHG 下单量 3176700.0 超过当前 Bar 成交量的 25.0%，实际成交 1053300.0
# 2018-07-11 WARN 300202.XSHE 下单量 123594500 超过当前 Bar 成交量的 25.0%，实际成交 3524300.0
# 2018-07-11 WARN 300308.XSHE 下单量 2279000 超过当前 Bar 成交量的 25.0%，实际成交 827700.0
# 2018-07-18 WARN 300202.XSHE 下单量 3524300.0 超过当前 Bar 成交量的 25.0%，实际成交 2450200.0
# 2018-07-18 WARN 603377.XSHG 下单量 79210700 超过当前 Bar 成交量的 25.0%，实际成交 970500.0
# 2018-07-25 WARN 603377.XSHG 下单量 3093900.0 超过当前 Bar 成交量的 25.0%，实际成交 634200.0
# 2018-07-25 WARN 订单被拒单: [300058.XSHE] 已涨停。
# 2018-08-01 WARN 300266.XSHE 下单量 247341800 超过当前 Bar 成交量的 25.0%，实际成交 15809000.0
# 2018-08-01 WARN 600575.XSHG 下单量 47517100 超过当前 Bar 成交量的 25.0%，实际成交 3012500.0
# 2018-08-01 WARN 600885.XSHG 下单量 20895700 超过当前 Bar 成交量的 25.0%，实际成交 5369300.0
# 2018-08-08 WARN 600575.XSHG 下单量 5678500.0 超过当前 Bar 成交量的 25.0%，实际成交 5073600.0
# 2018-08-08 WARN 600885.XSHG 下单量 5369300.0 超过当前 Bar 成交量的 25.0%，实际成交 2547900.0
# 2018-08-08 WARN 600754.XSHG 下单量 42916700 超过当前 Bar 成交量的 25.0%，实际成交 1894200.0
# 2018-08-15 WARN 600754.XSHG 下单量 1894200.0 超过当前 Bar 成交量的 25.0%，实际成交 842700.0
# 2018-08-15 WARN 000766.XSHE 下单量 136000500 超过当前 Bar 成交量的 25.0%，实际成交 2029900.0
# 2018-08-15 WARN 600298.XSHG 下单量 26647400 超过当前 Bar 成交量的 25.0%，实际成交 4996900.0
# 2018-08-22 WARN 600298.XSHG 下单量 4996900.0 超过当前 Bar 成交量的 25.0%，实际成交 4186900.0
# 2018-08-22 WARN 000979.XSHE 下单量 1279785000 超过当前 Bar 成交量的 25.0%，实际成交 39158200.0
# 2018-08-22 WARN 600282.XSHG 下单量 121547900 超过当前 Bar 成交量的 25.0%，实际成交 15873800.0
# 2018-08-29 WARN 002600.XSHE 下单量 346474200 超过当前 Bar 成交量的 25.0%，实际成交 23141400.0
# 2018-08-29 WARN 603816.XSHG 下单量 11963700 超过当前 Bar 成交量的 25.0%，实际成交 348500.0
# 2018-09-05 WARN 002600.XSHE 下单量 23141400.0 超过当前 Bar 成交量的 25.0%，实际成交 8848800.0
# 2018-09-05 WARN 订单被拒单: [002028.XSHE] 已涨停。
# 2018-09-05 WARN 订单被拒单: [600640.XSHG] 已涨停。
# 2018-09-12 WARN 002384.XSHE 下单量 18645800 超过当前 Bar 成交量的 25.0%，实际成交 4327900.0
# 2018-09-12 WARN 600280.XSHG 下单量 203766700 超过当前 Bar 成交量的 25.0%，实际成交 25059900.0
# 2018-09-19 WARN 600280.XSHG 下单量 25059900.0 超过当前 Bar 成交量的 25.0%，实际成交 8541900.0
# 2018-09-19 WARN 002366.XSHE 下单量 58353000 超过当前 Bar 成交量的 25.0%，实际成交 7283500.0
# 2018-09-19 WARN 002699.XSHE 下单量 82646400 超过当前 Bar 成交量的 25.0%，实际成交 11589700.0
# 2018-09-27 WARN 002366.XSHE 下单量 9797000.0 超过当前 Bar 成交量的 25.0%，实际成交 3415600.0
# 2018-09-27 WARN 002699.XSHE 下单量 11589700.0 超过当前 Bar 成交量的 25.0%，实际成交 5229100.0
# 2018-09-27 WARN 603444.XSHG 下单量 6786900 超过当前 Bar 成交量的 25.0%，实际成交 157900.0
# 2018-10-11 WARN 002699.XSHE 下单量 6360600.0 超过当前 Bar 成交量的 25.0%，实际成交 2956500.0
# 2018-10-11 WARN 订单被拒单: [603444.XSHG] 已跌停。
# 2018-10-11 WARN 300156.XSHE 下单量 74498800 超过当前 Bar 成交量的 25.0%，实际成交 4557400.0
# 2018-10-11 WARN 600240.XSHG 下单量 215913700 超过当前 Bar 成交量的 25.0%，实际成交 10011800.0
# 2018-10-18 WARN 订单被拒单: [600240.XSHG] 已跌停。
# 2018-10-18 WARN 002030.XSHE 下单量 13388900 超过当前 Bar 成交量的 25.0%，实际成交 901700.0
# 2018-10-18 WARN 300116.XSHE 下单量 212048000 超过当前 Bar 成交量的 25.0%，实际成交 13115200.0
# 2018-10-25 WARN 002699.XSHE 下单量 138744100 超过当前 Bar 成交量的 25.0%，实际成交 10133200.0
# 2018-10-25 WARN 601233.XSHG 下单量 58722700 超过当前 Bar 成交量的 25.0%，实际成交 7549900.0
# 2018-11-01 WARN 002699.XSHE 下单量 13537300.0 超过当前 Bar 成交量的 25.0%，实际成交 8908700.0
# 2018-11-01 WARN 601233.XSHG 下单量 9188880.0 超过当前 Bar 成交量的 25.0%，实际成交 6514300.0
# 2018-11-01 WARN 603589.XSHG 下单量 23168900 超过当前 Bar 成交量的 25.0%，实际成交 3519600.0
# 2018-11-08 WARN 603589.XSHG 下单量 3519600.0 超过当前 Bar 成交量的 25.0%，实际成交 2065900.0
# 2018-11-08 WARN 000596.XSHE 下单量 12989800 超过当前 Bar 成交量的 25.0%，实际成交 668300.0
# 2018-11-08 WARN 订单被拒单: [002477.XSHE] 已涨停。
# 2018-11-15 WARN 000596.XSHE 下单量 668300.0 超过当前 Bar 成交量的 25.0%，实际成交 641600.0
# 2018-11-15 WARN 订单被拒单: [600316.XSHG] 已涨停。
# 2018-11-22 WARN 600017.XSHG 下单量 257954900 超过当前 Bar 成交量的 25.0%，实际成交 1931900.0
# 2018-11-22 WARN 600751.XSHG 下单量 146265800 超过当前 Bar 成交量的 25.0%，实际成交 9587400.0
# 2018-11-29 WARN 600751.XSHG 下单量 9587400.0 超过当前 Bar 成交量的 25.0%，实际成交 6182600.0
# 2018-11-29 WARN 002147.XSHE 下单量 131873100 超过当前 Bar 成交量的 25.0%，实际成交 14709700.0
# 2018-11-29 WARN 600058.XSHG 下单量 58918200 超过当前 Bar 成交量的 25.0%，实际成交 485500.0
# 2018-12-06 WARN 订单被拒单: [002147.XSHE] 已跌停。
# 2018-12-06 WARN 002463.XSHE 下单量 52736000 超过当前 Bar 成交量的 25.0%，实际成交 29217900.0
# 2018-12-06 WARN 002841.XSHE 下单量 4251300 超过当前 Bar 成交量的 25.0%，实际成交 330400.0
# 2018-12-06 WARN 600166.XSHG 下单量 84968100 超过当前 Bar 成交量的 25.0%，实际成交 5523900.0
# 2018-12-13 WARN 002147.XSHE 下单量 14709700.0 超过当前 Bar 成交量的 25.0%，实际成交 13285300.0
# 2018-12-13 WARN 002463.XSHE 下单量 29217900.0 超过当前 Bar 成交量的 25.0%，实际成交 8909100.0
# 2018-12-13 WARN 002841.XSHE 下单量 330400.0 超过当前 Bar 成交量的 25.0%，实际成交 260200.0
# 2018-12-13 WARN 600166.XSHG 下单量 5523900.0 超过当前 Bar 成交量的 25.0%，实际成交 5117200.0
# 2018-12-13 WARN 600058.XSHG 下单量 29718400 超过当前 Bar 成交量的 25.0%，实际成交 478200.0
# 2018-12-13 WARN 603568.XSHG 下单量 23546000 超过当前 Bar 成交量的 25.0%，实际成交 328900.0
# 2018-12-20 WARN 600058.XSHG 下单量 478200.0 超过当前 Bar 成交量的 25.0%，实际成交 378200.0
# 2018-12-20 WARN 000979.XSHE 下单量 2468041900 超过当前 Bar 成交量的 25.0%，实际成交 18759500.0
# 2018-12-20 WARN 600657.XSHG 下单量 92463300 超过当前 Bar 成交量的 25.0%，实际成交 2649500.0
# 2018-12-20 WARN 600757.XSHG 下单量 85526000 超过当前 Bar 成交量的 25.0%，实际成交 2094500.0
# 2018-12-27 WARN 600757.XSHG 下单量 2094500.0 超过当前 Bar 成交量的 25.0%，实际成交 1221400.0
# 2018-12-27 WARN 002147.XSHE 下单量 177580500 超过当前 Bar 成交量的 25.0%，实际成交 11329600.0
# 2018-12-27 WARN 002353.XSHE 下单量 34768500 超过当前 Bar 成交量的 25.0%，实际成交 3374600.0
# 2018-12-27 WARN 300146.XSHE 下单量 7298000 超过当前 Bar 成交量的 25.0%，实际成交 6315400.0
# 2018-12-27 WARN 600058.XSHG 下单量 42387700 超过当前 Bar 成交量的 25.0%，实际成交 302100.0
# 2019-01-07 WARN 002147.XSHE 下单量 11329600.0 超过当前 Bar 成交量的 25.0%，实际成交 7945700.0
# 2019-01-07 WARN 002353.XSHE 下单量 3374600.0 超过当前 Bar 成交量的 25.0%，实际成交 2326000.0
# 2019-01-07 WARN 300146.XSHE 下单量 6315400.0 超过当前 Bar 成交量的 25.0%，实际成交 3437200.0
# 2019-01-07 WARN 000656.XSHE 下单量 44748600 超过当前 Bar 成交量的 25.0%，实际成交 4538000.0
# 2019-01-07 WARN 300347.XSHE 下单量 11741000 超过当前 Bar 成交量的 25.0%，实际成交 1554600.0
# 2019-01-07 WARN 订单被拒单: [600614.XSHG] 已涨停。
# 2019-01-14 WARN 000656.XSHE 下单量 4538000.0 超过当前 Bar 成交量的 25.0%，实际成交 1661800.0
# 2019-01-14 WARN 300347.XSHE 下单量 1554600.0 超过当前 Bar 成交量的 25.0%，实际成交 1040500.0
# 2019-01-14 WARN 600062.XSHG 下单量 39342700 超过当前 Bar 成交量的 25.0%，实际成交 1691800.0
# 2019-01-14 WARN 600751.XSHG 下单量 30322100 超过当前 Bar 成交量的 25.0%，实际成交 3116800.0
# 2019-01-21 WARN 600751.XSHG 下单量 6521600.0 超过当前 Bar 成交量的 25.0%，实际成交 3703300.0
# 2019-01-21 WARN 订单被拒单: [000612.XSHE] 已涨停。
# 2019-01-21 WARN 000636.XSHE 下单量 21805800 超过当前 Bar 成交量的 25.0%，实际成交 12676100.0
# 2019-01-28 WARN 000636.XSHE 下单量 12676100.0 超过当前 Bar 成交量的 25.0%，实际成交 6714400.0
# 2019-01-28 WARN 000656.XSHE 下单量 18473700 超过当前 Bar 成交量的 25.0%，实际成交 4068500.0
# 2019-01-28 WARN 002399.XSHE 下单量 17405300 超过当前 Bar 成交量的 25.0%，实际成交 844500.0
# 2019-01-28 WARN 600086.XSHG 下单量 110675900 超过当前 Bar 成交量的 25.0%，实际成交 12181000.0
# 2019-02-11 WARN 000656.XSHE 下单量 3928700 超过当前 Bar 成交量的 25.0%，实际成交 2613500.0
# 2019-02-11 WARN 002414.XSHE 下单量 13169500 超过当前 Bar 成交量的 25.0%，实际成交 2524300.0
# 2019-02-11 WARN 600086.XSHG 下单量 11283521 超过当前 Bar 成交量的 25.0%，实际成交 1680100.0
# 2019-02-18 WARN 000656.XSHE 下单量 9558200.0 超过当前 Bar 成交量的 25.0%，实际成交 5032600.0
# 2019-02-18 WARN 002414.XSHE 下单量 2524300.0 超过当前 Bar 成交量的 25.0%，实际成交 1696300.0
# 2019-02-18 WARN 002266.XSHE 下单量 52393200 超过当前 Bar 成交量的 25.0%，实际成交 2623000.0
# 2019-02-18 WARN 订单被拒单: [002426.XSHE] 已涨停。
# 2019-02-18 WARN 订单被拒单: [002463.XSHE] 已涨停。
# 2019-02-25 WARN 000656.XSHE 下单量 51366100 超过当前 Bar 成交量的 25.0%，实际成交 7584700.0
# 2019-02-25 WARN 订单被拒单: [600240.XSHG] 已涨停。
# 2019-02-25 WARN 订单被拒单: [600895.XSHG] 已涨停。
# 2019-02-25 WARN 订单被拒单: [601990.XSHG] 已涨停。
# 2019-03-04 WARN 000656.XSHE 下单量 12110300.0 超过当前 Bar 成交量的 25.0%，实际成交 11712500.0
# 2019-03-04 WARN 订单被拒单: [600060.XSHG] 已涨停。
# 2019-03-11 WARN 600525.XSHG 下单量 33073000 超过当前 Bar 成交量的 25.0%，实际成交 29593700.0
# 2019-03-11 WARN 订单被拒单: [603556.XSHG] 已涨停。
# 2019-03-18 WARN 600525.XSHG 下单量 32306200.0 超过当前 Bar 成交量的 25.0%，实际成交 14776800.0
# 2019-03-18 WARN 订单被拒单: [600478.XSHG] 已涨停。
# 2019-03-25 WARN 600748.XSHG 下单量 58085800 超过当前 Bar 成交量的 25.0%，实际成交 5873400.0
# 2019-03-25 WARN 601019.XSHG 下单量 51565600 超过当前 Bar 成交量的 25.0%，实际成交 1975700.0
# 2019-04-01 WARN 订单被拒单: [002663.XSHE] 已涨停。
# 2019-04-01 WARN 订单被拒单: [600648.XSHG] 已涨停。
# 2019-04-09 WARN 订单创建失败: 002064.XSHE 在 2019-04-09 15:00:00 时停牌
# 2019-04-09 WARN 300383.XSHE 下单量 26890200 超过当前 Bar 成交量的 25.0%，实际成交 4475000.0
# 2019-04-16 WARN 订单被拒单: [601777.XSHG] 已涨停。
# 2019-04-23 WARN 300001.XSHE 下单量 25282100 超过当前 Bar 成交量的 25.0%，实际成交 3746300.0
# 2019-04-23 WARN 600687.XSHG 下单量 130693600 超过当前 Bar 成交量的 25.0%，实际成交 12102400.0
# 2019-04-30 WARN 300001.XSHE 下单量 3746300.0 超过当前 Bar 成交量的 25.0%，实际成交 1974800.0
# 2019-04-30 WARN 订单创建失败: 600687.XSHG 在 2019-04-30 15:00:00 时停牌
# 2019-04-30 WARN 订单被拒单: [600086.XSHG] 已涨停。
# 2019-04-30 WARN 600094.XSHG 下单量 65502400 超过当前 Bar 成交量的 25.0%，实际成交 11010500.0
# 2019-05-10 WARN 600094.XSHG 下单量 11010500.0 超过当前 Bar 成交量的 25.0%，实际成交 4852700.0
# 2019-05-10 WARN 600240.XSHG 下单量 195005100 超过当前 Bar 成交量的 25.0%，实际成交 207200.0
# 2019-05-10 WARN 600325.XSHG 下单量 48759200 超过当前 Bar 成交量的 25.0%，实际成交 6845300.0
# 2019-05-10 WARN 600614.XSHG 下单量 66571700 超过当前 Bar 成交量的 25.0%，实际成交 97800.0
# 2019-05-17 WARN 订单被拒单: [600240.XSHG] 已跌停。
# 2019-05-17 WARN 600325.XSHG 下单量 6845300.0 超过当前 Bar 成交量的 25.0%，实际成交 5435100.0
# 2019-05-17 WARN 000732.XSHE 下单量 23694400 超过当前 Bar 成交量的 25.0%，实际成交 2738700.0
# 2019-05-17 WARN 600614.XSHG 下单量 102127500 超过当前 Bar 成交量的 25.0%，实际成交 154200.0
# 2019-05-24 WARN 000732.XSHE 下单量 2738700.0 超过当前 Bar 成交量的 25.0%，实际成交 1546500.0
# 2019-05-24 WARN 订单被拒单: [600614.XSHG] 已跌停。
# 2019-05-24 WARN 002118.XSHE 下单量 26573000 超过当前 Bar 成交量的 25.0%，实际成交 10295400.0
# 2019-05-24 WARN 002359.XSHE 下单量 55121400 超过当前 Bar 成交量的 25.0%，实际成交 18300.0
# 2019-05-24 WARN 600657.XSHG 下单量 69082500 超过当前 Bar 成交量的 25.0%，实际成交 1501500.0
# 2019-05-31 WARN 订单被拒单: [002359.XSHE] 已跌停。
# 2019-05-31 WARN 600657.XSHG 下单量 1501500.0 超过当前 Bar 成交量的 25.0%，实际成交 1321700.0
# 2019-05-31 WARN 002110.XSHE 下单量 41292000 超过当前 Bar 成交量的 25.0%，实际成交 5514100.0
# 2019-05-31 WARN 600277.XSHG 下单量 38743300 超过当前 Bar 成交量的 25.0%，实际成交 20112600.0
# 2019-05-31 WARN 订单被拒单: [600525.XSHG] 已涨停。
# 2019-06-10 WARN 订单被拒单: [002359.XSHE] 已跌停。
# 2019-06-10 WARN 600277.XSHG 下单量 20112600.0 超过当前 Bar 成交量的 25.0%，实际成交 13983600.0
# 2019-06-10 WARN 600525.XSHG 下单量 17529400.0 超过当前 Bar 成交量的 25.0%，实际成交 14296800.0
# 2019-06-10 WARN 000723.XSHE 下单量 34755300 超过当前 Bar 成交量的 25.0%，实际成交 30682700.0
# 2019-06-10 WARN 002110.XSHE 下单量 6559500 超过当前 Bar 成交量的 25.0%，实际成交 4543800.0
# 2019-06-17 WARN 000723.XSHE 下单量 30682700.0 超过当前 Bar 成交量的 25.0%，实际成交 29826800.0
# 2019-06-17 WARN 002110.XSHE 下单量 10057900.0 超过当前 Bar 成交量的 25.0%，实际成交 2385100.0
# 2019-06-17 WARN 订单被拒单: [002359.XSHE] 已跌停。
# 2019-06-17 WARN 订单被拒单: [002437.XSHE] 已涨停。
# 2019-06-17 WARN 600240.XSHG 下单量 369798400 超过当前 Bar 成交量的 25.0%，实际成交 11981100.0
# 2019-06-24 WARN 订单被拒单: [600240.XSHG] 已跌停。
# 2019-06-24 WARN 600267.XSHG 下单量 31610700 超过当前 Bar 成交量的 25.0%，实际成交 6068400.0
# 2019-07-01 WARN 600267.XSHG 下单量 6068400.0 超过当前 Bar 成交量的 25.0%，实际成交 3783600.0
# 2019-07-01 WARN 订单被拒单: [600179.XSHG] 已涨停。
# 2019-07-01 WARN 603501.XSHG 下单量 5444400 超过当前 Bar 成交量的 25.0%，实际成交 1603700.0
# 2019-07-08 WARN 603501.XSHG 下单量 1603700.0 超过当前 Bar 成交量的 25.0%，实际成交 973000.0
# 2019-07-08 WARN 002242.XSHE 下单量 8818900 超过当前 Bar 成交量的 25.0%，实际成交 1083200.0
# 2019-07-08 WARN 600021.XSHG 下单量 29195500 超过当前 Bar 成交量的 25.0%，实际成交 1221300.0
# 2019-07-08 WARN 601777.XSHG 下单量 59260300 超过当前 Bar 成交量的 25.0%，实际成交 18276600.0
# 2019-07-15 WARN 002242.XSHE 下单量 1083200.0 超过当前 Bar 成交量的 25.0%，实际成交 1042100.0
# 2019-07-15 WARN 600021.XSHG 下单量 1221300.0 超过当前 Bar 成交量的 25.0%，实际成交 1190200.0
# 2019-07-15 WARN 601777.XSHG 下单量 18276600.0 超过当前 Bar 成交量的 25.0%，实际成交 9633100.0
# 2019-07-15 WARN 订单被拒单: [300253.XSHE] 已涨停。
# 2019-07-22 WARN 600179.XSHG 下单量 82862700 超过当前 Bar 成交量的 25.0%，实际成交 1914200.0
# 2019-07-22 WARN 600393.XSHG 下单量 71989700 超过当前 Bar 成交量的 25.0%，实际成交 13347600.0
# 2019-07-29 WARN 600393.XSHG 下单量 13347600.0 超过当前 Bar 成交量的 25.0%，实际成交 10216500.0
# 2019-07-29 WARN 订单创建失败: 600179.XSHG 在 2019-07-29 15:00:00 时停牌
# 2019-07-29 WARN 订单被拒单: [600939.XSHG] 已涨停。
# 2019-08-05 WARN 600179.XSHG 下单量 1914200.0 超过当前 Bar 成交量的 25.0%，实际成交 1778400.0
# 2019-08-05 WARN 600338.XSHG 下单量 17596500 超过当前 Bar 成交量的 25.0%，实际成交 4411000.0
# 2019-08-05 WARN 600393.XSHG 下单量 61862900 超过当前 Bar 成交量的 25.0%，实际成交 7998700.0
# 2019-08-12 WARN 600338.XSHG 下单量 4411000.0 超过当前 Bar 成交量的 25.0%，实际成交 2698500.0
# 2019-08-12 WARN 600545.XSHG 下单量 32031600 超过当前 Bar 成交量的 25.0%，实际成交 461100.0
# 2019-08-12 WARN 600848.XSHG 下单量 7560800 超过当前 Bar 成交量的 25.0%，实际成交 3605700.0
# 2019-08-26 WARN 600848.XSHG 下单量 3605700.0 超过当前 Bar 成交量的 25.0%，实际成交 2860700.0
# 2019-08-26 WARN 601231.XSHG 下单量 14365900 超过当前 Bar 成交量的 25.0%，实际成交 5907700.0
# 2019-09-02 WARN 601231.XSHG 下单量 5907700.0 超过当前 Bar 成交量的 25.0%，实际成交 4412500.0
# 2019-09-02 WARN 600338.XSHG 下单量 13654700 超过当前 Bar 成交量的 25.0%，实际成交 5139300.0
# 2019-09-02 WARN 订单被拒单: [600745.XSHG] 已涨停。
# 2019-09-09 WARN 600338.XSHG 下单量 6851800.0 超过当前 Bar 成交量的 25.0%，实际成交 3841200.0
# 2019-09-09 WARN 订单被拒单: [300134.XSHE] 已涨停。
# 2019-09-09 WARN 订单被拒单: [600179.XSHG] 已涨停。
# 2019-09-17 WARN 600179.XSHG 下单量 41963700 超过当前 Bar 成交量的 25.0%，实际成交 3014900.0
# 2019-09-17 WARN 600845.XSHG 下单量 4113900 超过当前 Bar 成交量的 25.0%，实际成交 1350100.0
# 2019-09-24 WARN 600179.XSHG 下单量 3150700.0 超过当前 Bar 成交量的 25.0%，实际成交 2709200.0
# 2019-09-24 WARN 601811.XSHG 下单量 11066600 超过当前 Bar 成交量的 25.0%，实际成交 1145400.0
# [2019-10-25 06:55:08.882588] WARN: system_log: Missing Chinese fonts. Fallback to English.

# %% [markdown]
# # 回测记录

# %%
print(result.keys())
record = result['sys_analyser']
print(record.keys())
trade_detail = record['trades']
stock_account = record['stock_account']
stock_positions = record['stock_positions']
# Out:
# 2019-09-24 INFO dict_keys(['sys_analyser'])
# 2019-09-24 INFO dict_keys(['summary', 'trades', 'portfolio', 'benchmark_portfolio', 'stock_account', 'stock_positions'])

# %% [markdown]
# ## 回测曲线

# %%
def max_ddd(arr):
    max_seen = arr[0]
    ddd_start, ddd_end = 0, 0
    ddd = 0
    start = 0
    in_draw_down = False

    for i in range(len(arr)):
        if arr[i] > max_seen:
            if in_draw_down:
                in_draw_down = False
                if i - start > ddd:
                    ddd = i - start
                    ddd_start = start
                    ddd_end = i - 1
            max_seen = arr[i]
        elif arr[i] < max_seen:
            if not in_draw_down:
                in_draw_down = True
                start = i - 1

    if arr[i] < max_seen:
        if i - start > ddd:
            return start, i

    return ddd_start, ddd_end

# %%
from matplotlib import rc
from matplotlib import pyplot as plt
from matplotlib import rcParams, gridspec, ticker, image as mpimg, pyplot as plt
from matplotlib.font_manager import findfont, FontProperties
import plotly.offline as py
import plotly.graph_objs as go

rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = [
        u'Microsoft Yahei',
        u'Heiti SC',
        u'Heiti TC',
        u'STHeiti',
        u'WenQuanYi Zen Hei',
        u'WenQuanYi Micro Hei',
        u"文泉驿微米黑",
        u'SimHei',
    ] + rcParams['font.sans-serif']
rcParams['axes.unicode_minus'] = False

use_chinese_fonts = True
font = findfont(FontProperties(family=['sans-serif']))
if "/matplotlib/" in font:
    use_chinese_fonts = False

title = 'backTestResult'
summary = record["summary"]
portfolio = record["portfolio"]
benchmark_portfolio = record.get("benchmark_portfolio")
index = portfolio.index
portfolio_value = portfolio.unit_net_value * portfolio.units
xs = portfolio_value.values
rt = portfolio.unit_net_value.values
max_dd_end = np.argmax(np.maximum.accumulate(xs) / xs)
if max_dd_end == 0:
    max_dd_end = len(xs) - 1
max_dd_start = np.argmax(xs[:max_dd_end]) if max_dd_end > 0 else 0

max_ddd_start_day, max_ddd_end_day = max_ddd(xs)
max_dd_info = "MaxDD  {}~{}, {} days".format(index[max_dd_start], index[max_dd_end],
                                                 (index[max_dd_end] - index[max_dd_start]).days)
max_dd_info += "\nMaxDDD {}~{}, {} days".format(index[max_ddd_start_day], index[max_ddd_end_day],
                                                    (index[max_ddd_end_day] - index[max_ddd_start_day]).days)
plt.style.use('ggplot')
red = "#aa4643"
blue = "#4572a7"
black = "#000000"
green = "#6B8E23"

plots_area_size = 0
if "plots" in result:
    plots_area_size = 5
    
figsize = (18, 6 + int(plots_area_size * 0.9))
plt.figure(title, figsize=figsize)
max_height = 10 + plots_area_size
gs = gridspec.GridSpec(max_height, 8)

ax = plt.subplot(gs[:3, -1:])
ax.axis("off")   
ax.autoscale_view()

font_size = 12
value_font_size = 11
label_height, value_height = 0.8, 0.6
label_height2, value_height2 = 0.35, 0.15

portfolio_value = portfolio.unit_net_value * portfolio.units
portfolio_df = pd.DataFrame(portfolio_value)
max_values = 0 
pvmax_dd = []
for k, v in portfolio_df.iterrows():
    max_values = max(v.values[0],max_values)
    dd = (v.values[0] - max_values) / max_values
    pvmax_dd.append(dd)
    
benchmark_value = benchmark_portfolio.unit_net_value * portfolio.units
benchmark_df = pd.DataFrame(benchmark_value)
max_values = 0 
bvmax_dd = []
for k, v in benchmark_df.iterrows():
    max_values = max(v.values[0],max_values)
    dd = (v.values[0] - max_values) / max_values
    bvmax_dd.append(dd)
rmdd = abs(np.array(pvmax_dd).min() - np.array(bvmax_dd).min()) / 6

def _(txt):
    return gettext(txt) if use_chinese_fonts else txt


#相对收益及年化收益
relative_value = np.power(1 + record['summary']['annualized_returns'],3) - np.power(
    1 + record['summary']['benchmark_annualized_returns'],3)
relative_annual = relative_value / len(record['stock_account'].index)* 252

fig_data = [
        (0.00, label_height, value_height, _(u"Total Returns"), "{0:.3%}".format(
                    summary["total_returns"]), red, black),
        (0.15, label_height, value_height, _(u"Annual Returns"), "{0:.3%}".format(
                    summary["annualized_returns"]), red, black),
        
        (0.30, label_height, value_height, _(u"Relative Returns"), "{0:.3%}".format(
                    relative_value), red, black),
        (0.42, label_height, value_height, _(u"Relative Annual"), "{0:.3%}".format(
                    relative_annual), red, black),
    
        (0.55, label_height, value_height, _(u"Alpha"), "{0:.4}".format(summary["alpha"]), black, black),
        (0.60, label_height, value_height, _(u"Beta"), "{0:.4}".format(summary["beta"]), black, black),
        (0.65, label_height, value_height, _(u"Sharpe"), "{0:.4}".format(summary["sharpe"]), black, black),
        (0.75, label_height, value_height, _(u"Sortino"), "{0:.4}".format(summary["sortino"]), black, black),
        (0.85, label_height, value_height, _(u"Information Ratio"), "{0:.4}".format(
                    summary["information_ratio"]), black, black),

        (0.00, label_height2, value_height2, _(u"Benchmark Returns"), "{0:.3%}".format(
                    summary.get("benchmark_total_returns", 0)), blue,
         black),
        (0.15, label_height2, value_height2, _(u"Benchmark Annual"), "{0:.3%}".format(
                    summary.get("benchmark_annualized_returns", 0)),
         blue, black),
        (0.30, label_height2, value_height2, _(u"Volatility"), "{0:.4}".format(
                    summary["volatility"]), black, black),
        (0.40, label_height2, value_height2, _(u"MaxDrawdown"), "{0:.3%}".format(
                    summary["max_drawdown"]), black, black),
        (0.55, label_height2, value_height2, _(u"Relative MaxDrawdown"), "{0:.4%}".format(rmdd), black, black),
        (0.75, label_height2, value_height2, _(u"Downside Risk"), "{0:.4}".format(
                    summary["downside_risk"]), black, black),
]

ax = plt.subplot(gs[:3, :-1])
ax.axis("off")

for x, y1, y2, label, value, label_color, value_color in fig_data:
    ax.text(x, y1, label, color=label_color, fontsize=font_size)
    ax.text(x, y2, value, color=value_color, fontsize=value_font_size)
#for x, y1, y2, label, value, label_color, value_color in [
#        (0.85, label_height2, value_height2, _(u"MaxDD/MaxDDD"), max_dd_info, black, black)]:
#    ax.text(x, y1, label, color=label_color, fontsize=font_size)
#    ax.text(x, y2, value, color=value_color, fontsize=8)
    
# strategy vs benchmark
ax = plt.subplot(gs[4:10, :])

ax.get_xaxis().set_minor_locator(ticker.AutoMinorLocator())
ax.get_yaxis().set_minor_locator(ticker.AutoMinorLocator())
ax.grid(b=True, which='minor', linewidth=.2)
ax.grid(b=True, which='major', linewidth=1)


# plot two lines
ax.plot(portfolio["unit_net_value"] - 1.0, label=_(u"strategy"), alpha=1, linewidth=2, color=red)
if benchmark_portfolio is not None:
    ax.plot(benchmark_portfolio["unit_net_value"] - 1.0, label=_(u"benchmark"), alpha=1, linewidth=2, color=blue)
    alpha_portfolio = portfolio["unit_net_value"] - benchmark_portfolio["unit_net_value"]
    ax.plot(alpha_portfolio, label=_(u"alpha"), alpha=1, linewidth=2, color=green)
    
# plot MaxDD/MaxDDD
ax.plot([index[max_dd_end], index[max_dd_start]], [rt[max_dd_end], rt[max_dd_start]],
            'v', color='Green', markersize=8, alpha=.7, label=_(u"MaxDrawdown"))
ax.plot([index[max_ddd_start_day], index[max_ddd_end_day]],
            [rt[max_ddd_start_day] - 1.0, rt[max_ddd_end_day] - 1.0], 'D', color='Blue', markersize=8, alpha=.7,
            label=_(u"MaxDDD"))


# place legend
leg = plt.legend(loc="best")
leg.get_frame().set_alpha(0.5)

# manipulate axis
vals = ax.get_yticks()
ax.set_yticklabels(['{:3.2f}%'.format(x * 100) for x in vals])

if "plots" in record:
    plots_df = result["plots"]
    ax2 = plt.subplot(gs[11:, :])
    for column in plots_df.columns:
        ax2.plot(plots_df[column], label=column)

    leg = plt.legend(loc="best")
    leg.get_frame().set_alpha(0.5)
    
plt.show()

# %% [markdown]
# ### 模型产生的股票交易指令

# %%
tune_record[tune_record['trade_date'] == '2017-03-28 00:00:00']
# Out:
#       portfolio_weight industry        er  code        dx           trade_date
# 5676          0.618019     医药生物  0.012469  2399 -0.019019  2017-03-28 00:00:00
# 5720          0.381898     家用电器  0.011640  2670 -0.159999  2017-03-28 00:00:00

# %%
tune_record[tune_record['trade_date'] == '2017-03-26 00:00:00']
# Out:
# Empty DataFrame
# Columns: [portfolio_weight, industry, er, code, dx, trade_date]
# Index: []

# %% [markdown]
# ### 获取指定交易日期的交易记录

# %%
trade_detail[trade_detail['trading_datetime'] == '2017-03-28 15:00:00']
# Out:
#                      commission         exec_id  last_price  last_quantity  \
# datetime
# 2017-03-28 15:00:00    10517.32  15719864990018       21.73       605000.0
#
#                     order_book_id        order_id position_effect side symbol  \
# datetime
# 2017-03-28 15:00:00   002399.XSHE  15719865001725            OPEN  BUY    海普瑞
#
#                      tax     trading_datetime  transaction_cost
# datetime
# 2017-03-28 15:00:00  0.0  2017-03-28 15:00:00          10517.32

# %%
trade_detail[trade_detail['trading_datetime'] == '2017-03-06 15:00:00']
# Out:
# Empty DataFrame
# Columns: [commission, exec_id, last_price, last_quantity, order_book_id, order_id, position_effect, side, symbol, tax, trading_datetime, transaction_cost]
# Index: []

# %% [markdown]
# ### 获取指定交易日的持仓仓位信息

# %%
stock_positions[(stock_positions.index == '2017-03-28') & (stock_positions.quantity != 0)].reset_index()
# Out:
#         date  avg_price  last_price  market_value order_book_id   quantity  \
# 0 2017-03-28      13.23       13.19     7519619.0   600597.XSHG   570100.0
# 1 2017-03-28      29.62       31.22    62630442.0   002368.XSHE  2006100.0
# 2 2017-03-28      10.60       10.44     1676664.0   002161.XSHE   160600.0
# 3 2017-03-28      21.73       21.73    13146650.0   002399.XSHE   605000.0
#
#   symbol
# 0   光明乳业
# 1   太极股份
# 2    远望谷
# 3    海普瑞

# %%
stock_positions[(stock_positions.index == '2017-03-06') & (stock_positions.quantity != 0)].reset_index()
# Out:
#         date  avg_price  last_price  market_value order_book_id   quantity  \
# 0 2017-03-06      13.23       13.20     7525320.0   600597.XSHG   570100.0
# 1 2017-03-06      29.62       33.08    66361788.0   002368.XSHE  2006100.0
# 2 2017-03-06      10.60       10.83     1739298.0   002161.XSHE   160600.0
# 3 2017-03-06      19.39       20.96    35258912.0   002642.XSHE  1682200.0
# 4 2017-03-06      42.57       44.13     2784603.0   603866.XSHG    63100.0
#
#   symbol
# 0   光明乳业
# 1   太极股份
# 2    远望谷
# 3  *ST荣联
# 4   桃李面包

# %%
# trade_detail.to_csv('./trades_record.csv', encoding="utf_8_sig")
