# %% [markdown]
# # 基础因子risk—netural回测结果

# %% [markdown]
# 添加费后曲线

# %%
# %matplotlib inline
import sys
sys.path.append('../../../')
sys.path.append('../')
import pandas as pd
from PyFin.api import *
from alphamind.api import *
from src.conf.models import *
import numpy as np
from alphamind.execution.naiveexecutor import NaiveExecutor
from matplotlib import pyplot as plt

data_source = 'postgresql+psycopg2://alpha:alpha@180.166.26.82:8889/alpha'
engine = SqlEngine(data_source)

# %%
universe = Universe('zz500')
freq = '2b'
benchmark_code = 905
start_date = '2019-01-01'
end_date = '2019-08-01'
ref_dates = makeSchedule(start_date, end_date, freq, 'china.sse')
horizon = map_freq(freq)
industry_name = 'sw'
industry_level = 1

# %%
basic_factor_store = {
    'f0': CSQuantiles(LAST('AccountsPayablesTDays'), groups='sw1'), 
    'f1': CSQuantiles(LAST('AccountsPayablesTRate'), groups='sw1'), 
    'f2': CSQuantiles(LAST('AdminiExpenseRate'), groups='sw1'), 
    'f3': CSQuantiles(LAST('ARTDays'), groups='sw1'), 
    'f4': CSQuantiles(LAST('ARTRate'), groups='sw1'), 
    'f5': CSQuantiles(LAST('ASSI'), groups='sw1'), 
    'f6': CSQuantiles(LAST('BLEV'), groups='sw1'), 
    'f7': CSQuantiles(LAST('BondsPayableToAsset'), groups='sw1'), 
    'f8': CSQuantiles(LAST('CashRateOfSales'), groups='sw1'), 
    'f9': CSQuantiles(LAST('CashToCurrentLiability'), groups='sw1'), 
    'f10': CSQuantiles(LAST('CMRA'), groups='sw1'), 
    'f11': CSQuantiles(LAST('CTOP'), groups='sw1'), 
    'f12': CSQuantiles(LAST('CTP5'), groups='sw1'), 
    'f13': CSQuantiles(LAST('CurrentAssetsRatio'), groups='sw1'), 
    'f14': CSQuantiles(LAST('CurrentAssetsTRate'), groups='sw1'), 
    'f15': CSQuantiles(LAST('CurrentAssetsTRate'), groups='sw1'), 
    'f16': CSQuantiles(LAST('DAVOL10'), groups='sw1'), 
    'f17': CSQuantiles(LAST('DAVOL20'), groups='sw1'), 
    'f18': CSQuantiles(LAST('DAVOL5'), groups='sw1'), 
    'f19': CSQuantiles(LAST('DDNBT'), groups='sw1'), 
    'f20': CSQuantiles(LAST('DDNCR'), groups='sw1'), 
    'f21': CSQuantiles(LAST('DDNSR'), groups='sw1'), 
    'f22': CSQuantiles(LAST('DebtEquityRatio'), groups='sw1'), 
    'f23': CSQuantiles(LAST('DebtsAssetRatio'), groups='sw1'), 
    'f24': CSQuantiles(LAST('DHILO'), groups='sw1'), 
    'f25': CSQuantiles(LAST('DilutedEPS'), groups='sw1'), 
    'f26': CSQuantiles(LAST('DVRAT'), groups='sw1'), 
    'f27': CSQuantiles(LAST('EBITToTOR'), groups='sw1'), 
    'f28': CSQuantiles(LAST('EGRO'), groups='sw1'), 
    'f29': CSQuantiles(LAST('EMA10'), groups='sw1'), 
    'f30': CSQuantiles(LAST('EMA120'), groups='sw1'), 
    'f31': CSQuantiles(LAST('EMA20'), groups='sw1'), 
    'f32': CSQuantiles(LAST('EMA5'), groups='sw1'), 
    'f33': CSQuantiles(LAST('EMA60'), groups='sw1'), 
    'f34': CSQuantiles(LAST('EPS'), groups='sw1'), 
    'f35': CSQuantiles(LAST('EquityFixedAssetRatio'), groups='sw1'), 
    'f36': CSQuantiles(LAST('EquityToAsset'), groups='sw1'), 
    'f37': CSQuantiles(LAST('EquityTRate'), groups='sw1'), 
    'f38': CSQuantiles(LAST('ETOP'), groups='sw1'), 
    'f39': CSQuantiles(LAST('ETP5'), groups='sw1'), 
    'f40': CSQuantiles(LAST('FinancialExpenseRate'), groups='sw1'), 
    'f41': CSQuantiles(LAST('FinancingCashGrowRate'), groups='sw1'), 
    'f42': CSQuantiles(LAST('FixAssetRatio'), groups='sw1'), 
    'f43': CSQuantiles(LAST('FixedAssetsTRate'), groups='sw1'), 
    'f44': CSQuantiles(LAST('GrossIncomeRatio'), groups='sw1'), 
    'f45': CSQuantiles(LAST('HBETA'), groups='sw1'), 
    'f46': CSQuantiles(LAST('HBETA'), groups='sw1'), 
    'f47': CSQuantiles(LAST('IntangibleAssetRatio'), groups='sw1'), 
    'f48': CSQuantiles(LAST('InventoryTDays'), groups='sw1'), 
    'f49': CSQuantiles(LAST('InventoryTRate'), groups='sw1'), 
    'f50': CSQuantiles(LAST('InvestCashGrowRate'), groups='sw1'), 
    'f51': CSQuantiles(LAST('LCAP'), groups='sw1'), 
    'f52': CSQuantiles(LAST('LFLO'), groups='sw1'), 
    'f53': CSQuantiles(LAST('LongDebtToAsset'), groups='sw1'), 
    'f54': CSQuantiles(LAST('LongDebtToWorkingCapital'), groups='sw1'), 
    'f55': CSQuantiles(LAST('LongTermDebtToAsset'), groups='sw1'), 
    'f56': CSQuantiles(LAST('MA10'), groups='sw1'), 
    'f57': CSQuantiles(LAST('MA120'), groups='sw1'), 
    'f58': CSQuantiles(LAST('MA20'), groups='sw1'), 
    'f59': CSQuantiles(LAST('MA5'), groups='sw1'), 
    'f60': CSQuantiles(LAST('MA60'), groups='sw1'), 
    'f61': CSQuantiles(LAST('MAWVAD'), groups='sw1'), 
    'f62': CSQuantiles(LAST('MFI'), groups='sw1'), 
    'f63': CSQuantiles(LAST('MLEV'), groups='sw1'), 
    'f64': CSQuantiles(LAST('NetAssetGrowRate'), groups='sw1'), 
    'f65': CSQuantiles(LAST('NetProfitGrowRate'), groups='sw1'), 
    'f66': CSQuantiles(LAST('NetProfitRatio'), groups='sw1'), 
    'f67': CSQuantiles(LAST('NetProfitRatio'), groups='sw1'), 
    'f68': CSQuantiles(LAST('NonCurrentAssetsRatio'), groups='sw1'), 
    'f69': CSQuantiles(LAST('NPParentCompanyGrowRate'), groups='sw1'), 
    'f70': CSQuantiles(LAST('NPToTOR'), groups='sw1'), 
    'f71': CSQuantiles(LAST('OperatingExpenseRate'), groups='sw1'), 
    'f72': CSQuantiles(LAST('OperatingProfitGrowRate'), groups='sw1'), 
    'f73': CSQuantiles(LAST('OperatingProfitRatio'), groups='sw1'), 
    'f74': CSQuantiles(LAST('OperatingProfitToTOR'), groups='sw1'), 
    'f75': CSQuantiles(LAST('OperatingRevenueGrowRate'), groups='sw1'), 
    'f76': CSQuantiles(LAST('OperCashGrowRate'), groups='sw1'), 
    'f77': CSQuantiles(LAST('OperCashInToCurrentLiability'), groups='sw1'), 
    'f78': CSQuantiles(LAST('PB'), groups='sw1'), 
    'f79': CSQuantiles(LAST('PCF'), groups='sw1'), 
    'f80': CSQuantiles(LAST('PE'), groups='sw1'), 
    'f81': CSQuantiles(LAST('PS'), groups='sw1'), 
    'f82': CSQuantiles(LAST('PSY'), groups='sw1'), 
    'f83': CSQuantiles(LAST('QuickRatio'), groups='sw1'), 
    'f84': CSQuantiles(LAST('REVS10'), groups='sw1'), 
    'f85': CSQuantiles(LAST('REVS20'), groups='sw1'), 
    'f86': CSQuantiles(LAST('REVS5'), groups='sw1'), 
    'f87': CSQuantiles(LAST('REVS5'), groups='sw1'), 
    'f88': CSQuantiles(LAST('ROA5'), groups='sw1'), 
    'f89': CSQuantiles(LAST('ROE'), groups='sw1'), 
    'f90': CSQuantiles(LAST('ROE5'), groups='sw1'), 
    'f91': CSQuantiles(LAST('RSI'), groups='sw1'), 
    'f92': CSQuantiles(LAST('RSTR12'), groups='sw1'), 
    'f93': CSQuantiles(LAST('RSTR24'), groups='sw1'), 
    'f94': CSQuantiles(LAST('SalesCostRatio'), groups='sw1'), 
    'f95': CSQuantiles(LAST('SaleServiceCashToOR'), groups='sw1'), 
    'f96': CSQuantiles(LAST('SUE'), groups='sw1'), 
    'f97': CSQuantiles(LAST('TaxRatio'), groups='sw1'), 
    'f98': CSQuantiles(LAST('TOBT'), groups='sw1'), 
    'f99': CSQuantiles(LAST('TotalAssetGrowRate'), groups='sw1'), 
    'f100': CSQuantiles(LAST('TotalAssetsTRate'), groups='sw1')}

# %%
# %%time
factor_data_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates)
# factor_data_org = engine.fetch_factor_range(universe, basic_factor_store, dates=ref_dates, used_factor_tables=[Alpha191])
# Out:
# CPU times: user 13.7 s, sys: 513 ms, total: 14.2 s
# Wall time: 19.1 s

# %%
# %%time
industry = engine.fetch_industry_range(universe, dates=ref_dates)
factor_data = pd.merge(factor_data_org, industry, on=['trade_date', 'code']).fillna(0.)
risk_total = engine.fetch_risk_model_range(universe, dates=ref_dates)[1]
# Out:
# CPU times: user 838 ms, sys: 104 ms, total: 942 ms
# Wall time: 2.41 s

# %%
# %%time
return_data = engine.fetch_dx_return_range(universe, dates=ref_dates, horizon=horizon, offset=0,benchmark = benchmark_code)
# Out:
# CPU times: user 281 ms, sys: 24.7 ms, total: 305 ms
# Wall time: 1.48 s

# %%
# %%time
benchmark_total = engine.fetch_benchmark_range(dates=ref_dates, benchmark=benchmark_code)
industry_total = engine.fetch_industry_matrix_range(universe, dates=ref_dates, category=industry_name, level=industry_level)
# Out:
# CPU times: user 304 ms, sys: 26.1 ms, total: 330 ms
# Wall time: 827 ms

# %%
# Constraintes settings
industry_names = industry_list(industry_name, industry_level)
constraint_risk = ['EARNYILD', 'LIQUIDTY', 'GROWTH', 'SIZE', 'BETA', 'MOMENTUM'] + industry_names
total_risk_names = constraint_risk + ['benchmark', 'total']

b_type = []
l_val = []
u_val = []

for name in total_risk_names:
    if name == 'benchmark':
        b_type.append(BoundaryType.RELATIVE)
        l_val.append(0.0)
        u_val.append(1.0)
    elif name == 'total':
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(.0)
        u_val.append(.0)
    else:
        b_type.append(BoundaryType.ABSOLUTE)
        l_val.append(-1.005)
        u_val.append(1.005)

bounds = create_box_bounds(total_risk_names, b_type, l_val, u_val)

# %%
train_data = pd.merge(factor_data, return_data, on=['trade_date', 'code']).dropna()
# train_data.head()

# %%
features = ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15',
           'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 
           'f30', 'f31', 'f32', 'f33', 'f34', 'f35', 'f36', 'f37', 'f38', 'f39', 'f40', 'f41', 'f42', 'f43',
           'f44', 'f45', 'f46', 'f47', 'f48', 'f49', 'f50', 'f51', 'f52', 'f53', 'f54', 'f55', 'f56', 'f57', 
           'f58', 'f59', 'f60', 'f61', 'f62', 'f63', 'f64', 'f65', 'f66', 'f67', 'f68', 'f69', 'f70', 'f71', 
           'f72', 'f73', 'f74', 'f75', 'f76', 'f77', 'f78', 'f79', 'f80', 'f81', 'f82', 'f83', 'f84', 'f85',
           'f86', 'f87', 'f88', 'f89', 'f90', 'f91', 'f92', 'f93', 'f94', 'f95', 'f96', 'f97', 'f98', 'f99',
           'f100']

label = ['dx']

# %%
# %%time
from datetime import datetime, timedelta
from m1_xgb import *
from src.conf.configuration import regress_conf
import xgboost as xgb
import gc

def create_scenario():
    weight_gap = 1
    transact_cost = 0.003

    executor = NaiveExecutor()
    turn_overs = []
    leverags = []
    trade_dates = []
    current_pos = pd.DataFrame()
    previous_pos = pd.DataFrame()
    tune_record = pd.DataFrame()  
    rets = []
    net_rets = []
    turn_overs = []
    leverags = []
    ics = []
    # take ref_dates[i] as an example
    for i, ref_date in enumerate(ref_dates):
        alpha_logger.info('{0} is start'.format(ref_date))

        # machine learning model
        # Filter Training data
        # train data
        trade_date_pre = ref_date - timedelta(days=1)
        trade_date_pre_80 = ref_date - timedelta(days=80)
        
        # train = train_data[(train_data.trade_date <= trade_date_pre) & (trade_date_pre_80 <= train_data.trade_date)].dropna()
        train = train_data[train_data.trade_date <= trade_date_pre].dropna()

        if len(train) <= 0:
            continue
        x_train = train[features]
        y_train = train[label]
        alpha_logger.info('len_x_train: {0}, len_y_train: {1}'.format(len(x_train.values), len(y_train.values)))
        alpha_logger.info('X_train.shape={0}, X_test.shape = {1}'.format(np.shape(x_train), np.shape(y_train)))

        # xgb_configuration
        regress_conf.xgb_config_r()
        regress_conf.cv_folds = None
        regress_conf.early_stop_round = 10
        regress_conf.max_round = 800
        tic = time.time()
        # training
        xgb_model = XGBooster(regress_conf)
        xgb_model.set_params(tree_method='gpu_hist', max_depth=5)
        # xgb_model.set_params(max_depth=5)
        print(xgb_model.get_params)
        best_score, best_round, cv_rounds, best_model = xgb_model.fit(x_train, y_train)
        alpha_logger.info('Training time cost {}s'.format(time.time() - tic))
        alpha_logger.info('best_score = {}, best_round = {}'.format(best_score, best_round))
    
        # Test data
        total_data_test_excess = train_data[train_data.trade_date == ref_date]
        alpha_logger.info('{0} total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))

        if len(total_data_test_excess) <= 0:
            alpha_logger.info('{0} HAS NO DATA!!!'.format(ref_date))
            continue

        industry_matrix = industry_total[industry_total.trade_date == ref_date]
        benchmark_w = benchmark_total[benchmark_total.trade_date == ref_date]
        risk_matrix = risk_total[risk_total.trade_date == ref_date]

        total_data = pd.merge(industry_matrix, benchmark_w, on=['code'], how='left').fillna(0.)
        total_data = pd.merge(total_data, risk_matrix, on=['code'])
        alpha_logger.info('{0} len_of_total_data: {1}'.format(ref_date, len(total_data)))

        total_data_test_excess = pd.merge(total_data, total_data_test_excess, on=['code'])
        alpha_logger.info('{0} len_of_total_data_test_excess: {1}'.format(ref_date, len(total_data_test_excess)))
        
        codes = total_data_test_excess.code.values.tolist()
        alpha_logger.info('{0} full re-balance: {1}'.format(ref_date, len(codes)))
        dx_returns = return_data[return_data.trade_date == ref_date][['code', 'dx']]

        benchmark_w = total_data_test_excess.weight.values
        alpha_logger.info('shape_of_benchmark_w: {}'.format(np.shape(benchmark_w)))
        is_in_benchmark = (benchmark_w > 0.).astype(float).reshape((-1, 1))
        total_risk_exp = np.concatenate([total_data_test_excess[constraint_risk].values.astype(float),
                                         is_in_benchmark,
                                         np.ones_like(is_in_benchmark)],
                                         axis=1)
        alpha_logger.info('shape_of_total_risk_exp_pre: {}'.format(np.shape(total_risk_exp)))
        total_risk_exp = pd.DataFrame(total_risk_exp, columns=total_risk_names)
        alpha_logger.info('shape_of_total_risk_exp: {}'.format(np.shape(total_risk_exp)))
        constraints = LinearConstraints(bounds, total_risk_exp, benchmark_w)
        alpha_logger.info('constraints: {0} in {1}'.format(np.shape(constraints.risk_targets()), ref_date))

        lbound = np.maximum(0., benchmark_w - weight_gap)
        ubound = weight_gap + benchmark_w
        alpha_logger.info('lbound: {0} in {1}'.format(np.shape(lbound), ref_date))
        alpha_logger.info('ubound: {0} in {1}'.format(np.shape(ubound), ref_date))

        # predict
        x_pred = total_data_test_excess[features]
        dpred = xgb.DMatrix(x_pred.values)
        predict_xgboost = best_model.predict(dpred)
        a = np.shape(predict_xgboost)
        predict_xgboost = np.reshape(predict_xgboost, (a[0], -1)).astype(np.float64)
        alpha_logger.info('shape_of_predict_xgboost: {}'.format(np.shape(predict_xgboost)))
        # alpha_logger.info('predict_xgboost: {}'.format(predict_xgboost))
        del xgb_model
        del best_model
        gc.collect()
        
        # backtest
        try:
            target_pos, _ = er_portfolio_analysis(predict_xgboost,
                                                  total_data_test_excess['industry'].values,
                                                  None,
                                                  constraints,
                                                  False,
                                                  benchmark_w,
                                                  method = 'risk_neutral',
                                                  lbound=lbound,
                                                  ubound=ubound)
        except:
            import pdb
            pdb.set_trace()
            alpha_logger.info('target_pos: {}'.format(target_pos))
        alpha_logger.info('target_pos_shape: {}'.format(np.shape(target_pos)))
        alpha_logger.info('len_codes:{}'.format(np.shape(codes)))
        target_pos['code'] = codes
        
        result = pd.merge(target_pos, dx_returns, on=['code'])
        result['trade_date'] = ref_date
        tune_record = tune_record.append(result)
        alpha_logger.info('len_result: {}'.format(len(result)))

        # excess_return = np.exp(result.dx.values) - 1. - index_return.loc[ref_date, 'dx']
        excess_return = np.exp(result.dx.values) - 1.
        ret = result.weight.values @ excess_return
        
        trade_dates.append(ref_date)
        rets.append(np.log(1. + ret))
        alpha_logger.info('len_rets: {}, len_trade_dates: {}'.format(len(rets), len(trade_dates)))
        
        turn_over_org, current_pos = executor.execute(target_pos=target_pos)
        turn_over = turn_over_org / sum(target_pos.weight.values)
        executor.set_current(current_pos)
        net_rets.append(np.log(1. + ret - transact_cost * turn_over))        
        alpha_logger.info('len_net_rets: {}, len_trade_dates: {}'.format(len(net_rets), len(trade_dates)))

        alpha_logger.info('{} is finished'.format(ref_date))
        
    # ret_df = pd.DataFrame({'xgb_regress': rets}, index=trade_dates)
    ret_df = pd.DataFrame({'xgb_regress': rets, 'net_xgb_regress':net_rets}, index=trade_dates)
    ret_df.loc[advanceDateByCalendar('china.sse', ref_dates[-1], freq).strftime('%Y-%m-%d')] = 0.
    ret_df = ret_df.shift(1)
    ret_df.iloc[0] = 0.
    return ret_df, tune_record
# Out:
# CPU times: user 5.48 ms, sys: 0 ns, total: 5.48 ms
# Wall time: 5.5 ms

# %%
ret_df, tune_record = create_scenario()
# Out:
# 2019-08-06 11:38:35,945 - ALPHA_MIND - INFO - 2019-01-02 00:00:00 is start
# 2019-08-06 11:38:35,958 - ALPHA_MIND - INFO - 2019-01-04 00:00:00 is start
# 2019-08-06 11:38:35,979 - ALPHA_MIND - INFO - len_x_train: 499, len_y_train: 499
# 2019-08-06 11:38:35,980 - ALPHA_MIND - INFO - X_train.shape=(499, 101), X_test.shape = (499, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7f8289243668>>
# non_cross_validation。。。。
# [0]	train-rmse:0.493206	valid-rmse:0.497822
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.488309	valid-rmse:0.492922
# [2]	train-rmse:0.483461	valid-rmse:0.488071
# [3]	train-rmse:0.478661	valid-rmse:0.483268
# [4]	train-rmse:0.473909	valid-rmse:0.478513
# [5]	train-rmse:0.469206	valid-rmse:0.473806
# [6]	train-rmse:0.464549	valid-rmse:0.469146
# [7]	train-rmse:0.459939	valid-rmse:0.464533
# [8]	train-rmse:0.455375	valid-rmse:0.459966
# [9]	train-rmse:0.450857	valid-rmse:0.455445
# [10]	train-rmse:0.446384	valid-rmse:0.450969
# [11]	train-rmse:0.441956	valid-rmse:0.446537
# [12]	train-rmse:0.437573	valid-rmse:0.44215
# [13]	train-rmse:0.433233	valid-rmse:0.437808
# [14]	train-rmse:0.428938	valid-rmse:0.433508
# [15]	train-rmse:0.424685	valid-rmse:0.429252
# [16]	train-rmse:0.420475	valid-rmse:0.425038
# [17]	train-rmse:0.416307	valid-rmse:0.420866
# [18]	train-rmse:0.412181	valid-rmse:0.416737
# [19]	train-rmse:0.408096	valid-rmse:0.412648
# [20]	train-rmse:0.404052	valid-rmse:0.408601
# [21]	train-rmse:0.400049	valid-rmse:0.404594
# [22]	train-rmse:0.396087	valid-rmse:0.400628
# [23]	train-rmse:0.392164	valid-rmse:0.396701
# [24]	train-rmse:0.38828	valid-rmse:0.392813
# [25]	train-rmse:0.384436	valid-rmse:0.388965
# [26]	train-rmse:0.38063	valid-rmse:0.385155
# [27]	train-rmse:0.376862	valid-rmse:0.381383
# [28]	train-rmse:0.373132	valid-rmse:0.377649
# [29]	train-rmse:0.36944	valid-rmse:0.373953
# [30]	train-rmse:0.365785	valid-rmse:0.370294
# [31]	train-rmse:0.362166	valid-rmse:0.366671
# [32]	train-rmse:0.358584	valid-rmse:0.363085
# [33]	train-rmse:0.355038	valid-rmse:0.359535
# [34]	train-rmse:0.351528	valid-rmse:0.35602
# [35]	train-rmse:0.348053	valid-rmse:0.352541
# [36]	train-rmse:0.344613	valid-rmse:0.349096
# [37]	train-rmse:0.341208	valid-rmse:0.345686
# [38]	train-rmse:0.337837	valid-rmse:0.342311
# [39]	train-rmse:0.3345	valid-rmse:0.338969
# [40]	train-rmse:0.331196	valid-rmse:0.335661
# [41]	train-rmse:0.327926	valid-rmse:0.332386
# [42]	train-rmse:0.324689	valid-rmse:0.329144
# [43]	train-rmse:0.321484	valid-rmse:0.325935
# [44]	train-rmse:0.318312	valid-rmse:0.322758
# [45]	train-rmse:0.315171	valid-rmse:0.319612
# [46]	train-rmse:0.312063	valid-rmse:0.316519
# [47]	train-rmse:0.308985	valid-rmse:0.313436
# [48]	train-rmse:0.305939	valid-rmse:0.310404
# [49]	train-rmse:0.302923	valid-rmse:0.307403
# [50]	train-rmse:0.299938	valid-rmse:0.304432
# [51]	train-rmse:0.296982	valid-rmse:0.301471
# [52]	train-rmse:0.294057	valid-rmse:0.298559
# [53]	train-rmse:0.291161	valid-rmse:0.295677
# [54]	train-rmse:0.288294	valid-rmse:0.292823
# [55]	train-rmse:0.285456	valid-rmse:0.289979
# [56]	train-rmse:0.282646	valid-rmse:0.287183
# [57]	train-rmse:0.279865	valid-rmse:0.284414
# [58]	train-rmse:0.277112	valid-rmse:0.281674
# [59]	train-rmse:0.274387	valid-rmse:0.278943
# [60]	train-rmse:0.271689	valid-rmse:0.276257
# [61]	train-rmse:0.269019	valid-rmse:0.273598
# [62]	train-rmse:0.266375	valid-rmse:0.270966
# [63]	train-rmse:0.263758	valid-rmse:0.268343
# [64]	train-rmse:0.261168	valid-rmse:0.265764
# [65]	train-rmse:0.258604	valid-rmse:0.263211
# [66]	train-rmse:0.256065	valid-rmse:0.260683
# [67]	train-rmse:0.253553	valid-rmse:0.258164
# [68]	train-rmse:0.251065	valid-rmse:0.255687
# [69]	train-rmse:0.248603	valid-rmse:0.253235
# [70]	train-rmse:0.246166	valid-rmse:0.250808
# [71]	train-rmse:0.243754	valid-rmse:0.248389
# [72]	train-rmse:0.241366	valid-rmse:0.24601
# [73]	train-rmse:0.239002	valid-rmse:0.243656
# [74]	train-rmse:0.236662	valid-rmse:0.241325
# [75]	train-rmse:0.234346	valid-rmse:0.239002
# [76]	train-rmse:0.232053	valid-rmse:0.236718
# [77]	train-rmse:0.229783	valid-rmse:0.234457
# [78]	train-rmse:0.227537	valid-rmse:0.232218
# [79]	train-rmse:0.225313	valid-rmse:0.229988
# [80]	train-rmse:0.223112	valid-rmse:0.227794
# [81]	train-rmse:0.220934	valid-rmse:0.225623
# [82]	train-rmse:0.218777	valid-rmse:0.223474
# [83]	train-rmse:0.216642	valid-rmse:0.221347
# [84]	train-rmse:0.214529	valid-rmse:0.219226
# [85]	train-rmse:0.212438	valid-rmse:0.217142
# [86]	train-rmse:0.210366	valid-rmse:0.215061
# [87]	train-rmse:0.208315	valid-rmse:0.213002
# [88]	train-rmse:0.206286	valid-rmse:0.21098
# [89]	train-rmse:0.204276	valid-rmse:0.208962
# [90]	train-rmse:0.202289	valid-rmse:0.20698
# [91]	train-rmse:0.20032	valid-rmse:0.205003
# [92]	train-rmse:0.198371	valid-rmse:0.203045
# [93]	train-rmse:0.196444	valid-rmse:0.201124
# [94]	train-rmse:0.194534	valid-rmse:0.199205
# [95]	train-rmse:0.192646	valid-rmse:0.197323
# [96]	train-rmse:0.190775	valid-rmse:0.195443
# [97]	train-rmse:0.188923	valid-rmse:0.193582
# [98]	train-rmse:0.187092	valid-rmse:0.191756
# [99]	train-rmse:0.185278	valid-rmse:0.189933
# [100]	train-rmse:0.183484	valid-rmse:0.18815
# [101]	train-rmse:0.181706	valid-rmse:0.186364
# [102]	train-rmse:0.179948	valid-rmse:0.184617
# [103]	train-rmse:0.178207	valid-rmse:0.182867
# [104]	train-rmse:0.176485	valid-rmse:0.181156
# [105]	train-rmse:0.174779	valid-rmse:0.179441
# [106]	train-rmse:0.173092	valid-rmse:0.177745
# [107]	train-rmse:0.17142	valid-rmse:0.176065
# [108]	train-rmse:0.169767	valid-rmse:0.174422
# [109]	train-rmse:0.16813	valid-rmse:0.172776
# [110]	train-rmse:0.16651	valid-rmse:0.171164
# [111]	train-rmse:0.164907	valid-rmse:0.169568
# [112]	train-rmse:0.16332	valid-rmse:0.167989
# [113]	train-rmse:0.161749	valid-rmse:0.166426
# [114]	train-rmse:0.160194	valid-rmse:0.164861
# [115]	train-rmse:0.158655	valid-rmse:0.163326
# [116]	train-rmse:0.157132	valid-rmse:0.161811
# [117]	train-rmse:0.155623	valid-rmse:0.160312
# [118]	train-rmse:0.154131	valid-rmse:0.158824
# [119]	train-rmse:0.152655	valid-rmse:0.157353
# [120]	train-rmse:0.151191	valid-rmse:0.155888
# [121]	train-rmse:0.149741	valid-rmse:0.154438
# [122]	train-rmse:0.14831	valid-rmse:0.153012
# [123]	train-rmse:0.14689	valid-rmse:0.151592
# [124]	train-rmse:0.14548	valid-rmse:0.150184
# [125]	train-rmse:0.14409	valid-rmse:0.148804
# [126]	train-rmse:0.142709	valid-rmse:0.147423
# [127]	train-rmse:0.141342	valid-rmse:0.146057
# [128]	train-rmse:0.139989	valid-rmse:0.144707
# [129]	train-rmse:0.138652	valid-rmse:0.143377
# [130]	train-rmse:0.137329	valid-rmse:0.142062
# [131]	train-rmse:0.136019	valid-rmse:0.14076
# [132]	train-rmse:0.134721	valid-rmse:0.139501
# [133]	train-rmse:0.133435	valid-rmse:0.138218
# [134]	train-rmse:0.132165	valid-rmse:0.136956
# [135]	train-rmse:0.130908	valid-rmse:0.135708
# [136]	train-rmse:0.129662	valid-rmse:0.1345
# [137]	train-rmse:0.12843	valid-rmse:0.133277
# [138]	train-rmse:0.127213	valid-rmse:0.132042
# [139]	train-rmse:0.126004	valid-rmse:0.130852
# [140]	train-rmse:0.124811	valid-rmse:0.129642
# [141]	train-rmse:0.123628	valid-rmse:0.128458
# [142]	train-rmse:0.12246	valid-rmse:0.127273
# [143]	train-rmse:0.121299	valid-rmse:0.126132
# [144]	train-rmse:0.120155	valid-rmse:0.124971
# [145]	train-rmse:0.119019	valid-rmse:0.123826
# [146]	train-rmse:0.117894	valid-rmse:0.12272
# [147]	train-rmse:0.116784	valid-rmse:0.121595
# [148]	train-rmse:0.115687	valid-rmse:0.120482
# [149]	train-rmse:0.114595	valid-rmse:0.11941
# [150]	train-rmse:0.113516	valid-rmse:0.118324
# [151]	train-rmse:0.112452	valid-rmse:0.117245
# [152]	train-rmse:0.111394	valid-rmse:0.116205
# [153]	train-rmse:0.110352	valid-rmse:0.115148
# [154]	train-rmse:0.109313	valid-rmse:0.114114
# [155]	train-rmse:0.108292	valid-rmse:0.113079
# [156]	train-rmse:0.107278	valid-rmse:0.11207
# [157]	train-rmse:0.106271	valid-rmse:0.111066
# [158]	train-rmse:0.105282	valid-rmse:0.110063
# [159]	train-rmse:0.104298	valid-rmse:0.109073
# [160]	train-rmse:0.103329	valid-rmse:0.108091
# [161]	train-rmse:0.102363	valid-rmse:0.107169
# [162]	train-rmse:0.101414	valid-rmse:0.106208
# [163]	train-rmse:0.100468	valid-rmse:0.105306
# [164]	train-rmse:0.099539	valid-rmse:0.104386
# [165]	train-rmse:0.098611	valid-rmse:0.103465
# [166]	train-rmse:0.097695	valid-rmse:0.102567
# [167]	train-rmse:0.096787	valid-rmse:0.101666
# [168]	train-rmse:0.095889	valid-rmse:0.100787
# [169]	train-rmse:0.094998	valid-rmse:0.099906
# [170]	train-rmse:0.094119	valid-rmse:0.09904
# [171]	train-rmse:0.093249	valid-rmse:0.098198
# [172]	train-rmse:0.092387	valid-rmse:0.097343
# [173]	train-rmse:0.091535	valid-rmse:0.096515
# [174]	train-rmse:0.090692	valid-rmse:0.095701
# [175]	train-rmse:0.089857	valid-rmse:0.094887
# [176]	train-rmse:0.08903	valid-rmse:0.094072
# [177]	train-rmse:0.088214	valid-rmse:0.093298
# [178]	train-rmse:0.087405	valid-rmse:0.092539
# [179]	train-rmse:0.086604	valid-rmse:0.09175
# [180]	train-rmse:0.085814	valid-rmse:0.09097
# [181]	train-rmse:0.085025	valid-rmse:0.090237
# [182]	train-rmse:0.084247	valid-rmse:0.089477
# [183]	train-rmse:0.083481	valid-rmse:0.088719
# [184]	train-rmse:0.08272	valid-rmse:0.087974
# [185]	train-rmse:0.081965	valid-rmse:0.087238
# [186]	train-rmse:0.081222	valid-rmse:0.086521
# [187]	train-rmse:0.080478	valid-rmse:0.085843
# [188]	train-rmse:0.079747	valid-rmse:0.085132
# [189]	train-rmse:0.079023	valid-rmse:0.08446
# [190]	train-rmse:0.078307	valid-rmse:0.083789
# [191]	train-rmse:0.077598	valid-rmse:0.083105
# [192]	train-rmse:0.076893	valid-rmse:0.082401
# [193]	train-rmse:0.076198	valid-rmse:0.081777
# [194]	train-rmse:0.075506	valid-rmse:0.081113
# [195]	train-rmse:0.074826	valid-rmse:0.080495
# [196]	train-rmse:0.074152	valid-rmse:0.079876
# [197]	train-rmse:0.073481	valid-rmse:0.079231
# [198]	train-rmse:0.072821	valid-rmse:0.078616
# [199]	train-rmse:0.072163	valid-rmse:0.077986
# [200]	train-rmse:0.071516	valid-rmse:0.077383
# [201]	train-rmse:0.070872	valid-rmse:0.076762
# [202]	train-rmse:0.070238	valid-rmse:0.076187
# [203]	train-rmse:0.069608	valid-rmse:0.07558
# [204]	train-rmse:0.068983	valid-rmse:0.075001
# [205]	train-rmse:0.068368	valid-rmse:0.074433
# [206]	train-rmse:0.06776	valid-rmse:0.073858
# [207]	train-rmse:0.067154	valid-rmse:0.073282
# [208]	train-rmse:0.066559	valid-rmse:0.072723
# [209]	train-rmse:0.065964	valid-rmse:0.07216
# [210]	train-rmse:0.065381	valid-rmse:0.071589
# [211]	train-rmse:0.064799	valid-rmse:0.071041
# [212]	train-rmse:0.064227	valid-rmse:0.070535
# [213]	train-rmse:0.063656	valid-rmse:0.070013
# [214]	train-rmse:0.063096	valid-rmse:0.069518
# [215]	train-rmse:0.062536	valid-rmse:0.069003
# [216]	train-rmse:0.061987	valid-rmse:0.06852
# [217]	train-rmse:0.06144	valid-rmse:0.068012
# [218]	train-rmse:0.060896	valid-rmse:0.067513
# [219]	train-rmse:0.060364	valid-rmse:0.067044
# [220]	train-rmse:0.059838	valid-rmse:0.06657
# [221]	train-rmse:0.059311	valid-rmse:0.0661
# [222]	train-rmse:0.058796	valid-rmse:0.065598
# [223]	train-rmse:0.05828	valid-rmse:0.06512
# [224]	train-rmse:0.05777	valid-rmse:0.064654
# [225]	train-rmse:0.05727	valid-rmse:0.064191
# [226]	train-rmse:0.056767	valid-rmse:0.063723
# [227]	train-rmse:0.056278	valid-rmse:0.063285
# [228]	train-rmse:0.055793	valid-rmse:0.062872
# [229]	train-rmse:0.055308	valid-rmse:0.062449
# [230]	train-rmse:0.054831	valid-rmse:0.062012
# [231]	train-rmse:0.054361	valid-rmse:0.061606
# [232]	train-rmse:0.053891	valid-rmse:0.061181
# [233]	train-rmse:0.053426	valid-rmse:0.060761
# [234]	train-rmse:0.052971	valid-rmse:0.060391
# [235]	train-rmse:0.052517	valid-rmse:0.059969
# [236]	train-rmse:0.052071	valid-rmse:0.059565
# [237]	train-rmse:0.051625	valid-rmse:0.059179
# [238]	train-rmse:0.05118	valid-rmse:0.058785
# [239]	train-rmse:0.050748	valid-rmse:0.058425
# [240]	train-rmse:0.050315	valid-rmse:0.058033
# [241]	train-rmse:0.049889	valid-rmse:0.05765
# [242]	train-rmse:0.04947	valid-rmse:0.057286
# [243]	train-rmse:0.049055	valid-rmse:0.056938
# [244]	train-rmse:0.048639	valid-rmse:0.056573
# [245]	train-rmse:0.048231	valid-rmse:0.056206
# [246]	train-rmse:0.047828	valid-rmse:0.055862
# [247]	train-rmse:0.047425	valid-rmse:0.055503
# [248]	train-rmse:0.047024	valid-rmse:0.055179
# [249]	train-rmse:0.046628	valid-rmse:0.054863
# [250]	train-rmse:0.046237	valid-rmse:0.054518
# [251]	train-rmse:0.04585	valid-rmse:0.054164
# [252]	train-rmse:0.045466	valid-rmse:0.053856
# [253]	train-rmse:0.045085	valid-rmse:0.053515
# [254]	train-rmse:0.044713	valid-rmse:0.053198
# [255]	train-rmse:0.044341	valid-rmse:0.052873
# [256]	train-rmse:0.043974	valid-rmse:0.052579
# [257]	train-rmse:0.04361	valid-rmse:0.052274
# [258]	train-rmse:0.043251	valid-rmse:0.051951
# [259]	train-rmse:0.042898	valid-rmse:0.051647
# [260]	train-rmse:0.042546	valid-rmse:0.051336
# [261]	train-rmse:0.042198	valid-rmse:0.051047
# [262]	train-rmse:0.041856	valid-rmse:0.050778
# [263]	train-rmse:0.041512	valid-rmse:0.05048
# [264]	train-rmse:0.041168	valid-rmse:0.050193
# [265]	train-rmse:0.040835	valid-rmse:0.049913
# [266]	train-rmse:0.040504	valid-rmse:0.049628
# [267]	train-rmse:0.040174	valid-rmse:0.049349
# [268]	train-rmse:0.039851	valid-rmse:0.049086
# [269]	train-rmse:0.039534	valid-rmse:0.048835
# [270]	train-rmse:0.03922	valid-rmse:0.048574
# [271]	train-rmse:0.0389	valid-rmse:0.048313
# [272]	train-rmse:0.03859	valid-rmse:0.048064
# [273]	train-rmse:0.038276	valid-rmse:0.047801
# [274]	train-rmse:0.037973	valid-rmse:0.04757
# [275]	train-rmse:0.037669	valid-rmse:0.047339
# [276]	train-rmse:0.037374	valid-rmse:0.047098
# [277]	train-rmse:0.037071	valid-rmse:0.046849
# [278]	train-rmse:0.036777	valid-rmse:0.046626
# [279]	train-rmse:0.03649	valid-rmse:0.046392
# [280]	train-rmse:0.036205	valid-rmse:0.046158
# [281]	train-rmse:0.035925	valid-rmse:0.045941
# [282]	train-rmse:0.035643	valid-rmse:0.04573
# [283]	train-rmse:0.035363	valid-rmse:0.045489
# [284]	train-rmse:0.035089	valid-rmse:0.045275
# [285]	train-rmse:0.034823	valid-rmse:0.045071
# [286]	train-rmse:0.034545	valid-rmse:0.044853
# [287]	train-rmse:0.034281	valid-rmse:0.044642
# [288]	train-rmse:0.034022	valid-rmse:0.044453
# [289]	train-rmse:0.033759	valid-rmse:0.044234
# [290]	train-rmse:0.033492	valid-rmse:0.044037
# [291]	train-rmse:0.033241	valid-rmse:0.043858
# [292]	train-rmse:0.032986	valid-rmse:0.043648
# [293]	train-rmse:0.032728	valid-rmse:0.043448
# [294]	train-rmse:0.032478	valid-rmse:0.043266
# [295]	train-rmse:0.032238	valid-rmse:0.043084
# [296]	train-rmse:0.031985	valid-rmse:0.042918
# [297]	train-rmse:0.031746	valid-rmse:0.042737
# [298]	train-rmse:0.031512	valid-rmse:0.042562
# [299]	train-rmse:0.031274	valid-rmse:0.042386
# [300]	train-rmse:0.031032	valid-rmse:0.042213
# [301]	train-rmse:0.030807	valid-rmse:0.042044
# [302]	train-rmse:0.030582	valid-rmse:0.041882
# [303]	train-rmse:0.030349	valid-rmse:0.041704
# [304]	train-rmse:0.03013	valid-rmse:0.041553
# [305]	train-rmse:0.029899	valid-rmse:0.041409
# [306]	train-rmse:0.029684	valid-rmse:0.041254
# [307]	train-rmse:0.029458	valid-rmse:0.041096
# [308]	train-rmse:0.029236	valid-rmse:0.04094
# [309]	train-rmse:0.029029	valid-rmse:0.040798
# [310]	train-rmse:0.028806	valid-rmse:0.040677
# [311]	train-rmse:0.028595	valid-rmse:0.04053
# [312]	train-rmse:0.028391	valid-rmse:0.040393
# [313]	train-rmse:0.02818	valid-rmse:0.040239
# [314]	train-rmse:0.027982	valid-rmse:0.040104
# [315]	train-rmse:0.027772	valid-rmse:0.039982
# [316]	train-rmse:0.027572	valid-rmse:0.039846
# [317]	train-rmse:0.027379	valid-rmse:0.039725
# [318]	train-rmse:0.027178	valid-rmse:0.039582
# [319]	train-rmse:0.026976	valid-rmse:0.039465
# [320]	train-rmse:0.026775	valid-rmse:0.039337
# [321]	train-rmse:0.026575	valid-rmse:0.039213
# [322]	train-rmse:0.026379	valid-rmse:0.039087
# [323]	train-rmse:0.026184	valid-rmse:0.038967
# [324]	train-rmse:0.025991	valid-rmse:0.03885
# [325]	train-rmse:0.025797	valid-rmse:0.03875
# [326]	train-rmse:0.025608	valid-rmse:0.038633
# [327]	train-rmse:0.025422	valid-rmse:0.038518
# [328]	train-rmse:0.025241	valid-rmse:0.038398
# [329]	train-rmse:0.025059	valid-rmse:0.038284
# [330]	train-rmse:0.024878	valid-rmse:0.038182
# [331]	train-rmse:0.024711	valid-rmse:0.038086
# [332]	train-rmse:0.024534	valid-rmse:0.037978
# [333]	train-rmse:0.024354	valid-rmse:0.03789
# [334]	train-rmse:0.024181	valid-rmse:0.037787
# [335]	train-rmse:0.024009	valid-rmse:0.037702
# [336]	train-rmse:0.023833	valid-rmse:0.037623
# [337]	train-rmse:0.023665	valid-rmse:0.037504
# [338]	train-rmse:0.023498	valid-rmse:0.037419
# [339]	train-rmse:0.023345	valid-rmse:0.037331
# [340]	train-rmse:0.023182	valid-rmse:0.037228
# [341]	train-rmse:0.023026	valid-rmse:0.037147
# [342]	train-rmse:0.022876	valid-rmse:0.037057
# [343]	train-rmse:0.022721	valid-rmse:0.03698
# [344]	train-rmse:0.022569	valid-rmse:0.036897
# [345]	train-rmse:0.022417	valid-rmse:0.036824
# [346]	train-rmse:0.022254	valid-rmse:0.036749
# [347]	train-rmse:0.022109	valid-rmse:0.036674
# [348]	train-rmse:0.021959	valid-rmse:0.036601
# [349]	train-rmse:0.021801	valid-rmse:0.036531
# [350]	train-rmse:0.02166	valid-rmse:0.036458
# [351]	train-rmse:0.021516	valid-rmse:0.036388
# [352]	train-rmse:0.021367	valid-rmse:0.036321
# [353]	train-rmse:0.021231	valid-rmse:0.036248
# [354]	train-rmse:0.021101	valid-rmse:0.036175
# [355]	train-rmse:0.020961	valid-rmse:0.036117
# [356]	train-rmse:0.020813	valid-rmse:0.036058
# [357]	train-rmse:0.020679	valid-rmse:0.036005
# [358]	train-rmse:0.02055	valid-rmse:0.035944
# [359]	train-rmse:0.020409	valid-rmse:0.035887
# [360]	train-rmse:0.020284	valid-rmse:0.03584
# [361]	train-rmse:0.020161	valid-rmse:0.035798
# [362]	train-rmse:0.020024	valid-rmse:0.035742
# [363]	train-rmse:0.019895	valid-rmse:0.035691
# [364]	train-rmse:0.019774	valid-rmse:0.035655
# [365]	train-rmse:0.019649	valid-rmse:0.035597
# [366]	train-rmse:0.019528	valid-rmse:0.035539
# [367]	train-rmse:0.019399	valid-rmse:0.03549
# [368]	train-rmse:0.019283	valid-rmse:0.03544
# [369]	train-rmse:0.019158	valid-rmse:0.035388
# [370]	train-rmse:0.01904	valid-rmse:0.035335
# [371]	train-rmse:0.018923	valid-rmse:0.035272
# [372]	train-rmse:0.01881	valid-rmse:0.035221
# [373]	train-rmse:0.018691	valid-rmse:0.035178
# [374]	train-rmse:0.01858	valid-rmse:0.035138
# [375]	train-rmse:0.018474	valid-rmse:0.035092
# [376]	train-rmse:0.018359	valid-rmse:0.03505
# [377]	train-rmse:0.018252	valid-rmse:0.035029
# [378]	train-rmse:0.018141	valid-rmse:0.034982
# [379]	train-rmse:0.018031	valid-rmse:0.034934
# [380]	train-rmse:0.017914	valid-rmse:0.034897
# [381]	train-rmse:0.01781	valid-rmse:0.034854
# [382]	train-rmse:0.017707	valid-rmse:0.03481
# [383]	train-rmse:0.017597	valid-rmse:0.034773
# [384]	train-rmse:0.017492	valid-rmse:0.034727
# [385]	train-rmse:0.017392	valid-rmse:0.034696
# [386]	train-rmse:0.017282	valid-rmse:0.034668
# [387]	train-rmse:0.017188	valid-rmse:0.034631
# [388]	train-rmse:0.017082	valid-rmse:0.034604
# [389]	train-rmse:0.016978	valid-rmse:0.034565
# [390]	train-rmse:0.016879	valid-rmse:0.034529
# [391]	train-rmse:0.016777	valid-rmse:0.034496
# [392]	train-rmse:0.016681	valid-rmse:0.034457
# [393]	train-rmse:0.016585	valid-rmse:0.034421
# [394]	train-rmse:0.016488	valid-rmse:0.034381
# [395]	train-rmse:0.016386	valid-rmse:0.03434
# [396]	train-rmse:0.016285	valid-rmse:0.034304
# [397]	train-rmse:0.016184	valid-rmse:0.034281
# [398]	train-rmse:0.016088	valid-rmse:0.03425
# [399]	train-rmse:0.015999	valid-rmse:0.034215
# [400]	train-rmse:0.01591	valid-rmse:0.034185
# [401]	train-rmse:0.015816	valid-rmse:0.034154
# [402]	train-rmse:0.015727	valid-rmse:0.034119
# [403]	train-rmse:0.015637	valid-rmse:0.034087
# [404]	train-rmse:0.015551	valid-rmse:0.034058
# [405]	train-rmse:0.015464	valid-rmse:0.034027
# [406]	train-rmse:0.015376	valid-rmse:0.034003
# [407]	train-rmse:0.015297	valid-rmse:0.033968
# [408]	train-rmse:0.015214	valid-rmse:0.033942
# [409]	train-rmse:0.015136	valid-rmse:0.033911
# [410]	train-rmse:0.015053	valid-rmse:0.033881
# [411]	train-rmse:0.014971	valid-rmse:0.033852
# [412]	train-rmse:0.014891	valid-rmse:0.033833
# [413]	train-rmse:0.014816	valid-rmse:0.033802
# [414]	train-rmse:0.014737	valid-rmse:0.033778
# [415]	train-rmse:0.014664	valid-rmse:0.033744
# [416]	train-rmse:0.014591	valid-rmse:0.033712
# [417]	train-rmse:0.014531	valid-rmse:0.033682
# [418]	train-rmse:0.014466	valid-rmse:0.033652
# [419]	train-rmse:0.014407	valid-rmse:0.033623
# [420]	train-rmse:0.014329	valid-rmse:0.03359
# [421]	train-rmse:0.014264	valid-rmse:0.033564
# [422]	train-rmse:0.014208	valid-rmse:0.033537
# [423]	train-rmse:0.014144	valid-rmse:0.033505
# [424]	train-rmse:0.014068	valid-rmse:0.033488
# [425]	train-rmse:0.014008	valid-rmse:0.033462
# [426]	train-rmse:0.013946	valid-rmse:0.033441
# [427]	train-rmse:0.013881	valid-rmse:0.033418
# [428]	train-rmse:0.013809	valid-rmse:0.033402
# [429]	train-rmse:0.013751	valid-rmse:0.033385
# [430]	train-rmse:0.013688	valid-rmse:0.033363
# [431]	train-rmse:0.013619	valid-rmse:0.033341
# [432]	train-rmse:0.013561	valid-rmse:0.033326
# [433]	train-rmse:0.013503	valid-rmse:0.033297
# [434]	train-rmse:0.013443	valid-rmse:0.033275
# [435]	train-rmse:0.013375	valid-rmse:0.033266
# [436]	train-rmse:0.01332	valid-rmse:0.033249
# [437]	train-rmse:0.013273	valid-rmse:0.033238
# [438]	train-rmse:0.013208	valid-rmse:0.033228
# [439]	train-rmse:0.013154	valid-rmse:0.03321
# [440]	train-rmse:0.013103	valid-rmse:0.033198
# [441]	train-rmse:0.013058	valid-rmse:0.033188
# [442]	train-rmse:0.013005	valid-rmse:0.033169
# [443]	train-rmse:0.012955	valid-rmse:0.033151
# [444]	train-rmse:0.0129	valid-rmse:0.03314
# [445]	train-rmse:0.012857	valid-rmse:0.033128
# [446]	train-rmse:0.012809	valid-rmse:0.033111
# [447]	train-rmse:0.012758	valid-rmse:0.033102
# [448]	train-rmse:0.012705	valid-rmse:0.033088
# [449]	train-rmse:0.012659	valid-rmse:0.033071
# [450]	train-rmse:0.012607	valid-rmse:0.033063
# [451]	train-rmse:0.012556	valid-rmse:0.03305
# [452]	train-rmse:0.012516	valid-rmse:0.033039
# [453]	train-rmse:0.012472	valid-rmse:0.033023
# [454]	train-rmse:0.012422	valid-rmse:0.033016
# [455]	train-rmse:0.012371	valid-rmse:0.033006
# [456]	train-rmse:0.012324	valid-rmse:0.032999
# [457]	train-rmse:0.012287	valid-rmse:0.03299
# [458]	train-rmse:0.012245	valid-rmse:0.032974
# [459]	train-rmse:0.012197	valid-rmse:0.032966
# [460]	train-rmse:0.012151	valid-rmse:0.032959
# [461]	train-rmse:0.012104	valid-rmse:0.032952
# [462]	train-rmse:0.012044	valid-rmse:0.032941
# [463]	train-rmse:0.011998	valid-rmse:0.032933
# [464]	train-rmse:0.011963	valid-rmse:0.032921
# [465]	train-rmse:0.01192	valid-rmse:0.032915
# [466]	train-rmse:0.011878	valid-rmse:0.032893
# [467]	train-rmse:0.011844	valid-rmse:0.032884
# [468]	train-rmse:0.011782	valid-rmse:0.032886
# [469]	train-rmse:0.011739	valid-rmse:0.03288
# [470]	train-rmse:0.01168	valid-rmse:0.032874
# [471]	train-rmse:0.011623	valid-rmse:0.032879
# [472]	train-rmse:0.01158	valid-rmse:0.032873
# [473]	train-rmse:0.011549	valid-rmse:0.032862
# [474]	train-rmse:0.011507	valid-rmse:0.032857
# [475]	train-rmse:0.011467	valid-rmse:0.032851
# [476]	train-rmse:0.011437	valid-rmse:0.032842
# [477]	train-rmse:0.011379	valid-rmse:0.03284
# [478]	train-rmse:0.011325	valid-rmse:0.032843
# [479]	train-rmse:0.011284	valid-rmse:0.032833
# [480]	train-rmse:0.011218	valid-rmse:0.032822
# [481]	train-rmse:0.011177	valid-rmse:0.032812
# [482]	train-rmse:0.011113	valid-rmse:0.032802
# [483]	train-rmse:0.011072	valid-rmse:0.032794
# [484]	train-rmse:0.011009	valid-rmse:0.032783
# [485]	train-rmse:0.010947	valid-rmse:0.032774
# [486]	train-rmse:0.010904	valid-rmse:0.03276
# [487]	train-rmse:0.010844	valid-rmse:0.032749
# [488]	train-rmse:0.010794	valid-rmse:0.03274
# [489]	train-rmse:0.010752	valid-rmse:0.032727
# [490]	train-rmse:0.010711	valid-rmse:0.032724
# [491]	train-rmse:0.010655	valid-rmse:0.032715
# [492]	train-rmse:0.01062	valid-rmse:0.032706
# [493]	train-rmse:0.010578	valid-rmse:0.032702
# [494]	train-rmse:0.010541	valid-rmse:0.032703
# [495]	train-rmse:0.010501	valid-rmse:0.032691
# [496]	train-rmse:0.010468	valid-rmse:0.032688
# [497]	train-rmse:0.010421	valid-rmse:0.032678
# [498]	train-rmse:0.010379	valid-rmse:0.032671
# [499]	train-rmse:0.010333	valid-rmse:0.032663
# [500]	train-rmse:0.010295	valid-rmse:0.032652
# [501]	train-rmse:0.010272	valid-rmse:0.032647
# [502]	train-rmse:0.01022	valid-rmse:0.03264
# [503]	train-rmse:0.01019	valid-rmse:0.032638
# [504]	train-rmse:0.010149	valid-rmse:0.032629
# [505]	train-rmse:0.010115	valid-rmse:0.032632
# [506]	train-rmse:0.010071	valid-rmse:0.032627
# [507]	train-rmse:0.010038	valid-rmse:0.03262
# [508]	train-rmse:0.010002	valid-rmse:0.03262
# [509]	train-rmse:0.00997	valid-rmse:0.032624
# [510]	train-rmse:0.009942	valid-rmse:0.03262
# [511]	train-rmse:0.009904	valid-rmse:0.032611
# [512]	train-rmse:0.009868	valid-rmse:0.032608
# [513]	train-rmse:0.00984	valid-rmse:0.032602
# [514]	train-rmse:0.009809	valid-rmse:0.032609
# [515]	train-rmse:0.009772	valid-rmse:0.032604
# [516]	train-rmse:0.009735	valid-rmse:0.032597
# [517]	train-rmse:0.009701	valid-rmse:0.032588
# [518]	train-rmse:0.009667	valid-rmse:0.032586
# [519]	train-rmse:0.009633	valid-rmse:0.032576
# [520]	train-rmse:0.009601	valid-rmse:0.032567
# [521]	train-rmse:0.009568	valid-rmse:0.032558
# [522]	train-rmse:0.009543	valid-rmse:0.032556
# [523]	train-rmse:0.009508	valid-rmse:0.032553
# [524]	train-rmse:0.009468	valid-rmse:0.032551
# [525]	train-rmse:0.009444	valid-rmse:0.032547
# [526]	train-rmse:0.00941	valid-rmse:0.032544
# [527]	train-rmse:0.00937	valid-rmse:0.032543
# [528]	train-rmse:0.009329	valid-rmse:0.032541
# [529]	train-rmse:0.009291	valid-rmse:0.032537
# [530]	train-rmse:0.009266	valid-rmse:0.032535
# [531]	train-rmse:0.009225	valid-rmse:0.032533
# [532]	train-rmse:0.009198	valid-rmse:0.032534
# [533]	train-rmse:0.009157	valid-rmse:0.032531
# [534]	train-rmse:0.009115	valid-rmse:0.032525
# [535]	train-rmse:0.009082	valid-rmse:0.032529
# [536]	train-rmse:0.00904	valid-rmse:0.032524
# [537]	train-rmse:0.008999	valid-rmse:0.03252
# [538]	train-rmse:0.008974	valid-rmse:0.03252
# [539]	train-rmse:0.008939	valid-rmse:0.032517
# [540]	train-rmse:0.008914	valid-rmse:0.032517
# [541]	train-rmse:0.008874	valid-rmse:0.032515
# [542]	train-rmse:0.008845	valid-rmse:0.032516
# [543]	train-rmse:0.008806	valid-rmse:0.032514
# [544]	train-rmse:0.00877	valid-rmse:0.03251
# [545]	train-rmse:0.008743	valid-rmse:0.032512
# [546]	train-rmse:0.008715	valid-rmse:0.032505
# [547]	train-rmse:0.008688	valid-rmse:0.032507
# [548]	train-rmse:0.008649	valid-rmse:0.032505
# [549]	train-rmse:0.008626	valid-rmse:0.032506
# [550]	train-rmse:0.008599	valid-rmse:0.032502
# [551]	train-rmse:0.008561	valid-rmse:0.0325
# [552]	train-rmse:0.008534	valid-rmse:0.032502
# [553]	train-rmse:0.008504	valid-rmse:0.032499
# [554]	train-rmse:0.008471	valid-rmse:0.032496
# [555]	train-rmse:0.008446	valid-rmse:0.032495
# [556]	train-rmse:0.008422	valid-rmse:0.032494
# [557]	train-rmse:0.008399	valid-rmse:0.032494
# [558]	train-rmse:0.008362	valid-rmse:0.032491
# [559]	train-rmse:0.008339	valid-rmse:0.03249
# [560]	train-rmse:0.008312	valid-rmse:0.032485
# [561]	train-rmse:0.008288	valid-rmse:0.032484
# [562]	train-rmse:0.008261	valid-rmse:0.03248
# [563]	train-rmse:0.008239	valid-rmse:0.032481
# [564]	train-rmse:0.008212	valid-rmse:0.032482
# [565]	train-rmse:0.008181	valid-rmse:0.03248
# [566]	train-rmse:0.008159	valid-rmse:0.03248
# [567]	train-rmse:0.008135	valid-rmse:0.032486
# [568]	train-rmse:0.00811	valid-rmse:0.032482
# [569]	train-rmse:0.008085	valid-rmse:0.032479
# [570]	train-rmse:0.008052	valid-rmse:0.032482
# [571]	train-rmse:0.008028	valid-rmse:0.032478
# [572]	train-rmse:0.008006	valid-rmse:0.032477
# [573]	train-rmse:0.007981	valid-rmse:0.032475
# [574]	train-rmse:0.007952	valid-rmse:0.032478
# [575]	train-rmse:0.007931	valid-rmse:0.032474
# [576]	train-rmse:0.007909	valid-rmse:0.032475
# [577]	train-rmse:0.007888	valid-rmse:0.032471
# [578]	train-rmse:0.007865	valid-rmse:0.032462
# [579]	train-rmse:0.007841	valid-rmse:0.032459
# [580]	train-rmse:0.007818	valid-rmse:0.032457
# [581]	train-rmse:0.007795	valid-rmse:0.032456
# [582]	train-rmse:0.007778	valid-rmse:0.032454
# [583]	train-rmse:0.007747	valid-rmse:0.032457
# [584]	train-rmse:0.007725	valid-rmse:0.032457
# [585]	train-rmse:0.007705	valid-rmse:0.032458
# [586]	train-rmse:0.007685	valid-rmse:0.032455
# [587]	train-rmse:0.007663	valid-rmse:0.032451
# [588]	train-rmse:0.007647	valid-rmse:0.032454
# [589]	train-rmse:0.00763	valid-rmse:0.032448
# [590]	train-rmse:0.007609	valid-rmse:0.032452
# [591]	train-rmse:0.007596	valid-rmse:0.032453
# [592]	train-rmse:0.007569	valid-rmse:0.032455
# [593]	train-rmse:0.007545	valid-rmse:0.032451
# [594]	train-rmse:0.007523	valid-rmse:0.032451
# [595]	train-rmse:0.007496	valid-rmse:0.032454
# [596]	train-rmse:0.00748	valid-rmse:0.032448
# [597]	train-rmse:0.007457	valid-rmse:0.032442
# [598]	train-rmse:0.007434	valid-rmse:0.032438
# [599]	train-rmse:0.00741	valid-rmse:0.032436
# [600]	train-rmse:0.007389	valid-rmse:0.032435
# [601]	train-rmse:0.007371	valid-rmse:0.032435
# [602]	train-rmse:0.00735	valid-rmse:0.032438
# [603]	train-rmse:0.007332	valid-rmse:0.032438
# [604]	train-rmse:0.007311	valid-rmse:0.032437
# [605]	train-rmse:0.007293	valid-rmse:0.032433
# [606]	train-rmse:0.007268	valid-rmse:0.032437
# [607]	train-rmse:0.007247	valid-rmse:0.032433
# [608]	train-rmse:0.007235	valid-rmse:0.032432
# [609]	train-rmse:0.007217	valid-rmse:0.032425
# [610]	train-rmse:0.007194	valid-rmse:0.032427
# [611]	train-rmse:0.007174	valid-rmse:0.03243
# [612]	train-rmse:0.007156	valid-rmse:0.032432
# [613]	train-rmse:0.007138	valid-rmse:0.032429
# [614]	train-rmse:0.00712	valid-rmse:0.032421
# [615]	train-rmse:0.0071	valid-rmse:0.03242
# [616]	train-rmse:0.007076	valid-rmse:0.032419
# [617]	train-rmse:0.007059	valid-rmse:0.032421
# [618]	train-rmse:0.007042	valid-rmse:0.032424
# [619]	train-rmse:0.007025	valid-rmse:0.032423
# [620]	train-rmse:0.007005	valid-rmse:0.032417
# [621]	train-rmse:0.006988	valid-rmse:0.032419
# [622]	train-rmse:0.006965	valid-rmse:0.032419
# [623]	train-rmse:0.006946	valid-rmse:0.032414
# [624]	train-rmse:0.00693	valid-rmse:0.032416
# [625]	train-rmse:0.006911	valid-rmse:0.03241
# [626]	train-rmse:0.006892	valid-rmse:0.032412
# [627]	train-rmse:0.006876	valid-rmse:0.032413
# [628]	train-rmse:0.006859	valid-rmse:0.032414
# [629]	train-rmse:0.006849	valid-rmse:0.032413
# [630]	train-rmse:0.006833	valid-rmse:0.032407
# [631]	train-rmse:0.00681	valid-rmse:0.032409
# [632]	train-rmse:0.006795	valid-rmse:0.032412
# [633]	train-rmse:0.006774	valid-rmse:0.032412
# [634]	train-rmse:0.006756	valid-rmse:0.032407
# [635]	train-rmse:0.006739	valid-rmse:0.032403
# [636]	train-rmse:0.006718	valid-rmse:0.032401
# [637]	train-rmse:0.006702	valid-rmse:0.032403
# [638]	train-rmse:0.006687	valid-rmse:0.0324
# [639]	train-rmse:0.006667	valid-rmse:0.032397
# [640]	train-rmse:0.006646	valid-rmse:0.032402
# [641]	train-rmse:0.006631	valid-rmse:0.032404
# [642]	train-rmse:0.006616	valid-rmse:0.032405
# [643]	train-rmse:0.006598	valid-rmse:0.0324
# [644]	train-rmse:0.006578	valid-rmse:0.032397
# [645]	train-rmse:0.006558	valid-rmse:0.032404
# [646]	train-rmse:0.006544	valid-rmse:0.032402
# [647]	train-rmse:0.006524	valid-rmse:0.032407
# [648]	train-rmse:0.006506	valid-rmse:0.032413
# [649]	train-rmse:0.006489	valid-rmse:0.032407
# Stopping. Best iteration:
# [639]	train-rmse:0.006667	valid-rmse:0.032397
# 2019-08-06 11:38:40,978 - ALPHA_MIND - INFO - Training time cost 4.997131586074829s
# 2019-08-06 11:38:40,979 - ALPHA_MIND - INFO - best_score = 0.032397, best_round = 639
# 2019-08-06 11:38:40,982 - ALPHA_MIND - INFO - 2019-01-04 00:00:00 total_data_test_excess: 499
# 2019-08-06 11:38:40,992 - ALPHA_MIND - INFO - 2019-01-04 00:00:00 len_of_total_data: 499
# 2019-08-06 11:38:40,997 - ALPHA_MIND - INFO - 2019-01-04 00:00:00 len_of_total_data_test_excess: 499
# 2019-08-06 11:38:40,998 - ALPHA_MIND - INFO - 2019-01-04 00:00:00 full re-balance: 499
# 2019-08-06 11:38:41,000 - ALPHA_MIND - INFO - shape_of_benchmark_w: (499,)
# 2019-08-06 11:38:41,002 - ALPHA_MIND - INFO - shape_of_total_risk_exp_pre: (499, 36)
# 2019-08-06 11:38:41,003 - ALPHA_MIND - INFO - shape_of_total_risk_exp: (499, 36)
# 2019-08-06 11:38:41,004 - ALPHA_MIND - INFO - constraints: (2, 36) in 2019-01-04 00:00:00
# 2019-08-06 11:38:41,004 - ALPHA_MIND - INFO - lbound: (499,) in 2019-01-04 00:00:00
# 2019-08-06 11:38:41,005 - ALPHA_MIND - INFO - ubound: (499,) in 2019-01-04 00:00:00
# 2019-08-06 11:38:41,009 - ALPHA_MIND - INFO - shape_of_predict_xgboost: (499, 1)
# 2019-08-06 11:38:41,059 - ALPHA_MIND - INFO - target_pos_shape: (499, 3)
# 2019-08-06 11:38:41,060 - ALPHA_MIND - INFO - len_codes:(499,)
# 2019-08-06 11:38:41,065 - ALPHA_MIND - INFO - len_result: 499
# 2019-08-06 11:38:41,065 - ALPHA_MIND - INFO - len_rets: 1, len_trade_dates: 1
# 2019-08-06 11:38:41,066 - ALPHA_MIND - INFO - len_net_rets: 1, len_trade_dates: 1
# 2019-08-06 11:38:41,067 - ALPHA_MIND - INFO - 2019-01-04 00:00:00 is finished
# 2019-08-06 11:38:41,067 - ALPHA_MIND - INFO - 2019-01-08 00:00:00 is start
# 2019-08-06 11:38:41,073 - ALPHA_MIND - INFO - len_x_train: 998, len_y_train: 998
# 2019-08-06 11:38:41,074 - ALPHA_MIND - INFO - X_train.shape=(998, 101), X_test.shape = (998, 1)
# <bound method XGBooster.get_params of <m1_xgb.XGBooster object at 0x7f82b0a93518>>
# non_cross_validation。。。。
# [0]	train-rmse:0.49385	valid-rmse:0.496502
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.488936	valid-rmse:0.491586
# [2]	train-rmse:0.484071	valid-rmse:0.48672
# [3]	train-rmse:0.479255	valid-rmse:0.481902
# [4]	train-rmse:0.474487	valid-rmse:0.477132
# [5]	train-rmse:0.469767	valid-rmse:0.47241
# [6]	train-rmse:0.465094	valid-rmse:0.467736
# [7]	train-rmse:0.460468	valid-rmse:0.463108
# [8]	train-rmse:0.455889	valid-rmse:0.458527
# [9]	train-rmse:0.451355	valid-rmse:0.453992
# [10]	train-rmse:0.446867	valid-rmse:0.449502
# [11]	train-rmse:0.442424	valid-rmse:0.445057
# [12]	train-rmse:0.438026	valid-rmse:0.440656
# [13]	train-rmse:0.433671	valid-rmse:0.4363
# [14]	train-rmse:0.429361	valid-rmse:0.431988
# [15]	train-rmse:0.425093	valid-rmse:0.427718
# [16]	train-rmse:0.420869	valid-rmse:0.423492
# [17]	train-rmse:0.416687	valid-rmse:0.419308
# [18]	train-rmse:0.412546	valid-rmse:0.415166
# [19]	train-rmse:0.408448	valid-rmse:0.411065
# [20]	train-rmse:0.40439	valid-rmse:0.407006
# [21]	train-rmse:0.400374	valid-rmse:0.402987
# [22]	train-rmse:0.396397	valid-rmse:0.399008
# [23]	train-rmse:0.392461	valid-rmse:0.39507
# [24]	train-rmse:0.388564	valid-rmse:0.391171
# [25]	train-rmse:0.384706	valid-rmse:0.387311
# [26]	train-rmse:0.380887	valid-rmse:0.38349
# [27]	train-rmse:0.377106	valid-rmse:0.379707
# [28]	train-rmse:0.373364	valid-rmse:0.375962
# [29]	train-rmse:0.369659	valid-rmse:0.372255
# [30]	train-rmse:0.365991	valid-rmse:0.368585
# [31]	train-rmse:0.36236	valid-rmse:0.364952
# [32]	train-rmse:0.358766	valid-rmse:0.361355
# [33]	train-rmse:0.355207	valid-rmse:0.357795
# [34]	train-rmse:0.351685	valid-rmse:0.35427
# [35]	train-rmse:0.348198	valid-rmse:0.350781
# [36]	train-rmse:0.344746	valid-rmse:0.347326
# [37]	train-rmse:0.341329	valid-rmse:0.343907
# [38]	train-rmse:0.337946	valid-rmse:0.340521
# [39]	train-rmse:0.334597	valid-rmse:0.33717
# [40]	train-rmse:0.331282	valid-rmse:0.333853
# [41]	train-rmse:0.328	valid-rmse:0.330568
# [42]	train-rmse:0.324752	valid-rmse:0.327317
# [43]	train-rmse:0.321536	valid-rmse:0.324099
# [44]	train-rmse:0.318352	valid-rmse:0.320913
# [45]	train-rmse:0.315201	valid-rmse:0.317759
# [46]	train-rmse:0.312081	valid-rmse:0.314636
# [47]	train-rmse:0.308993	valid-rmse:0.311545
# [48]	train-rmse:0.305936	valid-rmse:0.308486
# [49]	train-rmse:0.30291	valid-rmse:0.305457
# [50]	train-rmse:0.299914	valid-rmse:0.302458
# [51]	train-rmse:0.296948	valid-rmse:0.29949
# [52]	train-rmse:0.294013	valid-rmse:0.296551
# [53]	train-rmse:0.291107	valid-rmse:0.293642
# [54]	train-rmse:0.28823	valid-rmse:0.290763
# [55]	train-rmse:0.285382	valid-rmse:0.287912
# [56]	train-rmse:0.282563	valid-rmse:0.28509
# [57]	train-rmse:0.279773	valid-rmse:0.282297
# [58]	train-rmse:0.277011	valid-rmse:0.279532
# [59]	train-rmse:0.274276	valid-rmse:0.276794
# [60]	train-rmse:0.271569	valid-rmse:0.274085
# [61]	train-rmse:0.26889	valid-rmse:0.271402
# [62]	train-rmse:0.266238	valid-rmse:0.268747
# [63]	train-rmse:0.263612	valid-rmse:0.266118
# [64]	train-rmse:0.261013	valid-rmse:0.263516
# [65]	train-rmse:0.258441	valid-rmse:0.26094
# [66]	train-rmse:0.255894	valid-rmse:0.25839
# [67]	train-rmse:0.253373	valid-rmse:0.255866
# [68]	train-rmse:0.250878	valid-rmse:0.253368
# [69]	train-rmse:0.248408	valid-rmse:0.250894
# [70]	train-rmse:0.245963	valid-rmse:0.248446
# [71]	train-rmse:0.243543	valid-rmse:0.246022
# [72]	train-rmse:0.241147	valid-rmse:0.243623
# [73]	train-rmse:0.238776	valid-rmse:0.241248
# [74]	train-rmse:0.236429	valid-rmse:0.238898
# [75]	train-rmse:0.234105	valid-rmse:0.23657
# [76]	train-rmse:0.231805	valid-rmse:0.234267
# [77]	train-rmse:0.229529	valid-rmse:0.231987
# [78]	train-rmse:0.227275	valid-rmse:0.22973
# [79]	train-rmse:0.225045	valid-rmse:0.227495
# [80]	train-rmse:0.222837	valid-rmse:0.225284
# [81]	train-rmse:0.220651	valid-rmse:0.223094
# [82]	train-rmse:0.218488	valid-rmse:0.220931
# [83]	train-rmse:0.216347	valid-rmse:0.21879
# [84]	train-rmse:0.214227	valid-rmse:0.216671
# [85]	train-rmse:0.212129	valid-rmse:0.214569
# [86]	train-rmse:0.210053	valid-rmse:0.212492
# [87]	train-rmse:0.207997	valid-rmse:0.210437
# [88]	train-rmse:0.205962	valid-rmse:0.208402
# [89]	train-rmse:0.203949	valid-rmse:0.206388
# [90]	train-rmse:0.201955	valid-rmse:0.204391
# [91]	train-rmse:0.199982	valid-rmse:0.202418
# [92]	train-rmse:0.198029	valid-rmse:0.200465
# [93]	train-rmse:0.196096	valid-rmse:0.198532
# [94]	train-rmse:0.194183	valid-rmse:0.196618
# [95]	train-rmse:0.192289	valid-rmse:0.194724
# [96]	train-rmse:0.190414	valid-rmse:0.192846
# [97]	train-rmse:0.188559	valid-rmse:0.19099
# [98]	train-rmse:0.186723	valid-rmse:0.189153
# [99]	train-rmse:0.184905	valid-rmse:0.187336
# [100]	train-rmse:0.183104	valid-rmse:0.185537
# [101]	train-rmse:0.181323	valid-rmse:0.183756
# [102]	train-rmse:0.179558	valid-rmse:0.181994
# [103]	train-rmse:0.177814	valid-rmse:0.180249
# [104]	train-rmse:0.176085	valid-rmse:0.178522
# [105]	train-rmse:0.174374	valid-rmse:0.176813
# [106]	train-rmse:0.172682	valid-rmse:0.175121
# [107]	train-rmse:0.171006	valid-rmse:0.173447
# [108]	train-rmse:0.169349	valid-rmse:0.17179
# [109]	train-rmse:0.167707	valid-rmse:0.170149
# [110]	train-rmse:0.166084	valid-rmse:0.168526
# [111]	train-rmse:0.164475	valid-rmse:0.166919
# [112]	train-rmse:0.162885	valid-rmse:0.165329
# [113]	train-rmse:0.161309	valid-rmse:0.163751
# [114]	train-rmse:0.159749	valid-rmse:0.16219
# [115]	train-rmse:0.158208	valid-rmse:0.160644
# [116]	train-rmse:0.15668	valid-rmse:0.159114
# [117]	train-rmse:0.15517	valid-rmse:0.1576
# [118]	train-rmse:0.153675	valid-rmse:0.156102
# [119]	train-rmse:0.152195	valid-rmse:0.154628
# [120]	train-rmse:0.150731	valid-rmse:0.15317
# [121]	train-rmse:0.149279	valid-rmse:0.151716
# [122]	train-rmse:0.147841	valid-rmse:0.150276
# [123]	train-rmse:0.146422	valid-rmse:0.148853
# [124]	train-rmse:0.145017	valid-rmse:0.147454
# [125]	train-rmse:0.143626	valid-rmse:0.14607
# [126]	train-rmse:0.142248	valid-rmse:0.144683
# [127]	train-rmse:0.140886	valid-rmse:0.143312
# [128]	train-rmse:0.139534	valid-rmse:0.141973
# [129]	train-rmse:0.1382	valid-rmse:0.140635
# [130]	train-rmse:0.136876	valid-rmse:0.139323
# [131]	train-rmse:0.135568	valid-rmse:0.138011
# [132]	train-rmse:0.134274	valid-rmse:0.13671
# [133]	train-rmse:0.132994	valid-rmse:0.135436
# [134]	train-rmse:0.131726	valid-rmse:0.134164
# [135]	train-rmse:0.13047	valid-rmse:0.132903
# [136]	train-rmse:0.129226	valid-rmse:0.131671
# [137]	train-rmse:0.127995	valid-rmse:0.130451
# [138]	train-rmse:0.126779	valid-rmse:0.129231
# [139]	train-rmse:0.125577	valid-rmse:0.128025
# [140]	train-rmse:0.12438	valid-rmse:0.126842
# [141]	train-rmse:0.123199	valid-rmse:0.125673
# [142]	train-rmse:0.122033	valid-rmse:0.124503
# [143]	train-rmse:0.120873	valid-rmse:0.123357
# [144]	train-rmse:0.119729	valid-rmse:0.122224
# [145]	train-rmse:0.118599	valid-rmse:0.12109
# [146]	train-rmse:0.117475	valid-rmse:0.11998
# [147]	train-rmse:0.116368	valid-rmse:0.11887
# [148]	train-rmse:0.11527	valid-rmse:0.117779
# [149]	train-rmse:0.11418	valid-rmse:0.116713
# [150]	train-rmse:0.113105	valid-rmse:0.115643
# [151]	train-rmse:0.112037	valid-rmse:0.114599
# [152]	train-rmse:0.110983	valid-rmse:0.113541
# [153]	train-rmse:0.109941	valid-rmse:0.112501
# [154]	train-rmse:0.108908	valid-rmse:0.11148
# [155]	train-rmse:0.107887	valid-rmse:0.110468
# [156]	train-rmse:0.106875	valid-rmse:0.109453
# [157]	train-rmse:0.105875	valid-rmse:0.108462
# [158]	train-rmse:0.104885	valid-rmse:0.107473
# [159]	train-rmse:0.103902	valid-rmse:0.106505
# [160]	train-rmse:0.102932	valid-rmse:0.105545
# [161]	train-rmse:0.10197	valid-rmse:0.104597
# [162]	train-rmse:0.101021	valid-rmse:0.103649
# [163]	train-rmse:0.100078	valid-rmse:0.102721
# [164]	train-rmse:0.099148	valid-rmse:0.101788
# [165]	train-rmse:0.098227	valid-rmse:0.100882
# [166]	train-rmse:0.097316	valid-rmse:0.099974
# [167]	train-rmse:0.096413	valid-rmse:0.099086
# [168]	train-rmse:0.095518	valid-rmse:0.098201
# [169]	train-rmse:0.094635	valid-rmse:0.09733
# [170]	train-rmse:0.093762	valid-rmse:0.096466
# [171]	train-rmse:0.092898	valid-rmse:0.095608
# [172]	train-rmse:0.092044	valid-rmse:0.094768
# [173]	train-rmse:0.091196	valid-rmse:0.093928
# [174]	train-rmse:0.090357	valid-rmse:0.093095
# [175]	train-rmse:0.089526	valid-rmse:0.092274
# [176]	train-rmse:0.088707	valid-rmse:0.091454
# [177]	train-rmse:0.087895	valid-rmse:0.090647
# [178]	train-rmse:0.08709	valid-rmse:0.089863
# [179]	train-rmse:0.086294	valid-rmse:0.089074
# [180]	train-rmse:0.085508	valid-rmse:0.088288
# [181]	train-rmse:0.084725	valid-rmse:0.087518
# [182]	train-rmse:0.083955	valid-rmse:0.086752
# [183]	train-rmse:0.083192	valid-rmse:0.085999
# [184]	train-rmse:0.082436	valid-rmse:0.085258
# [185]	train-rmse:0.08169	valid-rmse:0.084514
# [186]	train-rmse:0.080946	valid-rmse:0.083775
# [187]	train-rmse:0.080215	valid-rmse:0.08306
# [188]	train-rmse:0.079492	valid-rmse:0.082347
# [189]	train-rmse:0.078773	valid-rmse:0.081652
# [190]	train-rmse:0.078065	valid-rmse:0.080947
# [191]	train-rmse:0.077363	valid-rmse:0.080263
# [192]	train-rmse:0.076666	valid-rmse:0.079588
# [193]	train-rmse:0.075975	valid-rmse:0.078905
# [194]	train-rmse:0.075294	valid-rmse:0.078236
# [195]	train-rmse:0.074621	valid-rmse:0.077576
# [196]	train-rmse:0.073957	valid-rmse:0.076923
# [197]	train-rmse:0.073297	valid-rmse:0.076277
# [198]	train-rmse:0.072647	valid-rmse:0.075638
# [199]	train-rmse:0.072001	valid-rmse:0.075018
# [200]	train-rmse:0.071361	valid-rmse:0.074405
# [201]	train-rmse:0.070732	valid-rmse:0.073788
# [202]	train-rmse:0.070108	valid-rmse:0.073197
# [203]	train-rmse:0.069488	valid-rmse:0.072599
# [204]	train-rmse:0.068876	valid-rmse:0.072008
# [205]	train-rmse:0.068269	valid-rmse:0.071414
# [206]	train-rmse:0.067669	valid-rmse:0.070835
# [207]	train-rmse:0.067075	valid-rmse:0.070274
# [208]	train-rmse:0.066487	valid-rmse:0.069697
# [209]	train-rmse:0.065905	valid-rmse:0.069129
# [210]	train-rmse:0.065329	valid-rmse:0.068561
# [211]	train-rmse:0.064764	valid-rmse:0.068011
# [212]	train-rmse:0.064201	valid-rmse:0.067477
# [213]	train-rmse:0.063643	valid-rmse:0.066933
# [214]	train-rmse:0.063093	valid-rmse:0.066398
# [215]	train-rmse:0.062549	valid-rmse:0.065881
# [216]	train-rmse:0.062009	valid-rmse:0.065353
# [217]	train-rmse:0.061474	valid-rmse:0.064851
# [218]	train-rmse:0.060947	valid-rmse:0.064338
# [219]	train-rmse:0.060424	valid-rmse:0.063826
# [220]	train-rmse:0.059906	valid-rmse:0.063321
# [221]	train-rmse:0.059397	valid-rmse:0.062836
# [222]	train-rmse:0.05889	valid-rmse:0.062359
# [223]	train-rmse:0.05839	valid-rmse:0.061898
# [224]	train-rmse:0.057896	valid-rmse:0.061423
# [225]	train-rmse:0.057409	valid-rmse:0.060969
# [226]	train-rmse:0.056924	valid-rmse:0.060523
# [227]	train-rmse:0.056445	valid-rmse:0.060073
# [228]	train-rmse:0.05597	valid-rmse:0.059625
# [229]	train-rmse:0.0555	valid-rmse:0.059191
# [230]	train-rmse:0.055039	valid-rmse:0.058757
# [231]	train-rmse:0.054579	valid-rmse:0.058332
# [232]	train-rmse:0.054124	valid-rmse:0.0579
# [233]	train-rmse:0.053669	valid-rmse:0.05749
# [234]	train-rmse:0.053226	valid-rmse:0.057079
# [235]	train-rmse:0.052786	valid-rmse:0.056667
# [236]	train-rmse:0.052345	valid-rmse:0.056273
# [237]	train-rmse:0.05191	valid-rmse:0.055882
# [238]	train-rmse:0.051485	valid-rmse:0.05548
# [239]	train-rmse:0.051061	valid-rmse:0.055101
# [240]	train-rmse:0.05064	valid-rmse:0.054724
# [241]	train-rmse:0.05023	valid-rmse:0.054339
# [242]	train-rmse:0.049823	valid-rmse:0.053979
# [243]	train-rmse:0.049421	valid-rmse:0.053604
# [244]	train-rmse:0.049022	valid-rmse:0.053231
# [245]	train-rmse:0.048623	valid-rmse:0.052878
# [246]	train-rmse:0.048234	valid-rmse:0.05253
# [247]	train-rmse:0.047845	valid-rmse:0.052181
# [248]	train-rmse:0.047459	valid-rmse:0.051836
# [249]	train-rmse:0.047085	valid-rmse:0.051493
# [250]	train-rmse:0.046712	valid-rmse:0.051161
# [251]	train-rmse:0.046344	valid-rmse:0.050819
# [252]	train-rmse:0.045978	valid-rmse:0.050478
# [253]	train-rmse:0.045613	valid-rmse:0.050159
# [254]	train-rmse:0.045253	valid-rmse:0.049836
# [255]	train-rmse:0.044902	valid-rmse:0.049521
# [256]	train-rmse:0.044553	valid-rmse:0.049218
# [257]	train-rmse:0.04421	valid-rmse:0.048906
# [258]	train-rmse:0.043864	valid-rmse:0.048603
# [259]	train-rmse:0.043523	valid-rmse:0.048301
# [260]	train-rmse:0.043189	valid-rmse:0.047994
# [261]	train-rmse:0.042857	valid-rmse:0.047692
# [262]	train-rmse:0.04253	valid-rmse:0.04741
# [263]	train-rmse:0.042207	valid-rmse:0.047115
# [264]	train-rmse:0.041881	valid-rmse:0.046826
# [265]	train-rmse:0.041565	valid-rmse:0.046545
# [266]	train-rmse:0.041253	valid-rmse:0.046258
# [267]	train-rmse:0.040945	valid-rmse:0.045976
# [268]	train-rmse:0.040642	valid-rmse:0.045707
# [269]	train-rmse:0.040334	valid-rmse:0.045446
# [270]	train-rmse:0.040035	valid-rmse:0.045193
# [271]	train-rmse:0.039741	valid-rmse:0.044929
# [272]	train-rmse:0.03945	valid-rmse:0.044662
# [273]	train-rmse:0.039156	valid-rmse:0.044408
# [274]	train-rmse:0.03887	valid-rmse:0.04417
# [275]	train-rmse:0.038589	valid-rmse:0.04392
# [276]	train-rmse:0.038309	valid-rmse:0.043684
# [277]	train-rmse:0.038034	valid-rmse:0.043456
# [278]	train-rmse:0.037762	valid-rmse:0.043214
# [279]	train-rmse:0.037487	valid-rmse:0.042979
# [280]	train-rmse:0.037219	valid-rmse:0.042753
# [281]	train-rmse:0.036957	valid-rmse:0.042519
# [282]	train-rmse:0.036696	valid-rmse:0.042303
# [283]	train-rmse:0.036441	valid-rmse:0.042077
# [284]	train-rmse:0.036186	valid-rmse:0.041864
# [285]	train-rmse:0.035932	valid-rmse:0.041644
# [286]	train-rmse:0.035683	valid-rmse:0.041439
# [287]	train-rmse:0.035437	valid-rmse:0.041233
# [288]	train-rmse:0.035189	valid-rmse:0.04103
# [289]	train-rmse:0.034948	valid-rmse:0.040843
# [290]	train-rmse:0.03471	valid-rmse:0.040645
# [291]	train-rmse:0.034475	valid-rmse:0.040452
# [292]	train-rmse:0.034242	valid-rmse:0.040264
# [293]	train-rmse:0.03401	valid-rmse:0.040067
# [294]	train-rmse:0.033784	valid-rmse:0.03988
# [295]	train-rmse:0.033559	valid-rmse:0.03971
# [296]	train-rmse:0.033338	valid-rmse:0.039527
# [297]	train-rmse:0.033112	valid-rmse:0.039345
# [298]	train-rmse:0.032895	valid-rmse:0.039174
# [299]	train-rmse:0.032682	valid-rmse:0.038997
# [300]	train-rmse:0.032471	valid-rmse:0.038833
# [301]	train-rmse:0.032261	valid-rmse:0.03865
# [302]	train-rmse:0.032048	valid-rmse:0.038484
# [303]	train-rmse:0.031843	valid-rmse:0.038307
# [304]	train-rmse:0.031642	valid-rmse:0.03814
# [305]	train-rmse:0.031436	valid-rmse:0.037981
# [306]	train-rmse:0.031236	valid-rmse:0.037815
# [307]	train-rmse:0.031036	valid-rmse:0.037661
# [308]	train-rmse:0.030842	valid-rmse:0.037504
# [309]	train-rmse:0.030646	valid-rmse:0.037351
# [310]	train-rmse:0.030456	valid-rmse:0.037199
# [311]	train-rmse:0.030268	valid-rmse:0.037048
# [312]	train-rmse:0.030083	valid-rmse:0.036896
# [313]	train-rmse:0.029903	valid-rmse:0.036744
# [314]	train-rmse:0.029722	valid-rmse:0.036603
# [315]	train-rmse:0.02954	valid-rmse:0.036467
# [316]	train-rmse:0.029363	valid-rmse:0.036331
# [317]	train-rmse:0.02919	valid-rmse:0.036198
# [318]	train-rmse:0.029023	valid-rmse:0.036068
# [319]	train-rmse:0.028853	valid-rmse:0.035932
# [320]	train-rmse:0.028683	valid-rmse:0.035811
# [321]	train-rmse:0.028516	valid-rmse:0.035686
# [322]	train-rmse:0.028357	valid-rmse:0.035557
# [323]	train-rmse:0.028193	valid-rmse:0.035434
# [324]	train-rmse:0.028032	valid-rmse:0.035315
# [325]	train-rmse:0.027879	valid-rmse:0.035194
# [326]	train-rmse:0.027724	valid-rmse:0.035082
# [327]	train-rmse:0.027568	valid-rmse:0.034961
# [328]	train-rmse:0.027417	valid-rmse:0.034854
# [329]	train-rmse:0.027266	valid-rmse:0.03474
# [330]	train-rmse:0.027116	valid-rmse:0.034634
# [331]	train-rmse:0.026973	valid-rmse:0.034525
# [332]	train-rmse:0.026828	valid-rmse:0.034417
# [333]	train-rmse:0.026684	valid-rmse:0.034315
# [334]	train-rmse:0.026543	valid-rmse:0.034222
# [335]	train-rmse:0.026405	valid-rmse:0.034122
# [336]	train-rmse:0.026265	valid-rmse:0.034034
# [337]	train-rmse:0.02613	valid-rmse:0.033937
# [338]	train-rmse:0.025997	valid-rmse:0.033841
# [339]	train-rmse:0.025867	valid-rmse:0.033753
# [340]	train-rmse:0.025735	valid-rmse:0.033646
# [341]	train-rmse:0.025603	valid-rmse:0.033561
# [342]	train-rmse:0.025462	valid-rmse:0.033467
# ...
# [71]	train-rmse:0.245063	valid-rmse:0.244229
# [72]	train-rmse:0.242661	valid-rmse:0.24182
# [73]	train-rmse:0.240284	valid-rmse:0.239435
# [74]	train-rmse:0.23793	valid-rmse:0.237074
# [75]	train-rmse:0.235601	valid-rmse:0.234737
# [76]	train-rmse:0.233295	valid-rmse:0.232424
# [77]	train-rmse:0.231013	valid-rmse:0.230134
# [78]	train-rmse:0.228754	valid-rmse:0.227869
# [79]	train-rmse:0.226518	valid-rmse:0.225626
# [80]	train-rmse:0.224305	valid-rmse:0.223406
# [81]	train-rmse:0.222115	valid-rmse:0.221208
# [82]	train-rmse:0.219946	valid-rmse:0.219033
# [83]	train-rmse:0.217801	valid-rmse:0.21688
# [84]	train-rmse:0.215677	valid-rmse:0.214749
# [85]	train-rmse:0.213574	valid-rmse:0.21264
# [86]	train-rmse:0.211494	valid-rmse:0.210552
# [87]	train-rmse:0.209435	valid-rmse:0.208485
# [88]	train-rmse:0.207396	valid-rmse:0.20644
# [89]	train-rmse:0.20538	valid-rmse:0.204414
# [90]	train-rmse:0.203383	valid-rmse:0.20241
# [91]	train-rmse:0.201407	valid-rmse:0.200426
# [92]	train-rmse:0.199452	valid-rmse:0.198463
# [93]	train-rmse:0.197517	valid-rmse:0.196519
# [94]	train-rmse:0.195601	valid-rmse:0.194595
# [95]	train-rmse:0.193705	valid-rmse:0.192691
# [96]	train-rmse:0.191829	valid-rmse:0.190806
# [97]	train-rmse:0.189972	valid-rmse:0.188941
# [98]	train-rmse:0.188134	valid-rmse:0.187094
# [99]	train-rmse:0.186316	valid-rmse:0.185267
# [100]	train-rmse:0.184516	valid-rmse:0.183458
# [101]	train-rmse:0.182734	valid-rmse:0.181668
# [102]	train-rmse:0.180971	valid-rmse:0.179896
# [103]	train-rmse:0.179226	valid-rmse:0.178142
# [104]	train-rmse:0.1775	valid-rmse:0.176406
# [105]	train-rmse:0.175791	valid-rmse:0.174686
# [106]	train-rmse:0.1741	valid-rmse:0.172986
# [107]	train-rmse:0.172426	valid-rmse:0.171303
# [108]	train-rmse:0.17077	valid-rmse:0.169637
# [109]	train-rmse:0.169131	valid-rmse:0.167986
# [110]	train-rmse:0.167509	valid-rmse:0.166355
# [111]	train-rmse:0.165904	valid-rmse:0.164739
# [112]	train-rmse:0.164315	valid-rmse:0.163141
# [113]	train-rmse:0.162743	valid-rmse:0.161557
# [114]	train-rmse:0.161188	valid-rmse:0.159994
# [115]	train-rmse:0.159649	valid-rmse:0.158444
# [116]	train-rmse:0.158125	valid-rmse:0.156908
# [117]	train-rmse:0.156618	valid-rmse:0.155391
# [118]	train-rmse:0.155126	valid-rmse:0.153889
# [119]	train-rmse:0.15365	valid-rmse:0.152405
# [120]	train-rmse:0.152189	valid-rmse:0.150935
# [121]	train-rmse:0.150744	valid-rmse:0.149481
# [122]	train-rmse:0.149313	valid-rmse:0.148047
# [123]	train-rmse:0.147898	valid-rmse:0.146624
# [124]	train-rmse:0.146498	valid-rmse:0.145212
# [125]	train-rmse:0.145112	valid-rmse:0.143817
# [126]	train-rmse:0.14374	valid-rmse:0.142437
# [127]	train-rmse:0.142384	valid-rmse:0.141076
# [128]	train-rmse:0.141041	valid-rmse:0.139727
# [129]	train-rmse:0.139713	valid-rmse:0.13839
# [130]	train-rmse:0.138398	valid-rmse:0.137067
# [131]	train-rmse:0.137097	valid-rmse:0.135763
# [132]	train-rmse:0.135811	valid-rmse:0.134464
# [133]	train-rmse:0.134538	valid-rmse:0.133189
# [134]	train-rmse:0.133278	valid-rmse:0.131923
# [135]	train-rmse:0.132031	valid-rmse:0.130669
# [136]	train-rmse:0.130798	valid-rmse:0.129434
# [137]	train-rmse:0.129578	valid-rmse:0.128204
# [138]	train-rmse:0.128371	valid-rmse:0.126991
# [139]	train-rmse:0.127177	valid-rmse:0.125787
# [140]	train-rmse:0.125996	valid-rmse:0.124599
# [141]	train-rmse:0.124827	valid-rmse:0.123428
# [142]	train-rmse:0.123671	valid-rmse:0.122262
# [143]	train-rmse:0.122527	valid-rmse:0.121105
# [144]	train-rmse:0.121395	valid-rmse:0.119964
# [145]	train-rmse:0.120275	valid-rmse:0.118833
# [146]	train-rmse:0.119168	valid-rmse:0.117715
# [147]	train-rmse:0.118072	valid-rmse:0.116615
# [148]	train-rmse:0.116988	valid-rmse:0.115519
# [149]	train-rmse:0.115916	valid-rmse:0.114439
# [150]	train-rmse:0.114856	valid-rmse:0.113366
# [151]	train-rmse:0.113807	valid-rmse:0.112312
# [152]	train-rmse:0.112769	valid-rmse:0.111264
# [153]	train-rmse:0.111742	valid-rmse:0.110228
# [154]	train-rmse:0.110727	valid-rmse:0.109202
# [155]	train-rmse:0.109723	valid-rmse:0.108193
# [156]	train-rmse:0.10873	valid-rmse:0.107188
# [157]	train-rmse:0.107747	valid-rmse:0.106193
# [158]	train-rmse:0.106775	valid-rmse:0.105215
# [159]	train-rmse:0.105814	valid-rmse:0.104244
# [160]	train-rmse:0.104863	valid-rmse:0.103286
# [161]	train-rmse:0.103923	valid-rmse:0.102336
# [162]	train-rmse:0.102993	valid-rmse:0.101399
# [163]	train-rmse:0.102073	valid-rmse:0.100472
# [164]	train-rmse:0.101163	valid-rmse:0.099552
# [165]	train-rmse:0.100264	valid-rmse:0.098643
# [166]	train-rmse:0.099374	valid-rmse:0.097746
# [167]	train-rmse:0.098495	valid-rmse:0.096858
# [168]	train-rmse:0.097625	valid-rmse:0.095981
# [169]	train-rmse:0.096764	valid-rmse:0.095108
# [170]	train-rmse:0.095914	valid-rmse:0.094249
# [171]	train-rmse:0.095072	valid-rmse:0.093398
# [172]	train-rmse:0.09424	valid-rmse:0.092555
# [173]	train-rmse:0.093418	valid-rmse:0.091722
# [174]	train-rmse:0.092605	valid-rmse:0.090895
# [175]	train-rmse:0.091801	valid-rmse:0.09008
# [176]	train-rmse:0.091006	valid-rmse:0.089273
# [177]	train-rmse:0.09022	valid-rmse:0.088475
# [178]	train-rmse:0.089443	valid-rmse:0.087684
# [179]	train-rmse:0.088674	valid-rmse:0.086904
# [180]	train-rmse:0.087915	valid-rmse:0.086131
# [181]	train-rmse:0.087164	valid-rmse:0.085368
# [182]	train-rmse:0.086421	valid-rmse:0.084612
# [183]	train-rmse:0.085687	valid-rmse:0.083865
# [184]	train-rmse:0.084961	valid-rmse:0.083126
# [185]	train-rmse:0.084244	valid-rmse:0.082397
# [186]	train-rmse:0.083535	valid-rmse:0.081674
# [187]	train-rmse:0.082834	valid-rmse:0.080961
# [188]	train-rmse:0.082141	valid-rmse:0.080256
# [189]	train-rmse:0.081456	valid-rmse:0.079558
# [190]	train-rmse:0.08078	valid-rmse:0.078869
# [191]	train-rmse:0.08011	valid-rmse:0.078187
# [192]	train-rmse:0.079449	valid-rmse:0.077515
# [193]	train-rmse:0.078795	valid-rmse:0.076845
# [194]	train-rmse:0.07815	valid-rmse:0.076186
# [195]	train-rmse:0.077511	valid-rmse:0.075531
# [196]	train-rmse:0.07688	valid-rmse:0.074885
# [197]	train-rmse:0.076257	valid-rmse:0.074248
# [198]	train-rmse:0.075641	valid-rmse:0.073617
# [199]	train-rmse:0.075033	valid-rmse:0.072996
# [200]	train-rmse:0.074432	valid-rmse:0.072381
# [201]	train-rmse:0.073837	valid-rmse:0.071771
# [202]	train-rmse:0.07325	valid-rmse:0.071165
# [203]	train-rmse:0.07267	valid-rmse:0.07057
# [204]	train-rmse:0.072097	valid-rmse:0.069983
# [205]	train-rmse:0.071531	valid-rmse:0.069402
# [206]	train-rmse:0.070972	valid-rmse:0.068829
# [207]	train-rmse:0.070419	valid-rmse:0.06826
# [208]	train-rmse:0.069873	valid-rmse:0.067696
# [209]	train-rmse:0.069333	valid-rmse:0.067142
# [210]	train-rmse:0.0688	valid-rmse:0.066593
# [211]	train-rmse:0.068274	valid-rmse:0.066054
# [212]	train-rmse:0.067754	valid-rmse:0.06552
# [213]	train-rmse:0.06724	valid-rmse:0.064988
# [214]	train-rmse:0.066733	valid-rmse:0.064467
# [215]	train-rmse:0.066233	valid-rmse:0.063951
# [216]	train-rmse:0.065739	valid-rmse:0.063442
# [217]	train-rmse:0.06525	valid-rmse:0.062938
# [218]	train-rmse:0.064768	valid-rmse:0.062439
# [219]	train-rmse:0.064292	valid-rmse:0.061944
# [220]	train-rmse:0.063821	valid-rmse:0.06146
# [221]	train-rmse:0.063357	valid-rmse:0.060981
# [222]	train-rmse:0.062898	valid-rmse:0.06051
# [223]	train-rmse:0.062446	valid-rmse:0.060043
# [224]	train-rmse:0.061998	valid-rmse:0.05958
# [225]	train-rmse:0.061557	valid-rmse:0.059124
# [226]	train-rmse:0.061122	valid-rmse:0.058671
# [227]	train-rmse:0.060692	valid-rmse:0.058224
# [228]	train-rmse:0.060267	valid-rmse:0.057783
# [229]	train-rmse:0.059848	valid-rmse:0.057349
# [230]	train-rmse:0.059434	valid-rmse:0.056914
# [231]	train-rmse:0.059025	valid-rmse:0.056492
# [232]	train-rmse:0.05862	valid-rmse:0.056077
# [233]	train-rmse:0.058222	valid-rmse:0.055666
# [234]	train-rmse:0.057828	valid-rmse:0.055261
# [235]	train-rmse:0.05744	valid-rmse:0.05486
# [236]	train-rmse:0.057057	valid-rmse:0.05446
# [237]	train-rmse:0.05668	valid-rmse:0.054067
# [238]	train-rmse:0.056306	valid-rmse:0.053681
# [239]	train-rmse:0.055939	valid-rmse:0.053297
# [240]	train-rmse:0.055577	valid-rmse:0.05292
# [241]	train-rmse:0.055219	valid-rmse:0.052545
# [242]	train-rmse:0.054866	valid-rmse:0.052176
# [243]	train-rmse:0.054517	valid-rmse:0.051815
# [244]	train-rmse:0.054172	valid-rmse:0.051459
# [245]	train-rmse:0.053834	valid-rmse:0.051104
# [246]	train-rmse:0.053499	valid-rmse:0.050757
# [247]	train-rmse:0.053169	valid-rmse:0.050413
# [248]	train-rmse:0.052843	valid-rmse:0.050068
# [249]	train-rmse:0.052521	valid-rmse:0.049736
# [250]	train-rmse:0.052205	valid-rmse:0.049399
# [251]	train-rmse:0.051892	valid-rmse:0.049072
# [252]	train-rmse:0.051584	valid-rmse:0.048752
# [253]	train-rmse:0.05128	valid-rmse:0.048434
# [254]	train-rmse:0.050981	valid-rmse:0.048119
# [255]	train-rmse:0.050686	valid-rmse:0.047808
# [256]	train-rmse:0.050394	valid-rmse:0.047507
# [257]	train-rmse:0.050107	valid-rmse:0.047204
# [258]	train-rmse:0.049824	valid-rmse:0.046902
# [259]	train-rmse:0.049545	valid-rmse:0.04661
# [260]	train-rmse:0.04927	valid-rmse:0.046321
# [261]	train-rmse:0.048998	valid-rmse:0.046037
# [262]	train-rmse:0.048731	valid-rmse:0.045754
# [263]	train-rmse:0.048468	valid-rmse:0.045472
# [264]	train-rmse:0.048208	valid-rmse:0.045197
# [265]	train-rmse:0.047953	valid-rmse:0.044925
# [266]	train-rmse:0.0477	valid-rmse:0.044659
# [267]	train-rmse:0.047452	valid-rmse:0.044396
# [268]	train-rmse:0.047206	valid-rmse:0.044139
# [269]	train-rmse:0.046965	valid-rmse:0.043883
# [270]	train-rmse:0.046727	valid-rmse:0.043634
# [271]	train-rmse:0.046492	valid-rmse:0.043389
# [272]	train-rmse:0.04626	valid-rmse:0.043146
# [273]	train-rmse:0.046031	valid-rmse:0.042907
# [274]	train-rmse:0.045807	valid-rmse:0.04267
# [275]	train-rmse:0.045587	valid-rmse:0.042437
# [276]	train-rmse:0.045369	valid-rmse:0.042208
# [277]	train-rmse:0.045154	valid-rmse:0.041979
# [278]	train-rmse:0.044943	valid-rmse:0.041756
# [279]	train-rmse:0.044734	valid-rmse:0.041536
# [280]	train-rmse:0.044529	valid-rmse:0.041319
# [281]	train-rmse:0.044327	valid-rmse:0.041103
# [282]	train-rmse:0.044128	valid-rmse:0.040893
# [283]	train-rmse:0.043933	valid-rmse:0.040685
# [284]	train-rmse:0.04374	valid-rmse:0.04048
# [285]	train-rmse:0.04355	valid-rmse:0.04028
# [286]	train-rmse:0.043363	valid-rmse:0.040084
# [287]	train-rmse:0.043179	valid-rmse:0.039884
# [288]	train-rmse:0.042997	valid-rmse:0.03969
# [289]	train-rmse:0.042818	valid-rmse:0.0395
# [290]	train-rmse:0.042642	valid-rmse:0.039314
# [291]	train-rmse:0.042467	valid-rmse:0.039132
# [292]	train-rmse:0.042297	valid-rmse:0.03895
# [293]	train-rmse:0.042129	valid-rmse:0.038771
# [294]	train-rmse:0.041963	valid-rmse:0.038596
# [295]	train-rmse:0.041801	valid-rmse:0.038423
# [296]	train-rmse:0.04164	valid-rmse:0.038252
# [297]	train-rmse:0.041482	valid-rmse:0.038083
# [298]	train-rmse:0.041327	valid-rmse:0.037918
# [299]	train-rmse:0.041173	valid-rmse:0.037759
# [300]	train-rmse:0.041023	valid-rmse:0.037602
# [301]	train-rmse:0.040875	valid-rmse:0.037443
# [302]	train-rmse:0.040729	valid-rmse:0.037288
# [303]	train-rmse:0.040586	valid-rmse:0.037136
# [304]	train-rmse:0.040446	valid-rmse:0.036984
# [305]	train-rmse:0.040308	valid-rmse:0.036837
# [306]	train-rmse:0.04017	valid-rmse:0.036694
# [307]	train-rmse:0.040035	valid-rmse:0.03655
# [308]	train-rmse:0.039903	valid-rmse:0.036409
# [309]	train-rmse:0.039772	valid-rmse:0.036272
# [310]	train-rmse:0.039645	valid-rmse:0.036136
# [311]	train-rmse:0.039518	valid-rmse:0.036002
# [312]	train-rmse:0.039394	valid-rmse:0.035869
# [313]	train-rmse:0.039272	valid-rmse:0.035738
# [314]	train-rmse:0.039152	valid-rmse:0.035612
# [315]	train-rmse:0.039034	valid-rmse:0.035489
# [316]	train-rmse:0.038918	valid-rmse:0.035365
# [317]	train-rmse:0.038804	valid-rmse:0.035243
# [318]	train-rmse:0.038692	valid-rmse:0.035123
# [319]	train-rmse:0.038582	valid-rmse:0.035008
# [320]	train-rmse:0.038473	valid-rmse:0.034892
# [321]	train-rmse:0.038366	valid-rmse:0.034777
# [322]	train-rmse:0.038262	valid-rmse:0.034665
# [323]	train-rmse:0.038158	valid-rmse:0.034558
# [324]	train-rmse:0.038057	valid-rmse:0.034449
# [325]	train-rmse:0.037956	valid-rmse:0.034343
# [326]	train-rmse:0.037859	valid-rmse:0.034239
# [327]	train-rmse:0.037762	valid-rmse:0.034136
# [328]	train-rmse:0.037667	valid-rmse:0.034035
# [329]	train-rmse:0.037574	valid-rmse:0.033936
# [330]	train-rmse:0.037481	valid-rmse:0.033839
# [331]	train-rmse:0.037392	valid-rmse:0.033744
# [332]	train-rmse:0.037304	valid-rmse:0.033649
# [333]	train-rmse:0.037216	valid-rmse:0.033557
# [334]	train-rmse:0.037131	valid-rmse:0.033466
# [335]	train-rmse:0.037046	valid-rmse:0.033378
# [336]	train-rmse:0.036963	valid-rmse:0.033291
# [337]	train-rmse:0.036881	valid-rmse:0.033205
# [338]	train-rmse:0.0368	valid-rmse:0.03312
# [339]	train-rmse:0.036722	valid-rmse:0.033036
# [340]	train-rmse:0.036644	valid-rmse:0.032954
# [341]	train-rmse:0.036568	valid-rmse:0.032874
# [342]	train-rmse:0.036492	valid-rmse:0.032794
# [343]	train-rmse:0.036419	valid-rmse:0.032717
# [344]	train-rmse:0.036347	valid-rmse:0.032642
# [345]	train-rmse:0.036276	valid-rmse:0.032568
# [346]	train-rmse:0.036206	valid-rmse:0.032494
# [347]	train-rmse:0.036137	valid-rmse:0.03242
# [348]	train-rmse:0.03607	valid-rmse:0.03235
# [349]	train-rmse:0.036004	valid-rmse:0.032279
# [350]	train-rmse:0.035938	valid-rmse:0.032211
# [351]	train-rmse:0.035875	valid-rmse:0.032144
# [352]	train-rmse:0.035812	valid-rmse:0.032079
# [353]	train-rmse:0.03575	valid-rmse:0.032016
# [354]	train-rmse:0.035689	valid-rmse:0.031951
# [355]	train-rmse:0.03563	valid-rmse:0.031888
# [356]	train-rmse:0.03557	valid-rmse:0.031825
# [357]	train-rmse:0.035513	valid-rmse:0.031766
# [358]	train-rmse:0.035456	valid-rmse:0.031707
# [359]	train-rmse:0.035399	valid-rmse:0.031647
# [360]	train-rmse:0.035344	valid-rmse:0.03159
# [361]	train-rmse:0.03529	valid-rmse:0.031533
# [362]	train-rmse:0.035237	valid-rmse:0.031477
# [363]	train-rmse:0.035185	valid-rmse:0.031421
# [364]	train-rmse:0.035134	valid-rmse:0.031369
# [365]	train-rmse:0.035083	valid-rmse:0.031317
# [366]	train-rmse:0.035033	valid-rmse:0.031264
# [367]	train-rmse:0.034985	valid-rmse:0.031213
# [368]	train-rmse:0.034938	valid-rmse:0.031165
# [369]	train-rmse:0.034891	valid-rmse:0.031115
# [370]	train-rmse:0.034845	valid-rmse:0.031067
# [371]	train-rmse:0.034799	valid-rmse:0.031019
# [372]	train-rmse:0.034754	valid-rmse:0.030973
# [373]	train-rmse:0.03471	valid-rmse:0.030929
# [374]	train-rmse:0.034667	valid-rmse:0.030881
# [375]	train-rmse:0.034625	valid-rmse:0.030836
# [376]	train-rmse:0.034584	valid-rmse:0.030794
# [377]	train-rmse:0.034542	valid-rmse:0.030752
# [378]	train-rmse:0.034503	valid-rmse:0.03071
# [379]	train-rmse:0.034463	valid-rmse:0.03067
# [380]	train-rmse:0.034425	valid-rmse:0.030631
# [381]	train-rmse:0.034386	valid-rmse:0.030591
# [382]	train-rmse:0.034348	valid-rmse:0.030552
# [383]	train-rmse:0.03431	valid-rmse:0.030515
# [384]	train-rmse:0.034274	valid-rmse:0.030479
# [385]	train-rmse:0.034238	valid-rmse:0.030443
# [386]	train-rmse:0.034203	valid-rmse:0.030408
# [387]	train-rmse:0.034169	valid-rmse:0.030373
# [388]	train-rmse:0.034135	valid-rmse:0.030339
# [389]	train-rmse:0.034101	valid-rmse:0.030305
# [390]	train-rmse:0.03407	valid-rmse:0.030271
# [391]	train-rmse:0.034038	valid-rmse:0.03024
# [392]	train-rmse:0.034005	valid-rmse:0.030208
# [393]	train-rmse:0.033974	valid-rmse:0.030176
# [394]	train-rmse:0.033943	valid-rmse:0.030145
# [395]	train-rmse:0.033913	valid-rmse:0.030116
# [396]	train-rmse:0.033883	valid-rmse:0.030087
# [397]	train-rmse:0.033854	valid-rmse:0.030058
# [398]	train-rmse:0.033826	valid-rmse:0.03003
# [399]	train-rmse:0.033797	valid-rmse:0.030002
# [400]	train-rmse:0.03377	valid-rmse:0.029976
# [401]	train-rmse:0.033743	valid-rmse:0.029949
# [402]	train-rmse:0.033717	valid-rmse:0.029923
# [403]	train-rmse:0.033691	valid-rmse:0.029892
# [404]	train-rmse:0.033665	valid-rmse:0.029868
# [405]	train-rmse:0.033639	valid-rmse:0.029843
# [406]	train-rmse:0.033613	valid-rmse:0.02982
# [407]	train-rmse:0.033589	valid-rmse:0.029796
# [408]	train-rmse:0.033565	valid-rmse:0.029773
# [409]	train-rmse:0.033542	valid-rmse:0.029752
# [410]	train-rmse:0.033518	valid-rmse:0.029724
# [411]	train-rmse:0.033495	valid-rmse:0.029702
# [412]	train-rmse:0.033474	valid-rmse:0.029681
# [413]	train-rmse:0.033451	valid-rmse:0.02966
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from pyecharts import options as opts
from example.commons import Collector
from pyecharts.charts import Line

plot = ret_df[['xgb_regress', 'net_xgb_regress']].cumsum()
v1 = list(plot.index)
v2 = list(plot.xgb_regress)
v3 = list(plot.net_xgb_regress)

line_chart = (
    Line()
    .add_xaxis(v1)
    .add_yaxis("xgb_regress", v2, is_smooth=True)
    .add_yaxis("net_xgb_regress", v3, is_smooth=True)
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        datazoom_opts=[opts.DataZoomOpts(pos_bottom="-1%")],
        title_opts=opts.TitleOpts(title='Fixed freq rebalanced: {0}'.format(freq)),
    )
)

line_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8191fc1a80a2437781f6605f98148db9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8191fc1a80a2437781f6605f98148db9 = echarts.init(
#             document.getElementById('8191fc1a80a2437781f6605f98148db9'), 'white', {renderer: 'canvas'});
#         var option_8191fc1a80a2437781f6605f98148db9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "xgb_regress",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "2019-01-04T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2019-01-08T00:00:00",
#                     0.07701407044397714
#                 ],
#                 [
#                     "2019-01-10T00:00:00",
#                     0.06451562126824306
#                 ],
#                 [
#                     "2019-01-14T00:00:00",
#                     0.17889730955702077
#                 ],
#                 [
#                     "2019-01-16T00:00:00",
#                     0.10642391922840594
#                 ],
#                 [
#                     "2019-01-18T00:00:00",
#                     0.1113186423645122
#                 ],
#                 [
#                     "2019-01-22T00:00:00",
#                     0.11005521501014104
#                 ],
#                 [
#                     "2019-01-24T00:00:00",
#                     0.10610735758656663
#                 ],
#                 [
#                     "2019-01-28T00:00:00",
#                     0.10474158328872389
#                 ],
#                 [
#                     "2019-01-30T00:00:00",
#                     0.08726228578611067
#                 ],
#                 [
#                     "2019-02-01T00:00:00",
#                     0.04570047088439254
#                 ],
#                 [
#                     "2019-02-12T00:00:00",
#                     0.1266504362019602
#                 ],
#                 [
#                     "2019-02-14T00:00:00",
#                     0.1522678900736097
#                 ],
#                 [
#                     "2019-02-18T00:00:00",
#                     0.15696479069995886
#                 ],
#                 [
#                     "2019-02-20T00:00:00",
#                     0.16883793092507687
#                 ],
#                 [
#                     "2019-02-22T00:00:00",
#                     0.14020541200921727
#                 ],
#                 [
#                     "2019-02-26T00:00:00",
#                     0.21558160012362612
#                 ],
#                 [
#                     "2019-02-28T00:00:00",
#                     0.2095294244977021
#                 ],
#                 [
#                     "2019-03-04T00:00:00",
#                     0.18458392209051105
#                 ],
#                 [
#                     "2019-03-06T00:00:00",
#                     0.20942654761794566
#                 ],
#                 [
#                     "2019-03-08T00:00:00",
#                     0.15254694784683717
#                 ],
#                 [
#                     "2019-03-12T00:00:00",
#                     0.1249034992718149
#                 ],
#                 [
#                     "2019-03-14T00:00:00",
#                     0.1409183342437245
#                 ],
#                 [
#                     "2019-03-18T00:00:00",
#                     0.11496023768910688
#                 ],
#                 [
#                     "2019-03-20T00:00:00",
#                     0.13115626720988496
#                 ],
#                 [
#                     "2019-03-22T00:00:00",
#                     0.08343864086923064
#                 ],
#                 [
#                     "2019-03-26T00:00:00",
#                     0.15116909246633498
#                 ],
#                 [
#                     "2019-03-28T00:00:00",
#                     0.0684344500670294
#                 ],
#                 [
#                     "2019-04-01T00:00:00",
#                     0.04077996478478966
#                 ],
#                 [
#                     "2019-04-03T00:00:00",
#                     0.21818478614287837
#                 ],
#                 [
#                     "2019-04-08T00:00:00",
#                     0.21947173617526794
#                 ],
#                 [
#                     "2019-04-10T00:00:00",
#                     0.21557105527779646
#                 ],
#                 [
#                     "2019-04-12T00:00:00",
#                     0.25192362358173725
#                 ],
#                 [
#                     "2019-04-16T00:00:00",
#                     0.03018670735494261
#                 ],
#                 [
#                     "2019-04-18T00:00:00",
#                     0.22112761982605655
#                 ],
#                 [
#                     "2019-04-22T00:00:00",
#                     0.23478936535776482
#                 ],
#                 [
#                     "2019-04-24T00:00:00",
#                     0.2365224522024547
#                 ],
#                 [
#                     "2019-04-26T00:00:00",
#                     0.24561126696780652
#                 ],
#                 [
#                     "2019-04-30T00:00:00",
#                     0.2495813611687069
#                 ],
#                 [
#                     "2019-05-07T00:00:00",
#                     0.2433907550868299
#                 ],
#                 [
#                     "2019-05-09T00:00:00",
#                     0.2114421470073925
#                 ],
#                 [
#                     "2019-05-13T00:00:00",
#                     0.1923514305855129
#                 ],
#                 [
#                     "2019-05-15T00:00:00",
#                     0.20711000653448375
#                 ],
#                 [
#                     "2019-05-17T00:00:00",
#                     0.1552378327258777
#                 ],
#                 [
#                     "2019-05-21T00:00:00",
#                     0.14989303725559172
#                 ],
#                 [
#                     "2019-05-23T00:00:00",
#                     0.035745603851732186
#                 ],
#                 [
#                     "2019-05-27T00:00:00",
#                     -0.04925161269688409
#                 ],
#                 [
#                     "2019-05-29T00:00:00",
#                     -0.07521817786180864
#                 ],
#                 [
#                     "2019-05-31T00:00:00",
#                     -0.025255168448733406
#                 ],
#                 [
#                     "2019-06-04T00:00:00",
#                     -0.0329960856414283
#                 ],
#                 [
#                     "2019-06-06T00:00:00",
#                     -0.06450674980804161
#                 ],
#                 [
#                     "2019-06-11T00:00:00",
#                     -0.03860004569927606
#                 ],
#                 [
#                     "2019-06-13T00:00:00",
#                     -0.012531669552616847
#                 ],
#                 [
#                     "2019-06-17T00:00:00",
#                     -0.01552355170200142
#                 ],
#                 [

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['net_xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['net_xgb_regress']/ np.std(ret_df['net_xgb_regress']))))
# Out:
# 年化收益: -0.22
# 夏普比率: -0.60

# %%
print("年化收益: {0:.2f}".format(len(ret_df) * np.mean(ret_df['xgb_regress'])))
print("夏普比率: {0:.2f}".format(np.sqrt(126) * np.mean(ret_df['xgb_regress']/ np.std(ret_df['xgb_regress']))))
# Out:
# 年化收益: 0.10
# 夏普比率: 0.27
